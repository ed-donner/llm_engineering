# %% [raw]
# Day - 2

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
else:
    print("API key fetch successful!")
# Out:
# API key fetch successful!

# %% [markdown]
# We are using API to call the openAI

# %%
import requests



url = "https://api.openai.com/v1/chat/completions"

headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}

payload = {
    "model": "gpt-5-nano",
    "messages": [{"role": "user", "content": "Tell me a fun fact"}],
}

print(url)
print(payload)
# Out:
# https://api.openai.com/v1/chat/completions
# {'model': 'gpt-5-nano', 'messages': [{'role': 'user', 'content': 'Tell me a fun fact'}]}

# %%
response = requests.post(url,headers=headers,json=payload)

print(response.json())
# Out:
# {'id': 'chatcmpl-CrIr2YJdvXLdWmkqoz3HAhUgDtvwq', 'object': 'chat.completion', 'created': 1766819896, 'model': 'gpt-5-nano-2025-08-07', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'Fun fact: Honey never truly spoils. Archaeologists have found jars of honey in ancient Egyptian tombs that are over 3,000 years old and still edible.', 'refusal': None, 'annotations': []}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 11, 'completion_tokens': 491, 'total_tokens': 502, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 448, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'service_tier': 'default', 'system_fingerprint': None}

# %%
response.json()["choices"][0]["message"]["content"]
# Out:
# 'Fun fact: Honey never truly spoils. Archaeologists have found jars of honey in ancient Egyptian tombs that are over 3,000 years old and still edible.'

# %% [markdown]
# Using package to call the openAI

# %%
from openai import OpenAI 

openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=[{"role": "user",
"content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# 'Fun fact: Bananas are berries, but strawberries aren’t. Botanically, a berry is a fruit from a single ovary, with seeds inside the flesh—bananas fit that definition, while strawberries do not. Want another fun fact?'
