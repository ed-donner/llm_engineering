# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from scraper import fetch_website_links, fetch_website_contents
from openai import OpenAI

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

openai = OpenAI()
# Out:
# API key found and looks good so far!

# %%
# here is the question; type over this to ask something new

question = """
You are a tech job assistant. A fresher to the field of tech is asking you for advice on how to get a job in tech in today's market as of 2026 May 24.
What will you advice the fresher to do to study and prepare for the job market in 2026?
Which skills will you advice the fresher to learn to get the job which would be in demand in 2026 and easy to learn?
"""
user_prompt = """ The fresher is an AIML Graduate and want a job in the next month. The fresher is from India and currently knows Python, SQL, Excel and PowerBI.
He has no work experience but is a quick learner and has a passion to learn and work in tech.
"""

# %%
# Get gpt-4o-mini to answer, with streaming
def stream_brochure(question):
    stream = openai.chat.completions.create(
        model=MODEL_GPT,
        messages=[
            {"role": "system", "content": question},
            {"role": "user", "content": user_prompt}
          ],
        stream=True
    )    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure(question)
# Out:
# As an AIML graduate with knowledge of Python, SQL, Excel, and PowerBI, you already have a solid foundation for entering the tech job market in 2026. Here are some focused steps and skills to help you prepare effectively:
#
# ### Steps to Prepare for the Job Market
#
# 1. **Update Your Resume and LinkedIn Profile**:
#    - Highlight your educational background in AIML, relevant projects, and technical skills.
#    - Include any coursework or certifications that demonstrate your expertise in AIML, Python, etc.
#
# 2. **Build a Portfolio**:
#    - Create a GitHub repository showcasing your projects. Include AIML models, data analysis projects with Python, SQL queries, and PowerBI dashboards.
#    - If possible, work on open-source projects or contribute to existing ones to gain visibility.
#
# 3. **Certifications**:
#    - Consider obtaining relevant certifications, such as:
#      - Google Cloud Data Engineer
#      - Microsoft Azure Data Scientist Associate
# ...

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
# Get gpt-4o-mini to answer, with streaming
def stream_brochure(question):
    stream = ollama.chat.completions.create(
        model=MODEL_LLAMA,
        messages=[
            {"role": "system", "content": question},
            {"role": "user", "content": user_prompt}
          ],
        stream=True
    )    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        update_display(Markdown(response), display_id=display_handle.display_id)# Get Llama 3.2 to answer

# %%
stream_brochure(question)
# Out:
# Thank you for sharing the details! As an AIML graduate looking to break into the tech industry quickly, I'd advise the following steps:
#
# **Immediate Actions (Next 2-4 weeks)**
#
# 1. **Update Online Profiles**: Create or update LinkedIn, GitHub, and other relevant social media profiles to showcase your skills, education, and interests.
# 2. **Build a Personal Project**: Choose a project that leverages your AIML skills and interests, such as building a chatbot, sentiment analysis tool, or language model. This will demonstrate your capability to apply theoretical knowledge in practical settings.
# 3. **Network with Professionals**: Reach out to alumni from your university's AI/ML group, attend online webinars or meetups related to AI/ML, and connect with professionals on LinkedIn to learn about job opportunities, industry insights, and best practices.
#
# **Short-term Learning (Next 2-6 months)**
#
# ...
