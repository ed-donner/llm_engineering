# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
import ollama

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment

load_dotenv(override=True)

openai = OpenAI()

# %%
question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Get gpt-4o-mini to answer, with streaming

system_prompt = """
You are a helpful technical tutor.
Explain technical concepts clearly and simply.
Use examples where helpful.
"""

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": question}
]

stream = openai.chat.completions.create(
    model=MODEL_GPT,
    messages=messages,
    stream=True
)

for chunk in stream:
    content = chunk.choices[0].delta.content
    if content:
        print(content, end="", flush=True)
# Out:
# Let’s break down the code you provided piece-by-piece to understand what it does and why.
#
# ### Code Breakdown:
#
# 1. **Set Comprehension**: The expression `{book.get("author") for book in books if book.get("author")}` is a **set comprehension**. This means it creates a set based on some conditions.
#
#    - `book.get("author")`: This retrieves the value associated with the key `"author"` from each `book` dictionary (assuming each item in `books` is a dictionary representing a book).
#    - `for book in books`: This iterates over each `book` in the collection `books`.
#    - `if book.get("author")`: This part is a **conditional filter**. It only includes the author's name if it is present (i.e., not `None` or an empty string).
#
#    **Example**: For a list of books defined like this:
#    ```python
#    books = [
#        {"title": "Book 1", "author": "Author A"},
#        {"title": "Book 2"},
#        {"title": "Book 3", "author": "Author B"},
#        {"title": "Book 4", "author": None},
#    ]
#    ```
#    The set comprehension results in the set `{"Author A", "Author B"}`.
#
# 2. **`yield from`**: This keyword is used in a generator function to yield values from another iterable. It essentially allows you to delegate part of the generator's task to another generator or iterable.
#
#    **Example**: If you wrap this in a generator function, like so:
#    ```python
#    def get_authors(books):
#        yield from {book.get("author") for book in books if book.get("author")}
#    ```
#    Calling `get_authors(books)` would yield each author in sequence. The use of `yield from` is beneficial because it simplifies the code by allowing the generator to produce values from another iterable directly.
#
# ### What Does the Code Do?
#
# 1. It collects all unique authors from a list of book dictionaries (`books`).
# 2. It yields these authors one by one to whoever is calling the generator function.
#
# ### Why Use This Code?
#
# - **Uniqueness**: Using a set comprehension automatically removes duplicate author names since sets do not allow duplicate values.
# - **Efficiency**: It processes the data in a single-pass manner, making it a clean and efficient way to gather and yield authors.
# - **Simplicity**: The use of `yield from` makes the generator function concise and easy to read.
#
# Overall, this line of code is a compact way to get a unique list of authors from the list of books and present them as a stream of data using a generator.

# %%
# Get Llama 3.2 to answer

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": question}
]

response = ollama.chat(
    model=MODEL_LLAMA,
    messages=messages
)

print(response["message"]["content"])
# Out:
# **Code Explanation**
#
# The given code snippet is using a Python feature called **Generator Expressions**.
#
# Here's a breakdown of what it does:
#
# ```python
# yield from {book.get("author") for book in books if book.get("author")}
# ```
#
# * `books` is an iterable (a list, tuple, or other sequence) containing dictionaries (`{...}`) representing book metadata.
# * The expression `{...}` is a **dictionary comprehension**, which iterates over the books and applies the condition `if book.get("author")`.
# * `book.get("author")` retrieves the value associated with the key `"author"` from each dictionary. If the key doesn't exist, it returns `None`.
# * The expression `(book.get("author"))` wraps the result in parentheses to ensure it's treated as a value (not as a function).
# * `for book in books if book.get("author")` iterates over only those books where `"author"` is present.
# * `yield from {...}` is a **generator expression** that yields each author name one at a time. The `yield from` syntax allows us to delegate iteration to the inner generator, which can be more memory-efficient than creating multiple generators.
#
# **Why it's used**
#
# In this context, the code is likely part of a larger function or loop that processes books with metadata. By using a generator expression, we:
#
# 1. **Filter out empty dictionaries**: Only consider books with author information.
# 2. **Retrieve authors efficiently**: Yield each author name individually, without loading the entire list into memory.
# 3. **Simplify code**: The `yield from` syntax is more concise and expressive than creating separate loops or generators.
#
# **Example use case**
#
# Suppose we have a list of book dictionaries:
# ```python
# books = [
#     {"title": "Book 1", "author": "Author A"},
#     {"title": "Book 2", "author": None},  # empty author info
#     {"title": "Book 3", "author": "Author C"}
# ]
# ```
# Running the given code will yield:
# ```python
# ['Author A', 'Author C']
# ```
# This shows how the generator expression efficiently filters out books without author information and yields each author name individually.
