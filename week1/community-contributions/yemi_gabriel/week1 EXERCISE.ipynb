# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import display, Markdown, update_display
from scraper import fetch_website_contents, fetch_website_links

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

OLLAMA_BASE_URL = "http://localhost:11434/v1"

# %%
# set up environment
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
# Out:
# API key looks good so far

# %%
openai = OpenAI()
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key="ollama")

# %% [markdown]
# System prompt - a technical expert to answer swift, python, java questions from teens learning to program

# %%
system_prompt = """
You are an expert in Swift, Python, and Java programming languages.
"""

# %%
user_prompt_prefix = """
Answer technical questions related to Swift, Python, and Java languages in a clear manner 
for teenagers learning to program for the first time. Your response is clear, fun, engaging, 
and indepth.


"""

# %%
# here is the question; type over this to ask something new

question = """
What is encapsulation in Swift?
"""

user_input = input("Ask a question")

user_prompt = f"{user_prompt_prefix} {user_input or question}"

# %%
messages = [
    {"role": "system", "content": system_prompt },
    {"role": "user", "content": user_prompt }
]

# %%
def stream_gpt():
    stream = openai.chat.completions.create(
        model=MODEL_GPT, 
        messages=messages,
        stream=True
    )
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or '' 
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
# Get gpt-4o-mini to answer, with streaming
stream_gpt()
# Out:
# ### What is Encapsulation in Swift?
#
# Hey there, aspiring programmer! 🌟 Today, let's dive into a neat concept in programming known as **encapsulation**. It's a fundamental idea not just in Swift, but in many programming languages.
#
# #### Picture This!
#
# Imagine your favorite toy in a box. The box keeps the toy safe and ensures that no one can mess with it without your permission. You control how the toy can be accessed, played with, or even taken out of the box. In programming, encapsulation does something similar!
#
# #### What is Encapsulation?
#
# Encapsulation is a technique used in Object-Oriented Programming (OOP), which is a way to organize and structure your code. It helps to bundle data (like your toy) and the methods (or actions you can do with the toy) that operate on that data into a single unit, called a **class**. But it gets better! It also restricts access to some of the object's components, which is like locking the box so others can’t get to the toy directly.
# ...

# %%
def stream_llama():
    stream = ollama.chat.completions.create(
        model=MODEL_LLAMA, 
        messages=messages,
        stream=True
    )
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or '' 
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
# Get Llama 3.2 to answer
stream_llama()
# Out:
# **Welcome to World of Coding!**
#
# Encapsulation is one of the fundamental concepts in programming that can seem a bit confusing at first, but trust me, you're about to nail it!
#
# In simple terms, **encapsulation** is an object-oriented programming (OOP) concept that says: "Don't mess with my internal stuff!"
#
# Let's break it down:
#
# Imagine you have a lemonade stand. You want to keep your secret recipe inside the lemonade (that's like your code) and not share it with anyone outside (like your friends asking to taste your famous lemonade).
#
# In programming, when we create an object (like our lemonade), we wrap its internal details in a "wrapper" or an **interface**. This interface decides what methods (functions) are available to interact with the object, but you can't access the object's internal state directly.
#
# For example, let's say we have a `Lemonaid` class:
# ```swift
# class Lemonaid {
#     private var secretRecipe = "Sweet and sour"
#
# ...
