# %%
import os
from dotenv import load_dotenv
from wordExtractor import fetch_word_of_the_day
from IPython.display import Markdown, display
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
system_prompt = """
You are a helpful and witty assistant that gets the word of the day from the website and provides its meaning. Make a sentence using the word.
"""

user_prompt_prefix = """
Analyze the content and provide the word of the day. Provide its meaning in two languages - Enlish and Hindi. 
Then make a sentence using this word only in English.

"""

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
openai = OpenAI()

def get_word_of_the_day(url):
    word_info = fetch_word_of_the_day(url)
    response = openai.chat.completions.create(
        model = "gpt-4.1-mini",
        messages = messages_for(word_info['word'])
    )
    return response.choices[0].message.content

# %%
URL = "https://www.vocabulary.com/word-of-the-day/"
word = get_word_of_the_day(URL)
display(Markdown(word))
# Out:
# Word of the Day: Disaffiliate
#
# Meaning:
# - English: To officially end a connection or association with an organization or group.
# - Hindi: किसी संगठन या समूह के साथ आधिकारिक रूप से संबंध समाप्त करना।
#
# Sentence:
# The university decided to disaffiliate from the national student union due to conflicting policies.
