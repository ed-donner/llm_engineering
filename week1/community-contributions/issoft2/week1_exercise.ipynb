# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
from IPython.display import display, Markdown
from openai import OpenAI
from dotenv import load_dotenv

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')
USEOLLAMA = True # Or set in .env
# oLLAMA SERVERING URL
oLLANA_BASE_URL = "http://localhost:11434"

# Check the api_key
if not api_key:
    print("OPENAI_API_KEY environment variable not found. Please set it in your .env file.")
elif not api_key.startswith("sk-"):
    print("An API key was found, but it does not start with 'sk-'. Please check your .env file.")

elif api_key.strip() != api_key:
    print("API key appears to be found, but it looks like it might have some leading or trailing whitespace. Please check your .env file.")

# %%
# here is the question; type over this to ask something new

question = """
What causes upstream premarturely closed conection in Nginx?
Give me 2 possible causes and how to fix them or migitate them.
"""
messages = [{"role": "user", "content": question}]

# %%
# Initialize the OpenAI client
if USEOLLAMA:
    client = OpenAI(
        base_url=oLLANA_BASE_URL,
        api_key="ollama"
    )

else:
    client = OpenAI(
        api_key=api_key
    )

# %%
# Get gpt-4o-mini to answer, with streaming
#NB: change the variable 'USEOLLAMA' to False to execute this line
response = client.chat.completions.create(
    model=MODEL_GPT,
    messages=messages,
    stream=True
)
# Display the response as it streams in
for chunk in response:
    display(Markdown(chunk.choices[0].delta.content))

# %%
# Get Llama 3.2 to answer
# NB: change the variable 'USEOLLAMA' to True to execute this block
response = client.chat.completions.create(
    model=MODEL_LLAMA,
    messages=messages,
)
display(response.choices[0].message.content)
