# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display

# %%
# constants
MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'
MODEL_GEMINI = 'gemini-3-flash-preview'

# %%
# set up environment
load_dotenv(override=True)

system_prompt="""
You're an expert in LLM Engineering and particularly in building Agen skills for Claude Code.
You will use this documentation as your guidelines: https://code.claude.com/docs/en/skills
Your main role is to help users to improve there agents and explain how they can improve these agents by themselves.
You will return improved and structured agent skills, then explainations.
Answer only in Markdown.
You can ask question to have more context if needed.
"""

# %%
# here is the question; type over this to ask something new

question = """
Please help me with this agent skill :
Extract only readable by humans content from a webpage and keep only content that is not related to navigation or CTAs
"""

# %%
# Get gpt-4o-mini to answer, with streaming
openai = OpenAI()
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": question}
]
response = openai.chat.completions.create(
    model=MODEL_GPT,
    messages=messages
)
display(Markdown(response.choices[0].message.content))

# %%
# Get Llama 3.2 to answer
OLLAMA_BASE_URL = "http://localhost:11434/v1"
openai = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": question}
]
response = openai.chat.completions.create(
    model=MODEL_LLAMA,
    messages=messages
)
display(Markdown(response.choices[0].message.content))

# %%
# Get Llama 3.2 to answer
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
ollama=OpenAI(base_url=GEMINI_BASE_URL, api_key=os.getenv("GOOGLE_API_KEY"))
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": question}
]
response = ollama.chat.completions.create(
    model=MODEL_GEMINI,
    messages=messages
)
display(Markdown(response.choices[0].message.content))
