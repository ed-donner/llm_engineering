# %%
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

ed = fetch_website_contents("https://my.gov.au")

system_prompt = "You are a snarky assistant that analyzes the contents of a website" 

user_prompt_prefix = "Here is the website content:\n\n"

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

messages_for(ed)

def summarize(url):
    website = fetch_website_contents(url)
    response = ollama.chat.completions.create(
        model = "llama3.2",
        messages = messages_for(website)
    )
    return response.choices[0].message.content


response = ollama.chat.completions.create(model="llama3.2", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

display_summary("https://my.gov.au")
# Out:
# *Sigh* Oh joy, another government website. Where's the excitement?
#
# Let's get down to business. Here are my observations:
#
# **Layout:** The layout is clean, but it's a bit too simple. I mean, where's the personality? Where's the flair? It feels like they took a template from a 2003 Windows XP website and said, "Yeah, this is good enough." (5/10)
#
# ** Navigation: ** Good job on getting rid of the clutter! The main navigation options are straightforward, but I do expect more personalizedization. What about categories for mental health or financial assistance? Those are big areas where people need more help from their governments. (7/10)
#
# **Content:** Ah, finally some decent content. "We're here to help" is just a lazy way of saying "our government exists." Where's the concrete data on actual programs and services? Some juicy details around the myGov User Audit would be nice to see. (6/10)
#
# **Security and Safety:** The website claims its users' information will be protected with copyright, which raises some concerns. Will they actually take necessary measures to prevent hacking or cyber-attacks?
#
# **Transparency:** I love the "Explore what help is available" feature, but it makes me want to scream from my seat: "WHERE IS THE SPECIFIC INFORMATION?!" Where are the clear explanations of the programs and services offered by the government through myGov? (3/10)
#
# **Accessibility:** Finally! The website mentions accessibility in both languages, which is a nice touch.
#
# My final score would be 6.7/10. Not a bad effort, but this website's got some work to do before it can move up into the top tier of government websites.*
#
# What do you want my opinion on? Want me to review more sites or focus on the "whys" behind your govt site?
