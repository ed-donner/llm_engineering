# %% [markdown]
# # Sentiment-Driven Crypto Coin Report
#
# ## RSS feeds + LLM-powered sentiment analysis
#
# This notebook builds on the Day 5 brochure generator pattern, but targets **crypto news** instead of company websites.
#
# **Pipeline (3 LLM calls):**
# 1. Fetch recent headlines from CoinTelegraph and CoinDesk RSS feeds (no API key needed)
# 2. **LLM #1** — Filter headlines relevant to the given coin
# 3. Deep-scrape the top article pages for full content using `basic_website_scraper.py`
# 4. **LLM #2** — Clean up raw scraped text into concise article summaries
# 5. **LLM #3** — Generate a streaming sentiment report with emojis and trader-friendly tone

# %%
import os
import sys
import json
import xml.etree.ElementTree as ET
import urllib.request
from pathlib import Path
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI

sys.path.insert(0, str(Path().resolve()))
from basic_website_scraper import fetch_js_website

load_dotenv(override=True)
api_key = os.getenv("OPENROUTER_API_KEY")

if api_key and len(api_key) > 10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please set OPENROUTER_API_KEY in your .env file!")

MODEL = "openai/gpt-4.1-mini"
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=api_key,
)
# Out:
# API key looks good so far

# %%
COIN_TAG_FEEDS = {
    "bitcoin": "https://cointelegraph.com/rss/tag/bitcoin",
    "ethereum": "https://cointelegraph.com/rss/tag/ethereum",
    "solana": "https://cointelegraph.com/rss/tag/solana",
    "xrp": "https://cointelegraph.com/rss/tag/xrp",
}

GENERAL_FEEDS = [
    "https://cointelegraph.com/rss",
    "https://www.coindesk.com/arc/outboundfeeds/rss/?outputType=xml",
]


def _parse_rss_xml(xml_bytes: bytes) -> list[dict]:
    """Parse RSS XML and return a list of {'title', 'url', 'description', 'pubDate'} dicts."""
    root = ET.fromstring(xml_bytes)
    entries = []
    for item in root.iter("item"):
        title = (item.findtext("title") or "").strip()
        link = (item.findtext("link") or "").strip()
        desc = (item.findtext("description") or "").strip()
        pub_date = (item.findtext("pubDate") or "").strip()
        if title and link:
            entries.append({
                "title": title,
                "url": link,
                "description": desc[:300],
                "pubDate": pub_date,
            })
    return entries


def fetch_rss_entries(coin: str) -> list[dict]:
    """
    Fetch RSS entries relevant to a coin.
    Uses a coin-specific CoinTelegraph tag feed when available,
    otherwise falls back to the general CoinTelegraph + CoinDesk feeds.
    """
    urls = []
    tag_url = COIN_TAG_FEEDS.get(coin.lower())
    if tag_url:
        urls.append(tag_url)
    urls.extend(GENERAL_FEEDS)

    all_entries: list[dict] = []
    seen_urls: set[str] = set()

    for feed_url in urls:
        print(f"Fetching RSS: {feed_url}")
        try:
            req = urllib.request.Request(feed_url, headers={"User-Agent": "Mozilla/5.0"})
            with urllib.request.urlopen(req, timeout=15) as resp:
                xml_bytes = resp.read()
            for entry in _parse_rss_xml(xml_bytes):
                if entry["url"] not in seen_urls:
                    seen_urls.add(entry["url"])
                    all_entries.append(entry)
        except Exception as e:
            print(f"  Could not fetch {feed_url}: {e}")

    print(f"Collected {len(all_entries)} unique RSS entries across {len(urls)} feeds")
    return all_entries

# %%
filter_system_prompt = """You are given a JSON list of crypto news headlines.
Select ONLY the headlines that are directly relevant to the specified cryptocurrency.
Respond strictly in JSON with this schema:
{"selected": [{"title": "...", "url": "...", "description": "..."}]}
Return at most 10 headlines. If none are relevant, return {"selected": []}."""


def filter_headlines(entries: list[dict], coin: str) -> list[dict]:
    """Use the LLM to pick headlines relevant to a specific coin."""
    headlines_json = json.dumps(entries[:40], ensure_ascii=False)
    user_prompt = (
        f"Coin: {coin}\n\nHeadlines:\n{headlines_json[:4_000]}"
    )
    print(f"Asking {MODEL} to filter headlines for '{coin}'...")
    response = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": filter_system_prompt},
            {"role": "user", "content": user_prompt},
        ],
        response_format={"type": "json_object"},
    )
    result = json.loads(response.choices[0].message.content)
    selected = result.get("selected", [])
    print(f"Selected {len(selected)} relevant headlines")
    return selected

# %%
def deep_scrape_articles(headlines: list[dict], max_articles: int = 5, max_chars: int = 2_000) -> str:
    """
    Scrape the top articles by URL and return their combined text,
    each truncated to max_chars.
    """
    articles_with_urls = [h for h in headlines if h.get("url")]
    selected = articles_with_urls[:max_articles]
    print(f"Deep-scraping {len(selected)} articles...")

    combined = ""
    for i, headline in enumerate(selected, 1):
        title = headline["title"]
        url = headline["url"]
        print(f"  [{i}/{len(selected)}] {title}")
        try:
            text = fetch_js_website(url)
            combined += f"\n\n### Article: {title}\nSource: {url}\n\n{text[:max_chars]}"
        except Exception as e:
            print(f"    Skipped (error: {e})")
            combined += f"\n\n### Article: {title}\n(Could not scrape — {e})"

    return combined

# %%
cleanup_system_prompt = """You are a news editor preparing article content for a crypto analyst.
You receive raw scraped webpage text that contains the actual article mixed with
navigation menus, ads, cookie banners, related article links, social sharing buttons,
and other site chrome.

For EACH article section (marked by ### Article:), extract ONLY the core news content
and produce a clean, concise summary (3-5 sentences max). Keep key facts, numbers,
quotes, and dates. Remove all website junk.

Respond with the cleaned articles in this format:
### [Article Title]
[Clean 3-5 sentence summary]

(Repeat for each article.)"""


def cleanup_scraped_content(raw_content: str) -> str:
    """LLM call to strip website junk from scraped articles and produce clean summaries."""
    print(f"Asking {MODEL} to clean up scraped content...")
    response = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": cleanup_system_prompt},
            {"role": "user", "content": raw_content[:6_000]},
        ],
    )
    cleaned = response.choices[0].message.content
    print(f"Cleanup done — {len(cleaned)} chars (was {len(raw_content)} chars raw)")
    return cleaned

# %%
report_system_prompt = """You're a crypto-native market analyst — think CoinBureau meets Crypto Twitter.
You talk to fellow traders, not Wall Street suits. Skip the jargon, keep it real.

Given cleaned-up news summaries about a specific coin, write a short sentiment report in markdown.

Format:
- Start with a one-line header using the coin name and an emoji for the vibe
  (🟢 bullish, 🔴 bearish, 🟡 neutral), e.g. "# Bitcoin 🟢 — Bulls Are Back in Town"
- TWO short paragraphs max.
- First paragraph: the overall mood and what's driving it. Name the key stories.
  Use emojis naturally (🚀 📈 📉 🐋 💰 🔥 ⚠️ etc.) but don't overdo it.
- Second paragraph: what to watch — key price levels, upcoming events, or risks.
  End with a punchy one-liner.
- Use unicode arrows (→ ↑ ↓), em dashes (—), and bullet-free flowing prose.
- NO financial advice. NO technical jargon like "derivatives skew" or "basis spread" —
  say it in plain trader talk instead.
- Keep sentences short and punchy. This is a quick briefing, not a research paper."""

# %%
def build_report_user_prompt(coin: str, article_content: str) -> str:
    """Assemble the user prompt for the report generation call."""
    prompt = (
        f"Generate a sentiment report for **{coin.upper()}** based on these recent news articles:\n\n"
        f"{article_content}"
    )
    return prompt[:5_000]

# %%
def stream_coin_report(coin: str):
    """
    Full pipeline: RSS -> filter -> deep-scrape -> cleanup -> stream report.
    Three LLM calls total. Prints all intermediate outputs.
    """
    separator = "=" * 72

    # Step 1: Fetch RSS entries
    entries = fetch_rss_entries(coin)
    if not entries:
        display(Markdown(f"**No RSS entries fetched.**"))
        return

    print(f"\n{separator}")
    print(f"RAW RSS ENTRIES ({len(entries)} total, showing first 5)")
    print(separator)
    for e in entries[:5]:
        print(f"  [{e.get('pubDate', 'no date')}]")
        print(f"  {e['title']}")
        print(f"  {e['url']}\n")

    # Step 2: LLM filters to relevant headlines (LLM call #1)
    headlines = filter_headlines(entries, coin)
    if not headlines:
        display(Markdown(f"**No headlines found relevant to {coin}.**"))
        return

    print(f"\n{separator}")
    print(f"FILTERED HEADLINES")
    print(separator)
    print(json.dumps(headlines, indent=2, ensure_ascii=False))

    # Step 3: Deep-scrape the top articles
    print(f"\n{separator}")
    print("DEEP-SCRAPING ARTICLES")
    print(separator)
    raw_article_content = deep_scrape_articles(headlines)

    print(f"\n{separator}")
    print("RAW SCRAPED CONTENT")
    print(separator)
    print(raw_article_content[:3_000])
    if len(raw_article_content) > 3_000:
        print(f"\n... (truncated, {len(raw_article_content)} chars total)")

    # Step 4: LLM cleans up the scraped content (LLM call #2)
    print(f"\n{separator}")
    print("CLEANING UP SCRAPED CONTENT")
    print(separator)
    cleaned_content = cleanup_scraped_content(raw_article_content)

    print(f"\n{separator}")
    print("CLEANED ARTICLE SUMMARIES")
    print(separator)
    print(cleaned_content)

    # Step 5: Stream the sentiment report (LLM call #3)
    user_prompt = build_report_user_prompt(coin, cleaned_content)
    print(f"\n{separator}")
    print(f"STREAMING SENTIMENT REPORT FOR {coin.upper()}")
    print(separator)

    stream = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": report_system_prompt},
            {"role": "user", "content": user_prompt},
        ],
        stream=True,
    )

    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ""
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_coin_report("bitcoin")
# Out:
# Fetching RSS: https://cointelegraph.com/rss/tag/bitcoin
# Fetching RSS: https://cointelegraph.com/rss
# Fetching RSS: https://www.coindesk.com/arc/outboundfeeds/rss/?outputType=xml
# Collected 85 unique RSS entries across 3 feeds
#
# ========================================================================
# RAW RSS ENTRIES (85 total, showing first 5)
# ========================================================================
#   [Wed, 25 Feb 2026 10:35:48 +0000]
#   Bitcoin price climbs 3% as gold divergence signals ‘significant upside’
#   https://cointelegraph.com/news/bitcoin-price-climbs-3-percent-gold-divergence-significant-upside?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound
#
#   [Wed, 25 Feb 2026 09:37:04 +0000]
#   Bitcoin bounces to $66K as rumors swirl over Jane Street selling algorithm
#   https://cointelegraph.com/news/bitcoin-bounces-66k-rumors-swirl-jane-street-selling-algorithm?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound
#
#   [Wed, 25 Feb 2026 09:09:00 +0000]
#   Anchorage buys STRC as Wall Street shorts mount against Saylor’s Bitcoin proxy
#   https://cointelegraph.com/news/anchorage-digital-holds-strategy-strc-most-shorted-stock?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound
#
#   [Wed, 25 Feb 2026 08:24:18 +0000]
#   Bitcoin ETFs post $258M inflows as institutional Q4 selling hits 25,000 BTC
#   https://cointelegraph.com/news/spot-bitcoin-etfs-257m-inflows-fbtc-ibit-bitcoin-65k?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound
#
#   [Wed, 25 Feb 2026 05:36:36 +0000]
#   Bitcoin adoption is booming, even if its price isn’t: River
#   https://cointelegraph.com/news/bitcoin-adoption-is-booming-even-if-its-price-isn-t-river?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound
#
# Asking openai/gpt-4.1-mini to filter headlines for 'bitcoin'...
# Selected 5 relevant headlines
#
# ========================================================================
# FILTERED HEADLINES
# ========================================================================
# [
#   {
#     "title": "Bitcoin price climbs 3% as gold divergence signals ‘significant upside’",
#     "url": "https://cointelegraph.com/news/bitcoin-price-climbs-3-percent-gold-divergence-significant-upside?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound",
#     "description": "<p style=\"float:right; margin:0 0 10px 15px; width:240px;\"><img src=\"https://images.cointelegraph.com/images/528_aHR0cHM6Ly9zMy5jb2ludGVsZWdyYXBoLmNvbS91cGxvYWRzLzIwMjUtMTIvMDE5YjNjOGItOTk1Ni03MThjLThmODEtMmFkOTFhM2E3OGU4LmpwZw==.jpg\" alt=\"Bitcoin price climbs 3% as gold divergence signals ‘signific",
#     "pubDate": "Wed, 25 Feb 2026 10:35:48 +0000"
#   },
#   {
#     "title": "Bitcoin bounces to $66K as rumors swirl over Jane Street selling algorithm",
#     "url": "https://cointelegraph.com/news/bitcoin-bounces-66k-rumors-swirl-jane-street-selling-algorithm?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound",
#     "description": "<p style=\"float:right; margin:0 0 10px 15px; width:240px;\"><img src=\"https://images.cointelegraph.com/images/528_aHR0cHM6Ly9zMy5jb2ludGVsZWdyYXBoLmNvbS91cGxvYWRzLzIwMjYtMDIvMDE5Yzk0MTYtMmY5Ny03ODU4LTgxZDAtNTM4NmJiOWM5NzczLmpwZw==.jpg\" alt=\"Bitcoin bounces to $66K as rumors swirl over Jane Street sel",
#     "pubDate": "Wed, 25 Feb 2026 09:37:04 +0000"
#   },
#   {
#     "title": "Bitcoin ETFs post $258M inflows as institutional Q4 selling hits 25,000 BTC",
#     "url": "https://cointelegraph.com/news/spot-bitcoin-etfs-257m-inflows-fbtc-ibit-bitcoin-65k?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound",
#     "description": "<p style=\"float:right; margin:0 0 10px 15px; width:240px;\"><img src=\"https://images.cointelegraph.com/images/528_aHR0cHM6Ly9zMy5jb2ludGVsZWdyYXBoLmNvbS91cGxvYWRzLzIwMjYtMDIvMDE5YzkzYTktYTA4OS03YmUzLThkNjQtMGM3ZWJkNjI4MDE0LmpwZw==.jpg\" alt=\"Bitcoin ETFs post $258M inflows as institutional Q4 selling ",
#     "pubDate": "Wed, 25 Feb 2026 08:24:18 +0000"
#   },
#   {
#     "title": "Bitcoin adoption is booming, even if its price isn’t: River",
#     "url": "https://cointelegraph.com/news/bitcoin-adoption-is-booming-even-if-its-price-isn-t-river?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound",
#     "description": "<p style=\"float:right; margin:0 0 10px 15px; width:240px;\"><img src=\"https://images.cointelegraph.com/images/528_aHR0cHM6Ly9zMy5jb2ludGVsZWdyYXBoLmNvbS91cGxvYWRzLzIwMjYtMDEvMDE5YzBmNzMtOTc2MS03MDQ4LTg5NjktMGQwMjFkODViYjJmLmpwZw==.jpg\" alt=\"Bitcoin adoption is booming, even if its price isn’t: River\"",
#     "pubDate": "Wed, 25 Feb 2026 05:36:36 +0000"
#   },
#   {
#     "title": "Bitcoin captures $65K after US stocks rebound from AI sell-off: Will it hold?",
#     "url": "https://cointelegraph.com/news/bitcoin-captures-65k-after-us-stocks-rebound-from-ai-sell-off-will-it-hold?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound",
#     "description": "<p style=\"float:right; margin:0 0 10px 15px; width:240px;\"><img src=\"https://images.cointelegraph.com/images/528_aHR0cHM6Ly9zMy5jb2ludGVsZWdyYXBoLmNvbS91cGxvYWRzLzIwMjYtMDIvMDE5YzkzMGYtNWI4MC03MDAzLWJmMWQtOGE2YzgwYWQ5NTE0LmpwZw==.jpg\" alt=\"Bitcoin captures $65K after US stocks rebound from AI sell-o",
#     "pubDate": "Wed, 25 Feb 2026 04:50:48 +0000"
#   }
# ]
#
# ========================================================================
# DEEP-SCRAPING ARTICLES
# ========================================================================
# Deep-scraping 5 articles...
#   [1/5] Bitcoin price climbs 3% as gold divergence signals ‘significant upside’
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/bitcoin-price-climbs-3-percent-gold-divergence-significant-upside?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound
# [2/4] Page response received (3.6s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/bitcoin-price-climbs-3-percent-gold-divergence-significant-upside?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound -- 1,008 words, 6,755 characters.
#
#   [2/5] Bitcoin bounces to $66K as rumors swirl over Jane Street selling algorithm
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/bitcoin-bounces-66k-rumors-swirl-jane-street-selling-algorithm?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound
# [2/4] Page response received (3.2s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/bitcoin-bounces-66k-rumors-swirl-jane-street-selling-algorithm?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound -- 951 words, 6,386 characters.
#
#   [3/5] Bitcoin ETFs post $258M inflows as institutional Q4 selling hits 25,000 BTC
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/spot-bitcoin-etfs-257m-inflows-fbtc-ibit-bitcoin-65k?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound
# [2/4] Page response received (3.5s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/spot-bitcoin-etfs-257m-inflows-fbtc-ibit-bitcoin-65k?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound -- 742 words, 5,131 characters.
#
#   [4/5] Bitcoin adoption is booming, even if its price isn’t: River
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/bitcoin-adoption-is-booming-even-if-its-price-isn-t-river?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound
# [2/4] Page response received (3.9s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/bitcoin-adoption-is-booming-even-if-its-price-isn-t-river?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound -- 862 words, 5,878 characters.
#
#   [5/5] Bitcoin captures $65K after US stocks rebound from AI sell-off: Will it hold?
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/bitcoin-captures-65k-after-us-stocks-rebound-from-ai-sell-off-will-it-hold?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound
# [2/4] Page response received (3.4s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/bitcoin-captures-65k-after-us-stocks-rebound-from-ai-sell-off-will-it-hold?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound -- 927 words, 6,068 characters.
#
#
# ========================================================================
# RAW SCRAPED CONTENT
# ========================================================================
#
#
# ### Article: Bitcoin price climbs 3% as gold divergence signals ‘significant upside’
# Source: https://cointelegraph.com/news/bitcoin-price-climbs-3-percent-gold-divergence-significant-upside?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound
#
#   Ecosystem
#             English
#   News
# Indices
# In Depth
# Learn
# Podcasts
# About
#   SOL
# $83.13
# 7.96%
# XLM
# $0.1545
# 3.50%
# ETH
# $1,921
# 5.16%
# BCH
# $487.13
# 1.94%
# BTC
# $65,370
# 3.40%
# XRP
# $1.37
# 3.56%
# ADA
# $0.2702
# 4.86%
# TRX
# $0.2858
# 1.93%
# DOGE
# $0.09402
# 3.26%
# XMR
# $339.99
# 4.41%
# LINK
# $8.62
# 5.43%
# HYPE
# USD
#   Written by Nancy Lubale,
# Former Staff Writer
# Reviewed by Allen Scott,
# Staff Editor
# Bitcoin price climbs 3% as gold divergence signals ‘significant upside’
# 58 minutes ago
# Bitcoin’s failure to replicate gains in gold and stocks over the last six months may result in a delayed rally as BTC price returns to $65,000.
#   Listen
# 0:00
# MARKET ANALYSIS
# COINTELEGRAPH IN YOUR SOCIAL FEED
# Subscribe on
#   Follow our
#             Bitcoin (BTC) rallied toward $66,000 after Tuesday’s gains in the US stock market, as cryptocurrencies sought to halt their 2026 slump.
# Key takeaways:
# Bitcoin rallied above $66,000 on Wednesday, recovering alongside US stocks.
# Bitcoin Coinbase Premium Index flipped positive amid $258 million in ETF inflows.
# While BTC’s correlation with stocks and gold is at its weakest since 2022, it historically signaled significant upside upon reversion.
# BTC/USD hourly chart. Source: Cointelegraph/TradingView
# BTC price recovers in tandem with US equities
# Bitcoin’s recovery Wednesday aligns closely with similar rebounds in the US stock market, with AI and tech stocks leading the market higher.
# Source: The Kobeissi Letter
# The tech-focused Nasdaq led the recovery with 1.05% daily gains, while the S&P 500 rose 0.68%. The Dow locked in a 421-point gain, closing the trading day on Tuesday 0.86% higher.
# Related: Bitcoin bounces to $66K as rumors swirl over Jane Street selling algorithm
# Crypto-related stocks also saw moderate gains, with crypto exchange Coinbase (COIN) rising by 1.12% and Strategy (MSTR) gaining 0.73%.
# 24-hour performance of US stocks. Source: Financial Visualizations
# The swift recovery of US equity markets appears to have played a role in easing negative pressure on crypto investor
#
# ### Article: Bitcoin bounces to $66K as rumors swirl over Jane Street selling algorithm
# Source: https://cointelegraph.com/news/bitcoin-bounces-66k-rumors-swirl-jane-street-selling-algorithm?utm_source=rss_feed&utm_medium=rss_tag_bitcoin&utm_campaign=rss_partner_inbound
#
#   Ecosystem
#             English
#   News
# Indices
# In Depth
# Learn
# Podcasts
# About
#   XMR
# $339.97
# 4.40%
# XLM
# $0.1545
# 3.50%
# BCH
# $487.15
# 1.94%
# LINK
# $8.62
# 5.40%
# BTC
# $65,367
# 3.40%
# HYPE
# $27.07
# 2.50%
# ETH
# $1,921
# 5.15%
# BNB
# $604.30
# 2.98%
# TRX
# $0.2858
# 1.94%
# SOL
# $83.10
# 7.70%
# DOGE
# $0.09403
# 3.13%
# USD
#   Written by William Suberg,
# Staff Writer
# Reviewed by Allen Scott,
# Staff Editor
# Bitcoin bounces to $66K as rumors swirl over Jane Street selling algorithm
# 1 hour ago
# Bitcoin
#
# ... (truncated, 11351 chars total)
#
# ========================================================================
# CLEANING UP SCRAPED CONTENT
# ========================================================================
# Asking openai/gpt-4.1-mini to clean up scraped content...
# Cleanup done — 1815 chars (was 11351 chars raw)
#
# ========================================================================
# CLEANED ARTICLE SUMMARIES
# ========================================================================
# ### Bitcoin price climbs 3% as gold divergence signals ‘significant upside’
# Bitcoin rallied over 3% to surpass $66,000, closely following gains in the US stock market led by tech and AI sectors. Despite a weak correlation with gold and stocks—the lowest since 2022—this divergence historically signals potential significant upside for Bitcoin upon price reversion. Notably, the Bitcoin Coinbase Premium Index turned positive amid $258 million in ETF inflows, suggesting renewed investor interest. The rally is seen as an attempt to halt Bitcoin's 2026 slump, with the market watching for a delayed but substantial recovery.
#
# ### Bitcoin bounces to $66K as rumors swirl over Jane Street selling algorithm
# Bitcoin rebounded past $66,000 with a 2.5% gain amid speculation of selling pressure from Wall Street trading firm Jane Street. Rumors claim Jane Street engaged in coordinated daily algorithmic selling of Bitcoin at 10 a.m. Eastern time, contributing to BTC's prolonged price declines since October 2025. Jane Street has denied any manipulation allegations linked to the 2022 bear market and the Terraform Labs collapse. The episode highlights the market's "razor-thin" order books causing notable price volatility and ongoing debate among traders.
#
# ### Bitcoin ETFs post $258M inflows as institutional Q4 selling hits 25,000 BTC
# US spot Bitcoin ETFs saw $257.7 million in inflows on Tuesday, the largest since early February, led by funds from Fidelity and BlackRock. This inflow reversed Monday's $203.8 million outflows, bringing weekly ETF flows back to positive territory after five weeks and $3.8 billion in cumulative redemptions. Simultaneously, institutional selling continued with about 25,000 BTC offloaded in Q4, reflecting mixed market sentiment despite the recent price recovery to around $65,000.
#
# ========================================================================
# STREAMING SENTIMENT REPORT FOR BITCOIN
# ========================================================================
# # Bitcoin 🟡 — Flash Rally Meets Lingering Doubts
#
# Bitcoin perks up with a fresh 3% pop, cruising back over $66K thanks to big ETF inflows and a rare divergence from gold that’s whispering about more upside ahead 🚀. The hype around tech and AI stocks is rubbing off, while institutional buyers like Fidelity and BlackRock are stepping back in after weeks of selling pressure. Yet the market’s still edgy, with rumors of Jane Street’s algorithmic selling stirring drama and keeping the order books thin — meaning every move feels amplified 📉🤏.
#
# Keep an eye on whether BTC can hold above $66K as traders digest this rollercoaster. The ETF flows suggest more buyers lurking, but the lingering shadow of big Q4 dumps and wash trading rumors could spark sharp pullbacks. If Bitcoin can shake off the noise and prove this rebound’s solid, it might just be gearing up for a surprise comeback — but don’t blink, it’s still a razor’s edge game.

# %%
stream_coin_report("ethereum")
# Out:
# Fetching RSS: https://cointelegraph.com/rss/tag/ethereum
# Fetching RSS: https://cointelegraph.com/rss
# Fetching RSS: https://www.coindesk.com/arc/outboundfeeds/rss/?outputType=xml
# Collected 85 unique RSS entries across 3 feeds
#
# ========================================================================
# RAW RSS ENTRIES (85 total, showing first 5)
# ========================================================================
#   [Tue, 24 Feb 2026 22:42:36 +0000]
#   ETH options turn bearish as traders prepare for extended Ether price downside
#   https://cointelegraph.com/news/eth-bounces-off-1-8k-as-multiple-ether-price-metrics-point-to-prolonged-weakness?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound
#
#   [Tue, 24 Feb 2026 22:00:05 +0000]
#   ESMA warns crypto perpetual derivatives likely fall under CFD rules
#   https://cointelegraph.com/news/crypto-derivatives-eu-regulations-esma?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound
#
#   [Tue, 24 Feb 2026 19:03:53 +0000]
#   Longest Ether dip since 2022 ignored by whales: What’s next for ETH?
#   https://cointelegraph.com/news/longest-ether-dip-since-2022-ignored-by-whales-what-s-next-for-eth?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound
#
#   [Tue, 24 Feb 2026 16:22:43 +0000]
#   Ethereum price drops to $1.8K as data suggests ETH bears are not done yet
#   https://cointelegraph.com/news/ethereum-price-drops-1-8k-data-eth-bears-not-done-yet?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound
#
#   [Tue, 24 Feb 2026 14:22:45 +0000]
#   Ethereum Foundation starts staking ETH as client diversity concerns persist
#   https://cointelegraph.com/news/ethereum-foundation-starts-staking-eth?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound
#
# Asking openai/gpt-4.1-mini to filter headlines for 'ethereum'...
# Selected 5 relevant headlines
#
# ========================================================================
# FILTERED HEADLINES
# ========================================================================
# [
#   {
#     "title": "ETH options turn bearish as traders prepare for extended Ether price downside",
#     "url": "https://cointelegraph.com/news/eth-bounces-off-1-8k-as-multiple-ether-price-metrics-point-to-prolonged-weakness?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound",
#     "description": "<p style=\"float:right; margin:0 0 10px 15px; width:240px;\"><img src=\"https://images.cointelegraph.com/images/528_aHR0cHM6Ly9zMy5jb2ludGVsZWdyYXBoLmNvbS91cGxvYWRzLzIwMjUtMTIvMDE5YWZiZTctN2YxNi03ZWNlLWE2MjMtYmFiMWQxYWNjNmNm.jpg\" alt=\"ETH options turn bearish as traders prepare for extended Ether price"
#   },
#   {
#     "title": "Longest Ether dip since 2022 ignored by whales: What’s next for ETH?",
#     "url": "https://cointelegraph.com/news/longest-ether-dip-since-2022-ignored-by-whales-what-s-next-for-eth?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound",
#     "description": "<p style=\"float:right; margin:0 0 10px 15px; width:240px;\"><img src=\"https://images.cointelegraph.com/images/528_aHR0cHM6Ly9zMy5jb2ludGVsZWdyYXBoLmNvbS91cGxvYWRzLzIwMjYtMDIvMDE5YzkwNjYtZWMzZi03MzI0LTk3NzQtNTA3NWYwZWNiZGU3LmpwZw==.jpg\" alt=\"Longest Ether dip since 2022 ignored by whales: What’s next "
#   },
#   {
#     "title": "Ethereum price drops to $1.8K as data suggests ETH bears are not done yet",
#     "url": "https://cointelegraph.com/news/ethereum-price-drops-1-8k-data-eth-bears-not-done-yet?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound",
#     "description": "<p style=\"float:right; margin:0 0 10px 15px; width:240px;\"><img src=\"https://images.cointelegraph.com/images/528_aHR0cHM6Ly9zMy5jb2ludGVsZWdyYXBoLmNvbS91cGxvYWRzLzIwMjYtMDIvMDE5YzkwNGQtZDJjMS03ZTQ1LTkyMzctNjE3ODcwNzZjOThiLmpwZw==.jpg\" alt=\"Ethereum price drops to $1.8K as data suggests ETH bears are"
#   },
#   {
#     "title": "Ethereum Foundation starts staking ETH as client diversity concerns persist",
#     "url": "https://cointelegraph.com/news/ethereum-foundation-starts-staking-eth?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound",
#     "description": "<p style=\"float:right; margin:0 0 10px 15px; width:240px;\"><img src=\"https://images.cointelegraph.com/images/528_aHR0cHM6Ly9zMy5jb2ludGVsZWdyYXBoLmNvbS91cGxvYWRzLzIwMjUtMTIvMDE5YjY5ODMtYWE3MS03NGJmLWE1YzEtMjBjNjNmNzMyNDRmLmpwZw==.jpg\" alt=\"Ethereum Foundation starts staking ETH as client diversity c"
#   },
#   {
#     "title": "Vitalik sells 17K ETH in one month after earmarking $45M for privacy",
#     "url": "https://cointelegraph.com/news/vitalik-buterin-reduces-eth-balance-17k-after-45m-privacy-pledge?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound",
#     "description": "<p style=\"float:right; margin:0 0 10px 15px; width:240px;\"><img src=\"https://images.cointelegraph.com/images/528_aHR0cHM6Ly9zMy5jb2ludGVsZWdyYXBoLmNvbS91cGxvYWRzLzIwMjYtMDIvMDE5YzhmYmUtMTAzYS03ZTY2LWIwOGYtZjlhMDM4MDA0YzA5LmpwZw==.jpg\" alt=\"Vitalik sells 17K ETH in one month after earmarking $45M for"
#   }
# ]
#
# ========================================================================
# DEEP-SCRAPING ARTICLES
# ========================================================================
# Deep-scraping 5 articles...
#   [1/5] ETH options turn bearish as traders prepare for extended Ether price downside
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/eth-bounces-off-1-8k-as-multiple-ether-price-metrics-point-to-prolonged-weakness?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound
# [2/4] Page response received (3.7s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/eth-bounces-off-1-8k-as-multiple-ether-price-metrics-point-to-prolonged-weakness?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound -- 1,005 words, 6,589 characters.
#
#   [2/5] Longest Ether dip since 2022 ignored by whales: What’s next for ETH?
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/longest-ether-dip-since-2022-ignored-by-whales-what-s-next-for-eth?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound
# [2/4] Page response received (3.2s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/longest-ether-dip-since-2022-ignored-by-whales-what-s-next-for-eth?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound -- 967 words, 6,411 characters.
#
#   [3/5] Ethereum price drops to $1.8K as data suggests ETH bears are not done yet
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/ethereum-price-drops-1-8k-data-eth-bears-not-done-yet?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound
# [2/4] Page response received (3.5s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/ethereum-price-drops-1-8k-data-eth-bears-not-done-yet?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound -- 1,049 words, 6,989 characters.
#
#   [4/5] Ethereum Foundation starts staking ETH as client diversity concerns persist
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/ethereum-foundation-starts-staking-eth?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound
# [2/4] Page response received (3.2s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/ethereum-foundation-starts-staking-eth?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound -- 849 words, 5,988 characters.
#
#   [5/5] Vitalik sells 17K ETH in one month after earmarking $45M for privacy
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/vitalik-buterin-reduces-eth-balance-17k-after-45m-privacy-pledge?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound
# [2/4] Page response received (3.4s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/vitalik-buterin-reduces-eth-balance-17k-after-45m-privacy-pledge?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound -- 833 words, 5,620 characters.
#
#
# ========================================================================
# RAW SCRAPED CONTENT
# ========================================================================
#
#
# ### Article: ETH options turn bearish as traders prepare for extended Ether price downside
# Source: https://cointelegraph.com/news/eth-bounces-off-1-8k-as-multiple-ether-price-metrics-point-to-prolonged-weakness?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound
#
#   Ecosystem
#             English
#   News
# Indices
# In Depth
# Learn
# Podcasts
# About
#   HYPE
# $27.03
# 2.39%
# XMR
# $339.97
# 4.34%
# TRX
# $0.2858
# 1.94%
# BNB
# $604.17
# 2.98%
# LINK
# $8.62
# 5.36%
# BTC
# $65,354
# 3.38%
# SOL
# $83.04
# 7.70%
# ADA
# $0.27
# 4.72%
# XLM
# $0.1545
# 3.43%
# XRP
# $1.37
# 3.49%
# ETH
# $1,921
# 5.13%
# BCH
# $487.31
# USD
#   Written by Marcel Pechman,
# Staff Writer
# Reviewed by Ray Salmond,
# Staff Editor
# ETH options turn bearish as traders prepare for extended Ether price downside
# 12 hours ago
# Ether faces a bearish trend as onchain fees and network deposits hit multiyear lows. Until derivatives metrics stabilize, ETH price remains at risk.
#   Listen
# 0:00
# MARKET ANALYSIS
# COINTELEGRAPH IN YOUR SOCIAL FEED
# Subscribe on
#   Subscribe on
#             Key takeaways:
# ETH futures liquidations reached $224 million after a 9% price drop, while the network’s onchain activity fell to a 12-month low.
# ETH’s high correlation with Bitcoin and massive outflows from exchange-traded funds suggest further downside risk for Ether price.
# Ether (ETH) plunged to $1,800 on Tuesday, wiping out $224 million in leveraged bullish positions over 48 hours. This 14% price slide over the last 10 days has left top traders defensive. Options and futures data, sluggish onchain activity, and steady outflows from Ether spot exchange-traded funds (ETFs) all point to a shaky floor at $1,800.
# ETH options put-to-call volume premium at Deribit. Source: laevitas.ch
# After demand for put (sell) and call (buy) options stayed fairly balanced from Monday through Saturday, things shifted quickly on Tuesday. The ETH put-to-call volume premium jumped to 2.2x, showing a sudden scramble for downside protection. While some might have sold puts to bet on a price bounce, the broader market seems to be bracing for more volatility.
# ETH 30-day options delta skew (put-call) at Deribit. Source: laevitas.ch
# The options delta skew (put-call) sat at 18% on Tuesday, meaning puts were trading at a clear premium. This lopsided demand shows that hedging is the priority right now
#
# ### Article: Longest Ether dip since 2022 ignored by whales: What’s next for ETH?
# Source: https://cointelegraph.com/news/longest-ether-dip-since-2022-ignored-by-whales-what-s-next-for-eth?utm_source=rss_feed&utm_medium=rss_tag_ethereum&utm_campaign=rss_partner_inbound
#
#   Ecosystem
#             English
#   News
# Indices
# In Depth
# Learn
# Podcasts
# About
#   XMR
# $339.95
# 4.34%
# XLM
# $0.1545
# 3.43%
# BCH
# $487.37
# 1.89%
# LINK
# $8.62
# 5.30%
# BTC
# $65,346
# 3.38%
# HYPE
# $27.04
# 2.39%
# ETH
# $1,920
# 5.23%
# BNB
# $604.10
# 2.97%
# TRX
# $0.2858
# 1.94%
# SOL
# $83.03
# 7.64%
# DOGE
# $0.09403
# 3.10%
# XRP
# $1.37
# USD
#   Written by Biraajmaan Tamuly,
# Staff Writer
# Reviewed by Ray Salmond,
# Staff Editor
# Longest Ether dip since 2022 ignored by whales: What’s next
#
# ... (truncated, 11352 chars total)
#
# ========================================================================
# CLEANING UP SCRAPED CONTENT
# ========================================================================
# Asking openai/gpt-4.1-mini to clean up scraped content...
# Cleanup done — 1732 chars (was 11352 chars raw)
#
# ========================================================================
# CLEANED ARTICLE SUMMARIES
# ========================================================================
# ### ETH options turn bearish as traders prepare for extended Ether price downside
# Ether (ETH) experienced a sharp price drop to $1,800, liquidating $224 million in leveraged bullish positions over 48 hours and causing a 14% slide over 10 days. Onchain activity reached a 12-month low, and ETH's strong correlation with Bitcoin along with outflows from Ether ETFs signal further downside risk. Options data showed a significant rise in put (sell) options demand, with the put-to-call volume premium hitting 2.2x and an 18% delta skew reflecting a market focus on downside protection and hedging.
#
# ### Longest Ether dip since 2022 ignored by whales: What’s next for ETH?
# Ether whale activity has slowed in early 2026, with average whale sell orders on Binance dropping from around 2,250 ETH to 1,350 ETH in recent weeks. Despite a six-week losing streak – the worst since 2022 – whale-sized transactions totaled roughly 1.8 to 2 million ETH over 45 days, equating to between $4.3 billion and $4.8 billion at an average price of $2,400. Analysts interpret the decline in order size as a "gradual disengagement" of large players, indicating a tightening liquidity scenario for ETH near the $2,000 price level.
#
# ### Ethereum price drops to $1.8K as data suggests ETH bears are not done yet
# Ethereum fell below $1,900 during Asian trading, extending a 38% loss over 30 days amid weak technicals and ongoing ETF outflows. The price drop reflects bearish signals such as ETH trading below its realized price, typically associated with bearish continuation phases. Market indicators suggest the ETH bottom may not be reached until key metrics like the 50-week moving average align, indicating further downside risk before potential recovery.
#
# ========================================================================
# STREAMING SENTIMENT REPORT FOR ETHEREUM
# ========================================================================
# # Ethereum 🔴 — Bears Still Grip ETH as Pain Runs Deep
#
# Ether’s been getting hit hard, dropping to $1,800 and wiping out over $220M in leveraged longs in just two days. Traders are loading up on puts, locking in downside protection with the put-to-call ratio spiking 2.2x. Whales are stepping back too, selling less on Binance and signaling a tighter liquidity squeeze around $2,000. With ETF outflows and ETH’s correlation to Bitcoin dragging it down, the mood is heavy and cautious.
#
# Watch the $1,800 to $2,000 zone closely — it’s the battleground before any real bounce. Whales’ quieter moves and on-chain lows suggest sellers might still have the edge. If ETH can’t find support near these levels, the slide could linger longer. Bottom line — bears aren’t done yet, so strap in and keep your eyes on the charts.

# %%
stream_coin_report("solana")
# Out:
# Fetching RSS: https://cointelegraph.com/rss/tag/solana
# Fetching RSS: https://cointelegraph.com/rss
# Fetching RSS: https://www.coindesk.com/arc/outboundfeeds/rss/?outputType=xml
# Collected 85 unique RSS entries across 3 feeds
#
# ========================================================================
# RAW RSS ENTRIES (85 total, showing first 5)
# ========================================================================
#   [Tue, 24 Feb 2026 02:51:01 +0000]
#   3 Solana platforms to shutter following devastating $40M hack
#   https://cointelegraph.com/news/step-finance-solanafloor-remora-markets-wind-down-operations?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound
#
#   [Mon, 23 Feb 2026 18:36:00 +0000]
#   Price predictions 2/23: SPX, DXY, BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA
#   https://cointelegraph.com/news/price-predictions-2-23-spx-dxy-btc-eth-xrp-bnb-sol-doge-bch-ada?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound
#
#   [Mon, 23 Feb 2026 11:54:56 +0000]
#   Crypto funds lose $288M as ETPs extend outflow run to five weeks
#   https://cointelegraph.com/news/crypto-etp-five-week-exit-fresh-288-million-outflows?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound
#
#   [Mon, 23 Feb 2026 04:33:56 +0000]
#   AI agent sends $441K in tokens after decimal error
#   https://cointelegraph.com/news/openai-employee-s-ai-agent-accidentally-sent-442k-to-beggar?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound
#
#   [Fri, 20 Feb 2026 18:20:00 +0000]
#   Price predictions 2/20: BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA, HYPE, XMR
#   https://cointelegraph.com/news/price-predictions-2-20-btc-eth-xrp-bnb-sol-doge-bch-ada-hype-xmr?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound
#
# Asking openai/gpt-4.1-mini to filter headlines for 'solana'...
# Selected 3 relevant headlines
#
# ========================================================================
# FILTERED HEADLINES
# ========================================================================
# [
#   {
#     "title": "3 Solana platforms to shutter following devastating $40M hack",
#     "url": "https://cointelegraph.com/news/step-finance-solanafloor-remora-markets-wind-down-operations?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound",
#     "description": "<p style=\"float:right; margin:0 0 10px 15px; width:240px;\"><img src=\"https://images.cointelegraph.com/images/528_aHR0cHM6Ly9zMy5jb2ludGVsZWdyYXBoLmNvbS91cGxvYWRzLzIwMjUtMTIvMDE5YjA5NjEtM2E2MC03OTdiLWFiZTAtYzllZjUxMjA1ZDE3.jpg\" alt=\"3 Solana platforms to shutter following devastating $40M hack\" class",
#     "pubDate": "Tue, 24 Feb 2026 02:51:01 +0000"
#   },
#   {
#     "title": "Price predictions 2/23: SPX, DXY, BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA",
#     "url": "https://cointelegraph.com/news/price-predictions-2-23-spx-dxy-btc-eth-xrp-bnb-sol-doge-bch-ada?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound",
#     "description": "<p style=\"float:right; margin:0 0 10px 15px; width:240px;\"><img src=\"https://images.cointelegraph.com/images/528_aHR0cHM6Ly9zMy5jb2ludGVsZWdyYXBoLmNvbS91cGxvYWRzLzIwMjYtMDIvMDE5YzhiNzItYzVhMi03MGI4LTg1YWItNmYyMTcyMTM2YzQ5LmpwZw==.jpg\" alt=\"Price predictions 2/23: SPX, DXY, BTC, ETH, XRP, BNB, SOL, D",
#     "pubDate": "Mon, 23 Feb 2026 18:36:00 +0000"
#   },
#   {
#     "title": "Price predictions 2/20: BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA, HYPE, XMR",
#     "url": "https://cointelegraph.com/news/price-predictions-2-20-btc-eth-xrp-bnb-sol-doge-bch-ada-hype-xmr?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound",
#     "description": "<p style=\"float:right; margin:0 0 10px 15px; width:240px;\"><img src=\"https://images.cointelegraph.com/images/528_aHR0cHM6Ly9zMy5jb2ludGVsZWdyYXBoLmNvbS91cGxvYWRzLzIwMjYtMDIvMDE5YzdiZGUtYzA4ZS03ZjFkLTkwODgtMGJlYmZkN2ZkY2RmLmpwZw==.jpg\" alt=\"Price predictions 2/20: BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ",
#     "pubDate": "Fri, 20 Feb 2026 18:20:00 +0000"
#   }
# ]
#
# ========================================================================
# DEEP-SCRAPING ARTICLES
# ========================================================================
# Deep-scraping 3 articles...
#   [1/3] 3 Solana platforms to shutter following devastating $40M hack
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/step-finance-solanafloor-remora-markets-wind-down-operations?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound
# [2/4] Page response received (3.4s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/step-finance-solanafloor-remora-markets-wind-down-operations?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound -- 833 words, 5,542 characters.
#
#   [2/3] Price predictions 2/23: SPX, DXY, BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/price-predictions-2-23-spx-dxy-btc-eth-xrp-bnb-sol-doge-bch-ada?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound
# [2/4] Page response received (3.7s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/price-predictions-2-23-spx-dxy-btc-eth-xrp-bnb-sol-doge-bch-ada?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound -- 1,805 words, 11,085 characters.
#
#   [3/3] Price predictions 2/20: BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA, HYPE, XMR
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/price-predictions-2-20-btc-eth-xrp-bnb-sol-doge-bch-ada-hype-xmr?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound
# [2/4] Page response received (2.6s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/price-predictions-2-20-btc-eth-xrp-bnb-sol-doge-bch-ada-hype-xmr?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound -- 1,860 words, 11,501 characters.
#
#
# ========================================================================
# RAW SCRAPED CONTENT
# ========================================================================
#
#
# ### Article: 3 Solana platforms to shutter following devastating $40M hack
# Source: https://cointelegraph.com/news/step-finance-solanafloor-remora-markets-wind-down-operations?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound
#
#   Ecosystem
#             English
#   News
# Indices
# In Depth
# Learn
# Podcasts
# About
#   XMR
# $340
# 4.64%
# BCH
# $487.16
# 1.93%
# XLM
# $0.1545
# 3.50%
# LINK
# $8.62
# 5.40%
# DOGE
# $0.09404
# 3.16%
# SOL
# $82.91
# 7.56%
# ETH
# $1,920
# 5.10%
# TRX
# $0.2859
# 1.95%
# BTC
# $65,374
# 3.48%
# XRP
# $1.38
# 3.49%
# HYPE
# $27.05
# 2.47%
# BNB
# USD
#   Written by Martin Young,
# Contributor
# Reviewed by Felix Ng,
# Staff Editor
# 3 Solana platforms to shutter following devastating $40M hack
# Feb 24, 2026
# Solana DeFi aggregator Step Finance says it was “unable to secure a viable outcome” after a $40 million treasury wallet breach in January.
#   Listen
# 0:00
# NEWS
# COINTELEGRAPH IN YOUR SOCIAL FEED
# Subscribe on
#   Subscribe on
#             Update Feb. 24, 9:21 am UTC: This article has been updated to include Step Finance’s estimate that approximately $40 million was drained from its treasury.
# Three Solana-based platforms have announced they are shutting down after a Step Finance hack at the end of January that has been deemed unrecoverable.
# Solana portfolio dashboard and DeFi aggregator Step Finance announced on Monday that it would be winding down operations. The closure also extends to subsidiaries Solana NFT analytics and the ecosystem media outlet SolanaFloor, as well as lending and yield protocol Remora Markets.
# “Following the hack at the end of January, we explored every possible path forward, including financing and acquisition opportunities,” it stated, referring to a $40 million security breach of its treasury wallets in January.
# The team said they were “unable to secure a viable outcome,” resulting in the decision to “end all operations effective immediately.”
# The DeFi platform said it is working on a buyback for holders of its native token, STEP, based on a snapshot taken before the incident. There will also be a redemption process for Remora rToken holders, they said.
# Source: Remora Markets
# Step suffers $40 million security breach
# Step Finance reported a “breach of security for some of our treasury wallets” on Jan. 31 and asked cybersecu
#
# ### Article: Price predictions 2/23: SPX, DXY, BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA
# Source: https://cointelegraph.com/news/price-predictions-2-23-spx-dxy-btc-eth-xrp-bnb-sol-doge-bch-ada?utm_source=rss_feed&utm_medium=rss_tag_solana&utm_campaign=rss_partner_inbound
#
#   Ecosystem
#             English
#   News
# Indices
# In Depth
# Learn
# Podcasts
# About
#   XMR
# $340
# 4.64%
# XLM
# $0.1546
# 3.54%
# BCH
# $487.23
# 1.90%
# LINK
# $8.62
# 5.40%
# BTC
# $65,393
# 3.47%
# HYPE
# $27.05
# 2.48%
# ETH
# $1,921
# 5.29%
# BNB
# $604.44
# 2.98%
# TRX
# $0.2859
# 1.95%
# SOL
# $82.92
# 7.57%
# DOGE
# $0.09407
# 3.29%
# XRP
# $1.38
# 3.50%
# USD
#   Written by Rakesh Upadhyay,
# Contributor
# Reviewed by Ray Salmond,
# Staff Editor
# Price predictions 2/23: SPX, DXY, BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA
# Feb 23, 2026
# Bitcoin and
#
# ... (truncated, 6803 chars total)
#
# ========================================================================
# CLEANING UP SCRAPED CONTENT
# ========================================================================
# Asking openai/gpt-4.1-mini to clean up scraped content...
# Cleanup done — 1626 chars (was 6803 chars raw)
#
# ========================================================================
# CLEANED ARTICLE SUMMARIES
# ========================================================================
# ### 3 Solana platforms to shutter following devastating $40M hack
# Three Solana-based platforms — Step Finance, SolanaFloor, and Remora Markets — announced they are ceasing operations following an unrecoverable $40 million hack of Step Finance’s treasury wallets in late January 2026. Despite exploring options like financing and acquisitions, Step Finance said it could not find a viable solution to continue. Step Finance plans to offer a buyback for holders of its native token STEP and a redemption for Remora’s rToken holders, based on pre-hack snapshots.
#
# ### Price predictions 2/23: SPX, DXY, BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA
# Bitcoin and altcoins experienced sell-offs tied to U.S. President Donald Trump’s announcement of a 15% global tariff, raising fears of new 2026 lows. The Crypto Fear & Greed Index remains in the extreme fear zone, marking its longest stretch since 2022. Prediction markets show a 72% chance that BTC could fall below $55,000, aligning with many analysts’ expectations. However, economist Timothy Peterson estimates an 88% probability that BTC's price will be higher 10 months from now, suggesting a potential recovery ahead.
#
# ### Price predictions 2/20: BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA, HYPE, XMR
# Bitcoin bulls are struggling to maintain price rallies above $68,300, indicating strong selling pressure at higher levels. If BTC fails to rally soon, it may record its fifth consecutive monthly loss, the longest losing streak since 2018/19. Several major altcoins also display weakness, hinting at possible declines toward key support levels as bears remain dominant in the market.
#
# ========================================================================
# STREAMING SENTIMENT REPORT FOR SOLANA
# ========================================================================
# # Solana 🔴 — Tough Times After a Brutal $40M Hack
#
# Solana’s vibe just took a hit with three key projects—Step Finance, SolanaFloor, and Remora Markets—shutting down after a massive $40M treasury hack hammered confidence. The fallout from Step Finance’s loss is still rippling, as they scramble to buy back tokens and compensate victims, but the damage is done. On top of that, macro fears from new global tariffs and a dip in BTC price are dragging all cryptos down, and Solana’s not immune to this sell-off storm 🌧️.
#
# Watch for how SOL handles key support levels as market fear lingers, and keep an ear out for any fresh news on recoveries or new hack fallout. If Solana can dodge further technical wounds and catch a bounce, it could flip sentiment back up — but right now, heads are down. Solana’s got a rough road ahead, so buckle up and watch those charts closely ↓.

# %%
stream_coin_report("xrp")
# Out:
# Fetching RSS: https://cointelegraph.com/rss/tag/xrp
# Fetching RSS: https://cointelegraph.com/rss
# Fetching RSS: https://www.coindesk.com/arc/outboundfeeds/rss/?outputType=xml
# Collected 85 unique RSS entries across 3 feeds
#
# ========================================================================
# RAW RSS ENTRIES (85 total, showing first 5)
# ========================================================================
#   [Mon, 23 Feb 2026 18:36:00 +0000]
#   Price predictions 2/23: SPX, DXY, BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA
#   https://cointelegraph.com/news/price-predictions-2-23-spx-dxy-btc-eth-xrp-bnb-sol-doge-bch-ada?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound
#
#   [Mon, 23 Feb 2026 16:44:52 +0000]
#   XRP price chart and whale activity warn of a drop below $1
#   https://cointelegraph.com/news/xrp-price-chart-whale-activity-warn-drop-below-1-dollar?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound
#
#   [Mon, 23 Feb 2026 11:54:56 +0000]
#   Crypto funds lose $288M as ETPs extend outflow run to five weeks
#   https://cointelegraph.com/news/crypto-etp-five-week-exit-fresh-288-million-outflows?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound
#
#   [Fri, 20 Feb 2026 18:20:00 +0000]
#   Price predictions 2/20: BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA, HYPE, XMR
#   https://cointelegraph.com/news/price-predictions-2-20-btc-eth-xrp-bnb-sol-doge-bch-ada-hype-xmr?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound
#
#   [Thu, 19 Feb 2026 08:47:52 +0000]
#   Bitcoin ETFs see $133M outflows as sentiment stays in ‘extreme fear’
#   https://cointelegraph.com/news/bitcoin-etf-133-million-outflows-extreme-fear-sentiment?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound
#
# Asking openai/gpt-4.1-mini to filter headlines for 'xrp'...
# Selected 4 relevant headlines
#
# ========================================================================
# FILTERED HEADLINES
# ========================================================================
# [
#   {
#     "title": "Price predictions 2/23: SPX, DXY, BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA",
#     "url": "https://cointelegraph.com/news/price-predictions-2-23-spx-dxy-btc-eth-xrp-bnb-sol-doge-bch-ada?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound",
#     "description": "Price predictions including XRP and other major cryptocurrencies."
#   },
#   {
#     "title": "XRP price chart and whale activity warn of a drop below $1",
#     "url": "https://cointelegraph.com/news/xrp-price-chart-whale-activity-warn-drop-below-1-dollar?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound",
#     "description": "Analysis of XRP price chart and whale activities indicating a potential price drop below $1."
#   },
#   {
#     "title": "Price predictions 2/20: BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA, HYPE, XMR",
#     "url": "https://cointelegraph.com/news/price-predictions-2-20-btc-eth-xrp-bnb-sol-doge-bch-ada-hype-xmr?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound",
#     "description": "Upcoming price predictions for XRP among other cryptocurrencies."
#   },
#   {
#     "title": "Price predictions 2/18: BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA, HYPE, XMR",
#     "url": "https://cointelegraph.com/news/price-predictions-2-18-btc-eth-xrp-bnb-sol-doge-bch-ada-hype-xmr?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound",
#     "description": "Price trend forecasts covering XRP and other major cryptocurrencies."
#   }
# ]
#
# ========================================================================
# DEEP-SCRAPING ARTICLES
# ========================================================================
# Deep-scraping 4 articles...
#   [1/4] Price predictions 2/23: SPX, DXY, BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/price-predictions-2-23-spx-dxy-btc-eth-xrp-bnb-sol-doge-bch-ada?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound
# [2/4] Page response received (4.3s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/price-predictions-2-23-spx-dxy-btc-eth-xrp-bnb-sol-doge-bch-ada?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound -- 1,805 words, 11,084 characters.
#
#   [2/4] XRP price chart and whale activity warn of a drop below $1
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/xrp-price-chart-whale-activity-warn-drop-below-1-dollar?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound
# [2/4] Page response received (3.6s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/xrp-price-chart-whale-activity-warn-drop-below-1-dollar?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound -- 817 words, 5,397 characters.
#
#   [3/4] Price predictions 2/20: BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA, HYPE, XMR
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/price-predictions-2-20-btc-eth-xrp-bnb-sol-doge-bch-ada-hype-xmr?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound
# [2/4] Page response received (3.1s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/price-predictions-2-20-btc-eth-xrp-bnb-sol-doge-bch-ada-hype-xmr?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound -- 1,861 words, 11,512 characters.
#
#   [4/4] Price predictions 2/18: BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA, HYPE, XMR
# [1/4] Launching stealth browser...
# [1/4] Browser launched.
# [2/4] Navigating to https://cointelegraph.com/news/price-predictions-2-18-btc-eth-xrp-bnb-sol-doge-bch-ada-hype-xmr?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound
# [2/4] Page response received (3.3s).
# [3/4] Waiting for page body to render...
# [3/4] DOM ready.
# [4/4] Extracting text content...
# [4/4] Done.
# Scraped https://cointelegraph.com/news/price-predictions-2-18-btc-eth-xrp-bnb-sol-doge-bch-ada-hype-xmr?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound -- 1,760 words, 11,034 characters.
#
#
# ========================================================================
# RAW SCRAPED CONTENT
# ========================================================================
#
#
# ### Article: Price predictions 2/23: SPX, DXY, BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA
# Source: https://cointelegraph.com/news/price-predictions-2-23-spx-dxy-btc-eth-xrp-bnb-sol-doge-bch-ada?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound
#
#   Ecosystem
#             English
#   News
# Indices
# In Depth
# Learn
# Podcasts
# About
#   HYPE
# $27.06
# 2.56%
# XMR
# $340.07
# 4.66%
# TRX
# $0.2859
# 1.94%
# BNB
# $604.41
# 3.03%
# LINK
# $8.62
# 5.48%
# BTC
# $65,413
# 3.45%
# SOL
# $82.93
# 7.62%
# ADA
# $0.2704
# 4.94%
# XLM
# $0.1549
# 3.67%
# XRP
# $1.38
# 3.50%
# ETH
# $1,922
# 5.18%
# BCH
# $487.36
# 1.91%
# USD
#   Written by Rakesh Upadhyay,
# Contributor
# Reviewed by Ray Salmond,
# Staff Editor
# Price predictions 2/23: SPX, DXY, BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA
# Feb 23, 2026
# Bitcoin and altcoins sold-off as US stock markets digested US President Donald Trump’s fresh 15% global tariff. Are new 2026 lows in store?
#   Listen
# 0:00
# PRICE ANALYSIS
# COINTELEGRAPH IN YOUR SOCIAL FEED
# Follow our
#   Follow our
#             Bitcoin’s (BTC) weakness extended into the weekly open as major stocks sold off in response to US President Donald Trump’s threat to enforce a 15% global tariff after the Supreme Court ruled that his IEEPA tariffs were illegal.
# Market sentiment remains fragile, as the Crypto Fear & Greed Index at 5 out of 100 remains in the “extreme fear” zone. Pseudonymous trader and investor BitcoinHyper said in a post on X that the index has been in the extreme fear zone for nearly three weeks, the longest since 2022.
# Traders on the prediction market Polymarket have increased the odds of BTC falling below $55,000 to 72%. The prediction market expectations matches several analysts and financial institutions who expect a fall near or below $55,000.
# Crypto market data daily view. Source: TradingView
# While a bottom may not have formed, expectations are that BTC will eventually recover and move higher. Economist Timothy Peterson said in a post on X that BTC has been positive 50% of the time in the past 24 months. Using a statistical model, Peterson estimated that there is an 88% chance that BTC “will be higher 10 months from now.”
# Could buyers defend the support levels in BTC and the major altcoins? Let’s analyze the charts of the top 10 cryptocurrencies to find out.
# S&P 500 Index price predictio
#
# ### Article: XRP price chart and whale activity warn of a drop below $1
# Source: https://cointelegraph.com/news/xrp-price-chart-whale-activity-warn-drop-below-1-dollar?utm_source=rss_feed&utm_medium=rss_tag_xrp&utm_campaign=rss_partner_inbound
#
#   Ecosystem
#             English
#   News
# Indices
# In Depth
# Learn
# Podcasts
# About
#   XMR
# $339.90
# 4.58%
# BCH
# $487.36
# 1.91%
# XLM
# $0.1548
# 3.66%
# LINK
# $8.63
# 5.53%
# DOGE
# $0.09413
# 3.37%
# SOL
# $82.98
# 7.77%
# ETH
# $1,924
# 5.27%
# TRX
# $0.2859
# 1.94%
# BTC
# $65,435
# 3.48%
# XRP
# $1.38
# 3.56%
# HYPE
# $27.08
# 2.61%
# BNB
# USD
#   Written by Nancy Lubale,
# Former Staff Writer
# Reviewed by Allen Scott,
# Staff Editor
# XRP price chart and whale activity warn of a drop below $1
# Feb 23, 2026
# XRP has formed a classic bearish pattern on it
#
# ... (truncated, 9057 chars total)
#
# ========================================================================
# CLEANING UP SCRAPED CONTENT
# ========================================================================
# Asking openai/gpt-4.1-mini to clean up scraped content...
# Cleanup done — 1854 chars (was 9057 chars raw)
#
# ========================================================================
# CLEANED ARTICLE SUMMARIES
# ========================================================================
# ### Price predictions 2/23: SPX, DXY, BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA
# Bitcoin and altcoins declined as U.S. stock markets reacted to President Donald Trump’s renewed threat of a 15% global tariff following the Supreme Court's ruling against his previous tariffs. The Crypto Fear & Greed Index remains at an extreme fear level of 5/100, suggesting ongoing market caution. Prediction markets give a 72% chance of Bitcoin falling below $55,000, aligning with several analysts' bearish outlooks. However, economist Timothy Peterson estimates an 88% probability that Bitcoin will be higher 10 months from now, indicating potential for long-term recovery despite near-term weakness.
#
# ### XRP price chart and whale activity warn of a drop below $1
# XRP is showing a classic bearish pattern—a bear pennant—on its two-day chart, which could lead to a price drop to approximately $0.80, representing a 42% decline from current levels. This pattern typically follows sharp declines and signals further downside after consolidation. Increased whale inflows to Binance have heightened concerns of additional selling pressure. While support at $1.22 may allow for a trend shift and potential recovery if held, a decisive breakdown below current pennant support could trigger a significant decline.
#
# ### Price predictions 2/20: BTC, ETH, XRP, BNB, SOL, DOGE, BCH, ADA, HYPE, XMR
# Bitcoin bulls failed to maintain momentum after pushing above $68,300, indicating persistent bearish pressure on intraday rallies. Many major altcoins are also showing signs of weakness, suggesting potential drops to their key support levels. Without a strong rally, Bitcoin may record its fifth consecutive red monthly candle—the longest losing streak since 2018/19. This suggests that bears remain dominant, and market participants should watch for possible further declines.
#
# ========================================================================
# STREAMING SENTIMENT REPORT FOR XRP
# ========================================================================
# # XRP 🔴 — Bearish Clouds Gather Over $1
#
# XRP’s looking shaky with a classic bear pennant flashing red 🚩—pointing down to around $0.80 if support cracks. Whale moves into Binance have traders spooked, adding fuel to the selling pressure. The broader crypto gloom isn’t helping either, as BTC and majors struggle and fear dominates the market vibe.
#
# Keep an eye on the $1.22 level—it’s the last line before things could get uglier. If that breaks, expect a sharper drop. No clear signs of relief yet, so buckle up and watch those whales. XRP’s in the danger zone, and the bears smell blood.
