# %% [markdown]
# This notebook, invokes openAI to ask solution for a math problem. It asks to explain the solution in a way that students can easily understand and then provide 3 more problems to apply this fundamental.

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI 
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
system_prompt = """ You are a mathematics professor at Cambridge university. 
    You would like to explain solutions to Math problems in simplest of the ways, almost like an ELI5 explanation. 
    You breakdown the solution into fundamental steps and explain each step in detail. 
    Your response is always in a Markdown friendly format.""" 

math_problem = """ The pupils in my class work very quickly. Jasleen answers four questions every 30 seconds and Ella
answers five questions every 40 seconds.
Last week, Jasleen took exactly 1 hour to answer a large set of questions.
How many minutes more than Jasleen did Ella take to answer the same set of questions? """ 

user_prompt = " help me understand how to solve: " + math_problem + " \n\n . Test if I have understood the method and then provide me with more questions I can solve on this concept. "

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

openai = OpenAI()
response = openai.chat.completions.create(model = "gpt-5-nano",
messages = messages)

display(Markdown(response.choices[0].message.content))
# Out:
# Here's a simple, step-by-step way to handle problems like this (ELI5 style), followed by a quick self-check and extra practice.
#
# Problem recap
# - Jasleen: 4 questions every 30 seconds.
# - Ella: 5 questions every 40 seconds.
# - Jasleen took exactly 1 hour to answer the large set.
# - We want: how many minutes more did Ella take for the same set?
#
# Step-by-step solution
# 1) Find each person’s rate (questions per second)
# - Jasleen: 4 questions / 30 seconds = 4/30 = 2/15 questions per second.
# - Ella: 5 questions / 40 seconds = 5/40 = 1/8 questions per second.
#
# 2) Figure out how many questions were in the set (N) using Jasleen’s time
# - Jasleen’s time = 1 hour = 3600 seconds.
# - N = Jasleen’s rate × time = (2/15) × 3600 = 2 × 3600 / 15 = 7200 / 15 = 480 questions.
#
# 3) Compute Ella’s time for the same set
# - Time for Ella = N ÷ Ella’s rate = 480 ÷ (1/8) = 480 × 8 = 3840 seconds.
# - In minutes: 3840 seconds ÷ 60 = 64 minutes.
#
# 4) Difference
# - Ella’s time − Jasleen’s time = 64 minutes − 60 minutes = 4 minutes.
#
# Answer: Ella took 4 minutes more than Jasleen.
#
# A quick self-check prompt
# - In your own words, can you describe why we first found the total number of questions using Jasleen’s rate and time, and then used Ella’s rate to find her time for that same total?
# - If you want, try recomputing N using a different approach (e.g., convert both rates to questions per minute first, then compute). Show me your result and I’ll compare.
#
# Extra practice problems (same concept)
# 1) Problem A
# - Runners: A answers 3 questions every 15 seconds. B answers 4 questions every 25 seconds.
# - A takes 50 minutes for a set. How many minutes more does B take to answer the same set?
#
# 2) Problem B
# - R1: 6 questions every 50 seconds. R2: 5 questions every 40 seconds.
# - R1 takes 30 minutes for a set. How many minutes more does R2 take?
#
# 3) Problem C
# - A: 7 questions every 28 seconds. B: 8 questions every 32 seconds.
# - A finishes the set in 40 minutes. How many minutes more does B take?
#
# 4) Problem D (slightly different twist)
# - A: 9 questions every 60 seconds. B: 12 questions every 80 seconds.
# - A finishes in 90 minutes. How many minutes more does B take?
#
# If you’d like, I can walk through any of these step by step or tailor a set to your current understanding level.
