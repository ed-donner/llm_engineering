# %% [markdown]
# # YOUR PERSONALIZED COOKBOOK
# ### Simple yet delicious generated using ingredients in your fridge and pantry
# Specify any cuisine you like and the AI assistant will generate the recipe(s) for you, bon appetit! 👩‍🍳
#
# 🍎 🥚 🐓 🐂 🐷 🐟 🥬

# %%
# imports

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
system_prompt = """
You are a professional cook that specializes in cuisines around the world.  
Based on the list of fresh ingredients, build recipes based on how many users asks.  
The recipes should not take more than 30-minutes to complete.  
They must be delicious and nutritious.  
Assume users already have condiments like salt, pepper, oil, mayo, etc."""

user_prompt = """
    I want 3 recipes using these ingredients (you decide the cuisine).  I'm a foodie: 
    chicken, spinach, scallions, butter, lemon
"""

messages = [{"role": "system", "content": system_prompt}, {"role": "user", "content": user_prompt}]

# Call OpenAI
openai = OpenAI()
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
response.choices[0].message.content

# Step 4: print the result
#print(response.choices[0].message.content)
display(Markdown(response.choices[0].message.content))
# Out:
# Great ingredients! I'll create 3 delicious and nutritious recipes showcasing chicken, spinach, scallions, butter, and lemon with different global flavors. Each dish is designed to take about 30 minutes.
#
# ---
#
# ### 1. Lemon Butter Chicken with Garlic Spinach (American/European Inspired)
#
# **Ingredients:**
# - Chicken breasts or thighs (boneless)
# - Fresh spinach
# - Scallions (green parts sliced)
# - Butter
# - Lemon (juice + zest)
# - Garlic (optional, pantry)
# - Salt & pepper
#
# **Method:**
# 1. Season chicken with salt, pepper, and a little lemon zest.
# 2. Heat butter in a skillet over medium-high heat. Sear chicken until golden and cooked through (5-7 mins per side depending on thickness). Remove and keep warm.
# 3. In the same pan, add more butter and sauté minced garlic (if available) for 1 min. Add spinach and cook until wilted. Stir in lemon juice, scallions, salt, and pepper.
# ...
