# %% [markdown]
# # My First Lab - Using CHATGPT API
# ### I created a user prompt which gives chatgpt information to work with
# ### I created a system prompt which gives chatgpt the guideance on how to respond to information given
#
#  <img src="../../../assets/resources.jpg" width="30%" height="100%" style="display: block; margin:0 auto;" />

# %%
# imports

import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
from openai import OpenAI

import sys
sys.path.append("../../") 
from scraper import fetch_website_contents

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %% [markdown]
# # Connecting to OpenAI

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %% [markdown]
# ## Types of prompts - here i edit the prompts to work with data i enter
#
#
# Models like GPT have been trained to receive instructions in a particular way.
#
# They expect to receive:
#
# **A system prompt** that tells them what task they are performing and what tone they should use
#
# **A user prompt** -- the conversation starter that they should reply to

# %% [markdown]
# ## Time to bring it together - the API for OpenAI is very simple!

# %%
# Step 1: Create your prompts

system_prompt = """You are my personal skills developer for my AI Company ckshift.com,
 anaylze all the jobs i've sent you and determine the AI and technical skills needed to accomplish them . 
 I would like only 1 bullet point per job description make sure to label which job number and make most repetitive skills at the top of the list. format each bullet on a new line use sub bullets for details use html bullet tags for each job to create the bullets"""
user_prompt = """
    #1

We’re looking for an experienced Full-Stack Web Developer to join our growing team at Motivation Monday Marketing. This role is ideal for someone who thrives on solving technical problems, building high-converting websites, and creating seamless customer experiences through automation.

You’ll be responsible for developing websites and landing pages, maintaining our hosting infrastructure, troubleshooting technical issues, and building sophisticated CRM workflows that help our clients generate and convert leads.

Responsibilities

* Build and maintain responsive websites using WordPress and Elementor.
* Develop and manage Shopify websites and eCommerce functionality.
* Create high-converting landing pages optimized for lead generation.
* Manage and maintain websites hosted on Cloudways, including:
* Server management
* Website migrations
* Performance optimization
* Security monitoring
* Malware removal
* Troubleshooting website issues
* Repairing corrupted websites and restoring backups when required.
* Configure and troubleshoot DNS records, SSL certificates, email routing, and domain settings.
* Set up and manage Google Analytics 4, Google Tag Manager, conversion tracking, and event tracking.
* Work extensively within GoHighLevel (HighLevel) to build and optimize CRM systems.
* Design and implement:
* Customer journeys
* Sales pipelines
* Automated workflows
* Email and SMS automation
* Lead nurturing campaigns
* Appointment booking systems
* Forms, surveys, and calendars
* Integrate third-party software and APIs.
* Optimize websites for SEO, speed, Core Web Vitals, and user experience.
* Work alongside our design and marketing teams to launch new client projects efficiently.
* Provide technical support and ongoing maintenance for client websites.

Required Skills & Experience

* 3+ years of experience developing websites.
* Advanced experience with WordPress and Elementor.
* Strong experience with Shopify.
* Experience managing websites on Cloudways hosting.
* Strong understanding of server administration, backups, security, SSL certificates, and website recovery.
* Experience repairing broken or corrupted WordPress websites.
* Advanced knowledge of GoHighLevel (HighLevel).
* Deep understanding of CRM architecture, customer journeys, automation, and workflow design.
* Experience with Google Analytics 4, Google Tag Manager, and conversion tracking.
* Strong understanding of HTML, CSS, JavaScript, and PHP.
* Familiarity with SEO best practices and website performance optimization.
* Excellent troubleshooting and problem-solving skills.
* Ability to manage multiple client projects while meeting deadlines.

Bonus Skills

* Experience with WooCommerce.
* API integrations using Zapier, Make.com, or webhooks.
* Experience with Meta Pixel, Google Ads conversion tracking, and server-side tracking.
* Knowledge of Cloudflare and CDN optimization.
* Familiarity with Git/version control.

What We’re Looking For

We’re looking for someone who is:

* Highly organized and detail-oriented.
* Proactive and able to solve problems independently.
* Passionate about building systems that improve customer experiences.
* Comfortable working in a fast-paced agency environment.
* Committed to producing high-quality work with minimal supervision. 
#2

We are looking for an experienced software development team to build and support a professional Automotive CRM platform.
The system will be used to manage vehicle sales, customer enquiries, leads, follow-ups, inventory, appointments, quotations, documents, reporting, and internal team activities.

Required Technology Stack

The development team must have strong experience with:
Node.js v18.12.0 LTS
PHP v8.2
Laravel Framework v12.0.0
REST API development and third-party integrations
MySQL or a similar relational database
Modern frontend frameworks
Secure authentication and role-based access control
Cloud deployment, server configuration, and ongoing maintenance
Key CRM Features

The platform may include:
Customer and lead management
Vehicle inventory management
Sales pipeline and deal tracking
Follow-up reminders and task management
Appointment and test-drive scheduling
Quotations, invoices, and document management
Staff roles and permissions
Email, SMS, WhatsApp, and third-party API integrations
Reports and management dashboards
Mobile-responsive interface
Audit logs, backups, and security controls
Developer Requirements

We are looking for a reliable team that can:
Review and understand detailed business requirements
Recommend a suitable system architecture
Develop clean, scalable, and well-documented code
Follow secure software development standards
Complete proper testing before delivery
Provide regular progress updates
Support deployment, maintenance, and future improvements
Communicate professionally in English

Experience developing automotive software, dealership management systems, CRM platforms, ERP systems, or similar business applications will be preferred.

#3
I'm looking for a developer to build a web application that works exactly like Claude.ai (Anthropic's chat interface), but fully white-labeled under my own branding.

How it should work:
- User asks a question in my platform's interface
- The platform sends the query to Claude via the Anthropic API
- Claude's response is displayed back to the user inside my platform
- No visible reference to "Claude" or "Anthropic" anywhere in the UI - fully white-labeled

Core functionality (matching Claude.ai's experience):
- Clean chat interface for asking questions and getting answers
- Persistent chat history per user
- User accounts / login system
- File upload support (so users can upload documents/images and ask questions about them, same as Claude.ai)
- Responsive web design

Tech expectations:
- Integration with the Anthropic API (I will provide the API key)
- Secure handling of API keys and user data
- Clean, modern, branded front-end (branding assets/guidelines will be provided)

What I need from you:
- A brief proposal on your intended tech stack
- Relevant experience with LLM API integrations (Anthropic, OpenAI, or similar) or chat-based SaaS products
- Rough timeline and cost estimate for the project

Budget: Please quote based on scope described above.
#4
We are seeking an experienced freelancer to assist in building our Admin dashboard. The ideal candidate will guide us on integrating third-party applications such as Hubspot CRM and Zoho People. The role requires a strong understanding of CRM and HR systems integration to ensure seamless functionality.

#5
We are seeking a skilled team to develop an AI-enabled SAAS platform for international admissions, compliance, and analytics. The platform should streamline processes, enhance decision-making, and provide actionable insights. The ideal candidate will have experience in AI, software development, and data analysis, and be able to deliver a scalable and user-friendly solution.

#6
I need to implement a feature that is called "Online Directories Submission".

This is when a website URL is automatically submitted to multiple online directories for listing.

This type of service has been on the marker for years and there are many existing websites that offer this service. Many sites claim they can submit your website URL and description to 100+ directories.

This is usually done to improve domain ranking.

I want to implement this feature for my website and allow customers to submit their website to multiple online listing directories automatically.

I need bare minimum - a working engine. You do not need to worry about the design and etc. This will be done by other people after. Your job is to build the working core. I don't mind if you build it using AI.

If you have experience working with this and know how to implement it, please reply to this job post with your offer.

#7
I need a full-stack AI-powered web application called "Career Growth AI for Kids." The website should allow parents to create an account, enter their child's details, and receive personalized career insights. The application should be user-friendly and secure, ensuring data privacy. The project involves both front-end and back-end development, requiring a full-stack developer.

#8
We are seeking an AI Implementation Specialist to develop and integrate AI tools for our business. The ideal candidate will have experience in AI tool development and integration, with a strong understanding of business needs. Responsibilities include designing AI solutions, collaborating with cross-functional teams, and ensuring seamless integration with existing systems. The role requires a proactive approach to identifying and resolving technical challenges.

#9
I have a web app mockup with the basic UI/design. I need a developer to take it from a static shell to a working product. The project involves implementing the design into a functional web application, ensuring it is user-friendly and efficient. The ideal candidate should have experience in web development and be able to deliver a high-quality product. https://brovan-hub-1--brovanprim.replit.app/

#10
Install self hosted open source Documenso into a multi-tenant Vue platform where each user and tenant have their own instance. The task involves integrating Documento into a Vue.js application, ensuring each user and tenant has a separate instance. The ideal candidate will have experience in web development and Vue.js, with a focus on multi-tenancy solutions.

2 part
Documenso as a standalone feature
Documenso link and integrated into CRM
"""

# Step 2: Make the messages list
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]


# Step 3: Call OpenAI

openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
# response.choices[0].message.content

from IPython.display import HTML

html = f"""
<table style="border-collapse:collapse;width:100%;">
<tr style="background:#4CAF50;color:white;">
    <th style="padding:10px;">Field</th>
    <th style="padding:10px;">Value</th>
</tr>
<tr>
    <td><b>Model</b></td>
    <td>{response.model}</td>
</tr>
<tr>
    <td><b>Response</b></td>
    <td>{response.choices[0].message.content}</td>
</tr>
<tr>
    <td><b>Finish Reason</b></td>
    <td>{response.choices[0].finish_reason}</td>
</tr>
</table>
"""

HTML(html)
# response =

# Step 4: print the result
# print(
# Out:
# <table style="border-collapse:collapse;width:100%;">
# <tr style="background:#4CAF50;color:white;">
#     <th style="padding:10px;">Field</th>
#     <th style="padding:10px;">Value</th>
# </tr>
# <tr>
#     <td><b>Model</b></td>
#     <td>gpt-5-nano-2025-08-07</td>
# </tr>
# <tr>
#     <td><b>Response</b></td>
#     <td><ul>
#   <li>Job #1 — Full-Stack Web Developer for Motivation Monday Marketing
#     <ul>
#       <li>Full-stack web development with WordPress/Elementor, Shopify, and CRM automation (GoHighLevel)</li>
#       <li>Hosting/infrastructure management on Cloudways, including server admin, migrations, performance tuning, security, and backups</li>
#       <li>CRM workflows, automation, API integrations, analytics setup, and SEO/performance optimization</li>
#     </ul>
#   </li>
#   <li>Job #2 — Automotive CRM platform development team
#     <ul>
#       <li>Full-stack development with Node.js (v18), PHP/Laravel, REST APIs, and MySQL</li>
# ...

# %% [markdown]
# ## An extra exercise for those who enjoy web scraping
#
# You may notice that if you try `display_summary("https://openai.com")` - it doesn't work! That's because OpenAI has a fancy website that uses Javascript. There are many ways around this that some of you might be familiar with. For example, Selenium is a hugely popular framework that runs a browser behind the scenes, renders the page, and allows you to query it. If you have experience with Selenium, Playwright or a similar browser automation framework, then feel free to implement an alternative version of the scraping functions in `scraper.py` (or in a separate module) using one of these tools. In the community-contributions folder, you'll find examples contributed by other students, including a Selenium implementation (thank you!)

# %% [markdown]
# # Sharing your code
#
# I'd love it if you share your code afterwards so I can share it with others! You'll notice that some students have already made changes (including a Selenium implementation) which you will find in the community-contributions folder. If you'd like add your changes to that folder, submit a Pull Request with your new versions in that folder and I'll merge your changes.
#
# If you're not an expert with git (and I am not!) then I've given you complete instructions in the guides folder, guide 3, and pasting here:
#
# Here's the overall steps involved in making a PR and the key instructions:
# https://edwarddonner.com/pr
#
# Please check before submitting:
# 1. Your PR only contains changes in community-contributions (unless we've discussed it)
# 2. All notebook outputs are clear
# 3. Less than 2,000 lines of code in total, and not too many files
# 4. Don't include unnecessary test files, or overly wordy README or .env.example or emojis or other LLM artifacts!
#
# Thanks so much!
#
# Detailed steps here:
#
# https://chatgpt.com/share/6873c22b-2a1c-8012-bc9a-debdcf7c835b
