# %%
# Load environment variables in a file called .env

import os

from dotenv import load_dotenv


load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

# %%
import openai

system_prompt = """
Your are a nutritionist with many years of experience.
You provide a detailed list of nutritious foods.
"""
user_prompt = """
Create a list of nutritious foods for the following categories.  The rows and colums should be formatted as a markdown table.
Please list serving sizes in grams and ounces, caloric content, carbohydrates in grams, protein in grams, and fat in grams.
For each category provide the top 20 healthiest options.
- Lean Proteins (meats, fish, poultry)
- Complex Carbohydrates
- Healthy Fats
- Vegetables
- Fruits
- Snacks
"""

def messages(system_prompt, user_prompt):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ]

def create_healthiest_foods_list(system_prompt, user_prompt):
    response = openai.chat.completions.create(model="gpt-5-nano", messages=messages(system_prompt, user_prompt))
    return response.choices[0].message.content

# Output in table format
print(create_healthiest_foods_list(system_prompt, user_prompt))

# %%
system_prompt_2 = """
Your are a nutritionist with many years of experience.
You provide a detailed list of nutritious foods.
"""
user_prompt_2 = """
Create a list of nutritious foods for the following categories.
Please list serving sizes in grams and ounces, caloric content, carbohydrates in grams, protein in grams, and fat in grams.
Include micronutrients such as vitamins and minerals.
Include fiber content.
For each category provide the top 20 healthiest options.
- Lean Proteins (meats, fish, poultry)
- Complex Carbohydrates
- Healthy Fats
- Vegetables
- Fruits
- Snacks
Each category should be an array of objects in JSON format.
Do not output in table format.
"""
#Output in JSON format
print(create_healthiest_foods_list(system_prompt_2, user_prompt_2))
# Out:
# {
#   "Lean Proteins": [
#     {
#       "name": "Skinless chicken breast",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 165,
#       "carbs_g": 0,
#       "protein_g": 31,
#       "fat_g": 3.6,
#       "micronutrients": {
#         "Vitamin_B3_mg": 11,
#         "Vitamin_B6_mg": 0.6,
#         "Vitamin_B12_mcg": 0,
#         "Iron_mg": 0.9,
#         "Magnesium_mg": 28,
#         "Potassium_mg": 256,
#         "Selenium_mcg": 27
#       }
#     },
#     {
#       "name": "Turkey breast",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 135,
#       "carbs_g": 0,
#       "protein_g": 29,
#       "fat_g": 1,
#       "micronutrients": {
#         "Vitamin_B3_mg": 10,
#         "Vitamin_B6_mg": 0.5,
#         "Vitamin_B12_mcg": 0.3,
#         "Iron_mg": 1.1,
#         "Magnesium_mg": 28,
#         "Potassium_mg": 278,
#         "Selenium_mcg": 28
#       }
#     },
#     {
#       "name": "Salmon (Atlantic, cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 206,
#       "carbs_g": 0,
#       "protein_g": 22,
#       "fat_g": 12,
#       "micronutrients": {
#         "Vitamin_D_mcg": 10,
#         "Vitamin_B12_mcg": 2.2,
#         "Iron_mg": 0.3,
#         "Magnesium_mg": 26,
#         "Potassium_mg": 384,
#         "Selenium_mcg": 34
#       }
#     },
#     {
#       "name": "Tuna (canned in water)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 132,
#       "carbs_g": 0,
#       "protein_g": 28,
#       "fat_g": 1,
#       "micronutrients": {
#         "Vitamin_B3_mg": 11,
#         "Vitamin_B6_mg": 0.5,
#         "Vitamin_B12_mcg": 9.0,
#         "Iron_mg": 1.3,
#         "Magnesium_mg": 29,
#         "Potassium_mg": 320,
#         "Selenium_mcg": 80
#       }
#     },
#     {
#       "name": "Lean beef sirloin",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 206,
#       "carbs_g": 0,
#       "protein_g": 26,
#       "fat_g": 9,
#       "micronutrients": {
#         "Vitamin_B3_mg": 5,
#         "Vitamin_B6_mg": 0.4,
#         "Vitamin_B12_mcg": 2.6,
#         "Iron_mg": 2.2,
#         "Magnesium_mg": 21,
#         "Potassium_mg": 320,
#         "Selenium_mcg": 26
#       }
#     },
#     {
#       "name": "Lean ground turkey (90%+ lean)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 170,
#       "carbs_g": 0,
#       "protein_g": 28,
#       "fat_g": 7,
#       "micronutrients": {
#         "Vitamin_B3_mg": 6,
#         "Vitamin_B6_mg": 0.5,
#         "Vitamin_B12_mcg": 0.4,
#         "Iron_mg": 1.2,
#         "Magnesium_mg": 24,
#         "Potassium_mg": 260,
#         "Selenium_mcg": 24
#       }
#     },
#     {
#       "name": "Cod",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 105,
#       "carbs_g": 0,
#       "protein_g": 23,
#       "fat_g": 0.3,
#       "micronutrients": {
#         "Vitamin_B12_mcg": 1.0,
#         "Selenium_mcg": 40,
#         "Iron_mg": 0.4,
#         "Potassium_mg": 180,
#         "Magnesium_mg": 17
#       }
#     },
#     {
#       "name": "Shrimp",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 99,
#       "carbs_g": 0,
#       "protein_g": 24,
#       "fat_g": 0.5,
#       "micronutrients": {
#         "Vitamin_B12_mcg": 0.3,
#         "Selenium_mcg": 44,
#         "Iron_mg": 0.6,
#         "Potassium_mg": 264,
#         "Magnesium_mg": 23
#       }
#     },
#     {
#       "name": "Tilapia",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 129,
#       "carbs_g": 0,
#       "protein_g": 26,
#       "fat_g": 2.7,
#       "micronutrients": {
#         "Vitamin_B3_mg": 3,
#         "Vitamin_B6_mg": 0.2,
#         "Vitamin_B12_mcg": 0.4,
#         "Iron_mg": 0.9,
#         "Magnesium_mg": 23,
#         "Potassium_mg": 280,
#         "Selenium_mcg": 18
#       }
#     },
#     {
#       "name": "Scallops",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 90,
#       "carbs_g": 0,
#       "protein_g": 20,
#       "fat_g": 0.6,
#       "micronutrients": {
#         "Vitamin_B12_mcg": 0.6,
#         "Selenium_mcg": 28,
#         "Iron_mg": 0.8,
#         "Potassium_mg": 170,
#         "Magnesium_mg": 22
#       }
#     },
#     {
#       "name": "Venison",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 158,
#       "carbs_g": 0,
#       "protein_g": 28,
#       "fat_g": 5,
#       "micronutrients": {
#         "Vitamin_B12_mcg": 2.0,
#         "Iron_mg": 3.0,
#         "Selenium_mcg": 24,
#         "Zinc_mg": 4.0,
#         "Potassium_mg": 320
#       }
#     },
#     {
#       "name": "Pork loin (lean)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 143,
#       "carbs_g": 0,
#       "protein_g": 26,
#       "fat_g": 3,
#       "micronutrients": {
#         "Vitamin_B6_mg": 0.3,
#         "Vitamin_B12_mcg": 0.6,
#         "Iron_mg": 0.7,
#         "Selenium_mcg": 30,
#         "Phosphorus_mg": 210
#       }
#     },
#     {
#       "name": "Haddock",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 90,
#       "carbs_g": 0,
#       "protein_g": 20,
#       "fat_g": 0.3,
#       "micronutrients": {
#         "Vitamin_B12_mcg": 0.6,
#         "Selenium_mcg": 35,
#         "Iron_mg": 0.4,
#         "Potassium_mg": 290
#       }
#     },
#     {
#       "name": "Rainbow trout",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 145,
#       "carbs_g": 0,
#       "protein_g": 20,
#       "fat_g": 6,
#       "micronutrients": {
#         "Vitamin_B12_mcg": 1.5,
#         "Vitamin_D_mcg": 0.9,
#         "Selenium_mcg": 25,
#         "Potassium_mg": 320
#       }
#     },
#     {
#       "name": "Sardines (canned in water)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 208,
#       "carbs_g": 0,
#       "protein_g": 25,
#       "fat_g": 11,
#       "micronutrients": {
#         "Vitamin_B12_mcg": 6.0,
#         "Vitamin_D_mcg": 3.0,
#         "Calcium_mg": 350,
#         "Selenium_mcg": 45,
#         "Omega3_g": 1.5
#       }
#     },
#     {
#       "name": "Lamb loin, lean",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 206,
#       "carbs_g": 0,
#       "protein_g": 23,
#       "fat_g": 12,
#       "micronutrients": {
#         "Vitamin_B12_mcg": 2.0,
#         "Iron_mg": 2.2,
#         "Zinc_mg": 3.0,
#         "Selenium_mcg": 18
#       }
#     },
#     {
#       "name": "Rabbit",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 173,
#       "carbs_g": 0,
#       "protein_g": 33,
#       "fat_g": 3,
#       "micronutrients": {
#         "Vitamin_B12_mcg": 2.0,
#         "Iron_mg": 2.0,
#         "Selenium_mcg": 25,
#         "Potassium_mg": 260
#       }
#     },
#     {
#       "name": "Chicken tenderloin",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 165,
#       "carbs_g": 0,
#       "protein_g": 31,
#       "fat_g": 3.5,
#       "micronutrients": {
#         "Vitamin_B3_mg": 9,
#         "Vitamin_B6_mg": 0.6,
#         "Vitamin_B12_mcg": 0.4,
#         "Iron_mg": 0.9,
#         "Selenium_mcg": 30
#       }
#     },
#     {
#       "name": "Duck breast, skinless",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 135,
#       "carbs_g": 0,
#       "protein_g": 23,
#       "fat_g": 4,
#       "micronutrients": {
#         "Vitamin_B3_mg": 4,
#         "Vitamin_B6_mg": 0.3,
#         "Vitamin_B12_mcg": 1.0,
#         "Iron_mg": 1.7,
#         "Selenium_mcg": 30
#       }
#     },
#     {
#       "name": "Flounder",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 90,
#       "carbs_g": 0,
#       "protein_g": 20,
#       "fat_g": 1,
#       "micronutrients": {
#         "Vitamin_B12_mcg": 0.6,
#         "Selenium_mcg": 30,
#         "Iron_mg": 0.4,
#         "Potassium_mg": 320
#       }
#     }
#   ],
#   "Complex Carbohydrates": [
#     {
#       "name": "Rolled oats",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 389,
#       "carbs_g": 66,
#       "protein_g": 17,
#       "fat_g": 7,
#       "micronutrients": {
#         "Fiber_g": 10,
#         "Magnesium_mg": 177,
#         "Iron_mg": 4.3,
#         "Potassium_mg": 357
#       }
#     },
#     {
#       "name": "Steel-cut oats",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 378,
#       "carbs_g": 66,
#       "protein_g": 13,
#       "fat_g": 7,
#       "micronutrients": {
#         "Fiber_g": 8,
#         "Magnesium_mg": 123,
#         "Iron_mg": 4.3
#       }
#     },
#     {
#       "name": "Quinoa (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 120,
#       "carbs_g": 21,
#       "protein_g": 4,
#       "fat_g": 2,
#       "micronutrients": {
#         "Fiber_g": 2.8,
#         "Magnesium_mg": 64,
#         "Iron_mg": 1.5,
#         "Zinc_mg": 1.1
#       }
#     },
#     {
#       "name": "Brown rice (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 112,
#       "carbs_g": 23,
#       "protein_g": 2.6,
#       "fat_g": 0.9,
#       "micronutrients": {
#         "Fiber_g": 1.8,
#         "Magnesium_mg": 43,
#         "Iron_mg": 0.6
#       }
#     },
#     {
#       "name": "Wild rice (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 101,
#       "carbs_g": 21,
#       "protein_g": 4,
#       "fat_g": 0.3,
#       "micronutrients": {
#         "Magnesium_mg": 50,
#         "Phosphorus_mg": 140,
#         "Potassium_mg": 140
#       }
#     },
#     {
#       "name": "Buckwheat groats (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 343,
#       "carbs_g": 71,
#       "protein_g": 13,
#       "fat_g": 3.4,
#       "micronutrients": {
#         "Fiber_g": 3.0,
#         "Magnesium_mg": 231,
#         "Manganese_mg": 0.6
#       }
#     },
#     {
#       "name": "Barley (pearled, cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 113,
#       "carbs_g": 23,
#       "protein_g": 3,
#       "fat_g": 0.4,
#       "micronutrients": {
#         "Fiber_g": 3.8,
#         "Manganese_mg": 0.7,
#         "Selenium_mcg": 16
#       }
#     },
#     {
#       "name": "Bulgur (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 83,
#       "carbs_g": 18,
#       "protein_g": 3,
#       "fat_g": 0.2,
#       "micronutrients": {
#         "Folate_mcg": 18,
#         "Iron_mg": 1.3,
#         "Magnesium_mg": 22
#       }
#     },
#     {
#       "name": "Farro (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 150,
#       "carbs_g": 32,
#       "protein_g": 6,
#       "fat_g": 1.0,
#       "micronutrients": {
#         "Magnesium_mg": 50,
#         "Phosphorus_mg": 180,
#         "Zinc_mg": 1.9
#       }
#     },
#     {
#       "name": "Amaranth (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 106,
#       "carbs_g": 19,
#       "protein_g": 4.7,
#       "fat_g": 1.7,
#       "micronutrients": {
#         "Calcium_mg": 47,
#         "Iron_mg": 2.1,
#         "Magnesium_mg": 62
#       }
#     },
#     {
#       "name": "Millet (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 119,
#       "carbs_g": 23,
#       "protein_g": 3.6,
#       "fat_g": 1.0,
#       "micronutrients": {
#         "Magnesium_mg": 33,
#         "Phosphorus_mg": 180,
#         "Manganese_mg": 0.6
#       }
#     },
#     {
#       "name": "Lentils (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 116,
#       "carbs_g": 20,
#       "protein_g": 9,
#       "fat_g": 0.4,
#       "micronutrients": {
#         "Fiber_g": 8,
#         "Folate_mcg": 181,
#         "Iron_mg": 3.3,
#         "Magnesium_mg": 36
#       }
#     },
#     {
#       "name": "Chickpeas (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 164,
#       "carbs_g": 27,
#       "protein_g": 9,
#       "fat_g": 2.6,
#       "micronutrients": {
#         "Fiber_g": 7.6,
#         "Folate_mcg": 131,
#         "Iron_mg": 2.9,
#         "Magnesium_mg": 45
#       }
#     },
#     {
#       "name": "Black beans (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 132,
#       "carbs_g": 24,
#       "protein_g": 9,
#       "fat_g": 0.5,
#       "micronutrients": {
#         "Fiber_g": 7.5,
#         "Folate_mcg": 149,
#         "Iron_mg": 2.1,
#         "Magnesium_mg": 70
#       }
#     },
#     {
#       "name": "Kidney beans (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 127,
#       "carbs_g": 22,
#       "protein_g": 8.7,
#       "fat_g": 0.5,
#       "micronutrients": {
#         "Fiber_g": 6.4,
#         "Folate_mcg": 131,
#         "Iron_mg": 2.9,
#         "Magnesium_mg": 45
#       }
#     },
#     {
#       "name": "Navy beans (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 140,
#       "carbs_g": 26,
#       "protein_g": 8,
#       "fat_g": 0.8,
#       "micronutrients": {
#         "Folate_mcg": 170,
#         "Iron_mg": 3.0,
#         "Magnesium_mg": 50
#       }
#     },
#     {
#       "name": "Pinto beans (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 143,
#       "carbs_g": 26,
#       "protein_g": 9,
#       "fat_g": 0.8,
#       "micronutrients": {
#         "Folate_mcg": 172,
#         "Iron_mg": 2.1,
#         "Magnesium_mg": 50
#       }
#     },
#     {
#       "name": "Cannellini beans (white beans, cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 139,
#       "carbs_g": 23,
#       "protein_g": 9,
#       "fat_g": 0.8,
#       "micronutrients": {
#         "Folate_mcg": 125,
#         "Iron_mg": 2.9,
#         "Magnesium_mg": 49
#       }
#     },
#     {
#       "name": "Whole wheat pasta (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 124,
#       "carbs_g": 25,
#       "protein_g": 5,
#       "fat_g": 0.6,
#       "micronutrients": {
#         "Fiber_g": 3.2,
#         "Iron_mg": 1.3,
#         "Magnesium_mg": 37
#       }
#     },
#     {
#       "name": "Sweet potato (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 86,
#       "carbs_g": 20,
#       "protein_g": 1.6,
#       "fat_g": 0.1,
#       "micronutrients": {
#         "Vitamin_A_mcg": 709,
#         "Fiber_g": 3.0,
#         "Potassium_mg": 337,
#         "Vitamin_C_mg": 1.8
#       }
#     },
#     {
#       "name": "Quinoa (dry, cooked as grain)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 120,
#       "carbs_g": 21,
#       "protein_g": 4,
#       "fat_g": 2,
#       "micronutrients": {
#         "Fiber_g": 2.8,
#         "Magnesium_mg": 64,
#         "Iron_mg": 1.5
#       }
#     },
#     {
#       "name": "Amaranth (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 106,
#       "carbs_g": 19,
#       "protein_g": 4.7,
#       "fat_g": 1.4,
#       "micronutrients": {
#         "Calcium_mg": 47,
#         "Iron_mg": 2.1,
#         "Magnesium_mg": 62
#       }
#     },
#     {
#       "name": "Millet (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 119,
#       "carbs_g": 23,
#       "protein_g": 3.6,
#       "fat_g": 1.0,
#       "micronutrients": {
#         "Magnesium_mg": 34,
#         "Phosphorus_mg": 200,
#         "Manganese_mg": 0.7
#       }
#     },
#     {
#       "name": "Lentils (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 116,
#       "carbs_g": 20,
#       "protein_g": 9,
#       "fat_g": 0.4,
#       "micronutrients": {
#         "Fiber_g": 7.9,
#         "Folate_mcg": 181,
#         "Iron_mg": 3.3,
#         "Magnesium_mg": 36
#       }
#     },
#     {
#       "name": "Chickpeas (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 164,
#       "carbs_g": 27,
#       "protein_g": 9,
#       "fat_g": 2.6,
#       "micronutrients": {
#         "Fiber_g": 7.6,
#         "Folate_mcg": 131,
#         "Iron_mg": 2.9,
#         "Magnesium_mg": 45
#       }
#     },
#     {
#       "name": "Black beans (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 132,
#       "carbs_g": 24,
#       "protein_g": 9,
#       "fat_g": 0.5,
#       "micronutrients": {
#         "Fiber_g": 8.7,
#         "Folate_mcg": 120,
#         "Iron_mg": 2.1,
#         "Magnesium_mg": 70
#       }
#     },
#     {
#       "name": "Navy beans (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 140,
#       "carbs_g": 26,
#       "protein_g": 8,
#       "fat_g": 0.8,
#       "micronutrients": {
#         "Fiber_g": 9.6,
#         "Folate_mcg": 214,
#         "Iron_mg": 3.4,
#         "Magnesium_mg": 64
#       }
#     },
#     {
#       "name": "Pinto beans (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 143,
#       "carbs_g": 26,
#       "protein_g": 9,
#       "fat_g": 0.8,
#       "micronutrients": {
#         "Fiber_g": 9.0,
#         "Folate_mcg": 172,
#         "Iron_mg": 2.1,
#         "Magnesium_mg": 53
#       }
#     },
#     {
#       "name": "Cannellini (white) beans, cooked",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 139,
#       "carbs_g": 23,
#       "protein_g": 9,
#       "fat_g": 0.8,
#       "micronutrients": {
#         "Fiber_g": 6.0,
#         "Folate_mcg": 115,
#         "Iron_mg": 2.9,
#         "Magnesium_mg": 49
#       }
#     },
#     {
#       "name": "Whole wheat pasta (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 124,
#       "carbs_g": 25,
#       "protein_g": 5,
#       "fat_g": 0.6,
#       "micronutrients": {
#         "Fiber_g": 3.0,
#         "Iron_mg": 1.3,
#         "Magnesium_mg": 37
#       }
#     },
#     {
#       "name": "Sweet potato (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 86,
#       "carbs_g": 20,
#       "protein_g": 1.6,
#       "fat_g": 0.1,
#       "micronutrients": {
#         "Vitamin_A_mcg": 709,
#         "Fiber_g": 3.0,
#         "Potassium_mg": 337,
#         "Vitamin_C_mg": 1.8
#       }
#     },
#     {
#       "name": "Quinoa (cooked, alternative entry)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 120,
#       "carbs_g": 21,
#       "protein_g": 4,
#       "fat_g": 2,
#       "micronutrients": {
#         "Fiber_g": 2.8,
#         "Magnesium_mg": 64,
#         "Iron_mg": 1.5
#       }
#     },
#     {
#       "name": "Amaranth (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 106,
#       "carbs_g": 19,
#       "protein_g": 4.7,
#       "fat_g": 1.4,
#       "micronutrients": {
#         "Calcium_mg": 47,
#         "Iron_mg": 2.1,
#         "Magnesium_mg": 62
#       }
#     },
#     {
#       "name": "Sunflower seeds (roasted, salted)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 584,
#       "carbs_g": 20,
#       "protein_g": 20,
#       "fat_g": 50,
#       "micronutrients": {
#         "Vitamin_E_mg": 35,
#         "Magnesium_mg": 325,
#         "Iron_mg": 5.0
#       }
#     },
#     {
#       "name": "Oat bran",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 246,
#       "carbs_g": 44,
#       "protein_g": 17,
#       "fat_g": 7,
#       "micronutrients": {
#         "Fiber_g": 10,
#         "Magnesium_mg": 180,
#         "Iron_mg": 4.0
#       }
#     },
#     {
#       "name": "Freekeh",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 320,
#       "carbs_g": 60,
#       "protein_g": 12,
#       "fat_g": 2,
#       "micronutrients": {
#         "Fiber_g": 9,
#         "Magnesium_mg": 130,
#         "Iron_mg": 3.0
#       }
#     },
#     {
#       "name": "Rye bread (100% whole grain)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 259,
#       "carbs_g": 48,
#       "protein_g": 9,
#       "fat_g": 2,
#       "micronutrients": {
#         "Fiber_g": 6,
#         "Thiamin_mg": 0.3,
#         "Iron_mg": 3.6
#       }
#     },
#     {
#       "name": "Couscous (whole wheat, cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 112,
#       "carbs_g": 23,
#       "protein_g": 3.8,
#       "fat_g": 0.2,
#       "micronutrients": {
#         "Folate_mcg": 58,
#         "Magnesium_mg": 23,
#         "Iron_mg": 0.9
#       }
#     },
#     {
#       "name": "Barley flakes (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 110,
#       "carbs_g": 23,
#       "protein_g": 2,
#       "fat_g": 0.5,
#       "micronutrients": {
#         "Fiber_g": 3.5,
#         "Manganese_mg": 0.3,
#         "Magnesium_mg": 25
#       }
#     },
#     {
#       "name": "Corn (sweet, cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 96,
#       "carbs_g": 21,
#       "protein_g": 3.4,
#       "fat_g": 1.2,
#       "micronutrients": {
#         "Vitamin_C_mg": 6.0,
#         "Magnesium_mg": 37,
#         "Potassium_mg": 270
#       }
#     },
#     {
#       "name": "Psyllium husk (ground, as cereal supplement)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 274,
#       "carbs_g": 84,
#       "protein_g": 2.0,
#       "fat_g": 0.8,
#       "micronutrients": {
#         "Fiber_g": 78,
#         "Magnesium_mg": 90,
#         "Calcium_mg": 60
#       }
#     },
#     {
#       "name": "White rice (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 130,
#       "carbs_g": 28,
#       "protein_g": 2.7,
#       "fat_g": 0.3,
#       "micronutrients": {
#         "Folate_mcg": 8,
#         "Manganese_mg": 0.8,
#         "Selenium_mcg": 7
#       }
#     },
#     {
#       "name": "Pearl barley (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 119,
#       "carbs_g": 25,
#       "protein_g": 3.5,
#       "fat_g": 0.5,
#       "micronutrients": {
#         "Fiber_g": 3.0,
#         "Magnesium_mg": 22,
#         "Iron_mg": 1.0
#       }
#     },
#     {
#       "name": "Polenta (cornmeal, cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 90,
#       "carbs_g": 22,
#       "protein_g": 2.2,
#       "fat_g": 0.6,
#       "micronutrients": {
#         "Calcium_mg": 18,
#         "Iron_mg": 0.7
#       }
#     },
#     {
#       "name": "Couscous (white, cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 112,
#       "carbs_g": 23,
#       "protein_g": 3.8,
#       "fat_g": 0.2,
#       "micronutrients": {
#         "Folate_mcg": 34,
#         "Iron_mg": 0.8,
#         "Magnesium_mg": 10
#       }
#     },
#     {
#       "name": "Rice noodles (cooked)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 109,
#       "carbs_g": 23,
#       "protein_g": 2.9,
#       "fat_g": 0.1,
#       "micronutrients": {
#         "Iron_mg": 0.5,
#         "Calcium_mg": 8,
#         "Magnesium_mg": 8
#       }
#     }
#   ],
#   "Healthy Fats": [
#     {
#       "name": "Extra-virgin olive oil",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 884,
#       "carbs_g": 0,
#       "protein_g": 0,
#       "fat_g": 100,
#       "micronutrients": {
#         "Vitamin_E_mg": 14,
#         "Vitamin_K_mcg": 60
#       }
#     },
#     {
#       "name": "Avocado",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 160,
#       "carbs_g": 9,
#       "protein_g": 2,
#       "fat_g": 15,
#       "micronutrients": {
#         "Potassium_mg": 485,
#         "Folate_mcg": 120,
#         "Vitamin_K_mcg": 14
#       }
#     },
#     {
#       "name": "Walnuts",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 654,
#       "carbs_g": 14,
#       "protein_g": 15,
#       "fat_g": 65,
#       "micronutrients": {
#         "Omega3_g": 2.5,
#         "Magnesium_mg": 158,
#         "Phosphorus_mg": 346
#       }
#     },
#     {
#       "name": "Almonds",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 576,
#       "carbs_g": 22,
#       "protein_g": 21,
#       "fat_g": 49,
#       "micronutrients": {
#         "Vitamin_E_mg": 25,
#         "Magnesium_mg": 270,
#         "Calcium_mg": 264
#       }
#     },
#     {
#       "name": "Pecans",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 691,
#       "carbs_g": 14,
#       "protein_g": 9,
#       "fat_g": 72,
#       "micronutrients": {
#         "Magnesium_mg": 121,
#         "Phosphorus_mg": 282
#       }
#     },
#     {
#       "name": "Pistachios",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 560,
#       "carbs_g": 28,
#       "protein_g": 20,
#       "fat_g": 45,
#       "micronutrients": {
#         "Vitamin_B6_mg": 0.5,
#         "Potassium_mg": 1025,
#         "Magnesium_mg": 120
#       }
#     },
#     {
#       "name": "Macadamia nuts",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 718,
#       "carbs_g": 14,
#       "protein_g": 8,
#       "fat_g": 76,
#       "micronutrients": {
#         "Manganese_mg": 4.1,
#         "Fiber_g": 8,
#         "Magnesium_mg": 130
#       }
#     },
#     {
#       "name": "Flaxseeds",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 534,
#       "carbs_g": 29,
#       "protein_g": 18,
#       "fat_g": 42,
#       "micronutrients": {
#         "Omega3_g": 2.3,
#         "Fiber_g": 27,
#         "Manganese_mg": 1.0
#       }
#     },
#     {
#       "name": "Chia seeds",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 486,
#       "carbs_g": 42,
#       "protein_g": 16,
#       "fat_g": 31,
#       "micronutrients": {
#         "Omega3_g": 2.5,
#         "Fiber_g": 34,
#         "Calcium_mg": 255
#       }
#     },
#     {
#       "name": "Hemp seeds",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 553,
#       "carbs_g": 9,
#       "protein_g": 32,
#       "fat_g": 48,
#       "micronutrients": {
#         "Omega3_mg": 1000,
#         "Magnesium_mg": 410,
#         "Zinc_mg": 5
#       }
#     },
#     {
#       "name": "Sunflower seeds",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 584,
#       "carbs_g": 20,
#       "protein_g": 20,
#       "fat_g": 50,
#       "micronutrients": {
#         "Vitamin_E_mg": 35,
#         "Magnesium_mg": 325
#       }
#     },
#     {
#       "name": "Sesame seeds",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 573,
#       "carbs_g": 23,
#       "protein_g": 17,
#       "fat_g": 50,
#       "micronutrients": {
#         "Calcium_mg": 975,
#         "Iron_mg": 14.6,
#         "Magnesium_mg": 351
#       }
#     },
#     {
#       "name": "Salmon (canned, as fat source)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 208,
#       "carbs_g": 0,
#       "protein_g": 25,
#       "fat_g": 11,
#       "micronutrients": {
#         "Vitamin_D_mcg": 2.0,
#         "Vitamin_B12_mcg": 4.0,
#         "Selenium_mcg": 32,
#         "Omega3_g": 1.0
#       }
#     },
#     {
#       "name": "Sardines (in oil)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 208,
#       "carbs_g": 0,
#       "protein_g": 25,
#       "fat_g": 11,
#       "micronutrients": {
#         "Vitamin_D_mcg": 3.0,
#         "Vitamin_B12_mcg": 8.0,
#         "Calcium_mg": 325,
#         "Selenium_mcg": 40
#       }
#     },
#     {
#       "name": "Tuna (canned in olive oil, optional)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 198,
#       "carbs_g": 0,
#       "protein_g": 22,
#       "fat_g": 12,
#       "micronutrients": {
#         "Vitamin_B12_mcg": 4.0,
#         "Selenium_mcg": 68,
#         "Potassium_mg": 300
#       }
#     },
#     {
#       "name": "Olives (extra-virgin, whole)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 145,
#       "carbs_g": 3,
#       "protein_g": 1.0,
#       "fat_g": 15,
#       "micronutrients": {
#         "Vitamin_E_mg": 1.0,
#         "Calcium_mg": 52,
#         "Iron_mg": 0.3
#       }
#     },
#     {
#       "name": "Natural peanut butter",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 599,
#       "carbs_g": 20,
#       "protein_g": 25,
#       "fat_g": 50,
#       "micronutrients": {
#         "Magnesium_mg": 170,
#         "Vitamin_E_mg": 4.0,
#         "Potassium_mg": 600
#       }
#     },
#     {
#       "name": "Tahini (sesame paste)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 595,
#       "carbs_g": 10,
#       "protein_g": 17,
#       "fat_g": 53,
#       "micronutrients": {
#         "Calcium_mg": 170,
#         "Iron_mg": 5.0,
#         "Magnesium_mg": 60
#       }
#     },
#     {
#       "name": "Coconut oil",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 892,
#       "carbs_g": 0,
#       "protein_g": 0,
#       "fat_g": 100,
#       "micronutrients": {
#         "MCTs_g": 0,
#         "Vitamin_E_mg": 0.0
#       }
#     },
#     {
#       "name": "Dark chocolate (70-85% cacao)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 600,
#       "carbs_g": 46,
#       "protein_g": 7,
#       "fat_g": 43,
#       "micronutrients": {
#         "Magnesium_mg": 230,
#         "Iron_mg": 6.0,
#         "Potassium_mg": 350
#       }
#     }
#   ],
#   "Vegetables": [
#     {
#       "name": "Spinach",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 23,
#       "carbs_g": 3.6,
#       "protein_g": 2.9,
#       "fat_g": 0.4,
#       "micronutrients": {
#         "Vitamin_A_mcg": 9373,
#         "Vitamin_K_mcg": 483,
#         "Vitamin_C_mg": 9.7,
#         "Calcium_mg": 99,
#         "Iron_mg": 2.7,
#         "Magnesium_mg": 79
#       }
#     },
#     {
#       "name": "Kale",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 49,
#       "carbs_g": 9,
#       "protein_g": 4.3,
#       "fat_g": 0.9,
#       "micronutrients": {
#         "Vitamin_A_mcg": 7541,
#         "Vitamin_K_mcg": 817,
#         "Vitamin_C_mg": 120,
#         "Calcium_mg": 150,
#         "Iron_mg": 1.5,
#         "Magnesium_mg": 33
#       }
#     },
#     {
#       "name": "Swiss chard",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 19,
#       "carbs_g": 3.7,
#       "protein_g": 1.8,
#       "fat_g": 0.2,
#       "micronutrients": {
#         "Vitamin_A_mcg": 5583,
#         "Vitamin_K_mcg": 830,
#         "Vitamin_C_mg": 30,
#         "Calcium_mg": 197,
#         "Iron_mg": 1.8,
#         "Magnesium_mg": 81
#       }
#     },
#     {
#       "name": "Broccoli",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 34,
#       "carbs_g": 6.6,
#       "protein_g": 2.8,
#       "fat_g": 0.4,
#       "micronutrients": {
#         "Vitamin_C_mg": 89.2,
#         "Vitamin_K_mcg": 101,
#         "Calcium_mg": 47,
#         "Iron_mg": 0.7,
#         "Folate_mcg": 63
#       }
#     },
#     {
#       "name": "Brussels sprouts",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 43,
#       "carbs_g": 9,
#       "protein_g": 3.4,
#       "fat_g": 0.3,
#       "micronutrients": {
#         "Vitamin_K_mcg": 177,
#         "Vitamin_C_mg": 85,
#         "Folate_mcg": 61,
#         "Potassium_mg": 316
#       }
#     },
#     {
#       "name": "Cauliflower",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 25,
#       "carbs_g": 5,
#       "protein_g": 1.9,
#       "fat_g": 0.1,
#       "micronutrients": {
#         "Vitamin_C_mg": 46,
#         "Vitamin_K_mcg": 15,
#         "Folate_mcg": 57,
#         "Potassium_mg": 142
#       }
#     },
#     {
#       "name": "Cabbage",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 25,
#       "carbs_g": 6,
#       "protein_g": 1.3,
#       "fat_g": 0.1,
#       "micronutrients": {
#         "Vitamin_C_mg": 36.6,
#         "Vitamin_K_mcg": 76,
#         "Folate_mcg": 53,
#         "Potassium_mg": 170
#       }
#     },
#     {
#       "name": "Asparagus",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 20,
#       "carbs_g": 3.9,
#       "protein_g": 2.2,
#       "fat_g": 0.1,
#       "micronutrients": {
#         "Folate_mcg": 53,
#         "Vitamin_K_mcg": 41,
#         "Vitamin_A_mcg": 58,
#         "Potassium_mg": 202
#       }
#     },
#     {
#       "name": "Green peas",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 81,
#       "carbs_g": 14,
#       "protein_g": 5,
#       "fat_g": 0.4,
#       "micronutrients": {
#         "Fiber_g": 5.5,
#         "Vitamin_C_mg": 40,
#         "Vitamin_K_mcg": 24,
#         "Folate_mcg": 65,
#         "Iron_mg": 1.5
#       }
#     },
#     {
#       "name": "Carrots",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 41,
#       "carbs_g": 9.6,
#       "protein_g": 0.9,
#       "fat_g": 0.2,
#       "micronutrients": {
#         "Vitamin_A_mcg": 835,
#         "Vitamin_K_mcg": 13,
#         "Vitamin_C_mg": 5.9,
#         "Potassium_mg": 320
#       }
#     },
#     {
#       "name": "Red bell peppers",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 31,
#       "carbs_g": 6,
#       "protein_g": 1,
#       "fat_g": 0.3,
#       "micronutrients": {
#         "Vitamin_C_mg": 127,
#         "Vitamin_A_mcg": 3131,
#         "Folate_mcg": 46,
#         "Potassium_mg": 251
#       }
#     },
#     {
#       "name": "Tomatoes",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 18,
#       "carbs_g": 3.9,
#       "protein_g": 0.9,
#       "fat_g": 0.2,
#       "micronutrients": {
#         "Vitamin_C_mg": 13,
#         "Potassium_mg": 237,
#         "Folate_mcg": 15,
#         "Vitamin_A_mcg": 31
#       }
#     },
#     {
#       "name": "Mushrooms",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 22,
#       "carbs_g": 3.3,
#       "protein_g": 3.1,
#       "fat_g": 0.3,
#       "micronutrients": {
#         "Selenium_mcg": 9.0,
#         "Copper_mg": 0.2,
#         "Potassium_mg": 318
#       }
#     },
#     {
#       "name": "Green beans",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 31,
#       "carbs_g": 7,
#       "protein_g": 1.8,
#       "fat_g": 0.1,
#       "micronutrients": {
#         "Fiber_g": 3.4,
#         "Vitamin_C_mg": 12,
#         "Vitamin_K_mcg": 14,
#         "Manganese_mg": 0.2
#       }
#     },
#     {
#       "name": "Beets",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 43,
#       "carbs_g": 9.6,
#       "protein_g": 1.6,
#       "fat_g": 0.2,
#       "micronutrients": {
#         "Folate_mcg": 109,
#         "Manganese_mg": 0.2,
#         "Potassium_mg": 308
#       }
#     },
#     {
#       "name": "Okra",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 33,
#       "carbs_g": 7.4,
#       "protein_g": 2.0,
#       "fat_g": 0.2,
#       "micronutrients": {
#         "Vitamin_C_mg": 23,
#         "Vitamin_K_mcg": 31,
#         "Magnesium_mg": 57
#       }
#     },
#     {
#       "name": "Zucchini",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 17,
#       "carbs_g": 3.1,
#       "protein_g": 1.2,
#       "fat_g": 0.3,
#       "micronutrients": {
#         "Vitamin_A_mcg": 200,
#         "Vitamin_C_mg": 17,
#         "Potassium_mg": 256
#       }
#     },
#     {
#       "name": "Eggplant",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 25,
#       "carbs_g": 6,
#       "protein_g": 1.0,
#       "fat_g": 0.2,
#       "micronutrients": {
#         "Fiber_g": 3.0,
#         "Manganese_mg": 0.2,
#         "Potassium_mg": 229
#       }
#     },
#     {
#       "name": "Romaine lettuce",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 17,
#       "carbs_g": 3.3,
#       "protein_g": 1.2,
#       "fat_g": 0.3,
#       "micronutrients": {
#         "Vitamin_A_mcg": 440,
#         "Vitamin_K_mcg": 24,
#         "Folate_mcg": 136,
#         "Potassium_mg": 141
#       }
#     },
#     {
#       "name": "Radishes",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 16,
#       "carbs_g": 3.4,
#       "protein_g": 0.7,
#       "fat_g": 0.1,
#       "micronutrients": {
#         "Vitamin_C_mg": 8.4,
#         "Potassium_mg": 233,
#         "Folate_mcg": 25
#       }
#     },
#     {
#       "name": "Cabbage (green)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 25,
#       "carbs_g": 5.8,
#       "protein_g": 1.3,
#       "fat_g": 0.1,
#       "micronutrients": {
#         "Vitamin_C_mg": 36.6,
#         "Vitamin_K_mcg": 76,
#         "Folate_mcg": 53,
#         "Potassium_mg": 170
#       }
#     }
#   ],
#   "Fruits": [
#     {
#       "name": "Blueberries",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 57,
#       "carbs_g": 14,
#       "protein_g": 0.7,
#       "fat_g": 0.3,
#       "micronutrients": {
#         "Vitamin_C_mg": 9.7,
#         "Vitamin_K_mcg": 19,
#         "Potassium_mg": 77,
#         "Manganese_mg": 0.5
#       }
#     },
#     {
#       "name": "Apple",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 52,
#       "carbs_g": 14,
#       "protein_g": 0.3,
#       "fat_g": 0.2,
#       "micronutrients": {
#         "Fiber_g": 2.4,
#         "Vitamin_C_mg": 4.6,
#         "Potassium_mg": 107
#       }
#     },
#     {
#       "name": "Oranges",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 47,
#       "carbs_g": 12,
#       "protein_g": 0.9,
#       "fat_g": 0.1,
#       "micronutrients": {
#         "Vitamin_C_mg": 53.2,
#         "Folate_mcg": 30,
#         "Potassium_mg": 181
#       }
#     },
#     {
#       "name": "Strawberries",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 32,
#       "carbs_g": 7.7,
#       "protein_g": 0.7,
#       "fat_g": 0.3,
#       "micronutrients": {
#         "Vitamin_C_mg": 58.8,
#         "Manganese_mg": 0.4,
#         "Fiber_g": 2
#       }
#     },
#     {
#       "name": "Banana",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 89,
#       "carbs_g": 23,
#       "protein_g": 1.1,
#       "fat_g": 0.3,
#       "micronutrients": {
#         "Potassium_mg": 358,
#         "Vitamin_B6_mg": 0.4,
#         "Vitamin_C_mg": 8.7
#       }
#     },
#     {
#       "name": "Pear",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 57,
#       "carbs_g": 15,
#       "protein_g": 0.4,
#       "fat_g": 0.1,
#       "micronutrients": {
#         "Fiber_g": 3.1,
#         "Vitamin_C_mg": 4.3,
#         "Potassium_mg": 121
#       }
#     },
#     {
#       "name": "Grape",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 69,
#       "carbs_g": 18,
#       "protein_g": 0.7,
#       "fat_g": 0.2,
#       "micronutrients": {
#         "Vitamin_C_mg": 10.8,
#         "Vitamin_K_mcg": 15,
#         "Potassium_mg": 191
#       }
#     },
#     {
#       "name": "Cherry",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 50,
#       "carbs_g": 12,
#       "protein_g": 1,
#       "fat_g": 0.3,
#       "micronutrients": {
#         "Vitamin_C_mg": 7.0,
#         "Potassium_mg": 222
#       }
#     },
#     {
#       "name": "Mango",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 60,
#       "carbs_g": 15,
#       "protein_g": 0.8,
#       "fat_g": 0.4,
#       "micronutrients": {
#         "Vitamin_C_mg": 36.4,
#         "Vitamin_A_mcg": 108,
#         "Folate_mcg": 43
#       }
#     },
#     {
#       "name": "Pineapple",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 50,
#       "carbs_g": 13,
#       "protein_g": 0.5,
#       "fat_g": 0.1,
#       "micronutrients": {
#         "Vitamin_C_mg": 47.8,
#         "Manganese_mg": 0.9
#       }
#     },
#     {
#       "name": "Kiwi",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 61,
#       "carbs_g": 15,
#       "protein_g": 1.1,
#       "fat_g": 0.5,
#       "micronutrients": {
#         "Vitamin_C_mg": 92.7,
#         "Vitamin_K_mcg": 40,
#         "Potassium_mg": 312
#       }
#     },
#     {
#       "name": "Pomegranate",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 83,
#       "carbs_g": 19,
#       "protein_g": 1.7,
#       "fat_g": 1.2,
#       "micronutrients": {
#         "Vitamin_C_mg": 6.0,
#         "Vitamin_K_mcg": 16,
#         "Potassium_mg": 236
#       }
#     },
#     {
#       "name": "Papaya",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 43,
#       "carbs_g": 11,
#       "protein_g": 0.5,
#       "fat_g": 0.1,
#       "micronutrients": {
#         "Vitamin_C_mg": 60.9,
#         "Vitamin_A_mcg": 950,
#         "Fiber_g": 1.7
#       }
#     },
#     {
#       "name": "Watermelon",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 30,
#       "carbs_g": 8,
#       "protein_g": 0.6,
#       "fat_g": 0.2,
#       "micronutrients": {
#         "Vitamin_C_mg": 8.1,
#         "Vitamin_A_mcg": 569,
#         "Potassium_mg": 112
#       }
#     },
#     {
#       "name": "Raspberries",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 52,
#       "carbs_g": 12,
#       "protein_g": 1.2,
#       "fat_g": 0.7,
#       "micronutrients": {
#         "Fiber_g": 6.5,
#         "Vitamin_C_mg": 26.2,
#         "Manganese_mg": 0.7
#       }
#     },
#     {
#       "name": "Blackberries",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 43,
#       "carbs_g": 10,
#       "protein_g": 1.4,
#       "fat_g": 0.5,
#       "micronutrients": {
#         "Fiber_g": 5.3,
#         "Vitamin_C_mg": 21,
#         "Vitamin_K_mcg": 34
#       }
#     },
#     {
#       "name": "Peach",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 39,
#       "carbs_g": 10,
#       "protein_g": 0.9,
#       "fat_g": 0.3,
#       "micronutrients": {
#         "Vitamin_C_mg": 6.6,
#         "Vitamin_A_mcg": 326,
#         "Potassium_mg": 190
#       }
#     },
#     {
#       "name": "Apricot",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 48,
#       "carbs_g": 11,
#       "protein_g": 1.4,
#       "fat_g": 0.4,
#       "micronutrients": {
#         "Vitamin_A_mcg": 192,
#         "Vitamin_C_mg": 8.0,
#         "Potassium_mg": 259
#       }
#     },
#     {
#       "name": "Cranberries",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 46,
#       "carbs_g": 12,
#       "protein_g": 0.4,
#       "fat_g": 0.1,
#       "micronutrients": {
#         "Vitamin_C_mg": 1.0,
#         "Manganese_mg": 0.1,
#         "Fiber_g": 2.0
#       }
#     },
#     {
#       "name": "Grapefruit",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 52,
#       "carbs_g": 13,
#       "protein_g": 0.8,
#       "fat_g": 0.1,
#       "micronutrients": {
#         "Vitamin_C_mg": 31.2,
#         "Potassium_mg": 135,
#         "Vitamin_A_mcg": 142
#       }
#     },
#     {
#       "name": "Fig (fresh)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 74,
#       "carbs_g": 19,
#       "protein_g": 0.8,
#       "fat_g": 0.9,
#       "micronutrients": {
#         "Calcium_mg": 35,
#         "Iron_mg": 0.4,
#         "Magnesium_mg": 15
#       }
#     },
#     {
#       "name": "Date (fresh, small)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 282,
#       "carbs_g": 75,
#       "protein_g": 2.5,
#       "fat_g": 0.4,
#       "micronutrients": {
#         "Fiber_g": 8,
#         "Potassium_mg": 624,
#         "Magnesium_mg": 54
#       }
#     },
#     {
#       "name": "Grapes (red or green)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 69,
#       "carbs_g": 18,
#       "protein_g": 0.7,
#       "fat_g": 0.2,
#       "micronutrients": {
#         "Vitamin_C_mg": 10,
#         "Potassium_mg": 191
#       }
#     },
#     {
#       "name": "Pomegranate seeds",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 83,
#       "carbs_g": 19,
#       "protein_g": 1.7,
#       "fat_g": 0.4,
#       "micronutrients": {
#         "Vitamin_C_mg": 10,
#         "Vitamin K_mcg": 0.1,
#         "Potassium_mg": 236
#       }
#     }
#   ],
#   "Snacks": [
#     {
#       "name": "Greek yogurt, plain nonfat",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 59,
#       "carbs_g": 3.6,
#       "protein_g": 10,
#       "fat_g": 0.4,
#       "micronutrients": {
#         "Calcium_mg": 110,
#         "Vitamin_B12_mcg": 0.9,
#         "Potassium_mg": 141
#       }
#     },
#     {
#       "name": "Cottage cheese, low-fat",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 98,
#       "carbs_g": 3.4,
#       "protein_g": 11,
#       "fat_g": 4.3,
#       "micronutrients": {
#         "Calcium_mg": 83,
#         "Phosphorus_mg": 170,
#         "Selenium_mcg": 10
#       }
#     },
#     {
#       "name": "Edamame (steamed)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 122,
#       "carbs_g": 9,
#       "protein_g": 11,
#       "fat_g": 5,
#       "micronutrients": {
#         "Fiber_g": 4,
#         "Iron_mg": 2.0,
#         "Magnesium_mg": 64
#       }
#     },
#     {
#       "name": "Hummus with carrot sticks",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 166,
#       "carbs_g": 14,
#       "protein_g": 5,
#       "fat_g": 9,
#       "micronutrients": {
#         "Folate_mcg": 60,
#         "Iron_mg": 2.0,
#         "Magnesium_mg": 70
#       }
#     },
#     {
#       "name": "Roasted chickpeas",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 164,
#       "carbs_g": 27,
#       "protein_g": 8.9,
#       "fat_g": 2.6,
#       "micronutrients": {
#         "Fiber_g": 7.6,
#         "Iron_mg": 2.9,
#         "Magnesium_mg": 65
#       }
#     },
#     {
#       "name": "Mixed nuts (unsalted)",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 607,
#       "carbs_g": 20,
#       "protein_g": 20,
#       "fat_g": 54,
#       "micronutrients": {
#         "Magnesium_mg": 210,
#         "Vitamin_E_mg": 7,
#         "Calcium_mg": 70
#       }
#     },
#     {
#       "name": "Apple slices with peanut butter",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 210,
#       "carbs_g": 28,
#       "protein_g": 6,
#       "fat_g": 9,
#       "micronutrients": {
#         "Fiber_g": 4,
#         "Potassium_mg": 260,
#         "Vitamin_E_mg": 0.5
#       }
#     },
#     {
#       "name": "String cheese (part-skim mozzarella)",
#       "serving_size_g": 28,
#       "serving_size_oz": 1,
#       "calories_kcal": 80,
#       "carbs_g": 1,
#       "protein_g": 6,
#       "fat_g": 6,
#       "micronutrients": {
#         "Calcium_mg": 200,
#         "Protein_g": 6
#       }
#     },
#     {
#       "name": "Hard-boiled eggs",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 143,
#       "carbs_g": 1.1,
#       "protein_g": 13,
#       "fat_g": 9.5,
#       "micronutrients": {
#         "Vitamin_B12_mcg": 1.1,
#         "Choline_mg": 125,
#         "Selenium_mcg": 15
#       }
#     },
#     {
#       "name": "Turkey jerky, low-sodium",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 116,
#       "carbs_g": 6,
#       "protein_g": 14,
#       "fat_g": 4,
#       "micronutrients": {
#         "Zinc_mg": 1.0,
#         "Selenium_mcg": 10
#       }
#     },
#     {
#       "name": "Tuna salad on cucumber rounds",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 120,
#       "carbs_g": 6,
#       "protein_g": 15,
#       "fat_g": 5,
#       "micronutrients": {
#         "Vitamin_B12_mcg": 2.0,
#         "Selenium_mcg": 60
#       }
#     },
#     {
#       "name": "Dark chocolate 70-85%",
#       "serving_size_g": 30,
#       "serving_size_oz": 1.0,
#       "calories_kcal": 170,
#       "carbs_g": 12,
#       "protein_g": 2,
#       "fat_g": 12,
#       "micronutrients": {
#         "Magnesium_mg": 65,
#         "Iron_mg": 1.9
#       }
#     },
#     {
#       "name": "Baby carrots with guacamole",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 150,
#       "carbs_g": 14,
#       "protein_g": 2,
#       "fat_g": 9,
#       "micronutrients": {
#         "Vitamin_A_mcg": 4000,
#         "Vitamin_E_mg": 2,
#         "Potassium_mg": 420
#       }
#     },
#     {
#       "name": "Seaweed snacks",
#       "serving_size_g": 8,
#       "serving_size_oz": 0.28,
#       "calories_kcal": 40,
#       "carbs_g": 6,
#       "protein_g": 1,
#       "fat_g": 1,
#       "micronutrients": {
#         "Iodine_mcg": 60,
#         "Calcium_mg": 60
#       }
#     },
#     {
#       "name": "Rice cakes with almond butter",
#       "serving_size_g": 40,
#       "serving_size_oz": 1.4,
#       "calories_kcal": 150,
#       "carbs_g": 18,
#       "protein_g": 4,
#       "fat_g": 7,
#       "micronutrients": {
#         "Magnesium_mg": 60,
#         "Calcium_mg": 50
#       }
#     },
#     {
#       "name": "Whole-grain crackers with cheese",
#       "serving_size_g": 28,
#       "serving_size_oz": 1,
#       "calories_kcal": 120,
#       "carbs_g": 16,
#       "protein_g": 4,
#       "fat_g": 4,
#       "micronutrients": {
#         "Calcium_mg": 60,
#         "Iron_mg": 0.6
#       }
#     },
#     {
#       "name": "Tzatziki with cucumber",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 90,
#       "carbs_g": 6,
#       "protein_g": 5,
#       "fat_g": 6,
#       "micronutrients": {
#         "Calcium_mg": 70,
#         "Protein_g": 5
#       }
#     },
#     {
#       "name": "Edamame hummus",
#       "serving_size_g": 100,
#       "serving_size_oz": 3.5,
#       "calories_kcal": 171,
#       "carbs_g": 8,
#       "protein_g": 7,
#       "fat_g": 12,
#       "micronutrients": {
#         "Fiber_g": 3.0,
#         "Iron_mg": 1.8,
#         "Magnesium_mg": 60
#       }
#     },
#     {
#       "name": "Boiled soy nuts",
#       "serving_size_g": 28,
#       "serving_size_oz": 1,
#       "calories_kcal": 150,
#       "carbs_g": 6,
#       "protein_g": 13,
#       "fat_g": 9,
#       "micronutrients": {
#         "Iron_mg": 2.0,
#         "Calcium_mg": 70
#       }
#     },
#     {
#       "name": "Dried apricots with almonds",
#       "serving_size_g": 40,
#       "serving_size_oz": 1.4,
#       "calories_kcal": 150,
#       "carbs_g": 30,
#       "protein_g": 3,
#       "fat_g": 4,
#       "micronutrients": {
#         "Fiber_g": 3.0,
#         "Potassium_mg": 300,
#         "Calcium_mg": 20
#       }
#     }
#   ]
# }
