# %%
# Load environment variables in a file called .env

import os

from dotenv import load_dotenv


load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

# %%
import openai

system_prompt = """
Your are a nutritionist with many years of experience.
You provide a detailed list of nutritious foods.
"""
user_prompt = """
Create a list of nutritious foods for the following categories.  The rows and colums should be formatted as a markdown table.
Please list serving sizes in grams and ounces, caloric content, carbohydrates in grams, protein in grams, and fat in grams.
For each category provide the top 20 healthiest options.
- Lean Proteins (meats, fish, poultry)
- Complex Carbohydrates
- Healthy Fats
- Vegetables
- Fruits
- Snacks
"""

def messages():
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ]

def create_healthiest_foods_list():
    response = openai.chat.completions.create(model="gpt-4.1-nano", messages=messages())
    return response.choices[0].message.content

print(create_healthiest_foods_list())
# Out:
# Certainly! Below is a comprehensive markdown table listing the top 20 healthiest options for each category, including serving sizes, caloric content, carbohydrates, protein, and fats.
#
# ---
#
# ### 1. Lean Proteins (Meats, Fish, Plant-based)
#
# | Food                     | Serving Size (g / oz) | Calories | Carbohydrates (g) | Protein (g) | Fats (g) |
# |--------------------------|----------------------|----------|------------------|-------------|----------|
# | Skinless Chicken Breast  | 100g / 3.5oz        | 165      | 0g               | 31g         | 3.6g     |
# | Turkey Breast            | 100g / 3.5oz        | 135      | 0g               | 29g         | 1.5g     |
# | Salmon (wild)            | 100g / 3.5oz        | 208      | 0g               | 20g         | 13g      |
# | Cod                      | 100g / 3.5oz        | 105      | 0g               | 23g         | 1g       |
# | Tuna (canned in water)   | 100g / 3.5oz        | 132      | 0g               | 28g         | 0.5g     |
# | Egg Whites               | 100g / 3.5oz        | 52       | 0.7g             | 11g         | 0g       |
# | Lentils (cooked)         | 100g / 3.5oz        | 116      | 20g              | 9g          | 0.4g     |
# | Chickpeas (cooked)       | 100g / 3.5oz        | 164      | 27g              | 9g          | 2.6g     |
# | Tofu (firm)              | 100g / 3.5oz        | 144      | 3g               | 15g         | 8g       |
# | Tempeh                   | 100g / 3.5oz        | 195      | 9g               | 20g         | 8g       |
# | Shrimp                   | 100g / 3.5oz        | 85       | 1.5g             | 20g         | 0.3g     |
# | Quinoa (cooked)          | 100g / 3.5oz        | 120      | 21g              | 4g          | 2g       |
# | Edamame (cooked)         | 100g / 3.5oz        | 122      | 10g              | 11g         | 5g       |
# | Seitan                   | 100g / 3.5oz        | 120      | 4g               | 21g         | 2g       |
# | Crab                     | 100g / 3.5oz        | 87       | 0g               | 19g         | 1g       |
# | Sardines (in water)      | 100g / 3.5oz        | 208      | 0g               | 25g         | 11g      |
# | Venison                  | 100g / 3.5oz        | 158      | 0g               | 30g         | 4g       |
# | Greek Yogurt (non-fat)   | 200g / 7oz          | 134      | 9g               | 23g         | 0g       |
# | Cottage Cheese (low-fat) | 100g / 3.5oz        | 98       | 3g               | 11g         | 4g       |
#
# ---
#
# ### 2. Complex Carbohydrates
#
# | Food                     | Serving Size (g / oz) | Calories | Carbohydrates (g) | Protein (g) | Fats (g) |
# |--------------------------|----------------------|----------|------------------|-------------|----------|
# | Quinoa (cooked)          | 100g / 3.5oz        | 120      | 21g              | 4g          | 2g       |
# | Brown Rice (cooked)      | 100g / 3.5oz        | 112      | 23g              | 2.5g        | 0.8g     |
# | Sweet Potatoes           | 100g / 3.5oz        | 86       | 20g              | 2g          | 0.1g     |
# | Oats (rolled)            | 100g / 3.5oz        | 389      | 66g              | 17g         | 7g       |
# | Barley (pearled)         | 100g / 3.5oz        | 354      | 73g              | 12g         | 2g       |
# | Lentils (cooked)         | 100g / 3.5oz        | 116      | 20g              | 9g          | 0.4g     |
# | Chickpeas (cooked)       | 100g / 3.5oz        | 164      | 27g              | 9g          | 2.6g     |
# | Bulgur (cooked)          | 100g / 3.5oz        | 83       | 18g              | 3g          | 0.2g     |
# | Millet (cooked)          | 100g / 3.5oz        | 119      | 23g              | 4g          | 1g       |
# | Black Beans (cooked)     | 100g / 3.5oz        | 132      | 23g              | 8g          | 0.5g     |
# | Kidney Beans (cooked)    | 100g / 3.5oz        | 127      | 22g              | 8g          | 0.5g     |
# | Spelt (cooked)           | 100g / 3.5oz        | 338      | 70g              | 14g         | 2g       |
# | Barley (pearled)         | 100g / 3.5oz        | 354      | 73g              | 12g         | 2g       |
# | Amaranth (cooked)        | 100g / 3.5oz        | 368      | 66g              | 14g         | 7g       |
# | Buckwheat (cooked)       | 100g / 3.5oz        | 92       | 20g              | 3g          | 0.6g     |
# | Freekeh (cooked)         | 100g / 3.5oz        | 120      | 22g              | 4g          | 0.4g     |
# | Quinoa (uncooked)        | 100g / 3.5oz        | 368      | 64g              | 14g         | 6g       |
# | Kasha (cooked)           | 100g / 3.5oz        | 100      | 19g              | 3g          | 0.5g     |
# | Carrots (raw)            | 100g / 3.5oz        | 41       | 10g              | 0.9g        | 0.2g     |
# | Beets (cooked)           | 100g / 3.5oz        | 44       | 10g              | 1.6g        | 0.2g     |
#
# ---
#
# ### 3. Healthy Fats
#
# | Food                     | Serving Size (g / oz) | Calories | Carbohydrates (g) | Protein (g) | Fats (g) |
# |--------------------------|----------------------|----------|------------------|-------------|----------|
# | Avocado                  | 100g / 3.5oz        | 160      | 9g               | 2g          | 15g      |
# | Extra Virgin Olive Oil   | 13.5g / 0.5oz       | 119      | 0g               | 0g          | 14g      |
# | Chia Seeds               | 28g / 1oz            | 138      | 12g              | 5g          | 9g       |
# | Flaxseeds (ground)       | 28g / 1oz            | 150      | 8g               | 5g          | 12g      |
# | Walnuts                  | 28g / 1oz            | 185      | 4g               | 4g          | 18g      |
# | Almonds                  | 28g / 1oz            | 161      | 6g               | 6g          | 14g      |
# | Hemp Seeds               | 30g / 1oz            | 166      | 2g               | 9g          | 14g      |
# | Pumpkin Seeds (shelled)  | 28g / 1oz            | 151      | 5g               | 7g          | 13g      |
# | Sesame Seeds             | 28g / 1oz            | 160      | 6g               | 5g          | 14g      |
# | Macadamia Nuts           | 28g / 1oz            | 204      | 4g               | 2g          | 21g      |
# | Peanuts (dry roasted)    | 28g / 1oz            | 166      | 6g               | 7g          | 14g      |
# | Coconut Oil              | 13.5g / 0.5oz       | 117      | 0g               | 0g          | 14g      |
# | Tahini (Sesame Paste)     | 30g / 1oz            | 178      | 5g               | 5g          | 16g      |
# | Almond Butter            | 32g / 1.1oz          | 190      | 6g               | 4g          | 16g      |
# | Cashew Nuts              | 28g / 1oz            | 157      | 9g               | 5g          | 12g      |
# | Pistachios               | 28g / 1oz            | 159      | 8g               | 6g          | 13g      |
# | Hemp Oil                 | 1 tbsp / 14g        | 120      | 0g               | 0g          | 14g      |
# | Walnut Oil               | 1 tbsp / 14g        | 119      | 0g               | 0g          | 14g      |
# | Brazil Nuts              | 28g / 1oz            | 187      | 3g               | 4g          | 19g      |
#
# ---
#
# ### 4. Vegetables
#
# | Food                     | Serving Size (g / oz) | Calories | Carbohydrates (g) | Protein (g) | Fats (g) |
# |--------------------------|----------------------|----------|------------------|-------------|----------|
# | Spinach (raw)            | 30g / 1oz            | 7        | 1g               | 1g          | 0g       |
# | Kale (raw)               | 30g / 1oz            | 33       | 6g               | 2g          | 0.5g     |
# | Broccoli (raw)           | 91g / 3oz            | 55       | 11g              | 4g          | 0.5g     |
# | Brussels Sprouts         | 88g / 3oz            | 38       | 8g               | 3g          | 0.3g     |
# | Carrots (raw)            | 61g / 2oz            | 25       | 6g               | 0.5g        | 0g       |
# | Bell Peppers (raw)       | 119g / 4oz           | 40       | 9g               | 1g          | 0g       |
# | Asparagus                | 134g / 4.7oz         | 27       | 5g               | 3g          | 0.2g     |
# | Cauliflower (raw)        | 107g / 3.7oz         | 25       | 5g               | 2g          | 0g       |
# | Zucchini (raw)           | 124g / 4.4oz         | 20       | 3g               | 1g          | 0g       |
# | Mushrooms (raw)          | 86g / 3oz            | 15       | 2g               | 2g          | 0.2g     |
# | Sweet Corn (cooked)      | 166g / 5.8oz         | 185      | 41g              | 5g          | 2g       |
# | Eggplant (raw)           | 99g / 3.5oz          | 25       | 6g               | 1g          | 0.2g     |
# | Cabbage (raw)            | 89g / 3oz            | 22       | 5g               | 1g          | 0g       |
# | Peas (green, cooked)     | 160g / 5.8oz         | 134      | 25g              | 9g          | 0.5g     |
# | Pumpkin (raw)            | 116g / 4oz           | 30       | 7g               | 1g          | 0.2g     |
# | Leeks                    | 89g / 3oz            | 54       | 13g              | 1g          | 0.2g     |
# | Swiss Chard              | 36g / 1.3oz          | 19       | 3g               | 1g          | 0g       |
# | Radishes (raw)           | 70g / 2.5oz          | 16       | 3g               | 1g          | 0g       |
# | Celery (raw)             | 40g / 1.4oz          | 6        | 1g               | 0.3g        | 0g       |
# | Green Beans (raw)        | 125g / 4.4oz         | 31       | 7g               | 2g          | 0.2g     |
#
# ---
#
# ### 5. Fruits
#
# | Food                     | Serving Size (g / oz) | Calories | Carbohydrates (g) | Protein (g) | Fats (g) |
# |--------------------------|----------------------|----------|------------------|-------------|----------|
# | Blueberries              | 148g / 5.2oz         | 84       | 21g              | 1g          | 0.5g     |
# | Strawberries             | 152g / 5.4oz         | 49       | 12g              | 1g          | 0.5g     |
# | Apple (with skin)        | 182g / 6.4oz         | 95       | 25g              | 0.5g        | 0.3g     |
# | Banana                   | 118g / 4.2oz         | 105      | 27g              | 1g          | 0.3g     |
# | Kiwi                     | 91g / 3.2oz          | 61       | 14g              | 1g          | 0.5g     |
# | Mango                    | 200g / 7oz           | 135      | 35g              | 1.4g        | 0.6g     |
# | Papaya                   | 165g / 5.8oz         | 62       | 16g              | 2g          | 0.2g     |
# | Pomegranate Seeds        | 174g / 6.1oz         | 83       | 19g              | 2g          | 1.2g     |
# | Grapefruit               | 230g / 8.1oz         | 52       | 13g              | 1g          | 0.2g     |
# | Watermelon               | 152g / 5.4oz         | 46       | 12g              | 0.9g        | 0.2g     |
# | Raspberries              | 123g / 4.3oz         | 64       | 15g              | 1.5g        | 0.8g     |
# | Blackberries             | 144g / 5oz           | 62       | 14g              | 2g          | 0.5g     |
# | Cherries                 | 138g / 4.9oz         | 87       | 22g              | 1.6g        | 0.3g     |
# | Peach                    | 150g / 5.3oz         | 68       | 17g              | 1g          | 0.4g     |
# | Pear                     | 178g / 6.3oz         | 102      | 27g              | 0.6g        | 0.2g     |
# | Apricots (fresh)         | 35g / 1.2oz          | 17       | 4g               | 0.5g        | 0.1g     |
# | Plums                    | 66g / 2.3oz          | 30       | 8g               | 0.5g        | 0g       |
# | Nectarines               | 150g / 5.3oz         | 62       | 15g              | 1g          | 0.2g     |
# | Melons (cantaloupe)      | 177g / 6.2oz         | 60       | 14g              | 1.5g        | 0g       |
#
# ---
#
# ### 6. Snacks (Nut/Seed-based, Healthy Options)
#
# | Food                     | Serving Size (g / oz) | Calories | Carbohydrates (g) | Protein (g) | Fats (g) |
# |--------------------------|----------------------|----------|------------------|-------------|----------|
# | Almonds                  | 28g / 1oz            | 161      | 6g               | 6g          | 14g      |
# | Walnuts                  | 28g / 1oz            | 185      | 4g               | 4g          | 18g      |
# | Cashews                  | 28g / 1oz            | 157      | 9g               | 5g          | 12g      |
# | Pistachios               | 28g / 1oz            | 159      | 8g               | 6g          | 13g      |
# | Pumpkin Seeds            | 28g / 1oz            | 151      | 5g               | 7g          | 13g      |
# | Sunflower Seeds          | 28g / 1oz            | 164      | 6g               | 6g          | 14g      |
# | Chia Seeds               | 28g / 1oz            | 138      | 12g              | 5g          | 9g       |
# | Flaxseeds (ground)       | 28g / 1oz            | 150      | 8g               | 5g          | 12g      |
# | Dark Chocolate (70-85%)  | 40g / 1.4oz          | 234      | 13g              | 3g          | 17g      |
# | Greek Yogurt (plain, non-fat)| 200g / 7oz      | 134      | 9g               | 23g         | 0g       |
# | Hummus                   | 100g / 3.5oz         | 166      | 14g              | 8g          | 10g      |
# | Roasted Edamame          | 100g / 3.5oz         | 121      | 10g              | 11g         | 5g       |
# | Baked Kale Chips        | 30g / 1oz            | 150      | 10g              | 3g          | 10g      |
# | Seaweed Snacks         | 5g / 0.2oz            | 30       | 5g               | 1g          | 1g       |
# | Unsweetened Coconut Flakes | 28g / 1oz        | 187      | 7g               | 2g          | 18g      |
#
# ---
#
# This list combines nutrient-dense options across all categories for diverse, health-boosting diets. For personalized recommendations, portions can be adjusted based on specific dietary needs, fitness goals, or health conditions.
#
# Would you like a downloadable format or specific focus on certain nutrients?
