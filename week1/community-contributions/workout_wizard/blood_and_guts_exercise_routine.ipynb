# %%
# Load environment variables in a file called .env

import os

from dotenv import load_dotenv


load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
import openai

system_prompt = """
Your are a personal trainer who has been friends with Dorian Yates for many years.
You provide a detailed 4-day training split for a week, inspired by Dorian Yates' training philosophy.
"""
user_prompt = """
Create a 4-day workout routine based on Dorian Yates' training principles.
Include exercises, sets, reps, and rest periods for each day.   
Focus on high intensity and proper form.
Provide tips for recovery and nutrition to complement the training.
"""

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt+ "use this website: " + website}
    ]

website = "https://www.ironstudiogym.co.za/dorian-yates-4-day-split-routine.html"

def fetch_blood_and_guts_contents(website):
    response = openai.chat.completions.create(model="gpt-4.1-nano", messages=messages_for(website))
    return response.choices[0].message.content

print(fetch_blood_and_guts_contents(website))
# Out:
# Certainly! Drawing inspiration from Dorian Yates' legendary training philosophy, here's a 4-day high-intensity workout plan that emphasizes maximum effort, proper form, and efficient recovery. This routine mirrors Yates’ approach of low volume but extremely intense sessions, ensuring each set is performed with utmost focus and effort.
#
# ---
#
# ### **Dorian Yates-Inspired 4-Day Split Routine**
#
# ---
#
# ## **Day 1: Back & Biceps**
#
# **1. Barbell Deadlifts**
# - Sets: 2
# - Reps: 8-10
# - Rest: 2-3 minutes
# - Tips: Focus on a controlled eccentric, keep your back flat, and drive through your heels.
#
# **2. Bent-Over Barbell Rows**
# - Sets: 1
# - Reps: 8-10
# - Rest: 2 minutes
# - Tips: Maintain a slight bend at the hips, squeeze your back at the top.
#
# **3. Wide-Grip Pulldowns** (or Pull-Ups if capable)
# - Sets: 1
# - Reps: 8-10
# - Rest: 2 minutes
# - Tips: Focus on pulling your elbows down, squeeze lats at the bottom.
#
# **4. Seated Cable Rows**
# - Sets: 1
# ...
