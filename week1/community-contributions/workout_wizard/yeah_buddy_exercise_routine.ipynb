# %%
# Load environment variables in a file called .env

import os

from dotenv import load_dotenv


load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

# %%
import openai

system_prompt = """
Your are a personal trainer who used to train with Ronnie Coleman.
You provide a detailed 6-day training split for a week, inspired by Ronnie Coleman
 training philosophy.
"""
user_prompt = """
Create a 6-day workout routine based on Ronnie Coleman's training principles.
Include exercises, sets, reps, and rest periods for each day.   
Focus on high intensity and proper form.
Provide tips for recovery and nutrition to complement the training.
Properly format rows and columns so that everything lines up and separate each day's routine.
"""
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt+ "use this website: " + website}
    ]

website = "https://muscleandbrawn.com/workouts/training-ronnie-coleman-workout-rouine/"

def fetch_exercise_routine(website):
    response = openai.chat.completions.create(model="gpt-4.1-nano", messages=messages_for(website))
    return response.choices[0].message.content

print(fetch_exercise_routine(website))
# Out:
# Certainly! Drawing inspiration from Ronnie Coleman's training philosophy, which emphasizes high volume, intensity, and proper form, here's a 6-day split based on his principles. I'll incorporate exercises, sets, reps, rest periods, and tips for recovery and nutrition.
#
# ---
#
# ### **Day 1: Chest & Biceps**
#
# | Exercise                     | Sets | Reps  | Rest | Tips                                              |
# |------------------------------|-------|--------|-------|---------------------------------------------------|
# | Barbell Bench Press          | 4     | 8-12   | 60-90 sec | Use controlled reps, focus on full range of motion. |
# | Incline Dumbbell Press       | 4     | 8-12   | 60-90 sec | Keep the core tight, avoid locking elbows.     |
# | Dumbbell Flyes               | 3     | 10-15  | 45-60 sec | Stretch at the bottom, squeeze at the top.    |
# | Barbell Curl                 | 4     | 8-12   | 60 sec     | Keep elbows close, avoid swinging.             |
# | Preacher Curl                | 3     | 10-12  | 45 sec     | Focus on squeezing biceps at the top.          |
# | Concentration Curl           | 3     | 12-15  | 45 sec     | Slow negatives for maximum overload.         |
#
# ---
#
# ### **Day 2: Back & Abs**
#
# | Exercise                      | Sets | Reps  | Rest | Tips                                              |
# |------------------------------|--------|--------|-------|---------------------------------------------------|
# | Deadlifts                     | 4      | 6-8    | 90 sec | Maintain proper form, engage the back thoroughly. |
# | Bent-Over Rows                | 4      | 8-12   | 60-90 sec | Keep back flat, pull toward your lower ribs.   |
# | Pull-Ups or Lat Pulldowns     | 4      | 8-12   | 60 sec  | Full stretch at the top, squeeze lats during pull. |
# | Seated Cable Rows             | 3      | 10-12  | 45-60 sec | Keep shoulder blades retracted.               |
# | Hanging Leg Raises            | 3      | 15-20  | 30-45 sec | Control the movement, avoid swinging.          |
# | Cable Ab Crunches             | 3      | 15-20  | 30 sec | Focus on contraction, breathe out on crunch. |
#
# ---
#
# ### **Day 3: Legs**
#
# | Exercise                     | Sets | Reps  | Rest | Tips                                              |
# |------------------------------|--------|--------|-------|---------------------------------------------------|
# | Squats                       | 4      | 8-12   | 90 sec | Deep squat, engage core, keep knees tracking toes. |
# | Leg Press                    | 4      | 10-15  | 60 sec | Do not lock out knees, control the descent.     |
# | Leg Curls (Seated or Lying)   | 4      | 10-15  | 45-60 sec | Squeeze during flexion, avoid using momentum. |
# | Standing Calf Raises          | 4      | 12-20  | 30 sec | Full stretch at the bottom, pause at the top.   |
# | Seated Calf Raises            | 4      | 15-20  | 30 sec | Slow negatives, stretch at the bottom.         |
#
# ---
#
# ### **Day 4: Shoulders & Traps**
#
# | Exercise                     | Sets | Reps  | Rest | Tips                                              |
# |------------------------------|--------|--------|-------|---------------------------------------------------|
# | Military Press               | 4      | 8-12   | 60-90 sec | Keep back straight, avoid arching.             |
# | Lateral Raises               | 4      | 10-15  | 45 sec  | Controlled reps, slight pause at the top.      |
# | Upright Rows                 | 3      | 8-12   | 45-60 sec | Pull to chest level, elbows high.             |
# | Dumbbell Shrugs              | 4      | 12-15  | 30 sec  | Squeeze traps at the top, slow controlled descent. |
#
# ---
#
# ### **Day 5: Arms (Triceps & Biceps Focus)**
#
# | Exercise                     | Sets | Reps  | Rest | Tips                                              |
# |------------------------------|--------|--------|-------|---------------------------------------------------|
# | Close-Grip Bench Press       | 4      | 8-12   | 60 sec | Keep elbows close, control the negative.       |
# | Overhead Dumbbell Triceps Extension | 3 | 10-12 | 45 sec | Full stretch at the bottom, control the movement. |
# | Dumbbell Curls               | 4      | 8-12   | 60 sec | Avoid swinging, focus on biceps contraction.  |
# | Hammer Curls                 | 3      | 10-12  | 45 sec | Keep wrists neutral, squeeze at the top.     |
# | Tricep Rope Pushdowns       | 3      | 12-15  | 45 sec | Focus on full extension and squeeze.          |
#
# ---
#
# ### **Day 6: Legs & Core (Optional for Volume/Recovery)**
#
# | Exercise                     | Sets | Reps  | Rest | Tips                                              |
# |------------------------------|--------|--------|-------|---------------------------------------------------|
# | Front Squats                 | 4      | 8-12   | 90 sec | Engage core, keep torso upright.                |
# | Lunges                       | 3      | 10-12 per leg | 60 sec | Step far, sink deep, control movement.       |
# | Stiff-Legged Deadlifts       | 4      | 8-12   | 60 sec | Stretch hamstrings, maintain back neutrality. |
# | Plank                        | 3      | 60 sec | 30 sec | Keep core tight, hips neutral.                 |
# | Russian Twists               | 3      | 20 (10 per side) | 30 sec | Twist fully, control movement.               |
#
# ---
#
# ### **Training Tips:**
# - **High Intensity:** Push yourself close to failure, especially on the last set.
# - **Proper Form:** Prioritize technique over weight to prevent injury.
# - **Progressive Overload:** Increase weights gradually as strength improves.
# - **Rest Periods:** Keep rest tight but enough to recover for maximum effort.
#
# ---
#
# ### **Recovery & Nutrition Tips:**
#
# | Aspect                  | Recommendations                                            |
# |-------------------------|--------------------------------------------------------------|
# | Sleep                   | Aim for 7-9 hours per night for optimal recovery.          |
# | Hydration               | Drink plenty of water throughout the day (at least 3-4 liters). |
# | Protein Intake          | Consume 1.2-2.0g of protein per kg of body weight daily. Include lean meats, eggs, dairy, and plant-based proteins. |
# | Carbohydrates           | Include complex carbs for sustained energy (brown rice, oats, sweet potatoes). |
# | Fats                    | Healthy fats from nuts, avocados, and fish support recovery. |
# | Supplements             | Consider whey protein, BCAAs, creatine, and multivitamins for support. |
# | Stretching & Mobility   | Dedicate time daily for stretching, foam rolling, and mobility work to prevent injury and enhance recovery. |
#
# ---
#
# *Remember: Consistency, proper form, and listening to your body are key. Inspired by Ronnie Coleman, push yourself hard, but always prioritize safety and recovery.*
