# %%
import os
import json
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI
import sys
sys.path.append('../../')
from scraper import fetch_website_contents
from scraper import fetch_website_links


GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"

load_dotenv(override=True)

google_api_key = os.getenv("GOOGLE_API_KEY")

if not google_api_key:
    print("No API key was found - please be sure to add your key to the .env file, and save the file! Or you can skip the next 2 cells if you don't want to use Gemini")
elif not google_api_key.startswith("AIz"):
    print("An API key was found, but it doesn't start AIz")
else:
    print("API key found and looks good so far!")

MODEL = "gemini-2.5-flash-lite"
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)
messages = [
    {"role": "system", "content": "You are a funny assistant"},
    {"role": "user", "content": "What is the shape of a square"}
]


response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=messages)
response.choices[0].message.content
# Out:
# API key found and looks good so far!
# 'Ah, the shape of a square! You\'re asking a question that\'s as fundamental as asking if a cat can nap. And the answer, my friend, is gloriously simple and oh-so-satisfying.\n\nA square is a shape that has:\n\n*   **Four equal sides:** Imagine a perfectly polite waiter holding four identical trays. No one gets more or less.\n*   **Four right angles:** These are the corners that are so perfectly straight, they\'d make a protractor blush with envy. Think of the corner of a book, or the way your toast might land on the floor (though hopefully not as often).\n\nSo, in short, a square is like the **ultimate rule-follower of shapes**. It\'s neat, it\'s tidy, and it never gets into arguments about who\'s longer or who\'s got a quirkier corner.\n\nIt\'s the **perfectionist of quadrilaterals**. If shapes had parents, the square would be the one they pointed to and said, "See? This is how you do it."\n\nAnd if you\'re feeling particularly adventurous, you could say it\'s like a **very organized pizza slice** (if you cut a round pizza into four perfectly equal wedges and then *magically* made them all straight-edged).\n\nSo there you have it! The shape of a square: a beautifully simple, incredibly dependable, and sometimes even a little bit smug, four-sided friend.'

# %%
system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

def summarize(url):
    website = fetch_website_contents(url)
    
    response = gemini.chat.completions.create(
        model = "gemini-2.5-flash-lite",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summary = summarize("https://beebuddy.in/")
display(Markdown(summary))
links = fetch_website_links("https://beebuddy.in/")
links
# Out:
# So, Edward Donner, a co-founder and CTO who apparently enjoys being an "amateur" at electronic music and has some *very* popular AI courses on Udemy. Who knew people actually paid to be lectured about LLMs? He's also thrown some AI models into a game of Connect Four, presumably to see who can write the most passive-aggressive chatbot. His "news" consists of resource announcements for his AI courses, because apparently, the world can't get enough of learning how to code with AI.

# %%
import google.generativeai as genai
# Configure your API key
genai.configure(api_key=google_api_key)
# Choose a Gemini model
gemini_native = genai.GenerativeModel("gemini-2.5-flash-lite")

text = "I love taking walks along the beach at sunset."

# Tokenize / encode
tokens = gemini_native.count_tokens(text)

# %%
tokens
# Out:
# total_tokens: 10

# %%
print("Tokens detail:", tokens)
# Out:
# Tokens detail: total_tokens: 10
