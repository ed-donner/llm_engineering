# %%
# imports

import os
import sys
import json
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# constants
requests.get("http://localhost:11434").content

MODEL = 'llama3.2'

# %%
# set up environment
OLLAMA_BASE_URL="http://localhost:11434/v1"
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
# here is the question; type over this to ask something new

user_question = """
Explain the 10 commonly used AI terminologies to a layman
"""

# %%
# Get Llama 3.2 to answer

stream = ollama.chat.completions.create(
    model= MODEL, 
    messages=[{"role": "user", "content": user_question}],
    stream = True
    )
response = ""
display_content = display(Markdown(""), display_id=True)

for chunk in stream:
    response += chunk.choices[0].delta.content or ''
    update_display(Markdown(response), display_id=display_content.display_id)
# Out:
# Here are 10 commonly used AI terminologies explained in simple terms:
#
# 1. **Machine Learning (ML)**: Imagine you train a robot to recognize your face, but instead of following a set of instructions, it uses examples and data to learn how to do it better on its own.
#
# 2. **Deep Learning (DL)**: A type of machine learning that uses many layers of algorithms to analyze complex patterns in data, like images or speech. It's like having a super powerful filter for recognizing pictures.
#
# 3. **Natural Language Processing (NLP)**: This allows computers to understand and interpret human language, including grammar, syntax, and context. It helps virtual assistants, chatbots, and language translation apps work smoothly.
#
# 4. **Neural Network**: A complex web of interconnected nodes that mimic the human brain's structure. Neural networks help AI systems learn and recognize patterns in data, like images or speech.
#
# 5. **Deepfake**: An image or video created using artificial intelligence to make someone appear as if they're saying or doing something they didn't really do. It can be used for entertainment, creative expression, but also for malicious purposes.
#
# 6. **Chatbot**: A computer program designed to simulate conversations with humans, often used in customer support, messaging apps, and virtual assistants like Siri or Alexa.
#
# 7. **Algorithm**: A set of rules or instructions that helps a computer solve problems or make decisions based on data. Think of it as a recipe book for solving specific tasks.
#
# 8. **Predictive Analytics**: The use of statistical models to analyze historical data and predict future events or trends. It's like using yesterday's weather forecast to predict tomorrow's weather.
#
# 9. **Recommendation Engine**: A system that uses data and algorithms to suggest products, services, or content based on user behavior, preferences, and interests. Think of it as a personalized shopping assistant.
#
# 10. **TensorFlow** (or OpenCV, PyTorch etc.): These are software frameworks used for building AI models, particularly machine learning and deep learning models. They act as a toolbox for developers to create and train AI systems.
#
# Remember, these terms are just the beginning of an exciting journey into the world of artificial intelligence!
