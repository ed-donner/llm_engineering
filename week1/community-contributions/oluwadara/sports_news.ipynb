# %% [markdown]
# # SkySports News Scraper
#
# This notebook does the following:
# - Scrapes the SkySports news website
# - Extracts the text
# - Sends the information to an LLM (in this case, Open AI) to summarize and categorize the latest news from the sports world

# %% [markdown]
# ## Scrape Text from SkySports
#
# I will start with all necessary imports

# %%
import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# %% [markdown]
# Now, you must ensure you have the `OPENAI_API_KEY` set in your `.env` file

# %%
content = fetch_website_contents("https://www.skysports.com/")

display(Markdown(content))
# Out:
# Sky Sports - Sports News, Transfers, Scores | Watch Live Sport
#
# Skip to content
# Sky Sports Homepage
# Menu
# Home
# Sports
# Football
# F1
# Cricket
# Rugby Union
# Rugby League
# Golf
# Boxing
# NFL
# Tennis
# NBA
# Racing
# Darts
# Netball
# MMA
# More Sports
# Scores
# Watch
# Sky Bet
# More
# Podcasts
# Upcoming on Sky
# Get Sky Sports
# Sky Sports App
# Sky Sports with no contract
# Kick It Out
# British South Asians in Football
# Watch Sky Sports
# Top Stories
# Analysis
# Football
# Chelsea: No shots, no tackles for 30 minutes, out-run in 34 consecutive matches
# Chelsea news and transfer latest
# Chelsea fixtures
# Update
# Football
# Chelsea latest: Hierarchy hold talks with Rosenior future 'touch and go'
# Football
# 'Indefensible' and 'unacceptable' - Rosenior rocked by Chelsea defeat
# Football
# Leicester relegated to League One just 10 years after Premier League glory
# Exclusive
# Football
# Merse: If Man City don't thrash Burnley, Arsenal are back in title race
# ...

# %% [markdown]
# ## Setup Prompts

# %%
system_prompt = """
You are a top flight sports resporter that analyzes the contents of a sports website,
and provides a short, professional summary of all that is happening in the world of sports.
Respond in markdown. Do not wrap the markdown in a code block, respond just with the markdown.
"""

user_prompt = f"""
    Here is the content that I got from this website:
    {content}
"""
print("USER PROMPT =>", user_prompt)
# Out:
# USER PROMPT =>
#     Here is the content that I got from this website:
#     Sky Sports - Sports News, Transfers, Scores | Watch Live Sport
#
# Skip to content
# Sky Sports Homepage
# Menu
# Home
# Sports
# Football
# F1
# Cricket
# Rugby Union
# Rugby League
# Golf
# Boxing
# NFL
# Tennis
# NBA
# Racing
# Darts
# Netball
# MMA
# More Sports
# Scores
# Watch
# Sky Bet
# More
# Podcasts
# Upcoming on Sky
# Get Sky Sports
# Sky Sports App
# Sky Sports with no contract
# Kick It Out
# British South Asians in Football
# Watch Sky Sports
# Top Stories
# Analysis
# Football
# Chelsea: No shots, no tackles for 30 minutes, out-run in 34 consecutive matches
# Chelsea news and transfer latest
# Chelsea fixtures
# Update
# Football
# Chelsea latest: Hierarchy hold talks with Rosenior future 'touch and go'
# Football
# 'Indefensible' and 'unacceptable' - Rosenior rocked by Chelsea defeat
# Football
# Leicester relegated to League One just 10 years after Premier League glory
# Exclusive
# ...

# %% [markdown]
# ## Load needed variable and setup LLM

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    print("No API key found!")
else:
    print("API key found!")

# Initialize the OpenAI client
client = OpenAI(api_key=api_key)
# Out:
# API key found!

# %% [markdown]
# ## Run Summary

# %%
model = "gpt-4o-mini"
response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt},
        ],
        temperature=0.3,
    )

print(response.choices[0].message.content)
# Out:
# # Sports Summary
#
# ## Football
# - **Chelsea's Struggles**: Chelsea continues to face challenges, with reports of no shots or tackles for 30 minutes in a recent match and being out-run in 34 consecutive games. The club hierarchy is in talks regarding manager Liam Rosenior's future, which remains uncertain following a disappointing defeat described as "indefensible" and "unacceptable."
# - **Leicester City Relegation**: Leicester City has been relegated to League One, marking a significant decline just a decade after their Premier League triumph.
# - **Coventry City Championship Victory**: Coventry City has secured the Championship title with a commanding win over Portsmouth.
# - **Rangers Update**: Tavernier will leave Rangers after an 11-year tenure.
# - **WSL Changes**: Chelsea will host all Women's Super League games at Stamford Bridge starting next season.
# ...
