# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display

# %%
MODEL_TO_USE = 'gpt-4o-mini'

# %%
api_key=os.getenv('OPENAI_API_KEY')
client=OpenAI(
    api_key=api_key,
    base_url="https://openrouter.ai/api/v1"
)

# %%
system_prompt = """
You are a highly technical assistant.
Respond using precise programming terminology.
Avoid casual language.
Be specific and concise.
"""

# user_prompt = """
# Explain line by line the syntax of a Python program that prints a star pattern using the '*' character.
# """

# %%
def message_for(programming_query):
    return [{"role":"system","content":system_prompt},
            {"role":"user","content":programming_query}]

# %%
def genarate_response(programming_query):
    response=client.chat.completions.create(model=MODEL_TO_USE,messages=message_for(programming_query))
    return response

programming_query="""
Explain line by line the syntax of a Python program that prints an arrow shaped made in stars pattern using the '*' character.
"""

response = genarate_response(programming_query)
print(response.choices[0].message.content)
# Out:
# Below is an example of a Python program that prints an arrow shape made from asterisks (`'*'`). I will explain the syntax line by line.
#
# ```python
# # Define a function to print the arrow pattern
# def print_arrow_height(n):
#     # Loop to print the upper triangular part of the arrow
#     for i in range(n):
#         # Print leading spaces for alignment
#         print(' ' * (n - i - 1), end='')
#         # Print '*' characters for the current row
#         print('*' * (2 * i + 1))
#
#     # Loop to print the lower triangular part of the arrow
#     for i in range(n - 1):
#         # Print leading spaces for alignment
#         print(' ' * (i + 1), end='')
#         # Print '*' characters for the current row
#         print('*' * (2 * (n - i - 2) + 1))
#
# # Call the function with a specific size
# print_arrow_height(5)
# ```
#
# ### Line-by-Line Explanation
#
# 1. **Comment**: `# Define a function to print the arrow pattern`
#    This line is a comment that explains the purpose of the following function.
#
# 2. **Function Definition**: `def print_arrow_height(n):`
#    Defines a function named `print_arrow_height` that takes a single parameter `n`, representing the height of the arrow.
#
# 3. **Comment**: `# Loop to print the upper triangular part of the arrow`
#    Indicates the beginning of the loop that prints the upper part of the arrow shape.
#
# 4. **For Loop**: `for i in range(n):`
#    Starts a `for` loop that iterates `n` times, with `i` taking values from `0` to `n-1`.
#
# 5. **Comment**: `# Print leading spaces for alignment`
#    A comment that describes the purpose of the following print statement.
#
# 6. **Print Leading Spaces**: `print(' ' * (n - i - 1), end='')`
#    Calculates the number of leading spaces needed to center the arrow. `end=''` prevents moving to a new line after printing spaces.
#
# 7. **Print Stars**: `print('*' * (2 * i + 1))`
#    Prints the asterisk characters for the current row. The expression `(2 * i + 1)` calculates the number of stars according to the current row, which forms the shape of the arrow.
#
# 8. **Comment**: `# Loop to print the lower triangular part of the arrow`
#    Indicates the start of the loop for the lower part of the arrow.
#
# 9. **For Loop**: `for i in range(n - 1):`
#    Starts a `for` loop that iterates `n-1` times for printing the lower part of the arrow.
#
# 10. **Comment**: `# Print leading spaces for alignment`
#     A comment clarifying the next step, which is printing leading spaces.
#
# 11. **Print Leading Spaces**: `print(' ' * (i + 1), end='')`
#     Calculates and prints the leading spaces for the current row in the lower part of the arrow.
#
# 12. **Print Stars**: `print('*' * (2 * (n - i - 2) + 1))`
#     Computes and prints the number of stars for the current row in the lower part. `(2 * (n - i - 2) + 1)` gives the correct count of stars.
#
# 13. **Comment**: `# Call the function with a specific size`
#     Preceding the next line, this indicates the function invocation with a specific argument.
#
# 14. **Function Call**: `print_arrow_height(5)`
#     Invokes the `print_arrow_height` function with `5`, specifying that the arrow should have a height of 5.
#
# This program will produce a star pattern in the shape of an arrow when executed.

# %%
# Test the output

def print_arrow(height):
    # Loop to create the upper part of the arrow
    for i in range(height):
        # Print spaces to center the arrow
        print(' ' * (height - i - 1), end='')
        # Print the '*' characters
        print('*' * (2 * i + 1))
    
    # Loop to create the lower part of the arrow
    for i in range(height - 1):
        # Print spaces to center the arrow
        print(' ' * (i + 1), end='')
        # Print the '*' characters
        print('*' * (2 * (height - i - 1) - 1))

# Call the function with a height parameter
print_arrow(5)
# Out:
#     *
#    ***
#   *****
#  *******
# *********
#  *******
#   *****
#    ***
#     *
