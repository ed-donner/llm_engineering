# %%
# imports

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
# Step 1: Create your prompts

system_prompt = """
You are a helpful assistant that summarizes website content.

Write a short and clear summary of the website.
Explain the main purpose of the website and include only the important information.
Ignore navigation menus, advertisements, cookie notices, and unrelated text.
Do not add information that is not in the website content.
Use simple English and bullet points.
"""

user_prompt = """
Please summarize the website content below:
"""

# Step 2: Make the messages list
url = "https://datarockie.com/blog/suddenly-talented/"
website = fetch_website_contents(url)
messages = [
    {"role": "system","content": system_prompt},
    {"role": "user","content": user_prompt + website }
    ]
# Step 3: Call OpenAI
openai = OpenAI()
response = openai.chat.completions.create(
    model = "gpt-4.1-nano",
    messages = messages
)
# print(website)
print(response.choices[0].message.content)
# response =

# Step 4: print the result
# print(
# Out:
# Suddenly Talented วิธีพัฒนาตัวเองแบบเก่งปุบปับด้วย ECS Framework
#
# DataRockie
# Hello
# Blog
# 🍟 Bootcamp
# Modern Fight Club
# Free online courses for lifelong learners
# เริ่มเรียน Data Science ง่ายๆด้วยตัวเอง 🍟
# Learning
# Suddenly Talented วิธีพัฒนาตัวเองแบบเก่งปุบปับ
# February 6, 2026
# วันเสาร์ที่ผ่านมา แอดเพิ่งจัดงาน
# Duck Con 2024
# เป็น free event ที่ใหญ่สุดตั้งแต่เราเปิดเพจ
# DataRockie
# มา นั่งฟังจุกๆ 5 ชั่วโมงเต็ม ผู้ร่วมงานมากกว่า 300 คน
# แอดขึ้นพูดเป็นคนสุดท้ายกับหัวข้อ Suddenly Talented ปุบปับเก่งเลย เป็นไอเดียที่ได้มาจากหนังสือชื่อเดียวกันกับทอล์คนี้เขียนโดยคุณ Sean D’Souza
# Duck Con อีเว้นต์เป็ดโปรไม่จำกัด
# Thesis ของหนังสือเล่มนี้คือการตั้งคำถามว่าจริงๆแล้ว
# talent
# คืออะไร?
# Talent คือความสามารถที่มีมาแต่กำเนิด “inborn” หรือจริงๆแล้วเราสามารถฝึกฝนเพื่อ “acquire” ทักษะนี้ได้
# ถ้า talent เป็นเรื่องที่เราพัฒนาได้จริง คำถามที่แอดอยากรู้คือต้องฝึกนานเท่าไหร่ ต้องเรียนถึง 10,000 ชั่วโมงเหมือนที่ conventional wisdom บอกไว้เลยไหม?
# บทความนี้แอดเขียนสรุปทอล์คนี้มาให้อ่านกันแล้ว อ่านจบเก่งเลย การันตี ✌️
# Who is Sean D'Souza?
# Suddenly Talented
# I'm NOT a talent
# The 10000-Hour Rule
# The ECS Framework
# Energy
# Confidence
# Skill
# Skill Comparison Trap
# Reduction of Errors
# Energy Over Passion
# Choose Progression
# The Real Enemy
# Time Management for Mortals
# The Most Important Skill
# How to Be Better
# See You at What The Duck 2024
# Who is Sean D’Souza?
# Sean คือนักวาดการ์ตูน นักเขียน และนักการตลาด
# สิบปีที่แล้ว วันธรรมดาทั่วๆไป แอดกดเข้าไปส่องเว็บ Amazon บังเอิญเจอหนังสือเล่มหนึ่ง ชื่อปกน่าสนใจดี “
# The Brain Audit
# “
# ช่วงนั้นแอดกำลังอินเรื่อง marketing พอดี ลงเรียน ป.โท การตลาดที่มหิดล (CMMU) อยู่ด้วย เลยกดซื้อมาอ่าน สนุกเฉย 555+
# ถ้าใครเคย binge-watch netflix แอดก็ binge-read เล่มนี้เหมือนกัน 555+
# แค่หนังสือเล่มเดียวก็เปลี่ยนชุดความคิดของเราได้เลย เหมือนเราดาวน์โหลดประสบการณ์ทั้งชีวิตของผู้เขียนเข้ามาในสมองของเรา
# ✌️ ตั้งแต่วันนั้นแอดเชื่อเลยว่าแค่หนังสือดีๆสักเล่มก็เปลี่ยนชีวิตเราได้ แต่เราต้องเลือกอ่านให้ถูกเล่มด้วยนะ 555+
# The Brain Audit เขียนโดย Sean D’Souza นักวาดการ์ตูนชาวอินเดียที่ย้ายประเทศมาอยู่ที่นิวซีแล
# - เว็บไซต์นี้เป็นบล็อกเกี่ยวกับการพัฒนาตนเองและทักษะ
# - เน้นเรื่องแนวคิด "Suddenly Talented" คือการพัฒนาทักษะอย่างรวดเร็วด้วย ECS Framework
# - เล่าเรื่องงาน Duck Con 2024 ซึ่งเป็นงานฟรีที่มีผู้เข้าร่วมมากกว่า 300 คน
# - เนื้อหาอธิบายเกี่ยวกับความสามารถ (talent) และความสามารถที่สามารถฝึกฝนได้ ไม่ใช่แค่ innate talent
# - บทความสรุปไอเดียจากหนังสือ "Suddenly Talented" โดย Sean D’Souza
# - อธิบายว่ากฎ 10,000 ชั่วโมงไม่จำเป็นต้องใช้เวลานานเสมอไป หากใช้แนวทางที่เหมาะสม
# - ECS Framework ประกอบด้วย Energy (พลังงาน), Confidence (ความมั่นใจ), และ Skill (ทักษะ)
# - เน้นให้เลือกความก้าวหน้าและลดข้อผิดพลาด เพื่อพัฒนาทักษะอย่างมีประสิทธิภาพ
# - แนะนำวิธีการบริหารเวลาสำหรับคนทั่วไป และเน้นเรื่องความสำคัญของการพัฒนาทักษะ
# - แนะนำ Sean D’Souza เป็นนักวาดการ์ตูน นักเขียน และนักการตลาด ที่เขียนหนังสือและให้ความรู้ด้านพัฒนาตนเอง
