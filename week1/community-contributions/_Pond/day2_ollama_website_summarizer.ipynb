# %%
# imports

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Step 1: Create your prompts




system_prompt = """
You are a helpful assistant that summarizes website content.

Write a short and clear summary of the website.
Explain the main purpose of the website and include only the important information.
Ignore navigation menus, advertisements, cookie notices, and unrelated text.
Do not add information that is not in the website content.
Use simple English and bullet points.
"""

user_prompt = """
Please summarize the website content below:
"""

# Step 2: Make the messages list


# Step 1: Choose a website

url = "https://datarockie.com/blog/suddenly-talented/"

website = fetch_website_contents(url)


# Step 2: Create messages

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt + website}
]


# Step 3: Connect to Ollama

OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(
    base_url=OLLAMA_BASE_URL,
    api_key="ollama"
)


# Step 4: Call the local model

response = ollama.chat.completions.create(
    model="llama3.2",
    messages=messages
)


# Step 5: Print the result

print(response.choices[0].message.content)
# Out:
# Here is a summary of the website content in simple English and bullet points:
#
# **Main Purpose:**
# The website is to share knowledge and experience on personal development and self-improvement.
#
# **Content:**
#
# * "Suddenly Talented" is a concept that asks whether talent is something that can be developed or if it's innate.
# 	+ The author wants to discuss whether it's possible to develop skill beyond the conventional "10,000-hour rule".
# * The author met the author of a book called "The Brain Audit" while learning marketing.
# 	+ The book changed the author's perspective on life and marketing.
# * The author wants to share their experience and knowledge on various topics, including:
# 	+ Energy and confidence
# 	+ Skills and skill comparison
# 	+ Time management and progress
# 	+ The real enemy and overcoming obstacles
# 	+ How to be better
