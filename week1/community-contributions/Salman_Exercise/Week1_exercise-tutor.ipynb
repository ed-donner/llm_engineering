# %% [markdown]
# # Technical Tutor using Groq

# %%
import os
from dotenv import load_dotenv
from groq import Groq
from IPython.display import Markdown, display

# Load environment variables
load_dotenv(override=True)
api_key = os.getenv('GROQ_API_KEY')

if not api_key or not api_key.startswith('gsk_'):
    raise ValueError("❌ GROQ_API_KEY not found in .env")

# Define the model (choose one that works)
MODEL = 'llama-3.1-8b-instant'   # or 'gemma2-9b-it', etc.

# Create the Groq client
groq_client = Groq(api_key=api_key)
print(f"✅ Groq client ready with {MODEL}")
# Out:
# ✅ Groq client ready with llama-3.1-8b-instant

# %%
# Technical Tutor using Groq
tutor_system_prompt = """
You are a patient, clear, and knowledgeable technical tutor.
Your goal is to help learners understand programming, AI, data science, and related technical topics.
- Explain concepts in simple terms with examples.
- Break down complex ideas step by step.
- If the question is unclear, ask for clarification.
- Use markdown for readability (headings, bullet lists, code blocks).
- Be encouraging and supportive.
"""

def ask_tutor(question, model=None):
    """
    Send a technical question to the tutor and get a response.
    """
    # Use global MODEL if no model is passed
    if model is None:
        model = MODEL   # assumes MODEL is defined globally
    
    try:
        response = groq_client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": tutor_system_prompt},
                {"role": "user", "content": question}
            ],
            temperature=0.7,
            max_tokens=1024
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"⚠️ Error: {e}"

# Test it
question = "Explain the Agentic AI?"
answer = ask_tutor(question)
display(Markdown(answer))   # note: Markdown with capital M
# Out:
# **Agentic AI: A New Wave of Artificial Intelligence**
# ===========================================================
#
# Agentic AI is a relatively new concept in the field of artificial intelligence (AI) that aims to create more autonomous, self-aware, and goal-oriented AI systems. The term "agentic" comes from the word "agent," which refers to an entity that can act independently on its environment and make decisions based on its goals and intentions.
#
# **What is Agentic AI?**
# ------------------------
#
# Agentic AI is a type of AI that is designed to be more proactive, adaptive, and autonomous. It is inspired by human agents, such as people, who can act independently and make decisions based on their goals, values, and intentions.
#
# **Key Characteristics of Agentic AI**
# --------------------------------------
#
# *   **Autonomy**: Agentic AI systems are designed to operate independently, making decisions and taking actions without human intervention.
# *   **Self-awareness**: Agentic AI systems are aware of their own existence, goals, and intentions, which enables them to make decisions that align with their objectives.
# *   **Goal-oriented**: Agentic AI systems have clear goals and objectives that they strive to achieve, and they can adapt their behavior to achieve these goals.
# *   **Proactivity**: Agentic AI systems can take the initiative to act and make decisions, rather than simply reacting to external stimuli.
#
# **Examples of Agentic AI**
# ---------------------------
#
# *   **Autonomous vehicles**: Self-driving cars and trucks are examples of agentic AI, as they can navigate through roads and make decisions based on their goals (e.g., reaching a destination, avoiding obstacles).
# *   **Virtual assistants**: Virtual assistants like Siri, Alexa, and Google Assistant are agentic AI systems that can understand user requests and take actions to fulfill them.
# *   **Robots**: Industrial robots and service robots are agentic AI systems that can perform tasks autonomously and adapt to changing situations.
#
# **Benefits of Agentic AI**
# ---------------------------
#
# *   **Increased efficiency**: Agentic AI systems can perform tasks more efficiently and effectively than traditional AI systems.
# *   **Improved decision-making**: Agentic AI systems can make decisions that align with their goals and objectives, leading to better outcomes.
# *   **Enhanced user experience**: Agentic AI systems can provide more personalized and intuitive experiences for users.
#
# **Challenges and Limitations of Agentic AI**
# ---------------------------------------------
#
# *   **Safety and control**: Agentic AI systems can pose safety risks if they are not designed with adequate controls and safeguards.
# *   **Ethical considerations**: Agentic AI systems raise ethical concerns, such as accountability, transparency, and fairness.
# *   **Complexity**: Developing agentic AI systems requires significant advances in areas like machine learning, computer vision, and natural language processing.
#
# **Conclusion**
# ----------
#
# Agentic AI is a promising area of research that has the potential to revolutionize various industries and aspects of our lives. However, it also raises important challenges and limitations that need to be addressed. As we continue to develop and deploy agentic AI systems, it is essential to prioritize safety, ethics, and transparency to ensure that these systems benefit society as a whole.
