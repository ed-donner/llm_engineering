# %% [markdown]
# The below code will create conversation between Llama and phi LLM models.
#
# "NumOfConv" parameter will control how many interaction they will have when we run.

# %%
import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

def messages_creation(user_prompt):
    system_prompt = "This model will chat with the users regarding programming languages"
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ]

NumOfConv = 6

def chat_with_llama(user_prompt):
    global NumOfConv
    if NumOfConv == 0:
        return
    NumOfConv = NumOfConv - 1
    messages = messages_creation(user_prompt)
    OLLAMA_BASE_URL = "http://localhost:11434/v1"
    ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')
    response = ollama.chat.completions.create(model="llama3.2:1b", messages=messages)
    message = response.choices[0].message.content  
    print("Llama: " + message)
    chat_with_phi(message)

def chat_with_phi(user_prompt):
    global NumOfConv
    if NumOfConv == 0:
       return
    NumOfConv = NumOfConv - 1
    messages = messages_creation(user_prompt)
    OLLAMA_BASE_URL = "http://localhost:11434/v1"
    ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')
    response = ollama.chat.completions.create(model="phi3", messages=messages)
    message = response.choices[0].message.content  
    print("phi: " + message)
    chat_with_llama(message)

chat_with_phi("Hello ask me a question regarding Python")
