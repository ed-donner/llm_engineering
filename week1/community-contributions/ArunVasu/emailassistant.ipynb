# %%
# %pip install python-dotenv openai

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# Load environment variables
load_dotenv()
# Out:
# True

# %%
# Step 1: Create your prompts

system_prompt = "you are a personal assistant for a busy person, create a professional email based on the given context"
user_prompt = """
    hi mgr, 2day i didnt gt a chnge to wrk with ur task please give me 2morrow, ll wrk and lyk the status
"""

# Step 2: Make the messages list

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
    ] # fill this in

# Step 3: Call OpenAI
client = OpenAI()
response = client.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

# Step 4: print the result
print(response.choices[0].message.content)
# Out:
# Subject: Request for Task Assignment for Tomorrow
#
# Dear [Manager's Name],
#
# I hope this message finds you well. I was unable to work on your tasks today and kindly request if I could be assigned to them tomorrow. I will ensure to complete the work and provide an update on the current status.
#
# Thank you for your understanding and support.
#
# Best regards,
# [Your Name]
