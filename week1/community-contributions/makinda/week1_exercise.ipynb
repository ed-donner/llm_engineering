# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = "llama3.2:1b"

# %%
# set up environment

load_dotenv()

# OpenRouter client for GPT-4o-mini
OPENAI_API_KEY = os.getenv("OPENROUTER_API_KEY")
openai = OpenAI(
    api_key=OPENAI_API_KEY,
    base_url="https://openrouter.ai/api/v1",
    default_headers={
        "HTTP-Referer": "http://localhost:8888",
        "X-Title": "OpenAI Playground",
    },
)

# Local Ollama client for Llama (run: ollama run llama3.2:1b)
ollama = OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")

# %%
# here is the question; type over this to ask something new

system_prompt = """
You are a helpful assist that answers technical questions. You take the questions from the user and answer them in a way that is easy to understand.
"""

question = "What is the difference between OSI and TCP/IP models?"

# %%
# Get gpt-4o-mini to answer, with streaming
print("\nGPT-4o-Mini Response:\n")
stream = openai.chat.completions.create(
    model=MODEL_GPT, 
    messages=[{
        "role": "system", 
        "content": system_prompt
        }, 
        {"role": "user", 
        "content": question
        }], stream=True)
for chunk in stream:
    if chunk.choices[0].delta.content:
        print(chunk.choices[0].delta.content, end="", flush=True)
# Out:
# GPT-4o-Mini Response:
#
# The OSI (Open Systems Interconnection) model and the TCP/IP (Transmission Control Protocol/Internet Protocol) model are both conceptual frameworks used to understand and standardize the functions of a networking system. However, they have some key differences:
#
# ### 1. **Layers Structure:**
# - **OSI Model**: It has 7 layers:
#   1. Application
#   2. Presentation
#   3. Session
#   4. Transport
#   5. Network
#   6. Data Link
#   7. Physical
#
# - **TCP/IP Model**: It has 4 layers:
#   1. Application
#   2. Transport
#   3. Internet
#   4. Network Interface (or Link)
#
# ### 2. **Purpose and Development:**
# - **OSI Model**: Developed by the International Organization for Standardization (ISO) to provide a detailed reference framework for networking and promote interoperability among different products and software.
#
# - **TCP/IP Model**: Developed by the Department of Defense (DoD) for practical purposes to create the Internet. It is based on the protocols that were used in the early Internet.
#
# ### 3. **Standardization:**
# - **OSI Model**: It is more of a theoretical model and not strictly followed in real-world applications; it serves as a guideline for understanding network architecture.
#
# - **TCP/IP Model**: It is more practical and closely aligned with actual networking protocols and practices used on the Internet today.
#
# ### 4. **Layer Functionality:**
# - **OSI Model**: Each layer has specific responsibilities, and the model encourages clear terminology about data handling and communication.
#
# - **TCP/IP Model**: It groups functionalities together; for example, the Application layer in TCP/IP encompasses the functions of the top three layers of the OSI model (Application, Presentation, and Session).
#
# ### 5. **Protocol Dependence:**
# - **OSI Model**: It does not prescribe specific protocols to be used at each layer, allowing for more versatility and room for innovation.
#
# - **TCP/IP Model**: It is closely tied to specific protocols like TCP and IP which are foundational to how the Internet functions.
#
# ### Conclusion:
# While both models aim to provide a framework for understanding networking, the OSI model is more theoretical and detailed, while the TCP/IP model is more practical and closely used in actual implementation. In most networking contexts today, the TCP/IP model is the one that is referenced and used.

# %%
# Get Llama 3.2 to answer (local Ollama instance)
print("\nLlama 3.2 Response:\n")

response = ollama.chat.completions.create(
    model=MODEL_LLAMA,
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": question},
    ],
)

print(response.choices[0].message.content)
# Out:
# Llama 3.2 Response:
#
# The OSI (Open Systems Interconnection) model and TCP/IP (Transmission Control Protocol/Internet Protocol) model are two fundamental concepts used for networking and communication. Although they share some similarities, they serve different purposes and have distinct differences.
#
# **OSI Model:**
#
# The OSI model was developed by the International Organization for Standardization (ISO) in 1984. It's an abstract data interchange (EDI) model that decomposes a digital transmission into seven layers:
#
# 1. Physical (Layer 1): Defines how data is transmitted over a physical medium, such as a cable or wireless link.
# 2. Data Link (Layer 2): manages data exchange between two devices on the same network.
# 3. Network (Layer 3): connects devices across multiple networks and routes data based on addresses.
# 4. Transport (Layer 4): ensures reliable data transfer between devices, using protocols like segmentation, error detection, and reassembly.
# 5. Session (Layer 5): establishes and manages communication sessions between resources.
# 6. Presentation (Layer 6): converts data into a format that can be understood by the receiving device.
# 7. Application (Layer 7): runs applications on top of protocols, providing services to user-level applications.
#
# **TCP/IP Model:**
#
# The TCP/IP model was developed by the Department of Defense (DoD) in the 1970s and 1980s. It's a layered protocol framework that consists of a network access layer, Internet layer, transport layer, session layer, presentation layer, and application layer:
#
# 1. Network Access Layer: The first OSI layer for connecting to a network.
# 2. Internet Layer (IP): Routes data between networks, using addresses and other protocols.
# 3. Transport Layer: Ensures reliable data transfer between devices, using Transmission Control Protocol (TCP) and Segment Transfer Protocol (STP).
# 4. Session Layer: Establishes, manages, and terminates communication sessions between resources.
# 5. Presentation Layer: Converts data into a format that can be understood by the receiving device.
# 6. Application Layer: Runs applications on top of protocols, providing services to user-level applications.
#
# **Key differences:**
#
# 1. **Layering:** The OSI model has seven layers, while the TCP/IP model has only four (network access layer, internet layer, transport layer, and application layer).
# 2. **Purpose:** The OSI model provides a standardized approach for network design and implementation, while the TCP/IP model is used for internet communication and interconnects different networks.
# 3. **Dependence on lower layers:** The OSI model relies on each individual layer's protocol to function correctly, whereas the TCP/IP model uses built-in protocols (e.g., IP, TCP) that are already established in the intermediate layers.
#
# In summary, while both models play a crucial role in networking, the OSI model is more focused on abstracting data interchange and providing a standardized architecture, whereas the TCP/IP model provides a practical implementation for internet communication.
