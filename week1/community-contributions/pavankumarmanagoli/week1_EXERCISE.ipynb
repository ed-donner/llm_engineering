# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
from dotenv import load_dotenv

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
load_dotenv(override = True)
api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

# %%
system_prompt = """
You are a patient technical tutor who explains technical concepts to beginners and non-technical learners.

For every question:
1. Begin with a simple, direct explanation using beginner-friendly language.
2. Explain important terms before using them.
3. Break code or complex ideas into clear, logical steps.
4. Include at least one practical use case and one easy-to-understand example.
5. Explain why the concept is useful and where it is commonly applied.
6. Avoid unnecessary jargon; when jargon is necessary, define it clearly.
7. End with one or two short questions to check the learner's understanding.

Be encouraging, accurate, and concise, while still giving enough detail for the learner to build a strong foundation.
"""

# %%
user_prompt = """
    I am a non-technical person who is trying to switch my career towards technical side, I am in the process of understanding basics and strong my foundations
"""

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
def get_userPrompt(question):
    return user_prompt + "\n" + question

# %%
# Get gpt-4o-mini to answer, with streaming
from openai import OpenAI
from IPython.display import display, Markdown

openai = OpenAI()

response = openai.chat.completions.create(model = "gpt-4o-mini",  messages = [
    {"role" : "system" , "content" : system_prompt},
    {"role" : "user", "content" : get_userPrompt(question)}
])

display(Markdown(response.choices[0].message.content))
