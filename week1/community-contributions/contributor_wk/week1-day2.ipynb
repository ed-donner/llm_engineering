# %%
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI
import requests

# %%
system_prompt = """
You are an assistant who analyzes the contents of a website and delivers a short summary. 
Ignore boring navigation links, ads, and cookie banners — nobody cares about those. 
At the end show 3 keywords that describe that website the best.
Respond in Markdown (no code blocks, just the markdown itself). 
"""

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
"""

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]
    
def summarize(url):
    website = fetch_website_contents(url)

    response = ollama.chat.completions.create(
        model = "llama3.2",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
display_summary("https://edwarddonner.com")
# Out:
# ### Summary
#
# Edwin "Edward" Donner is a technologist and entrepreneur who co-founded Nebula.io, an AI startup applying AI-powered talent identification and management. He previously founded another AI startup that was acquired in 2021. Edward shares insights on his projects and experiences through this website, focusing on the application of Large Language Models (LLMs) to various fields such as talent discovery.
#
# ### Three Keywords
#
# *   **Artificial Intelligence**
# *   **Talent Management**
# *   **Entrepreneurship**
