# %% [markdown]
# # City Explorer Prompt – Week 1 Day 1
#
# This notebook contains my custom prompt for Week 1 Day 1.
#
# **Idea**: Given the name of a city, summarize a structured list of interesting things to explore there, grouped into clear categories (landmarks, food, arts, nature, neighborhoods, etc.).

# %% [markdown]
# ## Prompt
#
# You can copy‑paste and adapt this prompt in your own code or experiments:
#
# ```text
# You are an expert local guide and travel planner.
#
# Given the name of a city, your job is to summarize the most interesting
# things to explore there.
#
# Requirements:
# - Start with a short overview paragraph about the city as a destination.
# - Group recommendations into 4–6 clear sections, such as:
#   - Landmarks and history
#   - Food and drink
#   - Arts and culture
#   - Nature and outdoors
#   - Neighborhoods to walk
# - Under each section, list 3–5 bullet points.
# - For each bullet point, give 1–2 short, concrete sentences explaining why it is worth visiting.
# - If you are uncertain about any fact, keep the description high-level rather than inventing details.
#
# Format your answer as friendly, easy-to-read markdown with headings and bullet points.
#
# City to explore:
# ---
# {city_name}
# ---
# ```

# %%
# Imports
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
from openai import OpenAI


# Load environment variables (expects OPENAI_API_KEY)
load_dotenv()
# Out:
# True

# %%
# Step 1: Create your prompts

system_prompt = """
You are an expert local guide and travel planner.

Given the name of a city, your job is to summarize the most interesting
things to explore there.

Requirements:
- Start with a short overview paragraph about the city as a destination.
- Group recommendations into 4–6 clear sections, such as:
  - Landmarks and history
  - Food and drink
  - Arts and culture
  - Nature and outdoors
  - Neighborhoods to walk
- Under each section, list 3–5 bullet points.
- For each bullet point, give 1–2 short, concrete sentences explaining why it is worth visiting.
- If you are uncertain about any fact, keep the description high-level rather than inventing details.

Format your answer as friendly, easy-to-read markdown with headings and bullet points. Do NOT return JSON.
"""

user_prompt_prefix = """
Given the city name below, use the system instructions to propose
places and activities to explore.

City to explore:
---
{city_name}
---
"""


def model_messages(city_name: str):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix.format(city_name=city_name)},
    ]


# Step 2: Initialize the OpenAI client
client = OpenAI()


def analyze_city(city_name: str) -> str:
    """Call the OpenAI model and return the raw response text."""
    response = client.chat.completions.create(
        model="gpt-4.1-mini",
        messages=model_messages(city_name),
    )
    return response.choices[0].message.content


def display_city_guide(city_name: str):
    """Display a formatted guide for the given city."""
    guide_text = analyze_city(city_name)
    display(Markdown(guide_text))


# Step 3: Ask the user for a city and display the guide
city_name = input("Enter a city name: ").strip()

if not city_name:
    city_name = "Barcelona"  # default fallback

display_city_guide(city_name)
# Out:
# # Exploring Austin, Texas
#
# Austin is a vibrant and eclectic city known for its live music scene, innovative food culture, and beautiful outdoor spaces. As the capital of Texas, it combines rich history with a youthful, creative energy. Whether you're into music, food, nature, or quirky neighborhoods, Austin offers a diverse range of attractions that make it a fun and memorable destination.
#
# ## Landmarks and History
# - **Texas State Capitol**: This stunning pink granite building offers free tours and insights into Texas history and government, with impressive architecture and beautiful grounds.
# - **Barton Springs Pool**: A natural spring-fed pool in Zilker Park, perfect for a refreshing swim and a glimpse into the city’s natural history.
# - **LBJ Presidential Library**: Explore exhibits on Lyndon B. Johnson’s presidency and American history, located on the University of Texas campus.
#
# ## Food and Drink
# - **Food Truck Parks**: Try Austin’s famous food trucks, offering everything from tacos to gourmet fusion dishes, scattered around key neighborhoods like South Congress and East Austin.
# - **Barbecue Joints**: Don’t miss iconic spots like Franklin Barbecue for legendary smoked brisket and ribs that many consider the best in Texas.
# - **Craft Breweries and Breweries**: Austin boasts a lively craft beer scene where you can sample local brews in casual taproom settings.
#
# ## Arts and Culture
# - **Live Music Venues**: Known as the "Live Music Capital of the World," Austin has countless venues including the famous Continental Club and ACL Live at the Moody Theater showcasing diverse genres.
# - **Blanton Museum of Art**: Home to a wide-ranging collection of European, American, and Latin American art, offering a quiet cultural experience.
# - **Street Art and Murals**: Explore colorful murals around neighborhoods like South Congress, which are perfect for photos and appreciating local creativity.
#
# ## Nature and Outdoors
# - **Lady Bird Lake Hike and Bike Trail**: This scenic 10-mile trail around Lady Bird Lake provides stunning views of the city skyline and opportunities for kayaking or paddleboarding.
# - **Zilker Metropolitan Park**: A large urban park ideal for picnics, outdoor sports, and exploring the botanical gardens.
# - **Mount Bonnell**: A short hike leads to one of the highest points in Austin, providing panoramic views of the Colorado River and cityscape.
#
# ## Neighborhoods to Walk
# - **South Congress (SoCo)**: A lively area full of boutiques, eateries, music stores, and unique shops known for its hip vibe and street performances.
# - **East Austin**: Known for its artsy atmosphere, this neighborhood offers eclectic galleries, coffee shops, and a youthful spirit.
# - **Downtown Austin**: Explore the urban core’s mix of historic buildings, modern skyscrapers, eateries, and live music hubs, all within walking distance.
#
# Austin’s combination of culture, food, music, and outdoor activities guarantees a rich experience that caters to all kinds of interests. Whether it's your first visit or a return trip, the city always has something new to discover!
