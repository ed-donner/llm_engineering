# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
from openai import OpenAI
from dotenv import load_dotenv
import os
from IPython.display import Markdown

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key and openai_api_key.startswith('sk-proj-'):
  print("API key looks good so far")
else: print("There's no OPENAI_API_KEY in the environment variables")

ollama_base_url = "http://localhost:11434/v1"

openAI = OpenAI(api_key=openai_api_key)
ollama = OpenAI(base_url=ollama_base_url, api_key="ollama")

# %%
# here is the question; type over this to ask something new

question = """
Act as a professional career coach and hiring expert.
Explain how to write a strong job cover letter in a clear and beginner-friendly way.
Break your answer into simple steps, including:
- The purpose of a cover letter
- The correct structure and sections
- What to include in each paragraph
- Common mistakes to avoid
- Tips to make it stand out
Also provide a short sample cover letter example for a generic job application.
"""

# %%
# Get gpt-4o-mini to answer, with streaming
response = openAI.chat.completions.create(model=MODEL_GPT, messages=[{"role": "user", "content": question}],)
message = response.choices[0].message.content

Markdown(message)

# %%
import requests
requests.get("http://localhost:11434").content # to check if ollama is running
# !ollama pull llama3.2

# %%
# Get Llama 3.2 to answer

response = ollama.chat.completions.create(model=MODEL_LLAMA, messages=[{"role": "user", "content": question}],)
message = response.choices[0].message.content

Markdown(message)
