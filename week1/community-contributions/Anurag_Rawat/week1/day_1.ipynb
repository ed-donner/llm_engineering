# %% [markdown]
# ## Imports

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %% [markdown]
# ## Load Environment Variables

# %%
load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ### Check API Key

# %%
if not api_key:
    raise ValueError("OPENAI_API_KEY not found.")

print("✅ API key loaded successfully.")
# Out:
# ✅ API key loaded successfully.

# %% [markdown]
# ### Create OpenAI Client

# %%
client = OpenAI(api_key=api_key)

# %% [markdown]
# ### Prompt

# %%
system_prompt = """
You are an expert English grammar and spelling assistant.

Your tasks:
- Correct grammar
- Correct spelling
- Correct punctuation
- Correct capitalization

Then:
- Show the corrected text.
- Explain every correction.
- Give two similar example sentences.

Respond in Markdown.
Do not wrap your response in a markdown code block.
"""

user_prompt = """
If i have been there i will have them know it early.
"""

user_prompt = input("Enter some text: ")

# %% [markdown]
# ### Build Messages

# %%
messages = [
    {
        "role": "system",
        "content": system_prompt,
    },
    {
        "role": "user",
        "content": user_prompt,
    },
]

# %% [markdown]
# ### Send Request

# %%
def correct_grammar(messages):
    response = client.chat.completions.create(
        model="gpt-4.1-nano",
        messages=messages
    )
    return response.choices[0].message.content

# %% [markdown]
# ### Print the response

# %%
display(Markdown(correct_grammar(messages)))
# Out:
# Corrected text:
# Today, I would try to win all the games in college sports.
#
# Explanation of corrections:
# - "i" was capitalized to "I" because it is a pronoun and should always be capitalized.
# - "try to won" was corrected to "try to win". "Try to" is followed by the base form of the verb, so "won" (past tense) was corrected to "win" (base form).
# - "all games" was changed to "all the games" for grammatical correctness, as "the" specifies particular games.
# - "in sports of college" was rephrased to "in college sports" to sound more natural and concise.
#
# Similar example sentences:
# 1. I will try to finish all the assignments before the deadline.
# 2. She plans to win all the medals in the competition.
