# %% [markdown]
# ### Imports

# %%
# imports

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# # Base Variables

# %%
MODEL = "gemini-3.6-flash"
BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"

api_key = os.getenv('GEMINI_API_KEY')

# %% [markdown]
# # Check if env exists

# %%
# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("AQ."):
    print("An API key was found, but it doesn't start AQ.; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

# %% [markdown]
# # Connect LLM

# %%
openai = OpenAI(api_key=api_key, base_url=BASE_URL)

# %% [markdown]
# # Create Prompt

# %%
system_prompt = "You are a cool email assistant who can extract details from it and can summarize it aswell."
user_prompt = """ I am sharing an email that needs a relevant subject title and also summarize the email...
    Dear Xyz Owner,

I hope you’re doing well.

I’m reaching out to explore a potential business partnership between our companies. We believe there may be an opportunity to collaborate and create value for both sides through our respective products, services, and expertise.

I’d be happy to schedule a short meeting to discuss the idea in more detail and explore how we could work together.

Please let me know a convenient time for you.

Best regards,
Jaffer Sunny
"""

# Step 2: Make the messages list

messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ] # fill this in

# Step 3: Call OpenAI
response = openai.chat.completions.create(
        model = MODEL,
        messages = messages
    )

# Step 4: print the result
print(response.choices[0].message.content)
