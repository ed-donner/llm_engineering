# %% [markdown]
# ## C++ to Python converter

# %%
# imports

import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

# %%
# lets create a python to c++ converter

system_prompt = """
You are a senior software engineer with over 10 years of experience.
You specialize in converting code between programming languages while preserving logic and functionality.
You write clean, idiomatic code in the target language.
You fix minor bugs or inconsistencies in the original code when necessary.
You also add clear comments to improve readability and understanding.
You must output ONLY the final converted code and nothing else. Do not include explanations, markdown, or extra text.
"""

user_prompt_prefix = "Convert the following C++ code into Python. Ensure the output is clean, functional, and well-commented.\n\n"

code = """
#include <iostream>
#include <cstdlib>
#include <ctime>

using namespace std;

void randomGuessGame(int number_turns);

int main() {
    int turns;
    char choice;

    do {
        cout << "Enter number of turns: ";
        cin >> turns;

        randomGuessGame(turns);

        cout << "Try again? (y/n): ";
        cin >> choice;

    } while (choice == 'y' || choice == 'Y');

    cout << "Goodbye!" << endl;
    return 0;
}

void randomGuessGame(int number_turns) {
    srand(time(0));
    int target = rand() % 100 + 1;
    int guess;

    cout << "Guess the number between 1 and 100!" << endl;

    for (int i = 0; i < number_turns; i++) {
        cout << "Turn " << i + 1 << ": ";
        cin >> guess;

        if (guess == target) {
            cout << "You win!" << endl;
            return;
        } else if (guess < target) {
            cout << "Too low!" << endl;
        } else {
            cout << "Too high!" << endl;
        }
    }

    cout << "You lost! The number was " << target << endl;
}
"""

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt_prefix + code}
]

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# import random
#
# def random_guess_game(number_turns):
#     # Generate a random number between 1 and 100
#     target = random.randint(1, 100)
#     print("Guess the number between 1 and 100!")
#
#     # Allow the user to guess for the specified number of turns
#     for i in range(number_turns):
#         guess = int(input(f"Turn {i + 1}: "))
#
#         if guess == target:
#             print("You win!")
#             return
#         elif guess < target:
#             print("Too low!")
#         else:
#             print("Too high!")
#
#     print(f"You lost! The number was {target}")
#
# def main():
#     while True:
#         turns = int(input("Enter number of turns: "))
#         random_guess_game(turns)
#
#         choice = input("Try again? (y/n): ")
#         if choice.lower() != 'y':
#             break
#
#     print("Goodbye!")
#
# if __name__ == "__main__":
#     main()
