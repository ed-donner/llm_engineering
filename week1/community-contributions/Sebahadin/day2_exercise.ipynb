# %% [markdown]
# # C++ to Python Ollama Version

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv(override = True)
api_key = "Ollama"

# %%
# !ollama pull phi3
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest
# pulling 633fc5be925f: 100% ▕██████████████████▏ 2.2 GB
# pulling fa8235e5b48f: 100% ▕██████████████████▏ 1.1 KB
# pulling 542b217f179c: 100% ▕██████████████████▏  148 B
# pulling 8dde1baf1db0: 100% ▕██████████████████▏   78 B
# pulling 23291dc44752: 100% ▕██████████████████▏  483 B
# verifying sha256 digest
# writing manifest
# success

# %%
from openai import OpenAI

OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url = OLLAMA_BASE_URL, api_key = api_key)

# %%
system_prompt = """
You are a senior software engineer with over 10 years of experience.
You specialize in converting code between programming languages while preserving logic and functionality.
You write clean, idiomatic code in the target language.
You fix minor bugs or inconsistencies in the original code when necessary.
You also add clear comments to improve readability and understanding.
You must output ONLY the final converted code and nothing else. Do not include explanations, markdown, or extra text.
"""

user_prompt_prefix = "Convert the following C++ code into Python. Ensure the output is clean, functional, and well-commented.\n\n"

code = """
#include <iostream>
#include <cstdlib>
#include <ctime>

using namespace std;

void randomGuessGame(int number_turns);

int main() {
    int turns;
    char choice;

    do {
        cout << "Enter number of turns: ";
        cin >> turns;

        randomGuessGame(turns);

        cout << "Try again? (y/n): ";
        cin >> choice;

    } while (choice == 'y' || choice == 'Y');

    cout << "Goodbye!" << endl;
    return 0;
}

void randomGuessGame(int number_turns) {
    srand(time(0));
    int target = rand() % 100 + 1;
    int guess;

    cout << "Guess the number between 1 and 100!" << endl;

    for (int i = 0; i < number_turns; i++) {
        cout << "Turn " << i + 1 << ": ";
        cin >> guess;

        if (guess == target) {
            cout << "You win!" << endl;
            return;
        } else if (guess < target) {
            cout << "Too low!" << endl;
        } else {
            cout << "Too high!" << endl;
        }
    }

    cout << "You lost! The number was " << target << endl;
}
"""

# %%
messages = [{"role":"system", "content": system_prompt }, {"role":"user", "content":user_prompt_prefix + code}]
response = ollama.chat.completions.create(model = "phi3", messages = messages)

response.choices[0].message.content
# Out:
# 'import random\n\ndef main():\n    while True:\n        turns = int(input("Enter number of turns: "))\n        \n        if not (1 <= turns <= MAX_TURNS): # Assuming there\'s a maximum defined elsewhere in the system for safety\n            print("Invalid input. Please enter a positive integer within allowed range.")\n            continue\n\n        randomGuessGame(turns)\n\n        choice = input("Try again? (y/n): ")\n        \n        if choice not in (\'y\', \'Y\'): # Using lowered inputs for consistency with the rest of Python convention. \n            break\n            \n    print("Goodbye!")\n    return\n\ndef randomGuessGame(number_turns):\n    s = random.randint(1, MAX_NUMBER) # Assuming some maximum defined elsewhere in the system within safety checks for positive int and not too large input/output range\n    \n    while number_turns > 0:\n        guess = int(input("Guess your own (and higher only): "))\n        \n        if s == guess:\n            print(\'You win!\')\n            return True # Using a short-circuit logic to avoid unnecessary loops.\n            \n        elif guess < s:\n                print(\'Too low, you lose turn...\') \n                              \n        else:       # This will run if `guess\' is greater than the target number since no previous condition was satisfied.  \n            print(\'You win!\')\n            return True\n            \n        turns_left = max(1, number_turns-1)\n    \n    result = False \n    while not result: # Ensuring we have a valid boolean value to use in the next input loop or logic.\n        if s < int(input("Try again? - Enter \'no\' for exiting game: ")) + number_turns-1:\n            break  \n            \n    print(\'You lost! The correct answer is \', end=\'\') # Fixing string formatting based on modern python 3.6+, using f-string syntax if present in the original version to achieve similar behavior would be advisable here as well for best practice adaptation and readability enhancement.)  \n    \n    return result'
