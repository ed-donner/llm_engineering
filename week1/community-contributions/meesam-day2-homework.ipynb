# %%
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from ollama import Client
import os

load_dotenv(override=True)
api_key = os.getenv('OLLAMA_API_KEY')

client = Client(
    host="https://ollama.com",
    headers={'Authorization': 'Bearer ' + os.environ.get('OLLAMA_API_KEY')}
)

system_prompt = """
You are a snarkyassistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""
user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

def summarize(url):
    website = fetch_website_contents(url)
    response = client.chat(
        model = "gpt-oss:120b",
        messages = messages_for(website)
    )
    return response['message']['content']

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))


display_summary("https://www.daraz.pk/")
# Out:
# **BlackenWhite – Because Your Wardrobe Was Too Boring**
#
# - A Pakistani‑based men’s fashion shop that promises “free delivery all over Pakistan” (because apparently your neighbour’s house is a country).
# - The site is a labyrinth of “Somewhere in the Mid”, “Winter Archives”, “Combos”, and a smoking‑hot “CLEARANCE SALE” that still shows all prices at full‑price – guess the sale is just the word “sale”.
# - Product lineup: oversized Irish‑linen shirts, stretch‑linen “Pintex” trousers (yes, that’s a thing), and creased linen shirts that look like they were ironed by a bored monk. All priced at Rs 3,450‑3,950, and apparently all *sold out*—so you’ll have to admire them from the Shopify back‑end.
# - Contact: a phone number you’ll never dial, an email you’ll never receive a reply, and a promise of “Gamechanger Vol VI live now” that sounds more like a cryptic DJ set than a fashion launch.
#
# In short: BlackenWhite sells pricey, minimalist men’s clothes with a side of existential navigation and the occasional “sold out” tease. 🎩✨
