# %%
# imports

import os
from dotenv import load_dotenv
import ollama

#from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')
print(api_key)
# Out:
# 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

# %%
message = "Hey, I am Saksham and I am learning about AI api calls and development"
messages = [
    {
        'role': 'user',
        'content': message
    }
]

# %%
#openAi = OpenAI()
response = ollama.chat(
            model='minimax-m3:cloud',
            messages=messages
        )
print(response['message']['content'])
# Out:
# Hey Saksham! 👋 Welcome to the exciting world of AI API development! That's a fantastic area to be exploring right now.
#
# I'm MiniMax-M3, an AI assistant developed by MiniMax. I'd be happy to help you learn about AI API calls and development!
#
# To give you the most useful guidance, could you tell me a bit more about where you are in your journey? For example:
#
# **🚀 What level are you at?**
# - **Beginner** - Just starting out, learning what APIs are
# - **Intermediate** - Have made some API calls, want to expand knowledge
# - **Advanced** - Building complex applications, looking for optimization
#
# **🎯 What are you interested in learning?**
# - **Basics of APIs** - REST, HTTP methods, JSON, authentication
# - **Making your first API call** - Using tools like cURL, Postman, or Python
# - **Specific AI APIs** - OpenAI, Anthropic, Google Gemini, etc.
# - **Building applications** - Chatbots, AI agents, RAG systems
# - **Prompt engineering** - Crafting effective prompts
# - **Error handling & best practices** - Rate limits, retries, costs
# - **Deployment** - Hosting and scaling AI applications
#
# **💻 What languages/tools do you use?**
# - Python, JavaScript, or others?
#
# Feel free to ask any specific questions you have, and we can dive right in! What would you like to explore first? 😊
