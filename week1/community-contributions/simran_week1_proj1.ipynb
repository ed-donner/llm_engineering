# %%
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
from openai import OpenAI

# %%
feedback_txt=''' The app UI looks good but it crashes frequently on login.
Customer support is slow to respond.
I like the new features, but performance is very poor.
Great idea, but needs stability improvements.'''

# %%
messages=[
    {"role":"system",
    "content":"You are a customer feedback summarization assistant."},
    {
        "role":"user",
        "content":feedback_txt
    }
]

# %%
openai = OpenAI()

# %%
response =openai.chat.completions.create(model="gpt-5-nano", messages=messages)
output =response.choices[0].message.content

# Step 4: print the result
print(output)
