# %%
import requests
import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv(override=True)

URL = "https://en.wikipedia.org/wiki/Pune"
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"

webContent = fetch_website_contents(URL)

google_api_key = os.getenv("GOOGLE_API_KEY")

ollama = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)

messages = [
    {"role": "system", "content": "Extract the main content from the following website and summarize it in a few sentences ."},
    {"role": "user", "content": webContent}
]

response = ollama.chat.completions.create(model="gemini-2.5-flash-lite", messages=messages)

print(response.choices[0].message.content)
# Out:
# Pune is a major city in Maharashtra, India, with a rich history dating back to 758 CE. It was a significant center during the Maratha Empire and later under Peshwa rule, becoming a hub for social reform and nationalism during British rule. Today, Pune is a growing metropolis known for its educational institutions, IT industry, manufacturing, and cultural attractions.
