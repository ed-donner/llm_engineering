# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown,display, update_display

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
def create_brochure_hindi(company_name, url):
    response = openai.chat.completions.create(
        model="gpt-4.1-mini",
        messages=[
            {"role": "system", "content": hindi_brochure_system_prompt},
            {"role": "user", "content": get_hindi_brochure_user_prompt(company_name, url)}
        ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))
"""

# %%
# Get gpt-4o-mini to answer, with streaming

system_prompt = """
You are a helpful assitant in IT and Software Engineering that answers the technology and programming related question that is given in a very supportive and friendly way. You explain your answers such that it could be easily understood by a beginner of the field.
Respond in markdown without code blocks.
"""
user_prompt = f"""
I have a need of your help, I was reviewing this code, and I am not understaning this bit, please help me understand the code properly, as i am just a beginner. The code is:
{question}
"""

def gpt_answer():
    stream = openai.chat.completions.create(
        model=MODEL_GPT, 
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        stream=True
    )
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
gpt_answer()
# Out:
# Sure! Let's break down this code step-by-step so you can understand it better.
#
# ### What the Code Does:
#
# This code defines a function called `create_brochure_hindi`, which is used to generate a brochure in Hindi for a given company. Here's how it works:
#
# 1. **Function Definition**:
#    - `def create_brochure_hindi(company_name, url):`
#    - This line defines a function named `create_brochure_hindi`. It takes two parameters: `company_name` (the name of the company you're creating the brochure for) and `url` (a web address that may be related to the company).
#
# 2. **Making a Request to OpenAI**:
#    - The next line:
#    ```python
#    response = openai.chat.completions.create(
#    ```
#    - This line calls a method `create` from `openai.chat.completions`. This is where the function interacts with OpenAI’s API to generate text based on the input it provides.
#
# 3. **Parameters of the Request**:
#    - Here, it specifies:
#    ```python
#    model="gpt-4.1-mini",
# ...

# %%
# Get Llama 3.2 to answer
