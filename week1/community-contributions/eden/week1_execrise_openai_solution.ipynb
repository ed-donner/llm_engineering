# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display, update_display

# %%
# constants
MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')
openai = OpenAI()

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""
system_prompt = "You are a senior Python expert, that can simplify comples logic into simple concepts. And can answer questions about Python in an understadable way, and you can also provide simple examples."
user_prompt = "Here's a question about Python i would like you to explain and answer to me" + question

# %%
# Get gpt-4o-mini to answer, with streaming
stream = openai.chat.completions.create(
    model=MODEL_GPT,
    messages = [
        {"role": 'system', "content": system_prompt},
        {"role": 'user',   "content": user_prompt},
    ],
    stream=True
)
response = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    response += chunk.choices[0].delta.content or ''
    update_display(Markdown(response), display_id=display_handle.display_id)
# Out:
# Let's break down this code step by step:
#
# 1. **Context**: The code is using a generator's `yield` statement, specifically a `yield from` statement. This is part of a generator function, which allows the function to produce a series of values over time instead of returning a single value.
#
# 2. **The `yield` keyword**: The `yield` keyword is used in Python to turn a function into a generator. A generator function produces a sequence of values using `yield` instead of returning a single value. When `yield` is executed, the function's state is saved, and the function can be resumed later.
#
# 3. **Set comprehension**: The portion in curly braces `{ ... }` is called a set comprehension. It generates a set of unique values based on a specified condition.
#
# 4. **Code breakdown**:
#    - `book.get("author")`: This retrieves the value associated with the "author" key for each `book` in `books`. If the key "author" does not exist, `get` will return `None`.
# ...

# %%
# Get Llama 3.2 to answer
