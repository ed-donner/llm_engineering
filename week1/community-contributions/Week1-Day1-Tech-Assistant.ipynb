# %%
# imports

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI


# Step 1: Create your prompts

system_prompt = "You are a tech enthusiast assistant. Provide a short review of the mobile phone based on the Model, Camera features, and overall user experience."
user_prompt = """
    Here is the website content. Use it to review of the mobile phone based on the Model, Camera features, and overall user experience.
"""

# Step 2: Make the messages list

messages = [
    {"role": "system", "content": "You are a tech enthusiast assistant"},
    {"role": "user", "content": "Review iphone latest version"}
] # fill this in

# Step 3: Call OpenAI

def summarize(url):
    website = fetch_website_contents(url)
    response = gemini.chat.completions.create(
        model = "gemini-3.6-flash",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

display_summary("https://www.gsmarena.com/apple_iphone_17_pro-14049.php")
