# %% [markdown]
# ### Creating a toddler story creator using Gemini API
#
# First all the imports and check the key

# %%
# All imports
import os
from dotenv import load_dotenv
from google import genai
from google.genai import types
from rich.console import Console
from rich.markdown import Markdown

# Load environment variables in a file called .env
load_dotenv(override=True)
client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

# Check the key
if not client:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %% [markdown]
# Toddler Story Creator Source Code - I found Gemini to be simpler than OpenAI, no need for a dict of system and user prompts, everything goes in the generate content call to the API
#
# Feel free to use a different model as needed

# %%
def toddler_story_creator(url):
    # Step 1: Create your prompts
    system_prompt = """You are an assistant that will create a story for a toddler from those contents that should 
    keep them occupied for 5 minutes. Accuracy is not important, the story should be engaging and prefarably have 
    reference to animals  """

    user_prompt = f"Summarize contents of the website {url}"

    # And now: call the Gemini API. 
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        # 1. System Prompt goes here
        config=types.GenerateContentConfig(
            system_instruction=system_prompt
        ),
        # 2. User Prompt goes here
        contents=user_prompt
    )   
    console = Console()
    md = Markdown(response.text)
    console.print(md)

# %% [markdown]
# And now the fun part - Call the story creator assistant with any website here

# %%
toddler_story_creator("https://edwarddonner.com")
# Out:
# Okay, let's turn "Edward Donner" and all his grown-up business talk into a fun adventure for a toddler, full of
# friendly animals!
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# The Story of Barnaby the Bear and the Giggle Garden!
#
# Once upon a time, in a sparkly, sunny forest, lived a friendly little bear named Barnaby. Barnaby wasn't like other
# bears who just munched on berries all day. Oh no! Barnaby loved to think! He loved to think about how to make
# things extra good and super helpful for all his animal friends.
#
# One morning, Barnaby saw his friends looking a little bit... bored! There was Squeaky the Squirrel, who loved to
# gather acorns but didn't know where to put them all. There was Hoot the Owl, who was very wise but sometimes didn't
# know how to share all his good ideas. And there was Bouncy the Bunny, who loved to jump and play but wished there
# was a new, exciting place to bounce!
#
# Barnaby put on his thinking cap (it was a little leaf on his head!) and thought, "Hmm, how can I help all my
# friends have a super-duper happy day, every day?"
#
# He decided they needed a Giggle Garden! A special place where everyone could play and share and grow happy smiles!
#
# First, Barnaby talked to Squeaky the Squirrel. "Squeaky," he said, "instead of just gathering acorns, what if you
# helped gather the sparkliest pebbles and softest moss? We can use them to make a comfy path in our Giggle Garden!"
# Squeaky loved the idea! He zoomed off, zoom-zoom-zoom, gathering the best things!
#
# Next, Barnaby hooted hello to Hoot the Owl. "Hoot," Barnaby said, "you have so many smart ideas! How about you help
# us plan where to put the bouncy mushroom and the sparkly waterfall? We need your wise eyes to make sure it's safe
# and fun for everyone, even the tiny ladybugs!" Hoot flapped his wings happily and started pointing with his beak,
# hoot-hoot-hooting his best ideas!
#
# Then, Barnaby bounced over to Bouncy the Bunny. "Bouncy," he giggled, "you have so much energy! Can you help us
# find the sunniest spot for our yummy berry bushes? And maybe help us try out the new bouncy mushroom to make sure
# it's extra springy?" Bouncy boing-boing-boinged with excitement, ready to help test everything!
#
# Barnaby helped everyone work together! He helped Squeaky put the sparkly pebbles in a line. He listened to Hoot's
# ideas about where the tallest flowers should go. And he made sure Bouncy had enough room to bounce and play without
# bumping into anyone.
#
# They worked all morning, chitter-chatter and hoot-hoot and boing-boing! And guess what? By afternoon, their Giggle
# Garden was ready!
#
# It had a path made of sparkly pebbles, soft moss for sitting, a wobbly bouncy mushroom, and juicy red berry bushes
# for everyone to share. Hoot the Owl even hung up shiny leaves that tinkled like little bells in the breeze!
#
# All the animals loved it! Squeaky the Squirrel scurried along the pebble path. Hoot the Owl perched on the highest
# flower, hooting happy tunes. And Bouncy the Bunny bounced so high on the mushroom, he nearly touched the clouds!
# Boing-boing-boing!
#
# Barnaby the Bear watched his friends playing and sharing and giggling. He felt so happy! He had helped everyone
# think big, work together, and make something super special that would last for many, many sunny days. And that,
# thought Barnaby, was the best kind of fun there was!
#
# The end! Now, what do you think Barnaby should help his friends build next? A rainbow slide? Or a cookie tree?
