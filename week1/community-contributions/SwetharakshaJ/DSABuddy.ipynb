# %% [markdown]
# Learn any data structure concept

# %%
# imports

import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
from openai import OpenAI

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

openai = OpenAI()
# Out:
# API key found and looks good so far!

# %%
# Define  system (role and background) and user prompt (task in hand or action)

system_prompt = """ you are a data structures and algorithm expert and a great teacher who is capable of simplifying the most 
challenging data structures with easy real life examples. you are good at teaching these concepts to complete beginners as well as advances engineers.
"""

user_prompt_prefix = """ Here is the data structure concept user wants to learn. Explain the concept cleary in a very simple way. 
Provide 2 examples of using this concept to solve coding questions """

# %%
def explanationFor(concept):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + concept}
    ]

def fetchExplanation(concept) :
    response = openai.chat.completions.create(
        model = "gpt-4.1-mini",
        messages = explanationFor(concept)
    )
    return response.choices[0].message.content

def dsaBuddy(concept) :
    details = fetchExplanation (concept)
    display(Markdown(details))

# %%
dsaBuddy("arrays")
# Out:
# Great! Let's dive into arrays, one of the fundamental data structures in programming.
#
# ### What is an Array?
#
# An **array** is like a row of lockers, each locker positioned next to each other, and each locker can hold one item. Imagine you have 5 lockers in a row, numbered from 0 to 4. You can put a number, letter, or any data inside each locker, and you can easily find what is in any locker by knowing its number.
#
# - The number of lockers is fixed when you create the array.
# - The locker positions (indices) start from 0 and go to the array length minus 1.
# - Accessing any item in the array is very fast because you just need to know its position.
#
# ### Simple Real-Life Example:
#
# Imagine a row of pigeonholes for mail, marked from 0 to 9. If you want to find mailbox number 5, you just go directly to mailbox 5—it doesn’t matter what’s inside the mailboxes before it. This direct access is the strength of arrays.
#
# ---
#
# # Coding Example 1: Sum of Elements in an Array
#
# ...
