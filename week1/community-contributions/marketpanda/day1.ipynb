# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate familiarity with OpenAI API, and also Ollama, this tool that takes a technical question,
# and responds with an explanation.

# %%
# imports
import os
import requests
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# constants
MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

#Check the keys
if openai_api_key:
    print(f"OpenAI API Key exists and begins with '{openai_api_key[:8]}'")
else: 
    print("OpenAI API Key not set")
if (openrouter_api_key):
    print(f"OpenRouter API Key exists and begins with '{openrouter_api_key[:7]}'")
else:
    print("OpenRouter API Key not set")
# Out:
# OpenAI API Key exists and begins with 'sk-proj-'
# OpenRouter API Key not set

# %%
# here is the question; type over this to ask something new

question = """
What are the hiking best hiking destinations in the Philippines?

"""

# %%
openai = OpenAI(api_key=openai_api_key)
openai_stream = openai.chat.completions.create(model=MODEL_GPT, messages=[{"role": "user", "content": question}], stream=True)
openai_response = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in openai_stream:
    openai_response += chunk.choices[0].delta.content or ''
    update_display(Markdown(openai_response), display_id=display_handle.display_id)
# Out:
# The Philippines is known for its stunning natural landscapes, making it a fantastic destination for hiking enthusiasts. Here are some of the best hiking destinations in the country:
#
# 1. **Mount Pulag** (Benguet) - Known for its sea of clouds and diverse flora and fauna, Mount Pulag is the country's highest peak outside of Luzon, standing at 2,922 meters. The hike offers breathtaking views, especially at sunrise.
#
# 2. **Mount Apo** (Davao del Sur) - The highest mountain in the Philippines at 2,954 meters, Mount Apo is a challenging trek that rewards hikers with stunning views, unique wildlife, and a chance to see a crater lake.
#
# 3. **Mount Kitanglad** (Bukidnon) - This mountain is part of the Kitanglad Mountain Range and is known for its cool climate and diverse ecosystems. The trek to its summit provides gorgeous views of surrounding mountains and valleys.
#
# 4. **Mount Mayon** (Albay) - Famous for its perfect cone shape, Mount Mayon offers various trails ranging from easy to challenging. The views of the volcano and surrounding landscapes are spectacular.
#
# 5. **Mount Iglit** (Mindoro) - A less crowded destination, Mount Iglit is known for its unique wildlife and beautiful trails. It’s part of the Iglit-Baco National Park.
#
# 6. **Chocolate Hills** (Bohol) - While not a traditional hike, exploring the trails around these iconic geological formations offers stunning views and encounters with local flora.
#
# 7. **Mariveles Mountains** (Bataan) - This mountain range offers a variety of trekking options with diverse landscapes, historical significance, and incredible views of Manila Bay and the South China Sea.
#
# 8. **Mount Kalatungan** (Bukidnon) - A lesser-known gem, this mountain is less crowded and offers spectacular views of surrounding valleys, along with a chance to see unique endemic species.
#
# 9. **Mount Hamiguitan** (Davao Oriental) - This UNESCO World Heritage Site offers a unique blend of ecosystems and stunning landscapes. The hike showcases diverse flora, including bonsai trees.
#
# 10. **Mount Batur** (Bali, Indonesia) - While not part of the Philippines, it's worth mentioning as a popular hiking destination nearby. Many visitors combine a trip to the Philippines with a hike on Batur for sunrise views.
#
# 11. **Banahaw** (Quezon Province) - A favorite among locals, Mount Banahaw is known for its spiritual significance and a variety of trails that offer stunning views and waterfalls.
#
# 12. **Dulang-Dulang** (Bukidnon) - The second-highest mountain in the Philippines, Dulang-Dulang offers a challenging trek and breathtaking views, often enveloped in clouds.
#
# Before embarking on a hike, it’s essential to check local regulations, prepare adequately, and consider hiring local guides, especially for more challenging trails.

# %%
ollama = OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")
ollama_response = ollama.chat.completions.create(model=MODEL_LLAMA, messages=[{"role": "user", "content": question}])
ollama.response.choices[0].message.content
