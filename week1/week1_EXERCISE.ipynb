# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
from dotenv import load_dotenv
import openai

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Get gpt-4o-mini to answer, with streaming
from httpx import stream
from openai import OpenAI


openai = OpenAI()
stream = openai.responses.create(
    model=MODEL_GPT,
    input = question,
    stream=True
)

for chunk in stream:
    if chunk.type == "response.output_text.delta":
        print(chunk.delta,end="",flush=True)
# Out:
# The provided code snippet is a Python expression that uses a generator expression along with the `yield from` statement. Here's a breakdown of what it does:
#
# 1. **Set Comprehension**:
#    - `{book.get("author") for book in books if book.get("author")}` is a set comprehension.
#    - It iterates over each `book` in the iterable `books`.
#    - For each `book`, it retrieves the value associated with the key `"author"` using the `get` method.
#    - The `if book.get("author")` condition checks that the author is not `None` (or any falsy value).
#    - This comprehension creates a set of unique authors from the `books`.
#
# 2. **Yield From**:
#    - `yield from` is used in the context of a generator function. It yields each item from the iterable that follows it.
#    - In this case, it yields each unique author obtained from the set comprehension.
#
# ### Purpose of the Code
# - The purpose of this code is to extract a list of unique authors from a collection of `books`, where each `book` is expected to contain an "author" field. It effectively filters out any books that do not have an author listed, ensuring that only valid author names are yielded.
#
# ### Why Use This Code?
# - **Avoid Duplicates**: By using a set comprehension, you ensure that each author is only yielded once, eliminating duplicates.
# - **Efficiency**: The `yield from` construct allows for efficient iteration over a potentially large collection without creating an intermediate list or consuming additional memory unnecessarily.
# - **Simpler Code**: It provides a concise way to extract and yield multiple values from a collection in a single line.
#
# Overall, this snippet is a compact way to create a generator that produces unique author names from a list of books, only including those that actually have an author listed.

# %%
# Get Llama 3.2 to answer

ollama = OpenAI(base_url="http://localhost:11434/v1",api_key="ollama")

stream = ollama.responses.create(
    model=MODEL_LLAMA,
    input = question,
    stream=True
)

for chunk in stream:
    if chunk.type == "response.output_text.delta":
        print(chunk.delta,end="",flush=True)
# Out:
# This line of code is using a feature called "yield from" in Python, which was introduced in version 3.3.
#
# Let's break it down:
#
# - `for book in books`: This part is a standard `for` loop that iterates over an iterable object named `books`.
#
# - `if book.get("author")`: This condition filters the books based on whether they have an "author" key.
#
# - `{book.get("author")} for book in books if book.get("author")`: This is a generator expression. It's like a list comprehension, but instead of returning a list, it returns a generator object.
#
#   - `for book in books`: The same as above.
#
#   - `if book.get("author")`: The same as above.
#
#   - `{book.get("author")}`: This returns the value of `"author"` from each book where the condition is true. Again, using `.get()` ensures that we don't get a KeyError if the key doesn't exist.
#
# - `yield from {book.get("author") for book in books if book.get("author")}`: The "yield from" part takes all the values returned by the inner generator expression and yields them one after another, effectively flattening the list of lists into a single list. However, since we're already generating this value on-the-fly (and not storing it), you can think of it as yielding each author's name directly without having to store those names in memory.
#
# In essence, this line is using a generator expression inside `yield from` to yield the authors' names one by one, while filtering out any books that don't have an "author" key. This has the effect of avoiding unnecessary computations and reducing memory usage compared to storing all the values in a list and then yielding them.
#
# Example:
#
# ```python
# class Book:
#     def __init__(self, title, author):
#         self.title = title
#         self.author = author
#
# books = [
#     Book("Book 1", "Author 1"),
#     Book("Book 2", None),
#     Book("Book 3", "Author 3")
# ]
#
# for author in yield from {book.get("author") for book in books if book.get("author")}:
#     print(author)
# ```
#
# This will output:
#
# ```
# Author 1
# Author 3
# ```
