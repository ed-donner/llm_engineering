# %% [markdown]
# # Mistral API Tests

# %%
import os
from mistralai.client import Mistral

client = Mistral(api_key=os.environ["MISTRAL_API_KEY"])

response = client.chat.complete(
    model="mistral-large-latest",
    messages=[
        {"role": "user", "content": "What time is it currently in Vancouver, Canada?"}
    ],
)

print(response.choices[0].message.content)
# Out:
# To find the current time in **Vancouver, Canada**, you can check a reliable time service like:
#
# - **[Time.is](https://time.is/Vancouver)**
# - **[World Clock](https://www.timeanddate.com/worldclock/canada/vancouver)**
#
# ### **Current Time Zone:**
# Vancouver is in the **Pacific Time Zone (PT)**, which is:
# - **UTC−8** (Standard Time, **PST**) – from early November to mid-March
# - **UTC−7** (Daylight Saving Time, **PDT**) – from mid-March to early November
#
# ### **Quick Check:**
# - If it's **Daylight Saving Time (PDT)**, Vancouver is **3 hours behind New York (EDT)** and **8 hours behind UTC**.
# - If it's **Standard Time (PST)**, Vancouver is **4 hours behind New York (EST)** and **8 hours behind UTC**.
#
# Would you like me to check the exact time for you right now? 😊

# %% [markdown]
# ## Ollama: Access a local model

# %%
import os
import argparse
import ollama
from dotenv import load_dotenv

load_dotenv()
localModelName = os.getenv("LOCAL_OLLAMA_MODEL_NAME")

parser = argparse.ArgumentParser(description="Run a prompt with a local Ollama model.")
parser.add_argument("prompt", type=str, help="The prompt to send to the model")
args = parser.parse_args()

print(ollama.list()['models'])
response = ollama.generate(
    model=localModelName,
    prompt=args[0]
)

print(response['response'])
# Out:
# usage: ipykernel_launcher.py [-h] prompt
# ipykernel_launcher.py: error: the following arguments are required: prompt
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /Users/dave/dev/ai/udemy/ai-engineer-core-track/llm_engineering/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
