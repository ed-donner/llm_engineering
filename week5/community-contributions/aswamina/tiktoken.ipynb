# %%
import tiktoken

# %%
encoding = tiktoken.encoding_for_model("gpt-4o")

text = "This is a test of tokens in a string"
tokens = encoding.encode(text)
print(tokens)
# Out:
# [2500, 382, 261, 1746, 328, 20290, 306, 261, 1621]

# %%
decoded_text = encoding.decode(tokens)
print(decoded_text)
# Out:
# This is a test of tokens in a string
