# %% [markdown]
# Instead of the meta-llama/Llama-3.2-3B trained by Ed, I will be training Phi3 mini, I have chosen Phi3 mini becaus of its small size.
#
# Link to colab: https://colab.research.google.com/drive/16FUF0Rvt7PMAEvBa6k1_FPQjm8WWTmWY?usp=sharing
