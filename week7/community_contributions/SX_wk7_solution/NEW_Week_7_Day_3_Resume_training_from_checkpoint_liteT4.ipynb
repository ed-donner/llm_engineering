# %% [markdown]
# ## Adapted Colab file to resume training from checkpoint for the lite model
#
# ### Resuming fine-tuning from a checkpoint saved to the HuggingFace Hub
#
# [Continue Training](https://colab.research.google.com/drive/1g5I_hi1R-wABoqWW_hEa-3OsFMrV1qmB?usp=sharing)
