# %% [markdown]
# # The Price Is Right
#
# ### Evaluate my own fine-tuned open source model - lite version
#
# [Test my lite model](https://drive.google.com/file/d/1cWCC765C8QOFc3_fVF23YHSjhLJERjl5/view?usp=sharing)
