# %% [markdown]
# ## Predict Product Prices
#
# ### And now, to evaluate our fine-tuned open source model

# %%
# # pip installs

# !pip install -q --upgrade torch==2.5.1+cu124 torchvision==0.20.1+cu124 torchaudio==2.5.1+cu124 --index-url https://download.pytorch.org/whl/cu124
# !pip install -q --upgrade requests==2.32.3 bitsandbytes==0.46.0 transformers==4.48.3 accelerate==1.3.0 datasets==3.2.0 peft==0.14.0 trl==0.14.0 matplotlib wandb

# %%
# imports

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import torch.nn.functional as F
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, set_seed
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
from peft import PeftModel
import matplotlib.pyplot as plt
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
# Constants

BASE_MODEL = "meta-llama/Meta-Llama-3.1-8B"
PROJECT_NAME = "pricer"
HF_USER = "nikhilr12" # your HF name here! Or use mine if you just want to reproduce my results.

# The run itself

RUN_NAME = "2025-10-27_07.15.03"
PROJECT_RUN_NAME = f"{PROJECT_NAME}-{RUN_NAME}"
REVISION = None # or REVISION = None
FINETUNED_MODEL = f"{HF_USER}/{PROJECT_RUN_NAME}"

# Uncomment this line if you wish to use my model
# FINETUNED_MODEL = f"ed-donner/{PROJECT_RUN_NAME}"

# Data

DATASET_NAME = f"{HF_USER}/pricer-data"
# Or just use the one I've uploaded
# DATASET_NAME = "ed-donner/pricer-data"

# Hyperparameters for QLoRA

QUANT_4_BIT = True

# %matplotlib inline

# Used for writing to output in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %% [markdown]
# ### Log in to HuggingFace
#
# If you don't already have a HuggingFace account, visit https://huggingface.co to sign up and create a token.
#
# Then select the Secrets for this Notebook by clicking on the key icon in the left, and add a new secret called `HF_TOKEN` with the value as your token.

# %%
# Log in to HuggingFace

hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']

# %%
test[0]
# Out:
# {'text': "How much does this cost to the nearest dollar?\n\nOEM AC Compressor w/A/C Repair Kit For Ford F150 F-150 V8 & Lincoln Mark LT 2007 2008 - BuyAutoParts NEW\nAs one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. This A/C Compressor and Components Kit is manufactured and tested to the strictest OE standards for unparalleled performance. Built for trouble-free ownership and 100% visually inspected and quality tested, this A/C Compressor and Components Kit is backed by our 100% satisfaction guarantee. Guaranteed Exact Fit for easy installation 100% BRAND NEW, premium ISO/TS 16949 quality - tested to meet or exceed OEM specifications Engineered for superior durability, backed by industry-leading unlimited-mileage warranty Included in this K\n\nPrice is $",
#  'price': 374.41}

# %% [markdown]
# ## Now load the Tokenizer and Model

# %%
# pick the right quantization (thank you Robert M. for spotting the bug with the 8 bit version!)

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

# Load the fine-tuned model with PEFT
if REVISION:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL, revision=REVISION)
else:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL)


print(f"Memory footprint: {fine_tuned_model.get_memory_footprint() / 1e6:.1f} MB")
# Out:
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/752 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/109M [00:00<?, ?B/s]
# Memory footprint: 5700.6 MB

# %%
fine_tuned_model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#     )
#   )
# )

# %% [markdown]
# # THE MOMENT OF TRUTH!
#
# ## Use the model in inference mode
#
# Remember, GPT-4o had an average error of \$76.
# Llama 3.1 base model had an average error of \$396.
# This human had an error of \$127.
#
# ## Caveat
#
# Keep in mind that prices of goods vary considerably; the model can't predict things like sale prices that it doesn't have any information about.

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
extract_price("Price is $a fabulous 899.99 or so")
# Out:
# 899.99

# %%
# Original prediction function takes the most likely next token

def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = fine_tuned_model.generate(inputs, attention_mask=attention_mask, max_new_tokens=3, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    return extract_price(response)

# %%
# An improved prediction function takes a weighted average of the top 3 choices
# This code would be more complex if we couldn't take advantage of the fact
# That Llama generates 1 token for any 3 digit number

top_K = 3

def improved_model_predict(prompt, device="cuda"):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    attention_mask = torch.ones(inputs.shape, device=device)

    with torch.no_grad():
        outputs = fine_tuned_model(inputs, attention_mask=attention_mask)
        next_token_logits = outputs.logits[:, -1, :].to('cpu')

    next_token_probs = F.softmax(next_token_logits, dim=-1)
    top_prob, top_token_id = next_token_probs.topk(top_K)
    prices, weights = [], []
    for i in range(top_K):
      predicted_token = tokenizer.decode(top_token_id[0][i])
      probability = top_prob[0][i]
      try:
        result = float(predicted_token)
      except ValueError as e:
        result = 0.0
      if result > 0:
        prices.append(result)
        weights.append(probability)
    if not prices:
      return 0.0, 0.0
    total = sum(weights)
    weighted_prices = [price * weight / total for price, weight in zip(prices, weights)]
    return sum(weighted_prices).item()

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(improved_model_predict, test)
# Out:
# 1: Guess: $266.50 Truth: $374.41 Error: $107.91 SLE: 0.11 Item: OEM AC Compressor w/...
# 2: Guess: $123.19 Truth: $225.11 Error: $101.92 SLE: 0.36 Item: Motorcraft YB3125 Fa...
# 3: Guess: $63.34 Truth: $61.68 Error: $1.66 SLE: 0.00 Item: Dorman Front Washer ...
# 4: Guess: $516.00 Truth: $599.99 Error: $83.99 SLE: 0.02 Item: HP Premium HD Plus T...
# 5: Guess: $58.56 Truth: $16.99 Error: $41.57 SLE: 1.43 Item: Super Switch Pickup ...
# 6: Guess: $12.01 Truth: $31.99 Error: $19.98 SLE: 0.87 Item: Horror Bookmarks, Re...
# 7: Guess: $153.00 Truth: $101.79 Error: $51.21 SLE: 0.16 Item: SK6241 - Stinger 4 G...
# 8: Guess: $281.50 Truth: $289.00 Error: $7.50 SLE: 0.00 Item: Godox ML60Bi LED Lig...
# 9: Guess: $515.00 Truth: $635.86 Error: $120.86 SLE: 0.04 Item: Randall G3 Plus Comb...
# 10: Guess: $64.12 Truth: $65.99 Error: $1.86 SLE: 0.00 Item: HOLDWILL 6 Pack LED ...
# 11: Guess: $294.50 Truth: $254.21 Error: $40.29 SLE: 0.02 Item: Viking Horns 3 Gallo...
# 12: Guess: $253.00 Truth: $412.99 Error: $159.99 SLE: 0.24 Item: CURT 70110 Custom To...
# 13: Guess: $34.31 Truth: $205.50 Error: $171.19 SLE: 3.12 Item: Solar HAMMERED BRONZ...
# 14: Guess: $176.25 Truth: $248.23 Error: $71.98 SLE: 0.12 Item: COSTWAY Electric Tum...
# 15: Guess: $350.50 Truth: $399.00 Error: $48.50 SLE: 0.02 Item: FREE SIGNAL TV Trans...
# 16: Guess: $350.50 Truth: $373.94 Error: $23.44 SLE: 0.00 Item: Bilstein 5100 Monotu...
# 17: Guess: $110.12 Truth: $92.89 Error: $17.23 SLE: 0.03 Item: Sangean K-200 Multi-...
# 18: Guess: $108.94 Truth: $51.99 Error: $56.95 SLE: 0.53 Item: Charles Leonard Magn...
# 19: Guess: $220.25 Truth: $179.00 Error: $41.25 SLE: 0.04 Item: Gigabyte AMD Radeon ...
# 20: Guess: $12.03 Truth: $19.42 Error: $7.39 SLE: 0.20 Item: 3dRose LLC 8 x 8 x 0...
# 21: Guess: $370.00 Truth: $539.95 Error: $169.95 SLE: 0.14 Item: ROKINON 85mm F1.4 Au...
# 22: Guess: $107.56 Truth: $147.67 Error: $40.11 SLE: 0.10 Item: Headlight Assembly C...
# 23: Guess: $15.64 Truth: $24.99 Error: $9.35 SLE: 0.20 Item: ASI NAUTICAL 2.5 Inc...
# 24: Guess: $87.50 Truth: $149.00 Error: $61.50 SLE: 0.28 Item: Behringer TUBE OVERD...
# 25: Guess: $12.02 Truth: $16.99 Error: $4.97 SLE: 0.10 Item: Fun Express Insect F...
# 26: Guess: $10.69 Truth: $7.99 Error: $2.70 SLE: 0.07 Item: WAFJAMF Roller Stamp...
# 27: Guess: $127.00 Truth: $199.99 Error: $72.99 SLE: 0.20 Item: Capulina Tiffany Flo...
# 28: Guess: $277.25 Truth: $251.45 Error: $25.80 SLE: 0.01 Item: Apple Watch Series 6...
# 29: Guess: $116.75 Truth: $231.62 Error: $114.87 SLE: 0.46 Item: ICON 01725 Tandem Ax...
# 30: Guess: $133.12 Truth: $135.00 Error: $1.88 SLE: 0.00 Item: SanDisk 128GB Ultra ...
# 31: Guess: $166.00 Truth: $356.62 Error: $190.62 SLE: 0.58 Item: Velvac - 715427
# 2020...
# 32: Guess: $222.50 Truth: $257.99 Error: $35.49 SLE: 0.02 Item: TCMT Passenger Backr...
# 33: Guess: $36.28 Truth: $27.99 Error: $8.29 SLE: 0.06 Item: Alnicov 63.5MM Brass...
# 34: Guess: $129.50 Truth: $171.20 Error: $41.70 SLE: 0.08 Item: Subaru Forester Outb...
# 35: Guess: $264.00 Truth: $225.00 Error: $39.00 SLE: 0.03 Item: Richmond Auto Uphols...
# 36: Guess: $156.25 Truth: $105.00 Error: $51.25 SLE: 0.16 Item: AP-39 Automotive Pai...
# 37: Guess: $150.38 Truth: $299.99 Error: $149.62 SLE: 0.47 Item: Road Top Wireless Ca...
# 38: Guess: $402.75 Truth: $535.09 Error: $132.34 SLE: 0.08 Item: Gibson Performance E...
# 39: Guess: $23.75 Truth: $12.33 Error: $11.42 SLE: 0.38 Item: Bella Tunno Happy Li...
# 40: Guess: $114.25 Truth: $84.99 Error: $29.26 SLE: 0.09 Item: CANMORE H300 Handhel...
# 41: Guess: $17.67 Truth: $15.99 Error: $1.68 SLE: 0.01 Item: DCPOWER AC Adapter C...
# 42: Guess: $36.34 Truth: $62.44 Error: $26.10 SLE: 0.28 Item: Sharp, Commercial De...
# 43: Guess: $100.19 Truth: $82.99 Error: $17.20 SLE: 0.03 Item: Melissa & Doug Lifel...
# 44: Guess: $252.25 Truth: $599.95 Error: $347.70 SLE: 0.75 Item: Sony SSCS8 2-Way Cen...
# 45: Guess: $279.00 Truth: $194.99 Error: $84.01 SLE: 0.13 Item: ASUS Chromebook CX1,...
# 46: Guess: $335.50 Truth: $344.95 Error: $9.45 SLE: 0.00 Item: FiiO X7 32GB Hi-Res ...
# 47: Guess: $32.56 Truth: $37.99 Error: $5.43 SLE: 0.02 Item: TORRO Leather Case C...
# 48: Guess: $248.25 Truth: $224.35 Error: $23.90 SLE: 0.01 Item: Universal Air Condit...
# 49: Guess: $337.50 Truth: $814.00 Error: $476.50 SLE: 0.77 Item: Street Series Stainl...
# 50: Guess: $352.25 Truth: $439.88 Error: $87.63 SLE: 0.05 Item: Lenovo IdeaPad 3 Lap...
# 51: Guess: $301.25 Truth: $341.43 Error: $40.18 SLE: 0.02 Item: Access Bed Covers To...
# 52: Guess: $36.22 Truth: $46.78 Error: $10.56 SLE: 0.06 Item: G.I. JOE Hasbro 3 3/...
# 53: Guess: $154.00 Truth: $171.44 Error: $17.44 SLE: 0.01 Item: T&S Brass Double Pan...
# 54: Guess: $200.25 Truth: $458.00 Error: $257.75 SLE: 0.68 Item: ZTUOAUMA Fuel Inject...
# 55: Guess: $147.00 Truth: $130.75 Error: $16.25 SLE: 0.01 Item: Hp Prime Graphing Ca...
# 56: Guess: $58.22 Truth: $83.81 Error: $25.59 SLE: 0.13 Item: Lowrance Nmea 2000 2...
# 57: Guess: $139.25 Truth: $386.39 Error: $247.14 SLE: 1.03 Item: Jeep Genuine Accesso...
# 58: Guess: $99.75 Truth: $169.00 Error: $69.25 SLE: 0.27 Item: GODOX CB-06 Hard Car...
# 59: Guess: $10.76 Truth: $17.95 Error: $7.19 SLE: 0.23 Item: Au-Tomotive Gold, IN...
# 60: Guess: $134.50 Truth: $269.00 Error: $134.50 SLE: 0.48 Item: Snailfly Black Roof ...
# 61: Guess: $64.25 Truth: $77.77 Error: $13.52 SLE: 0.04 Item: KING SHA Anti Glare ...
# 62: Guess: $153.25 Truth: $88.99 Error: $64.26 SLE: 0.29 Item: APS Compatible with ...
# 63: Guess: $224.25 Truth: $364.41 Error: $140.16 SLE: 0.23 Item: Wilwood Engineering ...
# 64: Guess: $145.75 Truth: $127.03 Error: $18.72 SLE: 0.02 Item: ACDelco Gold Starter...
# 65: Guess: $388.25 Truth: $778.95 Error: $390.70 SLE: 0.48 Item: UWS Matte Black Heav...
# 66: Guess: $298.75 Truth: $206.66 Error: $92.09 SLE: 0.13 Item: Dell Latitude E5440 ...
# 67: Guess: $41.50 Truth: $35.94 Error: $5.56 SLE: 0.02 Item: (Plug and Play) Spar...
# 68: Guess: $151.50 Truth: $149.00 Error: $2.50 SLE: 0.00 Item: The Ultimate Roadsid...
# 69: Guess: $191.50 Truth: $251.98 Error: $60.48 SLE: 0.07 Item: Brand New 18 x 8.5 R...
# 70: Guess: $126.12 Truth: $160.00 Error: $33.88 SLE: 0.06 Item: Headlight Headlamp L...
# 71: Guess: $34.97 Truth: $39.99 Error: $5.02 SLE: 0.02 Item: Lilo And Stitch Delu...
# 72: Guess: $158.62 Truth: $362.41 Error: $203.79 SLE: 0.68 Item: AC Compressor & A/C ...
# 73: Guess: $129.75 Truth: $344.00 Error: $214.25 SLE: 0.94 Item: House Of Troy Pinnac...
# 74: Guess: $62.38 Truth: $25.09 Error: $37.28 SLE: 0.79 Item: Juno T29 WH Floating...
# 75: Guess: $122.75 Truth: $175.95 Error: $53.20 SLE: 0.13 Item: Sherman GO-PARTS - f...
# 76: Guess: $209.25 Truth: $132.64 Error: $76.61 SLE: 0.21 Item: Roland RPU-3 Electro...
# 77: Guess: $302.00 Truth: $422.99 Error: $120.99 SLE: 0.11 Item: Rockland VMI14 12,00...
# 78: Guess: $140.12 Truth: $146.48 Error: $6.35 SLE: 0.00 Item: Max Advanced Brakes ...
# 79: Guess: $144.12 Truth: $156.83 Error: $12.71 SLE: 0.01 Item: Quality-Built 11030 ...
# 80: Guess: $129.25 Truth: $251.99 Error: $122.74 SLE: 0.44 Item: Lucida LG-510 Studen...
# 81: Guess: $131.25 Truth: $940.33 Error: $809.08 SLE: 3.85 Item: Longacre Aluminum Tu...
# 82: Guess: $36.25 Truth: $52.99 Error: $16.74 SLE: 0.14 Item: Motion Pro Adjustabl...
# 83: Guess: $93.50 Truth: $219.95 Error: $126.45 SLE: 0.72 Item: Glyph Thunderbolt 3 ...
# 84: Guess: $168.38 Truth: $441.03 Error: $272.65 SLE: 0.92 Item: TOYO Open Country MT...
# 85: Guess: $215.12 Truth: $168.98 Error: $46.15 SLE: 0.06 Item: Razer Seiren X USB S...
# 86: Guess: $3.05 Truth: $2.49 Error: $0.56 SLE: 0.02 Item: Happy Birthday to Da...
# 87: Guess: $178.12 Truth: $98.62 Error: $79.50 SLE: 0.34 Item: Little Tikes My Real...
# 88: Guess: $298.00 Truth: $256.95 Error: $41.05 SLE: 0.02 Item: Studio M Peace and H...
# 89: Guess: $21.61 Truth: $30.99 Error: $9.38 SLE: 0.12 Item: MyVolts 12V Power Su...
# 90: Guess: $232.00 Truth: $569.84 Error: $337.84 SLE: 0.80 Item: Dell Latitude 7212 R...
# 91: Guess: $129.12 Truth: $177.99 Error: $48.87 SLE: 0.10 Item: Covermates Contour F...
# 92: Guess: $337.50 Truth: $997.99 Error: $660.49 SLE: 1.17 Item: Westin Black HDX Gri...
# 93: Guess: $249.25 Truth: $219.00 Error: $30.25 SLE: 0.02 Item: Fieldpiece JL2 Job L...
# 94: Guess: $271.50 Truth: $225.55 Error: $45.95 SLE: 0.03 Item: hansgrohe Talis S Mo...
# 95: Guess: $1.47 Truth: $495.95 Error: $494.48 SLE: 28.13 Item: G-Technology G-SPEED...
# 96: Guess: $216.75 Truth: $942.37 Error: $725.62 SLE: 2.15 Item: DreamLine Shower Doo...
# 97: Guess: $25.42 Truth: $1.94 Error: $23.48 SLE: 4.82 Item: Sanctuary Square Bac...
# 98: Guess: $200.38 Truth: $284.34 Error: $83.96 SLE: 0.12 Item: Pelican Protector 17...
# 99: Guess: $158.25 Truth: $171.90 Error: $13.65 SLE: 0.01 Item: Brock Replacement Dr...
# 100: Guess: $134.00 Truth: $144.99 Error: $10.99 SLE: 0.01 Item: Carlinkit Ai Box Min...
# 101: Guess: $248.38 Truth: $470.47 Error: $222.10 SLE: 0.41 Item: StarDot YouTube Live...
# 102: Guess: $56.28 Truth: $66.95 Error: $10.67 SLE: 0.03 Item: Atomic Compatible ME...
# 103: Guess: $130.12 Truth: $117.00 Error: $13.12 SLE: 0.01 Item: Bandai Awakening of ...
# 104: Guess: $258.25 Truth: $172.14 Error: $86.11 SLE: 0.16 Item: Fit System 62135G Pa...
# 105: Guess: $298.50 Truth: $392.74 Error: $94.24 SLE: 0.07 Item: Black Horse Black Al...
# 106: Guess: $13.63 Truth: $16.99 Error: $3.36 SLE: 0.04 Item: Dearsun Twinkle Star...
# 107: Guess: $1.89 Truth: $1.34 Error: $0.55 SLE: 0.04 Item: Pokemon - Gallade Sp...
# 108: Guess: $252.00 Truth: $349.98 Error: $97.98 SLE: 0.11 Item: Ibanez GIO Series Cl...
# 109: Guess: $254.50 Truth: $370.71 Error: $116.21 SLE: 0.14 Item: Set 2 Heavy Duty 12 ...
# 110: Guess: $64.81 Truth: $65.88 Error: $1.07 SLE: 0.00 Item: Hairpin Table Legs 2...
# 111: Guess: $134.62 Truth: $229.99 Error: $95.37 SLE: 0.28 Item: Marada Racing Seat w...
# 112: Guess: $10.68 Truth: $9.14 Error: $1.54 SLE: 0.02 Item: Remington Industries...
# 113: Guess: $400.25 Truth: $199.00 Error: $201.25 SLE: 0.48 Item: Acer Ultrabook, Inte...
# 114: Guess: $174.75 Truth: $109.99 Error: $64.76 SLE: 0.21 Item: ICBEAMER 7 RGB LED H...
# 115: Guess: $222.25 Truth: $570.42 Error: $348.17 SLE: 0.88 Item: R1 Concepts Front Re...
# 116: Guess: $169.25 Truth: $279.99 Error: $110.74 SLE: 0.25 Item: Camplux 2.64 GPM Tan...
# 117: Guess: $19.72 Truth: $30.99 Error: $11.27 SLE: 0.19 Item: KNOKLOCK 10 Pack 3.7...
# 118: Guess: $39.66 Truth: $31.99 Error: $7.67 SLE: 0.04 Item: Valley Enterprises Y...
# 119: Guess: $15.32 Truth: $15.90 Error: $0.58 SLE: 0.00 Item: G9 LED Light 100W re...
# 120: Guess: $109.94 Truth: $45.99 Error: $63.95 SLE: 0.74 Item: ZCHAOZ 4 Lights Anti...
# 121: Guess: $175.00 Truth: $113.52 Error: $61.48 SLE: 0.18 Item: Honeywell Honeywell ...
# 122: Guess: $300.50 Truth: $516.99 Error: $216.49 SLE: 0.29 Item: Patriot Exhaust 1-7/...
# 123: Guess: $114.88 Truth: $196.99 Error: $82.12 SLE: 0.29 Item: Fitrite Autopart New...
# 124: Guess: $10.68 Truth: $46.55 Error: $35.87 SLE: 1.97 Item: Technical Precision ...
# 125: Guess: $158.88 Truth: $356.99 Error: $198.12 SLE: 0.65 Item: Covercraft Carhartt ...
# 126: Guess: $346.25 Truth: $319.95 Error: $26.30 SLE: 0.01 Item: Sennheiser SD Pro 2 ...
# 127: Guess: $111.62 Truth: $96.06 Error: $15.56 SLE: 0.02 Item: Hitachi Mass Air Flo...
# 128: Guess: $199.25 Truth: $190.99 Error: $8.26 SLE: 0.00 Item: AmScope LED Cordless...
# 129: Guess: $144.25 Truth: $257.95 Error: $113.70 SLE: 0.33 Item: Front Left Driver Si...
# 130: Guess: $100.12 Truth: $62.95 Error: $37.17 SLE: 0.21 Item: Premium Replica Hubc...
# 131: Guess: $25.12 Truth: $47.66 Error: $22.53 SLE: 0.39 Item: Excellerations Phoni...
# 132: Guess: $199.62 Truth: $226.99 Error: $27.37 SLE: 0.02 Item: RC4WD BigDog Dual Ax...
# 133: Guess: $253.25 Truth: $359.95 Error: $106.70 SLE: 0.12 Item: Unknown Stage 2 Clut...
# 134: Guess: $62.69 Truth: $78.40 Error: $15.71 SLE: 0.05 Item: Dodge Ram 1500 Mopar...
# 135: Guess: $165.00 Truth: $172.77 Error: $7.77 SLE: 0.00 Item: Pro Comp Alloys Seri...
# 136: Guess: $253.00 Truth: $316.45 Error: $63.45 SLE: 0.05 Item: Detroit Axle - Front...
# 137: Guess: $112.25 Truth: $87.99 Error: $24.26 SLE: 0.06 Item: ECCPP Rear Wheel Axl...
# 138: Guess: $395.00 Truth: $226.63 Error: $168.37 SLE: 0.31 Item: Dell Latitude E6520 ...
# 139: Guess: $36.31 Truth: $31.49 Error: $4.82 SLE: 0.02 Item: F FIERCE CYCLE 251pc...
# 140: Guess: $118.62 Truth: $196.00 Error: $77.38 SLE: 0.25 Item: Flash Furniture 4 Pk...
# 141: Guess: $70.88 Truth: $78.40 Error: $7.53 SLE: 0.01 Item: B&M 30287 Throttle V...
# 142: Guess: $123.75 Truth: $116.25 Error: $7.50 SLE: 0.00 Item: Gates TCK226 PowerGr...
# 143: Guess: $164.00 Truth: $112.78 Error: $51.22 SLE: 0.14 Item: Monroe Shocks & Stru...
# 144: Guess: $24.38 Truth: $27.32 Error: $2.95 SLE: 0.01 Item: Feit Electric 35W EQ...
# 145: Guess: $62.41 Truth: $145.91 Error: $83.50 SLE: 0.71 Item: Yellow Jacket 2806 C...
# 146: Guess: $122.88 Truth: $171.09 Error: $48.22 SLE: 0.11 Item: Garage-Pro Tailgate ...
# 147: Guess: $67.50 Truth: $167.95 Error: $100.45 SLE: 0.81 Item: 3M Perfect It Buffin...
# 148: Guess: $36.25 Truth: $28.49 Error: $7.76 SLE: 0.05 Item: Chinese Style Dollho...
# 149: Guess: $110.00 Truth: $122.23 Error: $12.23 SLE: 0.01 Item: Generic NRG Innovati...
# 150: Guess: $75.50 Truth: $32.99 Error: $42.51 SLE: 0.66 Item: Learning Resources C...
# 151: Guess: $87.25 Truth: $71.20 Error: $16.05 SLE: 0.04 Item: Bosch Automotive 154...
# 152: Guess: $39.72 Truth: $112.75 Error: $73.03 SLE: 1.06 Item: Case of 24-2 Inch Bl...
# 153: Guess: $123.00 Truth: $142.43 Error: $19.43 SLE: 0.02 Item: MOCA Engine Water Pu...
# 154: Guess: $298.00 Truth: $398.99 Error: $100.99 SLE: 0.08 Item: SAREMAS Foot Step Ba...
# 155: Guess: $270.00 Truth: $449.00 Error: $179.00 SLE: 0.26 Item: Gretsch G9210 Square...
# 156: Guess: $201.38 Truth: $189.00 Error: $12.38 SLE: 0.00 Item: NikoMaku Mirror Dash...
# 157: Guess: $129.75 Truth: $120.91 Error: $8.84 SLE: 0.00 Item: Fenix HP25R v2.0 USB...
# 158: Guess: $223.75 Truth: $203.53 Error: $20.22 SLE: 0.01 Item: R&L Racing Heavy Dut...
# 159: Guess: $313.75 Truth: $349.99 Error: $36.24 SLE: 0.01 Item: Garmin GPSMAP 64sx, ...
# 160: Guess: $12.00 Truth: $34.35 Error: $22.35 SLE: 1.00 Item: Brown 5-7/8 X 8-1/2 ...
# 161: Guess: $293.25 Truth: $384.99 Error: $91.74 SLE: 0.07 Item: GAOMON PD2200 Pen Di...
# 162: Guess: $262.75 Truth: $211.00 Error: $51.75 SLE: 0.05 Item: VXMOTOR for 97-03 Fo...
# 163: Guess: $219.00 Truth: $129.00 Error: $90.00 SLE: 0.28 Item: HP EliteBook 2540p I...
# 164: Guess: $10.72 Truth: $111.45 Error: $100.73 SLE: 5.11 Item: Green EPX Mixing Noz...
# 165: Guess: $11.99 Truth: $81.12 Error: $69.13 SLE: 3.40 Item: Box Partners 6 1/4 x...
# 166: Guess: $302.00 Truth: $457.08 Error: $155.08 SLE: 0.17 Item: Vixen Air 1/2 NPT Ai...
# 167: Guess: $130.00 Truth: $49.49 Error: $80.51 SLE: 0.91 Item: Smart Floor Lamp, Mu...
# 168: Guess: $41.44 Truth: $80.56 Error: $39.12 SLE: 0.43 Item: SOZG 324mm Wheelbase...
# 169: Guess: $175.50 Truth: $278.39 Error: $102.89 SLE: 0.21 Item: Mickey Thompson ET S...
# 170: Guess: $271.50 Truth: $364.50 Error: $93.00 SLE: 0.09 Item: Pirelli 106W XL RFT ...
# 171: Guess: $194.25 Truth: $378.99 Error: $184.74 SLE: 0.44 Item: Torklift C3212 Rear ...
# 172: Guess: $158.50 Truth: $165.28 Error: $6.78 SLE: 0.00 Item: Cardone Remanufactur...
# 173: Guess: $107.62 Truth: $56.74 Error: $50.88 SLE: 0.40 Item: Kidde AccessPoint 00...
# 174: Guess: $151.75 Truth: $307.95 Error: $156.20 SLE: 0.50 Item: 3M Protecta Self Ret...
# 175: Guess: $83.00 Truth: $38.00 Error: $45.00 SLE: 0.59 Item: Plantronics Wired He...
# 176: Guess: $93.25 Truth: $53.00 Error: $40.25 SLE: 0.31 Item: Logitech K750 Wirele...
# 177: Guess: $583.00 Truth: $498.00 Error: $85.00 SLE: 0.02 Item: Olympus PEN E-PL9 Bo...
# 178: Guess: $111.62 Truth: $53.99 Error: $57.63 SLE: 0.51 Item: Beck/Arnley Hub & Be...
# 179: Guess: $252.88 Truth: $350.00 Error: $97.12 SLE: 0.10 Item: Eibach Pro-Kit Perfo...
# 180: Guess: $384.50 Truth: $299.95 Error: $84.55 SLE: 0.06 Item: LEGO DC Batman 1989 ...
# 181: Guess: $151.62 Truth: $94.93 Error: $56.69 SLE: 0.22 Item: Kingston Brass Resto...
# 182: Guess: $348.25 Truth: $379.00 Error: $30.75 SLE: 0.01 Item: Polk Vanishing Serie...
# 183: Guess: $211.00 Truth: $299.95 Error: $88.95 SLE: 0.12 Item: Spec-D Tuning LED Pr...
# 184: Guess: $16.72 Truth: $24.99 Error: $8.27 SLE: 0.15 Item: RICHMOND & FINCH Air...
# 185: Guess: $87.12 Truth: $41.04 Error: $46.09 SLE: 0.55 Item: LFA Industries - mm ...
# 186: Guess: $126.88 Truth: $327.90 Error: $201.02 SLE: 0.89 Item: SAUTVS LED Headlight...
# 187: Guess: $17.70 Truth: $10.99 Error: $6.71 SLE: 0.20 Item: 2 Pack Combo Womens ...
# 188: Guess: $11.06 Truth: $14.99 Error: $3.93 SLE: 0.08 Item: Arepa - Venezuelan c...
# 189: Guess: $32.19 Truth: $84.95 Error: $52.76 SLE: 0.91 Item: Schlage Lock Company...
# 190: Guess: $116.00 Truth: $111.00 Error: $5.00 SLE: 0.00 Item: Techni Mobili White ...
# 191: Guess: $130.50 Truth: $123.73 Error: $6.77 SLE: 0.00 Item: Special Lite Product...
# 192: Guess: $115.38 Truth: $557.38 Error: $442.00 SLE: 2.46 Item: Tascam Digital Porta...
# 193: Guess: $110.00 Truth: $95.55 Error: $14.45 SLE: 0.02 Item: Glow Lighting Vista ...
# 194: Guess: $127.88 Truth: $154.00 Error: $26.12 SLE: 0.03 Item: Z3 Wind Deflector, S...
# 195: Guess: $336.00 Truth: $198.99 Error: $137.01 SLE: 0.27 Item: Olympus E-20 5MP Dig...
# 196: Guess: $233.00 Truth: $430.44 Error: $197.44 SLE: 0.37 Item: PHYNEDI 1 1000 World...
# 197: Guess: $19.75 Truth: $45.67 Error: $25.92 SLE: 0.66 Item: YANGHUAN Unstable Un...
# 198: Guess: $235.50 Truth: $249.00 Error: $13.50 SLE: 0.00 Item: Interlogix NetworX T...
# 199: Guess: $29.09 Truth: $42.99 Error: $13.90 SLE: 0.14 Item: Steering Damper,Univ...
# 200: Guess: $119.50 Truth: $181.33 Error: $61.83 SLE: 0.17 Item: Amprobe TIC 410A Hot...
# 201: Guess: $1.43 Truth: $6.03 Error: $4.60 SLE: 1.13 Item: MyCableMart 3.5mm Pl...
# 202: Guess: $62.50 Truth: $29.99 Error: $32.51 SLE: 0.51 Item: OtterBox + Pop Symme...
# 203: Guess: $220.62 Truth: $899.00 Error: $678.38 SLE: 1.96 Item: Dell XPS Desktop ( I...
# 204: Guess: $290.00 Truth: $399.99 Error: $109.99 SLE: 0.10 Item: Franklin Iron Works ...
# 205: Guess: $32.03 Truth: $4.66 Error: $27.37 SLE: 3.11 Item: Avery Legal Dividers...
# 206: Guess: $156.75 Truth: $261.41 Error: $104.66 SLE: 0.26 Item: Moen 8346 Commercial...
# 207: Guess: $139.25 Truth: $136.97 Error: $2.28 SLE: 0.00 Item: Carlisle Versa Trail...
# 208: Guess: $80.25 Truth: $79.00 Error: $1.25 SLE: 0.00 Item: SUNWAYFOTO 44mm Trip...
# 209: Guess: $172.38 Truth: $444.99 Error: $272.62 SLE: 0.89 Item: NanoBeam AC 4 Units ...
# 210: Guess: $400.50 Truth: $411.94 Error: $11.44 SLE: 0.00 Item: WULF 4 Front 2 Rear ...
# 211: Guess: $218.75 Truth: $148.40 Error: $70.35 SLE: 0.15 Item: Alera ALEVABFMC Vale...
# 212: Guess: $109.88 Truth: $244.99 Error: $135.12 SLE: 0.64 Item: YU-GI-OH! Ignition A...
# 213: Guess: $126.00 Truth: $86.50 Error: $39.50 SLE: 0.14 Item: 48 x 36 Extra-Large ...
# 214: Guess: $200.00 Truth: $297.95 Error: $97.95 SLE: 0.16 Item: Dell Latitude D620 R...
# 215: Guess: $500.00 Truth: $399.99 Error: $100.01 SLE: 0.05 Item: acer Aspire 5 Laptop...
# 216: Guess: $190.25 Truth: $599.00 Error: $408.75 SLE: 1.31 Item: Elk 30 by 6-Inch Viv...
# 217: Guess: $69.44 Truth: $105.99 Error: $36.55 SLE: 0.17 Item: Barbie Top Model Dol...
# 218: Guess: $350.75 Truth: $689.00 Error: $338.25 SLE: 0.45 Item: Danby Designer 20-In...
# 219: Guess: $231.75 Truth: $404.99 Error: $173.24 SLE: 0.31 Item: FixtureDisplays® Met...
# 220: Guess: $145.75 Truth: $207.76 Error: $62.01 SLE: 0.12 Item: ACDelco GM Original ...
# 221: Guess: $225.00 Truth: $171.82 Error: $53.18 SLE: 0.07 Item: EBC Premium Street B...
# 222: Guess: $348.75 Truth: $293.24 Error: $55.51 SLE: 0.03 Item: FXR Men's Boost FX J...
# 223: Guess: $191.12 Truth: $374.95 Error: $183.82 SLE: 0.45 Item: SuperATV Scratch Res...
# 224: Guess: $100.31 Truth: $111.99 Error: $11.68 SLE: 0.01 Item: SBU 3 Layer All Weat...
# 225: Guess: $17.64 Truth: $42.99 Error: $25.35 SLE: 0.74 Item: 2 Pack Outdoor Broch...
# 226: Guess: $164.12 Truth: $116.71 Error: $47.42 SLE: 0.11 Item: Monroe Shocks & Stru...
# 227: Guess: $182.00 Truth: $118.61 Error: $63.39 SLE: 0.18 Item: Elements of Design M...
# 228: Guess: $156.75 Truth: $147.12 Error: $9.63 SLE: 0.00 Item: GM Genuine Parts Air...
# 229: Guess: $133.75 Truth: $119.99 Error: $13.76 SLE: 0.01 Item: Baseus USB C Docking...
# 230: Guess: $193.50 Truth: $369.98 Error: $176.48 SLE: 0.42 Item: Whitehall™ Personali...
# 231: Guess: $253.75 Truth: $315.55 Error: $61.80 SLE: 0.05 Item: Pro Circuit Works Pi...
# 232: Guess: $248.25 Truth: $190.99 Error: $57.26 SLE: 0.07 Item: HYANKA 15 1200W Prof...
# 233: Guess: $118.00 Truth: $155.00 Error: $37.00 SLE: 0.07 Item: Bluetooth X6BT Card ...
# 234: Guess: $242.75 Truth: $349.99 Error: $107.24 SLE: 0.13 Item: AIRAID Cold Air Inta...
# 235: Guess: $134.62 Truth: $249.99 Error: $115.37 SLE: 0.38 Item: Bostingner Shower Fa...
# 236: Guess: $61.41 Truth: $42.99 Error: $18.42 SLE: 0.12 Item: PIT66 Front Bumper T...
# 237: Guess: $18.06 Truth: $17.99 Error: $0.07 SLE: 0.00 Item: Caseology Bumpy Comp...
# 238: Guess: $298.25 Truth: $425.00 Error: $126.75 SLE: 0.12 Item: Fleck 2510 Timer Mec...
# 239: Guess: $243.75 Truth: $249.99 Error: $6.24 SLE: 0.00 Item: Haloview MC7108 Wire...
# 240: Guess: $41.50 Truth: $138.23 Error: $96.73 SLE: 1.41 Item: Schmidt Spiele - Man...
# 241: Guess: $253.50 Truth: $414.99 Error: $161.49 SLE: 0.24 Item: Corsa 14333 Tip Kit ...
# 242: Guess: $136.88 Truth: $168.28 Error: $31.41 SLE: 0.04 Item: Hoshizaki FM116A Fan...
# 243: Guess: $126.50 Truth: $199.99 Error: $73.49 SLE: 0.21 Item: BAINUO Antler Chande...
# 244: Guess: $110.12 Truth: $126.70 Error: $16.58 SLE: 0.02 Item: DNA MOTORING Smoke L...
# 245: Guess: $9.00 Truth: $5.91 Error: $3.09 SLE: 0.14 Item: Wera Stainless 3840/...
# 246: Guess: $177.25 Truth: $193.06 Error: $15.81 SLE: 0.01 Item: Celestron - PowerSee...
# 247: Guess: $299.50 Truth: $249.99 Error: $49.51 SLE: 0.03 Item: NHOPEEW Android Car ...
# 248: Guess: $61.31 Truth: $64.12 Error: $2.81 SLE: 0.00 Item: Other Harmonica A)
# F...
# 249: Guess: $126.56 Truth: $114.99 Error: $11.57 SLE: 0.01 Item: Harley Air Filter Ve...
# 250: Guess: $300.50 Truth: $926.00 Error: $625.50 SLE: 1.26 Item: Elite Screens Edge F...
