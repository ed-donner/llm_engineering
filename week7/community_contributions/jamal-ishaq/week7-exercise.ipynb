# %% [markdown]
# ## Project Overview
#
# This notebook builds an open-source **product price predictor** using a fine-tuned Llama model. It loads a home-products dataset, predicts prices from product descriptions, provides a Gradio demo, and evaluates model quality with error metrics and performance charts.
#
# Google Colab: [Open in Colab](https://colab.research.google.com/drive/1qYWCf-ywNn_A3CjaCeA0guTl27s6902t#scrollTo=56bb6dc3)
