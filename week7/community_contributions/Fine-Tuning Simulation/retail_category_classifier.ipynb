# %% [markdown]
# # Retail Product Category Classifier (Fine-Tuning Simulation)
#
# ## Business Context
#
# Retail platforms need automated product categorization.
#
# We simulate:
# - Dataset curation
# - Structured training examples
# - Before vs After comparison
#
# ## Concepts Applied
#
# - Dataset preparation
# - Prompt-format training data
# - Fine-tuning workflow understanding
# - Evaluation against base model

# %%
pip install openai python-dotenv --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\PC\Desktop\AI-ENGINEERING\llm_engineering\.venv\Scripts\python.exe: No module named pip

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
MODEL = "gpt-4"

# %%
def classify_product(text):
    response = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": "Classify product into: Electronics, Fashion, Grocery, Home."},
            {"role": "user", "content": text}
        ]
    )
    return response.choices[0].message.content

classify_product("Men leather formal shoes")
# Out:
# 'Fashion'
