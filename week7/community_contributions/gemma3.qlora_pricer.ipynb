# %% [markdown]
# # Gemma 3 QLoRA Pricer
#
# Fine-tune **Gemma** with **QLoRA** on Ed Donner's price prediction dataset.
#
# **👉 Run this notebook in Google Colab:**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1AjULXsBduOpq0rbe7MHOdODoFTapDIOK?usp=sharing)
#
# **Direct link:** https://colab.research.google.com/drive/1AjULXsBduOpq0rbe7MHOdODoFTapDIOK?usp=sharing
