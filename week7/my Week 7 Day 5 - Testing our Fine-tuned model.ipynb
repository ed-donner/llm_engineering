# %% [markdown]
# ## Predict Product Prices
#
# ### And now, to evaluate our fine-tuned open source model

# %%
# pip installs

# !pip install -q datasets peft requests torch bitsandbytes transformers trl accelerate sentencepiece matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 20.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.3/366.3 kB 24.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 28.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 16.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.

# %%
# imports

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import torch.nn.functional as F
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, set_seed
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
from peft import PeftModel
import matplotlib.pyplot as plt

# %%
# Constants

BASE_MODEL = "meta-llama/Meta-Llama-3.1-8B"
PROJECT_NAME = "pricer"
HF_USER = "ed-donner" # your HF name here! Or use mine if you just want to reproduce my results.

# The run itself

RUN_NAME = "2024-09-13_13.04.39"
PROJECT_RUN_NAME = f"{PROJECT_NAME}-{RUN_NAME}"
REVISION = "e8d637df551603dc86cd7a1598a8f44af4d7ae36" # or REVISION = None
FINETUNED_MODEL = f"{HF_USER}/{PROJECT_RUN_NAME}"

# Uncomment this line if you wish to use my model
FINETUNED_MODEL = f"ed-donner/{PROJECT_RUN_NAME}"

# Data

DATASET_NAME = f"{HF_USER}/pricer-data"
# Or just use the one I've uploaded
# DATASET_NAME = "ed-donner/pricer-data"

# Hyperparameters for QLoRA

QUANT_4_BIT = True

# %matplotlib inline

# Used for writing to output in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %% [markdown]
# ### Log in to HuggingFace
#
# If you don't already have a HuggingFace account, visit https://huggingface.co to sign up and create a token.
#
# Then select the Secrets for this Notebook by clicking on the key icon in the left, and add a new secret called `HF_TOKEN` with the value as your token.

# %%
# Log in to HuggingFace

hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# README.md:   0%|          | 0.00/416 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/185M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/914k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/400000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
len(train), len(test)

# %%
test[0]
# Out:
# {'text': "How much does this cost to the nearest dollar?\n\nOEM AC Compressor w/A/C Repair Kit For Ford F150 F-150 V8 & Lincoln Mark LT 2007 2008 - BuyAutoParts NEW\nAs one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. This A/C Compressor and Components Kit is manufactured and tested to the strictest OE standards for unparalleled performance. Built for trouble-free ownership and 100% visually inspected and quality tested, this A/C Compressor and Components Kit is backed by our 100% satisfaction guarantee. Guaranteed Exact Fit for easy installation 100% BRAND NEW, premium ISO/TS 16949 quality - tested to meet or exceed OEM specifications Engineered for superior durability, backed by industry-leading unlimited-mileage warranty Included in this K\n\nPrice is $",
#  'price': 374.41}

# %% [markdown]
# ## Now load the Tokenizer and Model

# %%
# pick the right quantization (thank you Robert M. for spotting the bug with the 8 bit version!)

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

# Load the fine-tuned model with PEFT
if REVISION:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL, revision=REVISION)
else:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL)


print(f"Memory footprint: {fine_tuned_model.get_memory_footprint() / 1e6:.1f} MB")
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/681 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/109M [00:00<?, ?B/s]
# Memory footprint: 5700.6 MB

# %%
fine_tuned_model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#     )
#   )
# )

# %% [markdown]
# # THE MOMENT OF TRUTH!
#
# ## Use the model in inference mode
#
# Remember, GPT-4o had an average error of \$76.
# Llama 3.1 base model had an average error of \$396.
# This human had an error of \$127.
#
# ## Caveat
#
# Keep in mind that prices of goods vary considerably; the model can't predict things like sale prices that it doesn't have any information about.

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
extract_price("Price is $a fabulous 899.99 or so")
# Out:
# 899.99

# %%
# Original prediction function takes the most likely next token

def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = fine_tuned_model.generate(inputs, attention_mask=attention_mask, max_new_tokens=3, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    return extract_price(response)

# %%
# An improved prediction function takes a weighted average of the top 3 choices
# This code would be more complex if we couldn't take advantage of the fact
# That Llama generates 1 token for any 3 digit number

top_K = 3

def improved_model_predict(prompt, device="cuda"):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    attention_mask = torch.ones(inputs.shape, device=device)

    with torch.no_grad():
        outputs = fine_tuned_model(inputs, attention_mask=attention_mask)
        next_token_logits = outputs.logits[:, -1, :].to('cpu')

    next_token_probs = F.softmax(next_token_logits, dim=-1)
    top_prob, top_token_id = next_token_probs.topk(top_K)
    prices, weights = [], []
    for i in range(top_K):
      predicted_token = tokenizer.decode(top_token_id[0][i])
      probability = top_prob[0][i]
      try:
        result = float(predicted_token)
      except ValueError as e:
        result = 0.0
      if result > 0:
        prices.append(result)
        weights.append(probability)
    if not prices:
      return 0.0, 0.0
    total = sum(weights)
    weighted_prices = [price * weight / total for price, weight in zip(prices, weights)]
    return sum(weighted_prices).item()

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(improved_model_predict, test)
# Out:
# 1: Guess: $374.00 Truth: $374.41 Error: $0.41 SLE: 0.00 Item: OEM AC Compressor w/...
# 2: Guess: $157.88 Truth: $225.11 Error: $67.24 SLE: 0.12 Item: Motorcraft YB3125 Fa...
# 3: Guess: $32.28 Truth: $61.68 Error: $29.40 SLE: 0.40 Item: Dorman Front Washer ...
# 4: Guess: $442.25 Truth: $599.99 Error: $157.74 SLE: 0.09 Item: HP Premium HD Plus T...
# 5: Guess: $16.98 Truth: $16.99 Error: $0.01 SLE: 0.00 Item: Super Switch Pickup ...
# 6: Guess: $16.91 Truth: $31.99 Error: $15.08 SLE: 0.37 Item: Horror Bookmarks, Re...
# 7: Guess: $119.75 Truth: $101.79 Error: $17.96 SLE: 0.03 Item: SK6241 - Stinger 4 G...
# 8: Guess: $298.50 Truth: $289.00 Error: $9.50 SLE: 0.00 Item: Godox ML60Bi LED Lig...
# 9: Guess: $872.00 Truth: $635.86 Error: $236.14 SLE: 0.10 Item: Randall G3 Plus Comb...
# 10: Guess: $69.12 Truth: $65.99 Error: $3.14 SLE: 0.00 Item: HOLDWILL 6 Pack LED ...
# 11: Guess: $229.38 Truth: $254.21 Error: $24.84 SLE: 0.01 Item: Viking Horns 3 Gallo...
# 12: Guess: $392.50 Truth: $412.99 Error: $20.49 SLE: 0.00 Item: CURT 70110 Custom To...
# 13: Guess: $230.62 Truth: $205.50 Error: $25.12 SLE: 0.01 Item: Solar HAMMERED BRONZ...
# 14: Guess: $261.50 Truth: $248.23 Error: $13.27 SLE: 0.00 Item: COSTWAY Electric Tum...
# 15: Guess: $320.00 Truth: $399.00 Error: $79.00 SLE: 0.05 Item: FREE SIGNAL TV Trans...
# 16: Guess: $363.00 Truth: $373.94 Error: $10.94 SLE: 0.00 Item: Bilstein 5100 Monotu...
# 17: Guess: $135.38 Truth: $92.89 Error: $42.48 SLE: 0.14 Item: Sangean K-200 Multi-...
# 18: Guess: $94.81 Truth: $51.99 Error: $42.82 SLE: 0.35 Item: Charles Leonard Magn...
# 19: Guess: $256.75 Truth: $179.00 Error: $77.75 SLE: 0.13 Item: Gigabyte AMD Radeon ...
# 20: Guess: $16.95 Truth: $19.42 Error: $2.47 SLE: 0.02 Item: 3dRose LLC 8 x 8 x 0...
# 21: Guess: $444.75 Truth: $539.95 Error: $95.20 SLE: 0.04 Item: ROKINON 85mm F1.4 Au...
# 22: Guess: $141.62 Truth: $147.67 Error: $6.04 SLE: 0.00 Item: Headlight Assembly C...
# 23: Guess: $26.00 Truth: $24.99 Error: $1.01 SLE: 0.00 Item: ASI NAUTICAL 2.5 Inc...
# 24: Guess: $104.62 Truth: $149.00 Error: $44.38 SLE: 0.12 Item: Behringer TUBE OVERD...
# 25: Guess: $12.98 Truth: $16.99 Error: $4.01 SLE: 0.06 Item: Fun Express Insect F...
# 26: Guess: $9.17 Truth: $7.99 Error: $1.18 SLE: 0.02 Item: WAFJAMF Roller Stamp...
# 27: Guess: $182.38 Truth: $199.99 Error: $17.62 SLE: 0.01 Item: Capulina Tiffany Flo...
# 28: Guess: $267.00 Truth: $251.45 Error: $15.55 SLE: 0.00 Item: Apple Watch Series 6...
# 29: Guess: $244.50 Truth: $231.62 Error: $12.88 SLE: 0.00 Item: ICON 01725 Tandem Ax...
# 30: Guess: $78.62 Truth: $135.00 Error: $56.38 SLE: 0.29 Item: SanDisk 128GB Ultra ...
# 31: Guess: $375.50 Truth: $356.62 Error: $18.88 SLE: 0.00 Item: Velvac - 715427
# 2020...
# 32: Guess: $283.25 Truth: $257.99 Error: $25.26 SLE: 0.01 Item: TCMT Passenger Backr...
# 33: Guess: $26.98 Truth: $27.99 Error: $1.01 SLE: 0.00 Item: Alnicov 63.5MM Brass...
# 34: Guess: $108.88 Truth: $171.20 Error: $62.32 SLE: 0.20 Item: Subaru Forester Outb...
# 35: Guess: $350.50 Truth: $225.00 Error: $125.50 SLE: 0.20 Item: Richmond Auto Uphols...
# 36: Guess: $171.00 Truth: $105.00 Error: $66.00 SLE: 0.23 Item: AP-39 Automotive Pai...
# 37: Guess: $299.50 Truth: $299.99 Error: $0.49 SLE: 0.00 Item: Road Top Wireless Ca...
# 38: Guess: $597.00 Truth: $535.09 Error: $61.91 SLE: 0.01 Item: Gibson Performance E...
# 39: Guess: $19.00 Truth: $12.33 Error: $6.67 SLE: 0.16 Item: Bella Tunno Happy Li...
# 40: Guess: $111.94 Truth: $84.99 Error: $26.95 SLE: 0.07 Item: CANMORE H300 Handhel...
# 41: Guess: $14.44 Truth: $15.99 Error: $1.55 SLE: 0.01 Item: DCPOWER AC Adapter C...
# 42: Guess: $40.75 Truth: $62.44 Error: $21.69 SLE: 0.18 Item: Sharp, Commercial De...
# 43: Guess: $94.38 Truth: $82.99 Error: $11.39 SLE: 0.02 Item: Melissa & Doug Lifel...
# 44: Guess: $270.75 Truth: $599.95 Error: $329.20 SLE: 0.63 Item: Sony SSCS8 2-Way Cen...
# 45: Guess: $245.75 Truth: $194.99 Error: $50.76 SLE: 0.05 Item: ASUS Chromebook CX1,...
# 46: Guess: $309.00 Truth: $344.95 Error: $35.95 SLE: 0.01 Item: FiiO X7 32GB Hi-Res ...
# 47: Guess: $38.53 Truth: $37.99 Error: $0.54 SLE: 0.00 Item: TORRO Leather Case C...
# 48: Guess: $238.75 Truth: $224.35 Error: $14.40 SLE: 0.00 Item: Universal Air Condit...
# 49: Guess: $857.50 Truth: $814.00 Error: $43.50 SLE: 0.00 Item: Street Series Stainl...
# 50: Guess: $358.50 Truth: $439.88 Error: $81.38 SLE: 0.04 Item: Lenovo IdeaPad 3 Lap...
# 51: Guess: $341.00 Truth: $341.43 Error: $0.43 SLE: 0.00 Item: Access Bed Covers To...
# 52: Guess: $53.12 Truth: $46.78 Error: $6.34 SLE: 0.02 Item: G.I. JOE Hasbro 3 3/...
# 53: Guess: $189.00 Truth: $171.44 Error: $17.56 SLE: 0.01 Item: T&S Brass Double Pan...
# 54: Guess: $433.00 Truth: $458.00 Error: $25.00 SLE: 0.00 Item: ZTUOAUMA Fuel Inject...
# 55: Guess: $130.25 Truth: $130.75 Error: $0.50 SLE: 0.00 Item: Hp Prime Graphing Ca...
# 56: Guess: $52.56 Truth: $83.81 Error: $31.25 SLE: 0.21 Item: Lowrance Nmea 2000 2...
# 57: Guess: $157.88 Truth: $386.39 Error: $228.51 SLE: 0.79 Item: Jeep Genuine Accesso...
# 58: Guess: $139.75 Truth: $169.00 Error: $29.25 SLE: 0.04 Item: GODOX CB-06 Hard Car...
# 59: Guess: $14.41 Truth: $17.95 Error: $3.54 SLE: 0.04 Item: Au-Tomotive Gold, IN...
# 60: Guess: $266.00 Truth: $269.00 Error: $3.00 SLE: 0.00 Item: Snailfly Black Roof ...
# 61: Guess: $99.50 Truth: $77.77 Error: $21.73 SLE: 0.06 Item: KING SHA Anti Glare ...
# 62: Guess: $77.56 Truth: $88.99 Error: $11.43 SLE: 0.02 Item: APS Compatible with ...
# 63: Guess: $350.50 Truth: $364.41 Error: $13.91 SLE: 0.00 Item: Wilwood Engineering ...
# 64: Guess: $143.25 Truth: $127.03 Error: $16.22 SLE: 0.01 Item: ACDelco Gold Starter...
# 65: Guess: $673.50 Truth: $778.95 Error: $105.45 SLE: 0.02 Item: UWS Matte Black Heav...
# 66: Guess: $195.25 Truth: $206.66 Error: $11.41 SLE: 0.00 Item: Dell Latitude E5440 ...
# 67: Guess: $35.81 Truth: $35.94 Error: $0.13 SLE: 0.00 Item: (Plug and Play) Spar...
# 68: Guess: $196.25 Truth: $149.00 Error: $47.25 SLE: 0.07 Item: The Ultimate Roadsid...
# 69: Guess: $243.25 Truth: $251.98 Error: $8.73 SLE: 0.00 Item: Brand New 18 x 8.5 R...
# 70: Guess: $214.25 Truth: $160.00 Error: $54.25 SLE: 0.08 Item: Headlight Headlamp L...
# 71: Guess: $35.50 Truth: $39.99 Error: $4.49 SLE: 0.01 Item: Lilo And Stitch Delu...
# 72: Guess: $239.38 Truth: $362.41 Error: $123.04 SLE: 0.17 Item: AC Compressor & A/C ...
# 73: Guess: $392.25 Truth: $344.00 Error: $48.25 SLE: 0.02 Item: House Of Troy Pinnac...
# 74: Guess: $32.28 Truth: $25.09 Error: $7.19 SLE: 0.06 Item: Juno T29 WH Floating...
# 75: Guess: $105.19 Truth: $175.95 Error: $70.76 SLE: 0.26 Item: Sherman GO-PARTS - f...
# 76: Guess: $331.25 Truth: $132.64 Error: $198.61 SLE: 0.83 Item: Roland RPU-3 Electro...
# 77: Guess: $266.50 Truth: $422.99 Error: $156.49 SLE: 0.21 Item: Rockland VMI14 12,00...
# 78: Guess: $148.62 Truth: $146.48 Error: $2.15 SLE: 0.00 Item: Max Advanced Brakes ...
# 79: Guess: $155.50 Truth: $156.83 Error: $1.33 SLE: 0.00 Item: Quality-Built 11030 ...
# 80: Guess: $180.88 Truth: $251.99 Error: $71.12 SLE: 0.11 Item: Lucida LG-510 Studen...
# 81: Guess: $353.75 Truth: $940.33 Error: $586.58 SLE: 0.95 Item: Longacre Aluminum Tu...
# 82: Guess: $57.81 Truth: $52.99 Error: $4.82 SLE: 0.01 Item: Motion Pro Adjustabl...
# 83: Guess: $274.50 Truth: $219.95 Error: $54.55 SLE: 0.05 Item: Glyph Thunderbolt 3 ...
# 84: Guess: $442.00 Truth: $441.03 Error: $0.97 SLE: 0.00 Item: TOYO Open Country MT...
# 85: Guess: $177.12 Truth: $168.98 Error: $8.15 SLE: 0.00 Item: Razer Seiren X USB S...
# 86: Guess: $2.51 Truth: $2.49 Error: $0.02 SLE: 0.00 Item: Happy Birthday to Da...
# 87: Guess: $88.69 Truth: $98.62 Error: $9.93 SLE: 0.01 Item: Little Tikes My Real...
# 88: Guess: $269.50 Truth: $256.95 Error: $12.55 SLE: 0.00 Item: Studio M Peace and H...
# 89: Guess: $26.55 Truth: $30.99 Error: $4.44 SLE: 0.02 Item: MyVolts 12V Power Su...
# 90: Guess: $703.00 Truth: $569.84 Error: $133.16 SLE: 0.04 Item: Dell Latitude 7212 R...
# 91: Guess: $198.50 Truth: $177.99 Error: $20.51 SLE: 0.01 Item: Covermates Contour F...
# 92: Guess: $995.50 Truth: $997.99 Error: $2.49 SLE: 0.00 Item: Westin Black HDX Gri...
# 93: Guess: $160.50 Truth: $219.00 Error: $58.50 SLE: 0.10 Item: Fieldpiece JL2 Job L...
# 94: Guess: $225.38 Truth: $225.55 Error: $0.18 SLE: 0.00 Item: hansgrohe Talis S Mo...
# 95: Guess: $669.00 Truth: $495.95 Error: $173.05 SLE: 0.09 Item: G-Technology G-SPEED...
# 96: Guess: $946.50 Truth: $942.37 Error: $4.13 SLE: 0.00 Item: DreamLine Shower Doo...
# 97: Guess: $6.00 Truth: $1.94 Error: $4.06 SLE: 0.75 Item: Sanctuary Square Bac...
# 98: Guess: $260.50 Truth: $284.34 Error: $23.84 SLE: 0.01 Item: Pelican Protector 17...
# 99: Guess: $162.75 Truth: $171.90 Error: $9.15 SLE: 0.00 Item: Brock Replacement Dr...
# 100: Guess: $233.88 Truth: $144.99 Error: $88.88 SLE: 0.23 Item: Carlinkit Ai Box Min...
# 101: Guess: $422.00 Truth: $470.47 Error: $48.47 SLE: 0.01 Item: StarDot YouTube Live...
# 102: Guess: $60.97 Truth: $66.95 Error: $5.98 SLE: 0.01 Item: Atomic Compatible ME...
# 103: Guess: $93.75 Truth: $117.00 Error: $23.25 SLE: 0.05 Item: Bandai Awakening of ...
# 104: Guess: $193.25 Truth: $172.14 Error: $21.11 SLE: 0.01 Item: Fit System 62135G Pa...
# 105: Guess: $347.50 Truth: $392.74 Error: $45.24 SLE: 0.01 Item: Black Horse Black Al...
# 106: Guess: $23.59 Truth: $16.99 Error: $6.60 SLE: 0.10 Item: Dearsun Twinkle Star...
# 107: Guess: $1.68 Truth: $1.34 Error: $0.34 SLE: 0.02 Item: Pokemon - Gallade Sp...
# 108: Guess: $276.25 Truth: $349.98 Error: $73.73 SLE: 0.06 Item: Ibanez GIO Series Cl...
# 109: Guess: $388.75 Truth: $370.71 Error: $18.04 SLE: 0.00 Item: Set 2 Heavy Duty 12 ...
# 110: Guess: $59.38 Truth: $65.88 Error: $6.50 SLE: 0.01 Item: Hairpin Table Legs 2...
# 111: Guess: $298.50 Truth: $229.99 Error: $68.51 SLE: 0.07 Item: Marada Racing Seat w...
# 112: Guess: $7.08 Truth: $9.14 Error: $2.06 SLE: 0.05 Item: Remington Industries...
# 113: Guess: $386.50 Truth: $199.00 Error: $187.50 SLE: 0.44 Item: Acer Ultrabook, Inte...
# 114: Guess: $248.25 Truth: $109.99 Error: $138.26 SLE: 0.65 Item: ICBEAMER 7 RGB LED H...
# 115: Guess: $371.25 Truth: $570.42 Error: $199.17 SLE: 0.18 Item: R1 Concepts Front Re...
# 116: Guess: $175.88 Truth: $279.99 Error: $104.12 SLE: 0.21 Item: Camplux 2.64 GPM Tan...
# 117: Guess: $23.64 Truth: $30.99 Error: $7.35 SLE: 0.07 Item: KNOKLOCK 10 Pack 3.7...
# 118: Guess: $39.09 Truth: $31.99 Error: $7.10 SLE: 0.04 Item: Valley Enterprises Y...
# 119: Guess: $69.75 Truth: $15.90 Error: $53.85 SLE: 2.05 Item: G9 LED Light 100W re...
# 120: Guess: $85.25 Truth: $45.99 Error: $39.26 SLE: 0.37 Item: ZCHAOZ 4 Lights Anti...
# 121: Guess: $188.00 Truth: $113.52 Error: $74.48 SLE: 0.25 Item: Honeywell Honeywell ...
# 122: Guess: $343.75 Truth: $516.99 Error: $173.24 SLE: 0.17 Item: Patriot Exhaust 1-7/...
# 123: Guess: $80.94 Truth: $196.99 Error: $116.05 SLE: 0.78 Item: Fitrite Autopart New...
# 124: Guess: $83.19 Truth: $46.55 Error: $36.64 SLE: 0.33 Item: Technical Precision ...
# 125: Guess: $317.00 Truth: $356.99 Error: $39.99 SLE: 0.01 Item: Covercraft Carhartt ...
# 126: Guess: $275.50 Truth: $319.95 Error: $44.45 SLE: 0.02 Item: Sennheiser SD Pro 2 ...
# 127: Guess: $125.88 Truth: $96.06 Error: $29.81 SLE: 0.07 Item: Hitachi Mass Air Flo...
# 128: Guess: $209.00 Truth: $190.99 Error: $18.01 SLE: 0.01 Item: AmScope LED Cordless...
# 129: Guess: $128.25 Truth: $257.95 Error: $129.70 SLE: 0.48 Item: Front Left Driver Si...
# 130: Guess: $75.00 Truth: $62.95 Error: $12.05 SLE: 0.03 Item: Premium Replica Hubc...
# 131: Guess: $75.94 Truth: $47.66 Error: $28.28 SLE: 0.21 Item: Excellerations Phoni...
# 132: Guess: $156.88 Truth: $226.99 Error: $70.12 SLE: 0.14 Item: RC4WD BigDog Dual Ax...
# 133: Guess: $323.50 Truth: $359.95 Error: $36.45 SLE: 0.01 Item: Unknown Stage 2 Clut...
# 134: Guess: $70.00 Truth: $78.40 Error: $8.40 SLE: 0.01 Item: Dodge Ram 1500 Mopar...
# 135: Guess: $157.25 Truth: $172.77 Error: $15.52 SLE: 0.01 Item: Pro Comp Alloys Seri...
# 136: Guess: $320.50 Truth: $316.45 Error: $4.05 SLE: 0.00 Item: Detroit Axle - Front...
# 137: Guess: $115.19 Truth: $87.99 Error: $27.20 SLE: 0.07 Item: ECCPP Rear Wheel Axl...
# 138: Guess: $196.00 Truth: $226.63 Error: $30.63 SLE: 0.02 Item: Dell Latitude E6520 ...
# 139: Guess: $28.03 Truth: $31.49 Error: $3.46 SLE: 0.01 Item: F FIERCE CYCLE 251pc...
# 140: Guess: $245.00 Truth: $196.00 Error: $49.00 SLE: 0.05 Item: Flash Furniture 4 Pk...
# 141: Guess: $62.69 Truth: $78.40 Error: $15.71 SLE: 0.05 Item: B&M 30287 Throttle V...
# 142: Guess: $131.25 Truth: $116.25 Error: $15.00 SLE: 0.01 Item: Gates TCK226 PowerGr...
# 143: Guess: $130.50 Truth: $112.78 Error: $17.72 SLE: 0.02 Item: Monroe Shocks & Stru...
# 144: Guess: $61.66 Truth: $27.32 Error: $34.34 SLE: 0.63 Item: Feit Electric 35W EQ...
# 145: Guess: $106.62 Truth: $145.91 Error: $39.28 SLE: 0.10 Item: Yellow Jacket 2806 C...
# 146: Guess: $155.25 Truth: $171.09 Error: $15.84 SLE: 0.01 Item: Garage-Pro Tailgate ...
# 147: Guess: $108.75 Truth: $167.95 Error: $59.20 SLE: 0.19 Item: 3M Perfect It Buffin...
# 148: Guess: $33.56 Truth: $28.49 Error: $5.07 SLE: 0.03 Item: Chinese Style Dollho...
# 149: Guess: $130.12 Truth: $122.23 Error: $7.89 SLE: 0.00 Item: Generic NRG Innovati...
# 150: Guess: $40.06 Truth: $32.99 Error: $7.07 SLE: 0.04 Item: Learning Resources C...
# 151: Guess: $126.00 Truth: $71.20 Error: $54.80 SLE: 0.32 Item: Bosch Automotive 154...
# 152: Guess: $48.34 Truth: $112.75 Error: $64.41 SLE: 0.70 Item: Case of 24-2 Inch Bl...
# 153: Guess: $98.50 Truth: $142.43 Error: $43.93 SLE: 0.13 Item: MOCA Engine Water Pu...
# 154: Guess: $305.00 Truth: $398.99 Error: $93.99 SLE: 0.07 Item: SAREMAS Foot Step Ba...
# 155: Guess: $513.00 Truth: $449.00 Error: $64.00 SLE: 0.02 Item: Gretsch G9210 Square...
# 156: Guess: $159.88 Truth: $189.00 Error: $29.12 SLE: 0.03 Item: NikoMaku Mirror Dash...
# 157: Guess: $114.75 Truth: $120.91 Error: $6.16 SLE: 0.00 Item: Fenix HP25R v2.0 USB...
# 158: Guess: $172.38 Truth: $203.53 Error: $31.16 SLE: 0.03 Item: R&L Racing Heavy Dut...
# 159: Guess: $346.25 Truth: $349.99 Error: $3.74 SLE: 0.00 Item: Garmin GPSMAP 64sx, ...
# 160: Guess: $16.22 Truth: $34.35 Error: $18.13 SLE: 0.52 Item: Brown 5-7/8 X 8-1/2 ...
# 161: Guess: $275.50 Truth: $384.99 Error: $109.49 SLE: 0.11 Item: GAOMON PD2200 Pen Di...
# 162: Guess: $215.62 Truth: $211.00 Error: $4.62 SLE: 0.00 Item: VXMOTOR for 97-03 Fo...
# 163: Guess: $193.88 Truth: $129.00 Error: $64.88 SLE: 0.16 Item: HP EliteBook 2540p I...
# 164: Guess: $15.44 Truth: $111.45 Error: $96.01 SLE: 3.70 Item: Green EPX Mixing Noz...
# 165: Guess: $35.12 Truth: $81.12 Error: $46.00 SLE: 0.67 Item: Box Partners 6 1/4 x...
# 166: Guess: $372.00 Truth: $457.08 Error: $85.08 SLE: 0.04 Item: Vixen Air 1/2 NPT Ai...
# 167: Guess: $70.25 Truth: $49.49 Error: $20.76 SLE: 0.12 Item: Smart Floor Lamp, Mu...
# 168: Guess: $123.94 Truth: $80.56 Error: $43.38 SLE: 0.18 Item: SOZG 324mm Wheelbase...
# 169: Guess: $302.00 Truth: $278.39 Error: $23.61 SLE: 0.01 Item: Mickey Thompson ET S...
# 170: Guess: $398.75 Truth: $364.50 Error: $34.25 SLE: 0.01 Item: Pirelli 106W XL RFT ...
# 171: Guess: $368.00 Truth: $378.99 Error: $10.99 SLE: 0.00 Item: Torklift C3212 Rear ...
# 172: Guess: $158.25 Truth: $165.28 Error: $7.03 SLE: 0.00 Item: Cardone Remanufactur...
# 173: Guess: $54.94 Truth: $56.74 Error: $1.80 SLE: 0.00 Item: Kidde AccessPoint 00...
# 174: Guess: $221.25 Truth: $307.95 Error: $86.70 SLE: 0.11 Item: 3M Protecta Self Ret...
# 175: Guess: $65.75 Truth: $38.00 Error: $27.75 SLE: 0.29 Item: Plantronics Wired He...
# 176: Guess: $79.75 Truth: $53.00 Error: $26.75 SLE: 0.16 Item: Logitech K750 Wirele...
# 177: Guess: $548.00 Truth: $498.00 Error: $50.00 SLE: 0.01 Item: Olympus PEN E-PL9 Bo...
# 178: Guess: $134.12 Truth: $53.99 Error: $80.13 SLE: 0.81 Item: Beck/Arnley Hub & Be...
# 179: Guess: $349.75 Truth: $350.00 Error: $0.25 SLE: 0.00 Item: Eibach Pro-Kit Perfo...
# 180: Guess: $274.25 Truth: $299.95 Error: $25.70 SLE: 0.01 Item: LEGO DC Batman 1989 ...
# 181: Guess: $95.19 Truth: $94.93 Error: $0.26 SLE: 0.00 Item: Kingston Brass Resto...
# 182: Guess: $442.50 Truth: $379.00 Error: $63.50 SLE: 0.02 Item: Polk Vanishing Serie...
# 183: Guess: $253.50 Truth: $299.95 Error: $46.45 SLE: 0.03 Item: Spec-D Tuning LED Pr...
# 184: Guess: $11.38 Truth: $24.99 Error: $13.61 SLE: 0.55 Item: RICHMOND & FINCH Air...
# 185: Guess: $146.88 Truth: $41.04 Error: $105.84 SLE: 1.58 Item: LFA Industries - mm ...
# 186: Guess: $284.25 Truth: $327.90 Error: $43.65 SLE: 0.02 Item: SAUTVS LED Headlight...
# 187: Guess: $20.11 Truth: $10.99 Error: $9.12 SLE: 0.32 Item: 2 Pack Combo Womens ...
# 188: Guess: $14.88 Truth: $14.99 Error: $0.11 SLE: 0.00 Item: Arepa - Venezuelan c...
# 189: Guess: $25.09 Truth: $84.95 Error: $59.86 SLE: 1.42 Item: Schlage Lock Company...
# 190: Guess: $62.25 Truth: $111.00 Error: $48.75 SLE: 0.33 Item: Techni Mobili White ...
# 191: Guess: $127.06 Truth: $123.73 Error: $3.33 SLE: 0.00 Item: Special Lite Product...
# 192: Guess: $508.00 Truth: $557.38 Error: $49.38 SLE: 0.01 Item: Tascam Digital Porta...
# 193: Guess: $95.44 Truth: $95.55 Error: $0.11 SLE: 0.00 Item: Glow Lighting Vista ...
# 194: Guess: $156.75 Truth: $154.00 Error: $2.75 SLE: 0.00 Item: Z3 Wind Deflector, S...
# 195: Guess: $108.62 Truth: $198.99 Error: $90.37 SLE: 0.36 Item: Olympus E-20 5MP Dig...
# 196: Guess: $204.38 Truth: $430.44 Error: $226.06 SLE: 0.55 Item: PHYNEDI 1 1000 World...
# 197: Guess: $25.28 Truth: $45.67 Error: $20.39 SLE: 0.33 Item: YANGHUAN Unstable Un...
# 198: Guess: $239.75 Truth: $249.00 Error: $9.25 SLE: 0.00 Item: Interlogix NetworX T...
# 199: Guess: $25.56 Truth: $42.99 Error: $17.43 SLE: 0.25 Item: Steering Damper,Univ...
# 200: Guess: $195.38 Truth: $181.33 Error: $14.04 SLE: 0.01 Item: Amprobe TIC 410A Hot...
# 201: Guess: $8.12 Truth: $6.03 Error: $2.09 SLE: 0.07 Item: MyCableMart 3.5mm Pl...
# 202: Guess: $52.19 Truth: $29.99 Error: $22.20 SLE: 0.29 Item: OtterBox + Pop Symme...
# 203: Guess: $752.00 Truth: $899.00 Error: $147.00 SLE: 0.03 Item: Dell XPS Desktop ( I...
# 204: Guess: $469.00 Truth: $399.99 Error: $69.01 SLE: 0.03 Item: Franklin Iron Works ...
# 205: Guess: $4.02 Truth: $4.66 Error: $0.64 SLE: 0.01 Item: Avery Legal Dividers...
# 206: Guess: $190.12 Truth: $261.41 Error: $71.29 SLE: 0.10 Item: Moen 8346 Commercial...
# 207: Guess: $155.25 Truth: $136.97 Error: $18.28 SLE: 0.02 Item: Carlisle Versa Trail...
# 208: Guess: $106.06 Truth: $79.00 Error: $27.06 SLE: 0.08 Item: SUNWAYFOTO 44mm Trip...
# 209: Guess: $334.50 Truth: $444.99 Error: $110.49 SLE: 0.08 Item: NanoBeam AC 4 Units ...
# 210: Guess: $412.50 Truth: $411.94 Error: $0.56 SLE: 0.00 Item: WULF 4 Front 2 Rear ...
# 211: Guess: $170.00 Truth: $148.40 Error: $21.60 SLE: 0.02 Item: Alera ALEVABFMC Vale...
# 212: Guess: $107.50 Truth: $244.99 Error: $137.49 SLE: 0.67 Item: YU-GI-OH! Ignition A...
# 213: Guess: $87.75 Truth: $86.50 Error: $1.25 SLE: 0.00 Item: 48 x 36 Extra-Large ...
# 214: Guess: $129.38 Truth: $297.95 Error: $168.57 SLE: 0.69 Item: Dell Latitude D620 R...
# 215: Guess: $472.00 Truth: $399.99 Error: $72.01 SLE: 0.03 Item: acer Aspire 5 Laptop...
# 216: Guess: $636.00 Truth: $599.00 Error: $37.00 SLE: 0.00 Item: Elk 30 by 6-Inch Viv...
# 217: Guess: $84.62 Truth: $105.99 Error: $21.36 SLE: 0.05 Item: Barbie Top Model Dol...
# 218: Guess: $526.50 Truth: $689.00 Error: $162.50 SLE: 0.07 Item: Danby Designer 20-In...
# 219: Guess: $302.25 Truth: $404.99 Error: $102.74 SLE: 0.09 Item: FixtureDisplays® Met...
# 220: Guess: $218.75 Truth: $207.76 Error: $10.99 SLE: 0.00 Item: ACDelco GM Original ...
# 221: Guess: $175.25 Truth: $171.82 Error: $3.43 SLE: 0.00 Item: EBC Premium Street B...
# 222: Guess: $289.25 Truth: $293.24 Error: $3.99 SLE: 0.00 Item: FXR Men's Boost FX J...
# 223: Guess: $396.50 Truth: $374.95 Error: $21.55 SLE: 0.00 Item: SuperATV Scratch Res...
# 224: Guess: $112.12 Truth: $111.99 Error: $0.14 SLE: 0.00 Item: SBU 3 Layer All Weat...
# 225: Guess: $43.69 Truth: $42.99 Error: $0.70 SLE: 0.00 Item: 2 Pack Outdoor Broch...
# 226: Guess: $124.62 Truth: $116.71 Error: $7.92 SLE: 0.00 Item: Monroe Shocks & Stru...
# 227: Guess: $220.00 Truth: $118.61 Error: $101.39 SLE: 0.38 Item: Elements of Design M...
# 228: Guess: $141.00 Truth: $147.12 Error: $6.12 SLE: 0.00 Item: GM Genuine Parts Air...
# 229: Guess: $159.75 Truth: $119.99 Error: $39.76 SLE: 0.08 Item: Baseus USB C Docking...
# 230: Guess: $464.00 Truth: $369.98 Error: $94.02 SLE: 0.05 Item: Whitehall™ Personali...
# 231: Guess: $286.75 Truth: $315.55 Error: $28.80 SLE: 0.01 Item: Pro Circuit Works Pi...
# 232: Guess: $285.00 Truth: $190.99 Error: $94.01 SLE: 0.16 Item: HYANKA 15 1200W Prof...
# 233: Guess: $228.38 Truth: $155.00 Error: $73.38 SLE: 0.15 Item: Bluetooth X6BT Card ...
# 234: Guess: $323.25 Truth: $349.99 Error: $26.74 SLE: 0.01 Item: AIRAID Cold Air Inta...
# 235: Guess: $206.75 Truth: $249.99 Error: $43.24 SLE: 0.04 Item: Bostingner Shower Fa...
# 236: Guess: $35.38 Truth: $42.99 Error: $7.62 SLE: 0.04 Item: PIT66 Front Bumper T...
# 237: Guess: $13.16 Truth: $17.99 Error: $4.83 SLE: 0.09 Item: Caseology Bumpy Comp...
# 238: Guess: $289.50 Truth: $425.00 Error: $135.50 SLE: 0.15 Item: Fleck 2510 Timer Mec...
# 239: Guess: $246.50 Truth: $249.99 Error: $3.49 SLE: 0.00 Item: Haloview MC7108 Wire...
# 240: Guess: $53.75 Truth: $138.23 Error: $84.48 SLE: 0.87 Item: Schmidt Spiele - Man...
# 241: Guess: $552.00 Truth: $414.99 Error: $137.01 SLE: 0.08 Item: Corsa 14333 Tip Kit ...
# 242: Guess: $208.00 Truth: $168.28 Error: $39.72 SLE: 0.04 Item: Hoshizaki FM116A Fan...
# 243: Guess: $235.25 Truth: $199.99 Error: $35.26 SLE: 0.03 Item: BAINUO Antler Chande...
# 244: Guess: $137.75 Truth: $126.70 Error: $11.05 SLE: 0.01 Item: DNA MOTORING Smoke L...
# 245: Guess: $5.10 Truth: $5.91 Error: $0.81 SLE: 0.02 Item: Wera Stainless 3840/...
# 246: Guess: $188.75 Truth: $193.06 Error: $4.31 SLE: 0.00 Item: Celestron - PowerSee...
# 247: Guess: $169.50 Truth: $249.99 Error: $80.49 SLE: 0.15 Item: NHOPEEW Android Car ...
# 248: Guess: $64.62 Truth: $64.12 Error: $0.50 SLE: 0.00 Item: Other Harmonica A)
# F...
# 249: Guess: $194.75 Truth: $114.99 Error: $79.76 SLE: 0.27 Item: Harley Air Filter Ve...
# 250: Guess: $568.50 Truth: $926.00 Error: $357.50 SLE: 0.24 Item: Elite Screens Edge F...
