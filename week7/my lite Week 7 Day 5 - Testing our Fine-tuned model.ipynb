# %% [markdown]
# # Google Colab

# %% [markdown]
# ## Predict Product Prices
#
# ### And now, to evaluate our fine-tuned open source model

# %%
# pip installs

# !pip install -q datasets peft requests torch bitsandbytes transformers trl accelerate sentencepiece matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 27.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 36.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.3/366.3 kB 28.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 32.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 17.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.

# %%
# imports

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import torch.nn.functional as F
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, set_seed
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
from peft import PeftModel
import matplotlib.pyplot as plt

# %%
# Constants

BASE_MODEL = "meta-llama/Meta-Llama-3.1-8B"

# PROJECT_NAME = "pricer"
PROJECT_NAME = "lite-pricer"

# HF_USER = "ed-donner" # your HF name here! Or use mine if you just want to reproduce my results.
HF_USER = "erasermw" # your HF name here! Or use mine if you just want to reproduce my results.

# The run itself

# RUN_NAME = "2024-09-13_13.04.39"
RUN_NAME = "2025-05-31_15.27.59"

PROJECT_RUN_NAME = f"{PROJECT_NAME}-{RUN_NAME}"

# REVISION = "e8d637df551603dc86cd7a1598a8f44af4d7ae36" # or REVISION = None
REVISION = None

FINETUNED_MODEL = f"{HF_USER}/{PROJECT_RUN_NAME}"

# Uncomment this line if you wish to use my model
# FINETUNED_MODEL = f"ed-donner/{PROJECT_RUN_NAME}"

# Data

# DATASET_NAME = f"{HF_USER}/pricer-data"
DATASET_NAME = f"{HF_USER}/lite-data"


# Or just use the one I've uploaded
# DATASET_NAME = "ed-donner/pricer-data"



# Hyperparameters for QLoRA

QUANT_4_BIT = True

# %matplotlib inline

# Used for writing to output in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %%
DATASET_NAME
# Out:
# 'erasermw/lite-data'

# %% [markdown]
# ### Log in to HuggingFace
#
# If you don't already have a HuggingFace account, visit https://huggingface.co to sign up and create a token.
#
# Then select the Secrets for this Notebook by clicking on the key icon in the left, and add a new secret called `HF_TOKEN` with the value as your token.

# %%
# Log in to HuggingFace

hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# README.md:   0%|          | 0.00/412 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/9.70M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/769k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
len(train), len(test)
# Out:
# (25000, 2000)

# %%
train[0]
# Out:
# {'text': 'How much does this cost to the nearest dollar?\n\nand Replacement Range Cooktop Drip Pans fit GE, Hotpoint - Two 6 Inch and Two 8 Inch Pans (4 pieces)\nContents 2 x (6 inches) and 2 x (8 inches) bowls, 4 drip bowls total Compatibility This replacement kit works with GE, Hotpoint, Moffat, Monogram (GE), Profile (GE), RCA (GE), and Roper models prior to 1996. replaces 65975, replaces and 65974, 770169 Premium quality Drip bowls are made of durable high-quality material. It features a chrome finish, well-tested by the manufacturer. Durable, stick-free, easy to clean, and dishwasher safe. Ensure long-lasting and effective performance Easy to install Shut off electrical power, tilt the coil\n\nPrice is $12.00',
#  'price': 11.99}

# %%
test[0]
# Out:
# {'text': "How much does this cost to the nearest dollar?\n\nSetpower Insulated Protective Cover for AJ30 Portable Refrigerator Freezer, suitable for AJ30 Only\nInsulation & Waterproof well-made insulation could save battery power and improve cooling efficiency by preventing cold air from flowing away. Durable and Foldable with its oxford cloth outer layer, it's durable and protects your portable refrigerator from scratches and dust. Expanded Bag for Accessories two expanded bags on its side, expand space to store the other accessories. Great Ventilation a hollowed design for positions of vents doesn't affect the ventilation. Attention this insulated cover is ONLY suitable for SetPower AJ30 portable refrigerator. FIT TO AJ30 ONLY. Brand Name Setpower, Model Info AJ30 COVER, model number AJ30 COVER, Installation Type Freestanding, Part AJ30 cover, Special Features Portable, Color\n\nPrice is $",
#  'price': 65.99}

# %% [markdown]
# ## Now load the Tokenizer and Model

# %%
# pick the right quantization (thank you Robert M. for spotting the bug with the 8 bit version!)

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

# Load the fine-tuned model with PEFT
if REVISION:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL, revision=REVISION)
else:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL)


print(f"Memory footprint: {fine_tuned_model.get_memory_footprint() / 1e6:.1f} MB")
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/811 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/109M [00:00<?, ?B/s]
# Memory footprint: 5700.6 MB

# %%
fine_tuned_model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#     )
#   )
# )

# %% [markdown]
# # THE MOMENT OF TRUTH!
#
# ## Use the model in inference mode
#
# Remember, GPT-4o had an average error of \$76.
# Llama 3.1 base model had an average error of \$396.
# This human had an error of \$127.
#
# ## Caveat
#
# Keep in mind that prices of goods vary considerably; the model can't predict things like sale prices that it doesn't have any information about.

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
extract_price("Price is $a fabulous 899.99 or so")
# Out:
# 899.99

# %%
# Original prediction function takes the most likely next token

def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = fine_tuned_model.generate(inputs, attention_mask=attention_mask, max_new_tokens=3, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    return extract_price(response)

# %%
# An improved prediction function takes a weighted average of the top 3 choices
# This code would be more complex if we couldn't take advantage of the fact
# That Llama generates 1 token for any 3 digit number

top_K = 3

def improved_model_predict(prompt, device="cuda"):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    attention_mask = torch.ones(inputs.shape, device=device)

    with torch.no_grad():
        outputs = fine_tuned_model(inputs, attention_mask=attention_mask)
        next_token_logits = outputs.logits[:, -1, :].to('cpu')

    next_token_probs = F.softmax(next_token_logits, dim=-1)
    top_prob, top_token_id = next_token_probs.topk(top_K)
    prices, weights = [], []
    for i in range(top_K):
      predicted_token = tokenizer.decode(top_token_id[0][i])
      probability = top_prob[0][i]
      try:
        result = float(predicted_token)
      except ValueError as e:
        result = 0.0
      if result > 0:
        prices.append(result)
        weights.append(probability)
    if not prices:
      return 0.0, 0.0
    total = sum(weights)
    weighted_prices = [price * weight / total for price, weight in zip(prices, weights)]
    return sum(weighted_prices).item()

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(improved_model_predict, test)
# Out:
# 1: Guess: $25.05 Truth: $65.99 Error: $40.94 SLE: 0.89 Item: Setpower Insulated P...
# 2: Guess: $9.04 Truth: $9.68 Error: $0.64 SLE: 0.00 Item: TUAIC Refrigerator D...
# 3: Guess: $100.25 Truth: $155.98 Error: $55.73 SLE: 0.19 Item: Kegco Secondary Regu...
# 4: Guess: $10.30 Truth: $5.59 Error: $4.71 SLE: 0.29 Item: Refrigerator Door Sp...
# 5: Guess: $58.00 Truth: $98.40 Error: $40.40 SLE: 0.27 Item: Ice-O-Matic Float Va...
# 6: Guess: $24.61 Truth: $54.99 Error: $30.38 SLE: 0.61 Item: Wireless Temperature...
# 7: Guess: $8.97 Truth: $5.71 Error: $3.26 SLE: 0.16 Item: 3Inch Thermometer Hy...
# 8: Guess: $11.64 Truth: $9.53 Error: $2.11 SLE: 0.03 Item: GE GE Timer Knob Ass...
# 9: Guess: $11.68 Truth: $11.24 Error: $0.44 SLE: 0.00 Item: newlifeapp Dryer Lin...
# 10: Guess: $21.28 Truth: $12.88 Error: $8.40 SLE: 0.22 Item: Away NV350 NV351 NV3...
# 11: Guess: $118.94 Truth: $99.99 Error: $18.95 SLE: 0.03 Item: Refrigerator Ice Mak...
# 12: Guess: $17.22 Truth: $16.99 Error: $0.23 SLE: 0.00 Item: 2 PACKS Water Filter...
# 13: Guess: $10.28 Truth: $12.74 Error: $2.46 SLE: 0.04 Item: STANCO METAL PROD 41...
# 14: Guess: $11.72 Truth: $10.95 Error: $0.77 SLE: 0.00 Item: GE 6-Inch Drip Pan
# P...
# 15: Guess: $32.00 Truth: $66.50 Error: $34.50 SLE: 0.51 Item: Edgewater Parts Drai...
# 16: Guess: $7.93 Truth: $11.99 Error: $4.06 SLE: 0.14 Item: Elyum Size 04 Cone C...
# 17: Guess: $43.62 Truth: $49.95 Error: $6.33 SLE: 0.02 Item: Everydrop by Whirlpo...
# 18: Guess: $27.25 Truth: $26.92 Error: $0.33 SLE: 0.00 Item: Beverage Air Door Ga...
# 19: Guess: $174.00 Truth: $89.98 Error: $84.02 SLE: 0.43 Item: Frigidaire Counter T...
# 20: Guess: $35.69 Truth: $25.99 Error: $9.70 SLE: 0.09 Item: Supplying Demand Ele...
# 21: Guess: $16.02 Truth: $17.99 Error: $1.97 SLE: 0.01 Item: 2-Pack Dryer Lint Fi...
# 22: Guess: $14.69 Truth: $6.99 Error: $7.70 SLE: 0.46 Item: Qlear-CLWT Premium R...
# 23: Guess: $10.97 Truth: $39.99 Error: $29.02 SLE: 1.52 Item: HUBBELL AC Plug NEMA...
# 24: Guess: $17.81 Truth: $13.99 Error: $3.82 SLE: 0.05 Item: Refrigerator Egg Hol...
# 25: Guess: $697.00 Truth: $339.95 Error: $357.05 SLE: 0.51 Item: ZLINE 20.5 Ducted Wa...
# 26: Guess: $42.09 Truth: $67.99 Error: $25.90 SLE: 0.22 Item: Supplying Demand Top...
# 27: Guess: $99.88 Truth: $139.00 Error: $39.12 SLE: 0.11 Item: Compatible Ice Maker...
# 28: Guess: $10.91 Truth: $8.97 Error: $1.94 SLE: 0.03 Item: Blutoget 6 Louvered ...
# 29: Guess: $24.84 Truth: $39.65 Error: $14.81 SLE: 0.21 Item: Edgewater Parts Evap...
# 30: Guess: $283.00 Truth: $229.98 Error: $53.02 SLE: 0.04 Item: Winflo 30 In. Conver...
# 31: Guess: $30.72 Truth: $25.80 Error: $4.92 SLE: 0.03 Item: Washer Shock Absorbe...
# 32: Guess: $11.69 Truth: $11.99 Error: $0.30 SLE: 0.00 Item: 2 PACK AF Compatible...
# 33: Guess: $11.58 Truth: $9.99 Error: $1.59 SLE: 0.02 Item: Poweka Refillable Co...
# 34: Guess: $22.77 Truth: $21.99 Error: $0.78 SLE: 0.00 Item: 2-Pack Replacement f...
# 35: Guess: $24.62 Truth: $17.90 Error: $6.73 SLE: 0.09 Item: Supco Dryer Heating ...
# 36: Guess: $41.97 Truth: $84.00 Error: $42.03 SLE: 0.47 Item: Frymaster Common Ele...
# 37: Guess: $11.75 Truth: $16.24 Error: $4.49 SLE: 0.09 Item: Plumb Craft 5-Foot W...
# 38: Guess: $28.31 Truth: $23.99 Error: $4.32 SLE: 0.03 Item: Overbest Replacement...
# 39: Guess: $12.25 Truth: $6.99 Error: $5.26 SLE: 0.26 Item: Fill 'n Brew Individ...
# 40: Guess: $28.22 Truth: $24.99 Error: $3.23 SLE: 0.01 Item: Maytag EDR7D1 Compar...
# 41: Guess: $9.06 Truth: $11.61 Error: $2.55 SLE: 0.05 Item: Coffee Filters - Nat...
# 42: Guess: $405.50 Truth: $949.00 Error: $543.50 SLE: 0.72 Item: EdgeStar 20 Inch Wid...
# 43: Guess: $49.56 Truth: $74.00 Error: $24.44 SLE: 0.16 Item: Bosch Door Lower Bin...
# 44: Guess: $40.81 Truth: $22.05 Error: $18.76 SLE: 0.35 Item: Samsung Switch Door-...
# 45: Guess: $162.25 Truth: $284.00 Error: $121.75 SLE: 0.31 Item: Jenn air Stove Cartr...
# 46: Guess: $59.38 Truth: $91.78 Error: $32.41 SLE: 0.18 Item: Whole Parts Burner G...
# 47: Guess: $25.27 Truth: $45.20 Error: $19.93 SLE: 0.32 Item: DEFLECTO SK8WF Supur...
# 48: Guess: $10.96 Truth: $8.69 Error: $2.27 SLE: 0.04 Item: Supco RR109 Receptac...
# 49: Guess: $16.92 Truth: $16.18 Error: $0.74 SLE: 0.00 Item: Dryer Lint Screen Fi...
# 50: Guess: $6.96 Truth: $6.50 Error: $0.46 SLE: 0.00 Item: Replacement Light Bu...
# 51: Guess: $11.62 Truth: $32.21 Error: $20.59 SLE: 0.94 Item: ForeverPRO Drum Ligh...
# 52: Guess: $21.00 Truth: $15.39 Error: $5.61 SLE: 0.09 Item: Highcraft Dishwasher...
# 53: Guess: $18.19 Truth: $17.99 Error: $0.20 SLE: 0.00 Item: and Stove Burner Dri...
# 54: Guess: $28.09 Truth: $26.99 Error: $1.10 SLE: 0.00 Item: ReplacementBrand Com...
# 55: Guess: $8.88 Truth: $11.99 Error: $3.11 SLE: 0.07 Item: 2-Pack 341241 Dryer ...
# 56: Guess: $9.03 Truth: $44.46 Error: $35.43 SLE: 2.28 Item: Power Nut Kit - Comp...
# 57: Guess: $11.70 Truth: $15.99 Error: $4.29 SLE: 0.08 Item: Stovetop Extender Ov...
# 58: Guess: $109.38 Truth: $129.99 Error: $20.62 SLE: 0.03 Item: COSVALVE Portable Wa...
# 59: Guess: $17.88 Truth: $24.99 Error: $7.11 SLE: 0.10 Item: AlaSou Washer Dustpr...
# 60: Guess: $24.91 Truth: $27.38 Error: $2.47 SLE: 0.01 Item: Honeywell Pad for He...
# 61: Guess: $12.94 Truth: $16.95 Error: $4.01 SLE: 0.06 Item: HQRP 2-Pack Wick Fil...
# 62: Guess: $11.66 Truth: $10.82 Error: $0.84 SLE: 0.00 Item: Whirlpool Pad Washer...
# 63: Guess: $11.52 Truth: $19.00 Error: $7.48 SLE: 0.22 Item: Durable Disposable E...
# 64: Guess: $12.22 Truth: $12.98 Error: $0.76 SLE: 0.00 Item: Anti Vibration Pads ...
# 65: Guess: $10.38 Truth: $16.99 Error: $6.61 SLE: 0.21 Item: Reusable K Cups for ...
# 66: Guess: $17.03 Truth: $24.97 Error: $7.94 SLE: 0.13 Item: Apace Living Pour Ov...
# 67: Guess: $10.30 Truth: $10.91 Error: $0.61 SLE: 0.00 Item: Kitchen Basics 101 2...
# 68: Guess: $11.55 Truth: $14.98 Error: $3.43 SLE: 0.06 Item: Mist Water Filter Re...
# 69: Guess: $25.34 Truth: $7.90 Error: $17.44 SLE: 1.18 Item: NEW Dryer Drum Felt ...
# 70: Guess: $34.62 Truth: $25.75 Error: $8.88 SLE: 0.08 Item: Cobectal Dryer Drum ...
# 71: Guess: $30.91 Truth: $41.77 Error: $10.86 SLE: 0.09 Item: Washer Shock Absorbe...
# 72: Guess: $20.92 Truth: $20.68 Error: $0.24 SLE: 0.00 Item: Fafeicy WT2000 Digit...
# 73: Guess: $87.62 Truth: $69.99 Error: $17.64 SLE: 0.05 Item: TJ. Clothes Dryer, 1...
# 74: Guess: $31.59 Truth: $23.99 Error: $7.60 SLE: 0.07 Item: Suspension Support R...
# 75: Guess: $31.38 Truth: $28.69 Error: $2.68 SLE: 0.01 Item: Supplying Demand Ele...
# 76: Guess: $19.03 Truth: $42.00 Error: $22.97 SLE: 0.58 Item: General Electric Kno...
# 77: Guess: $68.25 Truth: $123.57 Error: $55.32 SLE: 0.34 Item: Frigidaire Oven Door...
# 78: Guess: $10.88 Truth: $8.99 Error: $1.88 SLE: 0.03 Item: Waytiffer Gas Burner...
# 79: Guess: $39.19 Truth: $36.95 Error: $2.24 SLE: 0.00 Item: USA Made MSWF Compat...
# 80: Guess: $9.37 Truth: $11.99 Error: $2.62 SLE: 0.05 Item: 2-Pack 341241 Dryer ...
# 81: Guess: $39.56 Truth: $41.30 Error: $1.74 SLE: 0.00 Item: Washing Machine Hose...
# 82: Guess: $24.05 Truth: $35.61 Error: $11.56 SLE: 0.14 Item: Bosch Dishwasher Doo...
# 83: Guess: $352.50 Truth: $169.99 Error: $182.51 SLE: 0.53 Item: Broan QS3 Series Ran...
# 84: Guess: $25.97 Truth: $19.91 Error: $6.06 SLE: 0.06 Item: Bosch Range Surface ...
# 85: Guess: $8.97 Truth: $9.57 Error: $0.60 SLE: 0.00 Item: LONYE Oven Thermal F...
# 86: Guess: $31.50 Truth: $29.69 Error: $1.81 SLE: 0.00 Item: Upgrade Stainless St...
# 87: Guess: $23.97 Truth: $21.93 Error: $2.04 SLE: 0.01 Item: Supco Icemaker Contr...
# 88: Guess: $22.41 Truth: $32.56 Error: $10.15 SLE: 0.13 Item: Evaporator Fan Motor...
# 89: Guess: $31.50 Truth: $22.78 Error: $8.72 SLE: 0.10 Item: UPGRADE Refrigerator...
# 90: Guess: $16.91 Truth: $24.79 Error: $7.88 SLE: 0.13 Item: Supreme Covers Porta...
# 91: Guess: $20.03 Truth: $33.69 Error: $13.66 SLE: 0.25 Item: Frigidaire Surface B...
# 92: Guess: $11.48 Truth: $12.99 Error: $1.51 SLE: 0.01 Item: TooCust Milk Frothin...
# 93: Guess: $19.02 Truth: $12.99 Error: $6.03 SLE: 0.13 Item: Premium Vials 38 x 2...
# 94: Guess: $9.17 Truth: $10.98 Error: $1.81 SLE: 0.03 Item: Washer Door Lid Swit...
# 95: Guess: $21.72 Truth: $26.44 Error: $4.72 SLE: 0.04 Item: Aqua Fresh Replaceme...
# 96: Guess: $13.33 Truth: $16.99 Error: $3.66 SLE: 0.05 Item: InterDesign Covered ...
# 97: Guess: $22.73 Truth: $25.25 Error: $2.52 SLE: 0.01 Item: Upgrade Gas Range Ov...
# 98: Guess: $11.56 Truth: $11.88 Error: $0.32 SLE: 0.00 Item: Washing Machine Inne...
# 99: Guess: $17.86 Truth: $28.99 Error: $11.13 SLE: 0.22 Item: Maxmartt 100mm Vent ...
# 100: Guess: $15.64 Truth: $23.12 Error: $7.48 SLE: 0.14 Item: Upgraded Lifetime Ap...
# 101: Guess: $31.59 Truth: $52.97 Error: $21.38 SLE: 0.25 Item: Whirlpool Sensor for...
# 102: Guess: $17.78 Truth: $25.99 Error: $8.21 SLE: 0.13 Item: Wintact Digital Temp...
# 103: Guess: $17.84 Truth: $17.99 Error: $0.15 SLE: 0.00 Item: BOTNA Range Hood Gre...
# 104: Guess: $10.36 Truth: $7.99 Error: $2.37 SLE: 0.05 Item: Milk Frothing Pitche...
# 105: Guess: $27.84 Truth: $28.99 Error: $1.15 SLE: 0.00 Item: 1040 Replacement Wic...
# 106: Guess: $16.48 Truth: $12.07 Error: $4.41 SLE: 0.08 Item: Stanco Gas Range Dri...
# 107: Guess: $21.53 Truth: $18.99 Error: $2.54 SLE: 0.01 Item: Dampp Chaser Piano H...
# 108: Guess: $9.02 Truth: $9.99 Error: $0.97 SLE: 0.01 Item: Gardens Light Switch...
# 109: Guess: $31.34 Truth: $29.99 Error: $1.35 SLE: 0.00 Item: Waterspecialist Repl...
# 110: Guess: $11.50 Truth: $9.99 Error: $1.51 SLE: 0.02 Item: Upgraded Stove Knob,...
# 111: Guess: $39.34 Truth: $31.69 Error: $7.65 SLE: 0.04 Item: 5-PACK Top Burner Co...
# 112: Guess: $17.98 Truth: $24.99 Error: $7.01 SLE: 0.10 Item: Large Capacity Egg H...
# 113: Guess: $21.31 Truth: $25.99 Error: $4.68 SLE: 0.04 Item: FireFly Home Stove T...
# 114: Guess: $13.28 Truth: $18.99 Error: $5.71 SLE: 0.11 Item: Annbully Cartoon USB...
# 115: Guess: $11.53 Truth: $9.99 Error: $1.54 SLE: 0.02 Item: Goldenvalueable 6 x ...
# 116: Guess: $37.28 Truth: $22.99 Error: $14.29 SLE: 0.22 Item: Blueangle Pink Hibis...
# 117: Guess: $190.50 Truth: $169.99 Error: $20.51 SLE: 0.01 Item: ROVSUN 13LBS Portabl...
# 118: Guess: $31.27 Truth: $36.99 Error: $5.72 SLE: 0.03 Item: 1-Year Warranty Drye...
# 119: Guess: $18.41 Truth: $33.99 Error: $15.58 SLE: 0.35 Item: ICEPURE Replacement ...
# 120: Guess: $42.00 Truth: $104.89 Error: $62.89 SLE: 0.81 Item: Whirlpool Water Inle...
# 121: Guess: $24.72 Truth: $19.98 Error: $4.74 SLE: 0.04 Item: Washing Machine Wate...
# 122: Guess: $11.69 Truth: $9.99 Error: $1.70 SLE: 0.02 Item: Sunflowers Refrigera...
# 123: Guess: $11.70 Truth: $28.10 Error: $16.40 SLE: 0.69 Item: General Electric Fro...
# 124: Guess: $23.66 Truth: $27.50 Error: $3.84 SLE: 0.02 Item: Supco Refrigerator W...
# 125: Guess: $24.98 Truth: $36.99 Error: $12.01 SLE: 0.14 Item: HASMX Dishwasher Cut...
# 126: Guess: $25.97 Truth: $19.84 Error: $6.13 SLE: 0.07 Item: Whirlpool Range Surf...
# 127: Guess: $11.69 Truth: $24.99 Error: $13.30 SLE: 0.51 Item: 950S - Compatible wi...
# 128: Guess: $69.88 Truth: $169.99 Error: $100.12 SLE: 0.78 Item: WAFIET 12 Inch Gas C...
# 129: Guess: $21.44 Truth: $19.99 Error: $1.45 SLE: 0.00 Item: Reusable Vertuo Caps...
# 130: Guess: $20.03 Truth: $25.95 Error: $5.92 SLE: 0.06 Item: Coffee Filter Holder...
# 131: Guess: $120.88 Truth: $39.96 Error: $80.91 SLE: 1.19 Item: Star Deflector-Burne...
# 132: Guess: $11.64 Truth: $15.99 Error: $4.35 SLE: 0.09 Item: General Electric Ran...
# 133: Guess: $20.97 Truth: $39.99 Error: $19.02 SLE: 0.39 Item: WiFi Temperature Sen...
# 134: Guess: $24.75 Truth: $21.53 Error: $3.22 SLE: 0.02 Item: KITCHEN BASICS 101 1...
# 135: Guess: $35.62 Truth: $26.99 Error: $8.64 SLE: 0.07 Item: Dryer Heating Elemen...
# 136: Guess: $42.31 Truth: $43.99 Error: $1.68 SLE: 0.00 Item: Samsung HAF-CIN EXP ...
# 137: Guess: $16.97 Truth: $9.41 Error: $7.56 SLE: 0.30 Item: HQRP 3-Pack Wick Fil...
# 138: Guess: $11.50 Truth: $8.99 Error: $2.51 SLE: 0.05 Item: Reusable K Cups For ...
# 139: Guess: $69.75 Truth: $61.51 Error: $8.24 SLE: 0.02 Item: for GE Icemaker Refr...
# 140: Guess: $54.91 Truth: $122.30 Error: $67.39 SLE: 0.63 Item: Whirlpool Inlet Valv...
# 141: Guess: $11.56 Truth: $14.89 Error: $3.33 SLE: 0.06 Item: 100 UNIVERSAL Round ...
# 142: Guess: $21.47 Truth: $39.99 Error: $18.52 SLE: 0.36 Item: TRUE 811502 Nozzle a...
# 143: Guess: $11.59 Truth: $17.90 Error: $6.31 SLE: 0.16 Item: Dianoo Espresso Stea...
# 144: Guess: $21.28 Truth: $16.77 Error: $4.51 SLE: 0.05 Item: Air Filter Factory R...
# 145: Guess: $35.03 Truth: $23.99 Error: $11.04 SLE: 0.13 Item: EvertechPRO Washer D...
# 146: Guess: $41.19 Truth: $35.00 Error: $6.19 SLE: 0.03 Item: Cheftek CT1010 Porta...
# 147: Guess: $8.97 Truth: $4.95 Error: $4.02 SLE: 0.27 Item: HQRP 4 Pin Universal...
# 148: Guess: $11.69 Truth: $18.89 Error: $7.20 SLE: 0.20 Item: 2-Pack TSD2 Start De...
# 149: Guess: $11.56 Truth: $8.77 Error: $2.79 SLE: 0.06 Item: Air Filter Factory R...
# 150: Guess: $22.34 Truth: $17.22 Error: $5.12 SLE: 0.06 Item: Plumb Pak Braided Wa...
# 151: Guess: $26.00 Truth: $20.98 Error: $5.02 SLE: 0.04 Item: Bosch Button, Silver...
# 152: Guess: $34.81 Truth: $37.37 Error: $2.56 SLE: 0.00 Item: Siwdoy 279816 Dryer ...
# 153: Guess: $13.67 Truth: $11.99 Error: $1.68 SLE: 0.01 Item: OUGAR8 Refrigerator ...
# 154: Guess: $55.25 Truth: $119.95 Error: $64.70 SLE: 0.59 Item: Bosch Range Hood Fan...
# 155: Guess: $31.84 Truth: $31.00 Error: $0.84 SLE: 0.00 Item: Replacement Filter C...
# 156: Guess: $32.06 Truth: $31.00 Error: $1.06 SLE: 0.00 Item: Aprilaire Humidifier...
# 157: Guess: $10.94 Truth: $7.97 Error: $2.97 SLE: 0.08 Item: Technivorm Moccamast...
# 158: Guess: $83.12 Truth: $51.50 Error: $31.62 SLE: 0.22 Item: LG Electronics Washi...
# 159: Guess: $37.12 Truth: $27.99 Error: $9.14 SLE: 0.08 Item: ALAZA Flower on Marb...
# 160: Guess: $567.00 Truth: $466.24 Error: $100.76 SLE: 0.04 Item: Frigidaire 30 Inch E...
# 161: Guess: $15.36 Truth: $50.36 Error: $35.00 SLE: 1.31 Item: General Electric Ref...
# 162: Guess: $12.14 Truth: $19.97 Error: $7.83 SLE: 0.22 Item: Small Size Pour Over...
# 163: Guess: $24.09 Truth: $29.95 Error: $5.86 SLE: 0.04 Item: Sealegend Dryer Vent...
# 164: Guess: $29.06 Truth: $23.99 Error: $5.07 SLE: 0.03 Item: Waterspecialist XWF ...
# 165: Guess: $9.05 Truth: $12.74 Error: $3.69 SLE: 0.10 Item: GARP 279816 Compatib...
# 166: Guess: $6.95 Truth: $8.99 Error: $2.04 SLE: 0.05 Item: Premium Dishwasher B...
# 167: Guess: $24.47 Truth: $24.99 Error: $0.52 SLE: 0.00 Item: UpStart Components R...
# 168: Guess: $11.45 Truth: $17.99 Error: $6.54 SLE: 0.18 Item: Chef's Star Stainles...
# 169: Guess: $18.12 Truth: $19.99 Error: $1.86 SLE: 0.01 Item: Egg Container for Re...
# 170: Guess: $21.06 Truth: $18.77 Error: $2.29 SLE: 0.01 Item: AMI PARTS Dryer Lint...
# 171: Guess: $23.56 Truth: $47.86 Error: $24.30 SLE: 0.47 Item: GE Igniter for Gas B...
# 172: Guess: $23.73 Truth: $34.45 Error: $10.72 SLE: 0.13 Item: General Electric Dry...
# 173: Guess: $6.97 Truth: $7.99 Error: $1.02 SLE: 0.01 Item: 312959 Dryer Belt Re...
# 174: Guess: $30.91 Truth: $27.99 Error: $2.92 SLE: 0.01 Item: 5-Pack Replacement E...
# 175: Guess: $100.31 Truth: $117.99 Error: $17.68 SLE: 0.03 Item: OEM Samsung Refriger...
# 176: Guess: $352.25 Truth: $989.99 Error: $637.74 SLE: 1.06 Item: vevor 24 Undercounte...
# 177: Guess: $21.20 Truth: $18.99 Error: $2.21 SLE: 0.01 Item: Reusable Vertuo Caps...
# 178: Guess: $99.75 Truth: $164.98 Error: $65.23 SLE: 0.25 Item: 32 x 30 2.5 Heavy Du...
# 179: Guess: $18.09 Truth: $19.36 Error: $1.27 SLE: 0.00 Item: Fluidmaster 9WM60 No...
# 180: Guess: $22.52 Truth: $16.00 Error: $6.52 SLE: 0.11 Item: AYZE Electric Restri...
# 181: Guess: $17.72 Truth: $21.40 Error: $3.68 SLE: 0.03 Item: Whirlpool Door Handl...
# 182: Guess: $27.97 Truth: $46.99 Error: $19.02 SLE: 0.25 Item: Upgraded Dryer Repai...
# 183: Guess: $11.59 Truth: $13.69 Error: $2.10 SLE: 0.02 Item: Camco 00553 8 GE/Hot...
# 184: Guess: $25.00 Truth: $22.72 Error: $2.28 SLE: 0.01 Item: GE Part Number KNOB ...
# 185: Guess: $50.19 Truth: $105.13 Error: $54.94 SLE: 0.53 Item: Manitowoc Ice Curtai...
# 186: Guess: $27.34 Truth: $32.50 Error: $5.16 SLE: 0.03 Item: Heating Element ( Re...
# 187: Guess: $23.70 Truth: $114.60 Error: $90.90 SLE: 2.38 Item: Vulcan Hart Thermo
# P...
# 188: Guess: $49.94 Truth: $84.96 Error: $35.02 SLE: 0.27 Item: Turbo Air Thermostat...
# 189: Guess: $50.56 Truth: $83.40 Error: $32.84 SLE: 0.24 Item: Frigidaire Dispenser...
# 190: Guess: $7.14 Truth: $9.99 Error: $2.85 SLE: 0.09 Item: Splutch Cam Kit Repl...
# 191: Guess: $7.00 Truth: $9.49 Error: $2.49 SLE: 0.07 Item: newlifeapp Dryer The...
# 192: Guess: $24.91 Truth: $29.99 Error: $5.08 SLE: 0.03 Item: Upgraded Dryer Rear ...
# 193: Guess: $22.19 Truth: $13.57 Error: $8.62 SLE: 0.22 Item: 2 Pack Top Burner Sp...
# 194: Guess: $22.34 Truth: $19.96 Error: $2.38 SLE: 0.01 Item: Washer Drain Pump Mo...
# 195: Guess: $43.31 Truth: $56.99 Error: $13.68 SLE: 0.07 Item: New-Refrigerator Ice...
# 196: Guess: $11.01 Truth: $16.37 Error: $5.36 SLE: 0.14 Item: Whirlpool Adjuster
# P...
# 197: Guess: $21.31 Truth: $19.99 Error: $1.32 SLE: 0.00 Item: Nispira Replacement ...
# 198: Guess: $31.25 Truth: $37.98 Error: $6.73 SLE: 0.04 Item: Mist Water Filter Re...
# 199: Guess: $42.12 Truth: $34.79 Error: $7.34 SLE: 0.03 Item: UPGRADE Refrigerator...
# 200: Guess: $8.98 Truth: $8.39 Error: $0.59 SLE: 0.00 Item: DPD Washer Lid Switc...
# 201: Guess: $90.25 Truth: $117.86 Error: $27.61 SLE: 0.07 Item: GENUINE Frigidaire B...
# 202: Guess: $10.25 Truth: $15.99 Error: $5.74 SLE: 0.17 Item: Anti Vibration Pads ...
# 203: Guess: $11.55 Truth: $10.99 Error: $0.56 SLE: 0.00 Item: Dryer Drum Support R...
# 204: Guess: $18.36 Truth: $24.43 Error: $6.07 SLE: 0.07 Item: Whirlpool 279816 Dry...
# 205: Guess: $469.00 Truth: $426.98 Error: $42.02 SLE: 0.01 Item: Empava 36 500 CFM Is...
# 206: Guess: $35.25 Truth: $39.99 Error: $4.74 SLE: 0.02 Item: SpiroPure NSF Certif...
# 207: Guess: $23.23 Truth: $26.99 Error: $3.76 SLE: 0.02 Item: Replacement for Jenn...
# 208: Guess: $100.25 Truth: $138.69 Error: $38.44 SLE: 0.10 Item: GE Genuine OEM Dampe...
# 209: Guess: $9.17 Truth: $13.97 Error: $4.80 SLE: 0.15 Item: Dryer Thermal Fuse T...
# 210: Guess: $22.78 Truth: $21.99 Error: $0.79 SLE: 0.00 Item: 2-Pack Replacement f...
# 211: Guess: $9.05 Truth: $18.88 Error: $9.83 SLE: 0.47 Item: Terminal Block Assem...
# 212: Guess: $38.44 Truth: $18.41 Error: $20.03 SLE: 0.50 Item: Whirlpool 308180 Bak...
# 213: Guess: $10.86 Truth: $9.95 Error: $0.91 SLE: 0.01 Item: LG Sensor Kenmore Wa...
# 214: Guess: $11.44 Truth: $18.00 Error: $6.56 SLE: 0.18 Item: Compatible Drum Belt...
# 215: Guess: $21.22 Truth: $33.95 Error: $12.73 SLE: 0.21 Item: Whirlpool Dryer Liqu...
# 216: Guess: $18.02 Truth: $42.95 Error: $24.93 SLE: 0.70 Item: MCGILL Replacement B...
# 217: Guess: $59.31 Truth: $59.99 Error: $0.68 SLE: 0.00 Item: New Upgraded Refrige...
# 218: Guess: $50.44 Truth: $55.58 Error: $5.14 SLE: 0.01 Item: TRUE 810719 Black Ga...
# 219: Guess: $31.42 Truth: $15.10 Error: $16.32 SLE: 0.49 Item: LG Genuine OEM Drain...
# 220: Guess: $28.03 Truth: $45.99 Error: $17.96 SLE: 0.23 Item: Waterspecialist Refr...
# 221: Guess: $118.88 Truth: $60.14 Error: $58.73 SLE: 0.45 Item: GlobPro Washer Water...
# 222: Guess: $19.56 Truth: $45.99 Error: $26.43 SLE: 0.68 Item: AQUA CREST 847200 Re...
# 223: Guess: $21.14 Truth: $16.24 Error: $4.90 SLE: 0.06 Item: Frigidaire Frigidare...
# 224: Guess: $18.00 Truth: $31.99 Error: $13.99 SLE: 0.30 Item: Supplying Demand Clo...
# 225: Guess: $14.36 Truth: $34.00 Error: $19.64 SLE: 0.68 Item: Whole Parts Dryer Pu...
# 226: Guess: $18.08 Truth: $26.99 Error: $8.91 SLE: 0.15 Item: i Cafillas Refillabl...
# 227: Guess: $11.70 Truth: $15.39 Error: $3.69 SLE: 0.07 Item: Thermostat
# Brand new...
# 228: Guess: $22.94 Truth: $27.77 Error: $4.83 SLE: 0.03 Item: Beaquicy Oven Bake E...
# 229: Guess: $20.34 Truth: $26.08 Error: $5.74 SLE: 0.06 Item: Whirlpool 661570 Bel...
# 230: Guess: $40.25 Truth: $18.99 Error: $21.26 SLE: 0.52 Item: iFillMug 33 Pack for...
# 231: Guess: $100.44 Truth: $159.18 Error: $58.74 SLE: 0.21 Item: Frigidaire Freezer D...
# 232: Guess: $18.02 Truth: $34.95 Error: $16.93 SLE: 0.41 Item: New York Air Airplan...
# 233: Guess: $21.75 Truth: $25.19 Error: $3.44 SLE: 0.02 Item: Amazon Basics Replac...
# 234: Guess: $7.07 Truth: $19.51 Error: $12.44 SLE: 0.87 Item: Upgraded Dishrack St...
# 235: Guess: $37.09 Truth: $37.45 Error: $0.36 SLE: 0.00 Item: Sportman Pastoral St...
# 236: Guess: $31.09 Truth: $29.99 Error: $1.10 SLE: 0.00 Item: Motor OEM Mania New ...
# 237: Guess: $119.25 Truth: $163.56 Error: $44.31 SLE: 0.10 Item: Refrigerator Ice Mak...
# 238: Guess: $21.23 Truth: $27.00 Error: $5.77 SLE: 0.05 Item: Appliance Slide for ...
# 239: Guess: $7.00 Truth: $5.99 Error: $1.01 SLE: 0.02 Item: Lower Dishwasher Whe...
# 240: Guess: $6.99 Truth: $6.64 Error: $0.35 SLE: 0.00 Item: Gas Female Cap ORIFI...
# 241: Guess: $9.09 Truth: $26.04 Error: $16.95 SLE: 0.97 Item: 9pcs Silicon Rubber ...
# 242: Guess: $11.56 Truth: $13.79 Error: $2.23 SLE: 0.03 Item: Supplying Demand Clo...
# 243: Guess: $100.12 Truth: $78.98 Error: $21.14 SLE: 0.06 Item: General Electric Ref...
# 244: Guess: $11.56 Truth: $27.99 Error: $16.43 SLE: 0.70 Item: i Cafilas New Lid St...
# 245: Guess: $19.06 Truth: $14.99 Error: $4.07 SLE: 0.05 Item: GHM Humidifier Repla...
# 246: Guess: $100.25 Truth: $50.25 Error: $50.00 SLE: 0.46 Item: Manitowoc Ice Water ...
# 247: Guess: $59.25 Truth: $101.36 Error: $42.11 SLE: 0.28 Item: General Electric Doo...
# 248: Guess: $10.35 Truth: $4.98 Error: $5.37 SLE: 0.41 Item: Kitchen Stove Gap Co...
# 249: Guess: $9.18 Truth: $9.89 Error: $0.71 SLE: 0.00 Item: Washer & Dryer Lid S...
# 250: Guess: $24.62 Truth: $27.99 Error: $3.36 SLE: 0.02 Item: Nispira Humidifier W...
