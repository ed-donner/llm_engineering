# %% [markdown]
# # Introducing Colab
#
# Learn about Google Colab and set up a Google account (if you don't already have one) [here](https://colab.research.google.com/)
#
# You should be able to use the free tier or minimal spend to complete all the projects in the class. I personally signed up for Colab Pro+ and I'm loving it - but it's not required.
#
# To see some of what Colab can do, please follow the link below!
#
# https://colab.research.google.com/drive/1DjcrYDZldAXKJ08x1uYIVCtItoLPk1Wr?usp=sharing

# %%
import pandas

# %%
pip install -q --upgrade transformers==4.56.2 diffusers==0.32.2
# Out:
# /Users/nikhilsuresh/A_projects/llm_engineering/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Let's check the GPU - it should be a Tesla T4

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:    
  print('Not connected to a GPU')
else:
  print(gpu_info)
  if gpu_info.find('Tesla T4') >= 0:
    print("Success - Connected to a T4")
  else:
    print("NOT CONNECTED TO A T4")
# Out:
# zsh:1: command not found: nvidia-smi
# NOT CONNECTED TO A T4

# %%
import sys
import subprocess

def get_mac_gpu_info():
    try:
        # Use system_profiler to get display info
        gpu_info = subprocess.check_output(
            ['system_profiler', 'SPDisplaysDataType'],
            text=True
        )
        print(gpu_info)
        if "Apple M4" in gpu_info:
            print("Success - Connected to Apple M4 GPU!")
        elif "Metal" in gpu_info:
            print("Metal-capable GPU detected!")
        else:
            print("Apple GPU detected, but not M4.")
    except Exception as e:
        print(f"Could not get Mac GPU info: {e}")

if sys.platform == "darwin":
    get_mac_gpu_info()
else:
    print("This script is designed for Mac (Apple Silicon) systems.")
# Out:
# Graphics/Displays:
#
#     Apple M4 Pro:
#
#       Chipset Model: Apple M4 Pro
#       Type: GPU
#       Bus: Built-In
#       Total Number of Cores: 20
#       Vendor: Apple (0x106b)
#       Metal Support: Metal 3
#       Displays:
#         Color LCD:
#           Display Type: Built-in Liquid Retina XDR Display
#           Resolution: 3456 x 2234 Retina
#           Main Display: Yes
#           Mirror: Off
#           Online: Yes
#           Automatically Adjust Brightness: Yes
#           Connection Type: Internal
#         HP M27f FHD:
#           Resolution: 1920 x 1080 (1080p FHD - Full High Definition)
#           UI Looks like: 1920 x 1080 @ 75.00Hz
#           Mirror: Off
#           Online: Yes
#           Rotation: Supported
#         HP M27f FHD:
#           Resolution: 1920 x 1080 (1080p FHD - Full High Definition)
#           UI Looks like: 1920 x 1080 @ 75.00Hz
#           Mirror: Off
#           Online: Yes
#           Rotation: Supported
#
#
# Success - Connected to Apple M4 GPU!

# %%
gpu_info = subprocess.check_output(
        ['system_profiler', 'SPDisplaysDataType'],
        text=True
    )
print(gpu_info)
# Out:
# Graphics/Displays:
#
#     Apple M4 Pro:
#
#       Chipset Model: Apple M4 Pro
#       Type: GPU
#       Bus: Built-In
#       Total Number of Cores: 20
#       Vendor: Apple (0x106b)
#       Metal Support: Metal 3
#       Displays:
#         Color LCD:
#           Display Type: Built-in Liquid Retina XDR Display
#           Resolution: 3456 x 2234 Retina
#           Main Display: Yes
#           Mirror: Off
#           Online: Yes
#           Automatically Adjust Brightness: Yes
#           Connection Type: Internal
#         HP M27f FHD:
#           Resolution: 1920 x 1080 (1080p FHD - Full High Definition)
#           UI Looks like: 1920 x 1080 @ 75.00Hz
#           Mirror: Off
#           Online: Yes
#           Rotation: Supported
#         HP M27f FHD:
#           Resolution: 1920 x 1080 (1080p FHD - Full High Definition)
#           UI Looks like: 1920 x 1080 @ 75.00Hz
#           Mirror: Off
#           Online: Yes
#           Rotation: Supported
