# %% [markdown]
# # Meeting minutes creator
#
# In this colab, we make a meeting minutes program.
#
# It includes useful code to connect your Google Drive to your colab.
#
# Upload your own audio to make this work!!
#
# https://colab.research.google.com/drive/1KSMxOCprsl1QRpt_Rq0UqCAyMtPqDQYx?usp=sharing
#
# This should run nicely on a low-cost or free T4 box.

# %% [markdown]
# ### BUT FIRST - Something cool - really showing you how "model inference" works via OpenAI

# %%
import os
from visualizer import TokenPredictor, create_token_graph, visualize_predictions

# Restart kernel if you edited visualizer.py so the correct API client (OpenRouter vs OpenAI) is used.
message = "In one sentence, describe the color orange to someone who has never been able to see"
# Use OpenRouter model id when OPENROUTER_API_KEY is set (avoids OpenAI 429)
# visualizer picks the right client; use OpenAI-style name for either case
model_name = "openai/gpt-4o-mini" if os.getenv("OPENROUTER_API_KEY") else "gpt-4o-mini"

predictor = TokenPredictor(model_name)
predictions = predictor.predict_tokens(message)
G = create_token_graph(model_name, predictions)
plt = visualize_predictions(G)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[7], line 11
#       8 model_name = "openai/gpt-4o-mini" if os.getenv("OPENROUTER_API_KEY") else "gpt-4o-mini"
#      10 predictor = TokenPredictor(model_name)
# ---> 11 predictions = predictor.predict_tokens(message)
#      12 G = create_token_graph(model_name, predictions)
#      13 plt = visualize_predictions(G)
#
# File ~/projects/llm_engineering/week3/visualizer.py:23, in TokenPredictor.predict_tokens(self, prompt, max_tokens)
#      18 def predict_tokens(self, prompt: str, max_tokens: int = 100) -> List[Dict]:
#      19     """
#      20     Generate text token by token and track prediction probabilities.
#      21     Returns list of predictions with top token and alternatives.
#      22     """
# ---> 23     response = self.client.chat.completions.create(
#      24         model=self.model_name,
# ...
