# %% [markdown]
# # Synthetic Dataset generator
#
# Using Gradio Interface -
# 1. Enter the topic of dataset
# 2. Enter the columns
# 3. Select the number of rows
# 4. Generate dataset in CSV format
# 5. Download CSV from the Gradio interface
#
# Colab file link: https://colab.research.google.com/drive/15qUHDLPhUWyanTnac9N1EFm-m-KhcZ7d?usp=sharing
