# %% [markdown]
# ### Week 3 Final Assignment - YouTube Target Avatar Dataset Generator
#
# <p>This code uses a combination of open-source Gemma 4 model along with a frontier API.</p>
#
# **How it works:**
# </br>Generates a dataset that can potentially be used for fine-tuning a model.
# The dataset contains target audiences according to a niche, along with tone that a content creator must speak them with.
# </br>
#
# **Features:**
# - New Open-Source GEMMA model
# - GPT Frontier API
# - Reasoning for GEMMA
# - Ability to Modify Dataset Length
# - Gradio UI
#
# [Link to Google Colab](https://colab.research.google.com/drive/1__SVsZfPIjtpru-f0AsMvVJV3Rr1fK6z?usp=sharing)
