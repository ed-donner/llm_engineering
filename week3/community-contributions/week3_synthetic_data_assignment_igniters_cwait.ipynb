# %% [markdown]
# # Week 3 Assignment: Generating Synthetic Data
#
# This notebook fulfills the Week 3 assignment:
# - **Write models that can generate datasets** — Uses OpenAI and HuggingFace models to generate structured data.
# - **Use a variety of models and prompts for diverse outputs** — Multiple model backends and prompt types (business scenario, product catalog, job postings).
# - **Create a Gradio UI for your product** — Full Gradio interface to configure and run the generator.
#
# **Colab:** Set `HF_TOKEN` and `OPENAI_API_KEY` in Notebook secrets (🔑 in the left sidebar).
#
# Runs on a free or low-cost T4 GPU.

# %% [markdown]
# Here is the colab link [https://colab.research.google.com/drive/1bw-fYxjimPONAmXrptaRVPlcFI99_Qvv?usp=sharing](https://colab.research.google.com/drive/1bw-fYxjimPONAmXrptaRVPlcFI99_Qvv?usp=sharing)
