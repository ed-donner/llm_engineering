# %% [markdown]
# # AI synthetic data generator with openrouter and hugging face model with google colab
#
# In this colab, we generate synthetic data with openrouter(openai/gpt-4) and hugging face model(mistralai/Mistral-7B-Instruct-v0.1).
#
# You can generate any synthetic data with openai or huggingface(mistralai) models!!
#
# https://colab.research.google.com/drive/1fDZSGDN1Qs8BHFrU0qjpP9iu79Ljb3M9#scrollTo=ceMLUDP-VYCx
#
# This should run nicely on a low-cost or free T4 box.
