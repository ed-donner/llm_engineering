# %% [markdown]
# # Synthetic Data Generator with Gradio UI
#
# In this colab,I have created a synthetic data set generator and display data in Gradio UI.
#
#
# https://colab.research.google.com/drive/1wCEqwYzAn8u8gKY1429xnoSOxvlEgalQ?usp=sharing
#
# This should run nicely on a low-cost or free T4 box.
