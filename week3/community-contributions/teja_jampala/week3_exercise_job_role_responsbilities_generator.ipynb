# %% [markdown]
# # Job Role - Responsbilites Generator
#
# ## Creates a 7-8 points for resume based on Job role
#
# https://colab.research.google.com/drive/1v2keS8vcXlxqGN3nCZGH09hQbAmEAls4#scrollTo=aKs1PM-O-VQa
