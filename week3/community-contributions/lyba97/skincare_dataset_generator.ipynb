# %% [markdown]
# # 🧴 Skincare Ingredient Dataset Generator
# ### Week 3 Exercise - Synthetic Dataset Generation
#
# This notebook generates a synthetic skincare ingredient dataset using:
# - ☁️ **OpenAI GPT-4o mini** - cloud model, no quantization needed
# - 🦙 **LLaMA 3.1 8B Instruct** - open source, with 4-bit quantization
#
# Google Colab link with Week 3 exercise:
# https://colab.research.google.com/drive/1kTY24tZsEJb73ngB1_e3B4nD3zdM_iAz?usp=sharing
#
#
# ❤️ Went a step further and deployed it on huggingFace Space. Feel free to access it - it uses GPT-4o-mini to genertae the dataset ❤️
#
#
# I named it **SkinDecode** 💆🏻‍♀️🧖🏻‍♀️✨🌿💅🏻
# https://huggingface.co/spaces/lyba97/skincare-dataset-lab
