# %% [markdown]
# I generated Synthetic data using open source model from huggingface
#
# The link to the google colab code can be found [here](https://colab.research.google.com/drive/1z5Rqs2fyDX3zz1i495mdOx-L_6QcCdBe#scrollTo=JeaFwBoOYgTG)
