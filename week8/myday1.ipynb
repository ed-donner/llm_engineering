# %% [markdown]
# # Welcome to a very busy Week 8 folder
#
# ## We have lots to do this week!
#
# We'll move at a faster pace than usual, particularly as you're becoming proficient LLM engineers.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Especially important this week: pull the latest</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a <a href="https://chatgpt.com/share/6734e705-3270-8012-a074-421661af6ba9">git pull and merge your changes as needed</a>. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/><br/>
#             After you've pulled the code, from the llm_engineering directory, in an Anaconda prompt (PC) or Terminal (Mac), run:<br/>
#             <code>conda env update --f environment.yml --prune</code><br/>
#             Or if you used virtualenv rather than Anaconda, then run this from your activated environment in a Powershell (PC) or Terminal (Mac):<br/>
#             <code>pip install -r requirements.txt</code>
#             <br/>Then restart the kernel (Kernel menu >> Restart Kernel and Clear Outputs Of All Cells) to pick up the changes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Just one import to start with!!

import modal

# %% [markdown]
# # Setting up the modal tokens
#
# The first time you run this, please uncomment the next line and execute it.
# This is the same as running `modal setup` from the command line. It connects with Modal and installs your tokens.
#
# ## Debugging some common problems on Windows
#
# If this command fails in the next cell, or if any of the modal commands with the `!` fail, please try running them directly on the command line in an activated environment (without the `!`)
#
# A student on Windows mentioned that on Windows, you might also need to run this command from a command prompt in an activated environment afterwards:
# `modal token new`
# (Thank you Ed B. for that!)
#
# Another Windows student Minh N. mentioned you may need to use this approach, from an activated environment in the command line:
# `modal token set --token-id <your_token_id> --token-secret <your_token_secret>`
#
# Also, a student David S. mentioned the following:
# > In case anyone else using Windows hits this problem: Along with having to run `modal token new` from a command prompt, you have to move the generated token file. It will deploy the token file (.modal.toml) to your Windows profile folder. The virtual environment couldn't see that location (strangely, it couldn't even after I set environment variables for it and rebooted). I moved that token file to the folder I'm operating out of for the lab and it stopped throwing auth errors.
#
# And another Windows student (Robert M. - thank you!!) added another possible step:
#
#
# > I could not get modal to see my tokens (resulting in an 'auth error'), even after copying the ".modal.toml" file to the "week8" folder and restarting JupyterLab. The fix was to manually set the environment variables (the standard way). This config method is explained by modal on their [web site](https://modal.com/docs/reference/modal.config)
# ```
# import os
# os.environ["MODAL_TOKEN_ID"] = "xxx"
# os.environ["MODAL_TOKEN_SECRET"] = "yyy"
# ```
#
# Finally: I've also heard that in some situations, you might need to restart the Kernel of this jupyter notebook after running this. (Kernel menu >> Restart Kernel and Clear Outputs of All Cells).

# %% [markdown]
# ## Only run the modal setup once, unless the environment is cleared or use a new machine

# %%
# Remove the '# ' from the next line and run the cell, or run this command without the excalamation mark from an activated command prompt
# !modal setup
# Out:
# The web browser should have opened for you to authenticate and get an API token.
# If it didn't, please copy this URL into your web browser manually:
#
# ]8;id=41586;https://modal.com/token-flow/tf-fs8hErrMYyzPvDhRML1Zlw\https://modal.com/token-flow/tf-fs8hErrMYyzPvDhRML1Zlw]8;;\
#
# ⠋ Waiting for authentication in the web browser
# ⠼ Waiting for token flow to complete...omplete...
# Web authentication finished successfully!
# Token is connected to the h2625 workspace.
# Verifying token against https://api.modal.com
# Token verified successfully!
# ⠋ Storing token
# Token written to /Users/hongzhu/.modal.toml in profile h2625.

# %%
from hello import app, hello, hello_europe

# %% [markdown]
# ## creates a local Modal environment that simulates the behavior of running in the cloud but executes locally.
#
# * It’s commonly used for debugging or development before actually deploying to Modal cloud.
# * It sets up the necessary runtime so that cloud-decorated functions can run locally.
# * This is a special Modal method that runs your hello() function locally, not in the cloud.
# * hello.local() runs the function on your local machine, using your local Python environment.

# %%
with app.run():
    reply=hello.local()
reply
# Out:
# 'Hello from Schaumburg, Illinois, US!!'

# %% [markdown]
# # Run Python code without managing infrastructure
# ## execute the function in the cloud using Modal’s infrastructure.

# %%
with app.run():
    reply=hello.remote()
reply
# Out:
# 'Hello from Ashburn, Virginia, US!!'

# %% [markdown]
# ## Added thanks to student Tue H.
#
# If you look in hello.py, I've added a simple function hello_europe
#
# That uses the decorator:
# `@app.function(image=image, region="eu")`
#
# See the result below! More region specific settings are [here](https://modal.com/docs/guide/region-selection)
#
# Note that it does consume marginally more credits to specify a region.

# %%
with app.run():
    reply=hello_europe.remote()
reply
# Out:
# 'Hello from Frankfurt am Main, Hesse, DE!!'

# %% [markdown]
# # Before we move on -
#
# ## We need to set your HuggingFace Token as a secret in Modal
#
# 1. Go to modal.com, sign in and go to your dashboard
# 2. Click on Secrets in the nav bar
# 3. Create new secret, click on Hugging Face, this new secret needs to be called **hf-secret** because that's how we refer to it in the code
# 4. Fill in your HF_TOKEN where it prompts you
#
# ### And now back to business: time to work with Llama

# %%
# This import may give a deprecation warning about adding local Python modules to the Image
# That warning can be safely ignored. You may get the same warning in other places, too..

from llama import app, generate

# %%
with modal.enable_output():
    with app.run():
        result=generate.remote("Life is a mystery, everyone must stand alone, I hear")
result

# '<|begin_of_text|>Life is a mystery, everyone must stand alone, I hear you call my name,'
# Out:
# Output()
# ✓ Initialized. View run at https://modal.com/apps/h2625/main/ap-x6ozo4u4s3s6RnikIbpcIp
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Building image im-6AHJJhIQXV9NQHQyKxBdPj
# => Step 0: FROM base
# => Step 1: RUN python -m pip install accelerate bitsandbytes torch transformers
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# Collecting accelerate
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.7.0-py3-none-any.whl.metadata (19 kB)
# Collecting bitsandbytes
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Collecting torch
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting transformers
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.52.4-py3-none-any.whl.metadata (38 kB)
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting packaging>=20.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting psutil (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyyaml (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface-hub>=0.21.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.32.3-py3-none-any.whl.metadata (14 kB)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting filelock (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/site-packages (from torch) (4.12.2)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.0 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/site-packages (from triton==3.3.0->torch) (65.5.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting requests (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface-hub>=0.21.0->accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.7.0-py3-none-any.whl (362 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl (67.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 188.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl (865.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 MB 115.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 181.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 172.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 180.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 200.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 242.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 59.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 245.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 114.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 164.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 185.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 215.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 196.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 224.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 MB 208.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.52.4-py3-none-any.whl (10.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 306.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.32.3-py3-none-any.whl (512 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 198.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl (66 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 175.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 301.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl (6.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 451.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 297.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl (2.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 328.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (147 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 220.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 580.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.4.0-py3-none-any.whl (128 kB)
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, urllib3, triton, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, hf-xet, fsspec, filelock, charset-normalizer, requests, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, transformers, bitsandbytes, accelerate
# Successfully installed MarkupSafe-3.0.2 accelerate-1.7.0 bitsandbytes-0.46.0 charset-normalizer-3.4.2 filelock-3.18.0 fsspec-2025.5.1 hf-xet-1.1.2 huggingface-hub-0.32.3 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.2.6 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 packaging-25.0 psutil-7.0.0 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 safetensors-0.5.3 sympy-1.14.0 tokenizers-0.21.1 torch-2.7.0 tqdm-4.67.1 transformers-4.52.4 triton-3.3.0 urllib3-2.4.0
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Saving image...
# Image saved, took 13.92s
# Built image im-6AHJJhIQXV9NQHQyKxBdPj in 121.35s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount /Users/hongzhu/Documents/llm_engineering/week8/llama.py
# └── 🔨 Created function generate.
# Output()
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching 4 files:  25%|██▌       | 1/4 [01:04<03:12, 64.07s/it]Fetching 4 files: 100%|██████████| 4/4 [01:04<00:00, 16.02s/it]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:04<00:13,  4.43s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:09<00:09,  4.78s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:14<00:04,  4.83s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:14<00:00,  3.08s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:14<00:00,  3.68s/it]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local entrypoint completed.
# Runner terminated.
# ✓ App completed. View run at https://modal.com/apps/h2625/main/ap-x6ozo4u4s3s6RnikIbpcIp
# '<|begin_of_text|>Life is a mystery, everyone must stand alone, I hear you call my name,'

# %%
import modal
from pricer_ephemeral import app, price

# %%
with modal.enable_output():
    with app.run():
        result=price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
result
# Out:
# Output()
# ✓ Initialized. View run at https://modal.com/apps/h2625/main/ap-F54IJsxDa3wnJNeQpG42uL
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Building image im-76rqkJkWPjjnwSzB32DCRG
# => Step 0: FROM base
# => Step 1: RUN python -m pip install accelerate bitsandbytes peft torch transformers
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# Collecting accelerate
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.7.0-py3-none-any.whl.metadata (19 kB)
# Collecting bitsandbytes
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Collecting peft
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.15.2-py3-none-any.whl.metadata (13 kB)
# Collecting torch
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting transformers
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.52.4-py3-none-any.whl.metadata (38 kB)
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting packaging>=20.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting psutil (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyyaml (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface-hub>=0.21.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.32.3-py3-none-any.whl.metadata (14 kB)
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tqdm (from peft)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting filelock (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/site-packages (from torch) (4.12.2)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.0 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/site-packages (from triton==3.3.0->torch) (65.5.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting requests (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface-hub>=0.21.0->accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.7.0-py3-none-any.whl (362 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl (67.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 422.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.15.2-py3-none-any.whl (411 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl (865.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 MB 402.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 406.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 426.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 436.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 709.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 371.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 391.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 530.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 363.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 356.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 409.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 417.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 401.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 401.1 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 MB 415.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.52.4-py3-none-any.whl (10.5 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 457.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.32.3-py3-none-any.whl (512 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 417.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl (66 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 286.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 471.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl (6.3 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 460.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 438.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl (2.0 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 458.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (147 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 392.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #808000; text-decoration-color: #808000"></span></pre>
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 606.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.4.0-py3-none-any.whl (128 kB)
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, urllib3, triton, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, hf-xet, fsspec, filelock, charset-normalizer, requests, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# Successfully installed MarkupSafe-3.0.2 accelerate-1.7.0 bitsandbytes-0.46.0 charset-normalizer-3.4.2 filelock-3.18.0 fsspec-2025.5.1 hf-xet-1.1.2 huggingface-hub-0.32.3 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.2.6 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 packaging-25.0 peft-0.15.2 psutil-7.0.0 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 safetensors-0.5.3 sympy-1.14.0 tokenizers-0.21.1 torch-2.7.0 tqdm-4.67.1 transformers-4.52.4 triton-3.3.0 urllib3-2.4.0
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Saving image...
# Image saved, took 3.20s
# Built image im-76rqkJkWPjjnwSzB32DCRG in 64.99s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓ Created objects.
# ├── 🔨 Created mount /Users/hongzhu/Documents/llm_engineering/week8/pricer_ephemeral.py
# └── 🔨 Created function price.
# Output()
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching 4 files:  25%|██▌       | 1/4 [01:01<03:05, 61.68s/it]
# Fetching 4 files:  50%|█████     | 2/4 [01:01<00:51, 25.51s/it]
# Fetching 4 files:  75%|███████▌  | 3/4 [01:02<00:14, 14.17s/it]Fetching 4 files: 100%|██████████| 4/4 [01:02<00:00, 15.64s/it]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:05<00:17,  5.74s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:12<00:12,  6.32s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:19<00:06,  6.83s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:20<00:00,  4.36s/it]Loading checkpoint shards: 100%|██████████| 4/4 [00:20<00:00,  5.12s/it]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Stopping app - local entrypoint completed.
# Runner terminated.
# ✓ App completed. View run at https://modal.com/apps/h2625/main/ap-F54IJsxDa3wnJNeQpG42uL
# 133.0

# %% [markdown]
# ## Transitioning From Ephemeral Apps to Deployed Apps
#
# From a command line, `modal deploy xxx` will deploy your code as a Deployed App
#
# This is how you could package your AI service behind an API to be used in a Production System.
#
# You can also build REST endpoints easily, although we won't cover that as we'll be calling direct from Python.
#
# ## Important note about secrets
#
# In both the files `pricer_service.py` and `pricer_service2.py` you will find code like this near the top:
# `secrets = [modal.Secret.from_name("hf-secret")]`
# You may need to change from `hf-secret` to `huggingface-secret` depending on how the Secret is configured in modal.
# To check, visit this page and look in the first column:
# https://modal.com/secrets/
#
# ## Important note for Windows people:
#
# On the next line, I call `modal deploy` from within Jupyter lab; I've heard that on some versions of Windows this gives a strange unicode error because modal prints emojis to the output which can't be displayed. If that happens to you, simply use an Anaconda Prompt window or a Powershell instead, with your environment activated, and type `modal deploy pricer_service` there. Follow the same approach the next time we do `!modal deploy` too.
#
# As an alternative, a few students have mentioned you can run this code within Jupyter Lab if you want to run it from here:
# ```
# # Check the default encoding
# print(locale.getpreferredencoding())  # Should print 'UTF-8'
#
# # Ensure UTF-8 encoding
# os.environ['PYTHONIOENCODING'] = 'utf-8'
# ```

# %%
# You can also run "modal deploy -m pricer_service" at the command line in an activated environment
# !modal deploy -m pricer_service
# Out:
# ⠸ Creating objects.....
# ├── 🔨 Created mount
# │   /Users/hongzhu/Documents/llm_engineering/week8/pricer_service.py
# ⠸ Creating objects...
# ├── 🔨 Created mount
# │   /Users/hongzhu/Documents/llm_engineering/week8/pricer_service.py
# └── 🔨 Created function price.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/hongzhu/Documents/llm_engineering/week8/pricer_service.py
# └── 🔨 Created function price.
# ✓ App deployed in 0.627s! 🎉
#
# View Deployment: https://modal.com/apps/h2625/main/deployed/pricer-service

# %%
# call a deployed app
pricer = modal.Function.from_name("pricer-service", "price")

# %%
# This can take a while! We'll use faster approaches shortly

pricer.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
# Out:
# 133.0

# %% [markdown]
# ## smarter app, pricer_service2,

# %%
# You can also run "modal deploy -m pricer_service2" at the command line in an activated environment

# !modal deploy -m pricer_service2
# Out:
# ⠸ Creating objects.....
# └── ⠋ Creating mount
#     /Users/hongzhu/Documents/llm_engineering/week8/pricer_service2.py:
# ⠦ Creating objects...
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# Building image im-sKGSAPgd4tEGWSICmv7KMZr_service2.py
# ⠋ Creating objects...
# ⠹ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# hu/Documents/llm_engineering/week8/pricer_service2.py
# => Step 0: FROM base
# ⠸ Creating objects...
# 🔨 Created mount /Users/hongzhu/Documents/llm_engineering/week8/pricer_servi
# => Step 1: RUN python -m pip install accelerate bitsandbytes huggingface peft torch transformers
# ⠸ Creating objects...
# ⠴ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# ⠸ Creating objects...
# ⠴ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# Collecting accelerateneering/week8/pricer_service2.py
# ⠴ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.7.0-py3-none-any.whl.metadata (19 kB)
# ⠴ Creating objects...
# Collecting bitsandbytesUsers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# ⠴ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# ⠴ Creating objects...
# Collecting huggingface/Users/hongzhu/Documents/llm_engineering/week8/pricer_servi
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl.metadata (2.9 kB)
# ⠇ Creating objects...
# Collecting peft mount /Users/hongzhu/Documents/llm_engineering/week8/pricer_servi
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.15.2-py3-none-any.whl.metadata (13 kB)
# ⠇ Creating objects...
# Collecting torchmount /Users/hongzhu/Documents/llm_engineering/week8/pricer_servi
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# ⠇ Creating objects...
# Collecting transformersUsers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.52.4-py3-none-any.whl.metadata (38 kB)
# ⠇ Creating objects...
# ⠇ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# Collecting numpy<3.0.0,>=1.17 (from accelerate)ce2.py
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# ⠙ Creating objects...
# ⠙ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# Collecting packaging>=20.0 (from accelerate)rvice2.py
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# ⠼ Creating objects...
# Collecting psutil (from accelerate)u/Documents/llm_engineering/week8/pricer_servi
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# ⠼ Creating objects...
# Collecting pyyaml (from accelerate)u/Documents/llm_engineering/week8/pricer_servi
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# ⠼ Creating objects...
# Collecting huggingface-hub>=0.21.0 (from accelerate)ngineering/week8/pricer_servi
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.32.3-py3-none-any.whl.metadata (14 kB)
# ⠼ Creating objects...
# ⠼ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# Collecting safetensors>=0.4.3 (from accelerate)ce2.py
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# ⠇ Creating objects...
# Collecting tqdm (from peft)s/hongzhu/Documents/llm_engineering/week8/pricer_servi
# ⠇ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ⠇ Creating objects...
# Collecting filelock (from torch)gzhu/Documents/llm_engineering/week8/pricer_servi
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/site-packages (from torch) (4.12.2)
# ⠋ Creating objects...
# Collecting sympy>=1.13.3 (from torch)Documents/llm_engineering/week8/pricer_servi
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ⠋ Creating objects...
# Collecting networkx (from torch)gzhu/Documents/llm_engineering/week8/pricer_servi
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# ⠋ Creating objects...
# Collecting jinja2 (from torch)ongzhu/Documents/llm_engineering/week8/pricer_servi
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ⠋ Creating objects...
# Collecting fsspec (from torch)ongzhu/Documents/llm_engineering/week8/pricer_servi
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# ⠋ Creating objects...
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)neering/week8/pricer_servi
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ⠋ Creating objects...
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)ering/week8/pricer_servi
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# ⠋ Creating objects...
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)neering/week8/pricer_servi
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# ⠋ Creating objects...
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)engineering/week8/pricer_servi
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# ⠋ Creating objects...
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)ngineering/week8/pricer_servi
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# ⠋ Creating objects...
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)engineering/week8/pricer_servi
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# ⠋ Creating objects...
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)gineering/week8/pricer_servi
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# ⠋ Creating objects...
# ⠙ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# ⠸ Creating objects...
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)ineering/week8/pricer_servi
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# ⠸ Creating objects...
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)gineering/week8/pricer_servi
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# ⠸ Creating objects...
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)lm_engineering/week8/pricer_servi
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# ⠸ Creating objects...
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)m_engineering/week8/pricer_servi
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# ⠸ Creating objects...
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)ineering/week8/pricer_servi
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# ⠸ Creating objects...
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)ngineering/week8/pricer_servi
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# ⠸ Creating objects...
# Collecting triton==3.3.0 (from torch)Documents/llm_engineering/week8/pricer_servi
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# ⠸ Creating objects...
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/site-packages (from triton==3.3.0->torch) (65.5.1)
# ⠸ Creating objects...
# ⠼ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# Collecting regex!=2019.12.17 (from transformers)e2.py
# ⠦ Creating objects...
# ⠧ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# ⠏ Creating objects...
# Collecting requests (from transformers)cuments/llm_engineering/week8/pricer_servi
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ⠏ Creating objects...
# Collecting tokenizers<0.22,>=0.21 (from transformers)gineering/week8/pricer_servi
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# ⠏ Creating objects...
# ⠋ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface-hub>=0.21.0->accelerate)
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# ⠹ Creating objects...
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)ering/week8/pricer_servi
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ⠹ Creating objects...
# ⠼ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# Collecting MarkupSafe>=2.0 (from jinja2->torch)ce2.py
# ⠴ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# ⠴ Creating objects...
# Collecting charset-normalizer<4,>=2 (from requests->transformers)ek8/pricer_servi
# ⠴ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# ⠴ Creating objects...
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (3.10)
# ⠴ Creating objects...
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)ing/week8/pricer_servi
# ⠴ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.7.0-py3-none-any.whl (362 kB)
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl (67.0 MB)
# ⠦ Creating objects...
# ⠧ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...er_service2.py
# ⠸ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 152.7 MB/s eta 0:00:00
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.15.2-py3-none-any.whl (411 kB)
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.7.0-cp311-cp311-manylinux_2_28_x86_64.whl (865.2 MB)
# ⠼ Creating objects...
# ⠦ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...er_service2.py
# ⠼ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 MB 270.6 MB/s eta 0:00:00
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
# ⠼ Creating objects...
# ⠧ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...er_service2.py
# ⠋ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 276.1 MB/s eta 0:00:00
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
# ⠹ Creating objects...
# ⠹ Creating objects...cuments/llm_engineering/week8/pricer_servi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 303.0 MB/s eta 0:00:00ervi
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
# ⠹ Creating objects...
# ⠹ Creating objects...cuments/llm_engineering/week8/pricer_servi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 292.0 MB/s eta 0:00:00vi
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
# ⠹ Creating objects...
# ⠹ Creating objects...cuments/llm_engineering/week8/pricer_servi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 316.7 MB/s eta 0:00:00i
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
# ⠹ Creating objects...
# ⠸ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...er_service2.py
# ⠏ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 271.3 MB/s eta 0:00:00
# ⠋ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
# ⠋ Creating objects...
# ⠹ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...er_service2.py
# ⠇ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 279.0 MB/s eta 0:00:00
# ⠏ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
# ⠏ Creating objects...
# ⠏ Creating objects...cuments/llm_engineering/week8/pricer_servi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 307.8 MB/s eta 0:00:00ervi
# ⠏ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# ⠏ Creating objects...
# ⠏ Creating objects...cuments/llm_engineering/week8/pricer_servi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 282.3 MB/s eta 0:00:00vi
# ⠏ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
# ⠏ Creating objects...
# ⠙ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...er_service2.py
# ⠧ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 274.7 MB/s eta 0:00:00
# ⠏ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
# ⠏ Creating objects...
# ⠙ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...er_service2.py
# ⠧ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 280.9 MB/s eta 0:00:00
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
# ⠇ Creating objects...
# ⠋ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠸ Creating objects...er_service2.py
# ⠸ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 258.6 MB/s eta 0:00:00
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
# ⠦ Creating objects...
# ⠧ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...er_service2.py
# ⠸ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 275.8 MB/s eta 0:00:00
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
# ⠴ Creating objects...
# ⠴ Creating objects...cuments/llm_engineering/week8/pricer_servi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 271.0 MB/s eta 0:00:00vi
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.5 MB)
# ⠴ Creating objects...
# ⠦ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...er_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 MB 219.9 MB/s eta 0:00:00i
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.52.4-py3-none-any.whl (10.5 MB)
# ⠴ Creating objects...
# ⠴ Creating objects...cuments/llm_engineering/week8/pricer_servi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 311.1 MB/s eta 0:00:00vi
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.32.3-py3-none-any.whl (512 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.5.1-py3-none-any.whl (199 kB)
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# ⠴ Creating objects...
# ⠴ Creating objects...cuments/llm_engineering/week8/pricer_servi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 296.2 MB/s eta 0:00:00vi
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl (66 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
# ⠴ Creating objects...
# ⠴ Creating objects...cuments/llm_engineering/week8/pricer_servi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 596.0 MB/s eta 0:00:00i
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
# ⠴ Creating objects...
# ⠴ Creating objects...cuments/llm_engineering/week8/pricer_servi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 630.3 MB/s eta 0:00:00i
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl (6.3 MB)
# ⠴ Creating objects...
# ⠴ Creating objects...cuments/llm_engineering/week8/pricer_servi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 286.7 MB/s eta 0:00:00ervi
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# ⠴ Creating objects...
# ⠴ Creating objects...cuments/llm_engineering/week8/pricer_servi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 360.9 MB/s eta 0:00:00ervi
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl (134 kB)
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl (2.0 MB)
# ⠴ Creating objects...
# ⠴ Creating objects...cuments/llm_engineering/week8/pricer_servi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 384.3 MB/s eta 0:00:00ervi
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.3-py3-none-any.whl (64 kB)
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (147 kB)
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.2-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
# ⠴ Creating objects...
# ⠴ Creating objects...cuments/llm_engineering/week8/pricer_servi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 304.3 MB/s eta 0:00:00ervi
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
# ⠴ Creating objects...
# ⠴ Creating objects...cuments/llm_engineering/week8/pricer_servi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 448.3 MB/s eta 0:00:00i
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.4.0-py3-none-any.whl (128 kB)
# ⠴ Creating objects...
# ⠦ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, huggingface, urllib3, triton, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, hf-xet, fsspec, filelock, charset-normalizer, requests, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# ⠋ Creating objects...
# ⠙ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# Successfully installed MarkupSafe-3.0.2 accelerate-1.7.0 bitsandbytes-0.46.0 charset-normalizer-3.4.2 filelock-3.18.0 fsspec-2025.5.1 hf-xet-1.1.2 huggingface-0.0.1 huggingface-hub-0.32.3 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.2.6 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 packaging-25.0 peft-0.15.2 psutil-7.0.0 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 safetensors-0.5.3 sympy-1.14.0 tokenizers-0.21.1 torch-2.7.0 tqdm-4.67.1 transformers-4.52.4 triton-3.3.0 urllib3-2.4.0
# ⠴ Creating objects...
# ⠧ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# hu/Documents/llm_engineering/week8/pricer_service2.py
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# ⠇ Creating objects...
# ⠋ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# Saving image...m_engineering/week8/pricer_service2.py
# ⠙ Creating objects...
# ⠸ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.9/5.9 GB 0:00:00
# ⠦ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━ 3.1/5.9 GB 0:00:00
# ⠏ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━ 4.2/5.9 GB 0:00:00
# ⠹ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━ 5.4/5.9 GB 0:00:00
# ⠴ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5.9/5.9 GB 0:00:01
# ⠏ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5.9/5.9 GB 0:00:01
# ⠹ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5.9/5.9 GB 0:00:01
# ⠴ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5.9/5.9 GB 0:00:01
# ⠇ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5.9/5.9 GB 0:00:02
# ⠙ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5.9/5.9 GB 0:00:02
# ⠴ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5.9/5.9 GB 0:00:02
# ⠇ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5.9/5.9 GB 0:00:02
# ⠙ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5.9/5.9 GB 0:00:03
# ⠼ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5.9/5.9 GB 0:00:03
# ⠧ Creating objects...
# └── 🔨 Created mount
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 5.9/5.9 GB 0:00:03
# ⠙ Creating objects...
# └── 🔨 Created mount
# ⠼ Creating objects...8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠦ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠹ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# Image saved, took 7.95sering/week8/pricer_service2.py
# ⠋ Creating objects...
# ⠹ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# hu/Documents/llm_engineering/week8/pricer_service2.py
# Built image im-sKGSAPgd4tEGWSICmv7KMZ in 77.66s
#
#
# ⠸ Creating objects...
# ⠴ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠇ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠙ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠼ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠧ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# Building image im-i74GLc8Q9Cr68TbetN6JMfr_service2.py
# ⠸ Creating objects...
# ⠸ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# hu/Documents/llm_engineering/week8/pricer_service2.py
# => Step 0: FROM base
# ⠦ Creating objects...
# 🔨 Created mount /Users/hongzhu/Documents/llm_engineering/week8/pricer_servi
# => Step 1: ENV HF_HUB_CACHE=/cache
# ⠦ Creating objects...
# ⠧ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠋ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠸ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# Saving image...m_engineering/week8/pricer_service2.py
# ⠼ Creating objects...
# ⠦ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠏ Creating objects...ing/week8/pricer_service2.py
# └── 🔨 Created mount
# Image saved, took 562.58msng/week8/pricer_service2.py
# ⠙ Creating objects...
# 🔨 Created mount /Users/hongzhu/Documents/llm_engineering/week8/pricer_servi
# Built image im-i74GLc8Q9Cr68TbetN6JMf in 1.48s
#
#
# ⠙ Creating objects...
# ⠸ Creating objects...ers/hongzhu/Documents/llm_engineering/week8/pricer_servi
# └── 🔨 Created mount
# ⠴ Creating objects...ing/week8/pricer_service2.py
# ├── 🔨 Created mount
# │   /Users/hongzhu/Documents/llm_engineering/week8/pricer_service2.py
# └── 🔨 Created function Pricer.*.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/hongzhu/Documents/llm_engineering/week8/pricer_service2.py
# └── 🔨 Created function Pricer.*.
# ✓ App deployed in 83.153s! 🎉
#
# View Deployment: https://modal.com/apps/h2625/main/deployed/pricer-service

# %%
Pricer = modal.Cls.from_name("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(reply)
# Out:
# 133.0

# %% [markdown]
# # Optional: Keeping Modal warm
#
# ## A way to improve the speed of the Modal pricer service
#
# The first time you run this modal class, it might take as much as 10 minutes to build.
# Subsequently it should be much faster.. 30 seconds if it needs to wake up, otherwise 2 seconds.
# If you want it to always be 2 seconds, you can keep the container from going to sleep by editing this constant in pricer_service2.py:
#
# `MIN_CONTAINERS = 0`
#
# Make it 1 to keep a container alive.
# But please note: this will eat up credits! Only do this if you are comfortable to have a process running continually.

# %% [markdown]
# ## And now introducing our Agent class
#
# * agents: a folder, a package
# * specialist_agent.py, a python file which has SpecialistAgent Class
# * price() is a method within SpecialistAgent class,
# * make a remote call to return the estimate of the price of this item

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()
# agent.price("iPad Pro 2nd generation")
# agent.price("iphone 16")
agent.price("airpod pro")
# Out:
# 189.0
