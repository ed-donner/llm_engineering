# %% [markdown]
# # End of Week 8 Exercise – Agentic AI Capstone
#
# Demonstrate your familiarity with Week 8 by using the **DealAgentFramework** and week8 agents (e.g. PlanningAgent, deals, Gradio UI). Run the framework to surface opportunities or launch the "Price is Right" UI, using only code and modules from this week.
#
# Use only the week8 `agents` package, `deal_agent_framework`, and related week8 files (e.g. `price_is_right.py`).

# %%
# Imports – use only week8 modules (run from week8 directory)
import os
from dotenv import load_dotenv
from deal_agent_framework import DealAgentFramework
from agents.deals import Opportunity, Deal

# %%
# Environment
load_dotenv(override=True)

# %% [markdown]
# ## Initialize the DealAgentFramework and inspect memory
#
# The framework uses Chroma for the products vectorstore and persists opportunities in `memory.json`.

# %%
framework = DealAgentFramework()
print(f"Opportunities in memory: {len(framework.memory)}")
if framework.memory:
    print(framework.memory[0])

# %% [markdown]
# ## Your turn
#
# Call `framework.init_agents_as_needed()` and run the planner to surface new deals, or launch the full UI with `price_is_right.py` (e.g. `from price_is_right import App; App().run()`). Extend the agent pipeline or UI as you like.

# %%
# Optional: init agents and run planner, or launch Gradio UI
# framework.init_agents_as_needed()
# framework.planner.run(...)
# from price_is_right import App; App().run()
