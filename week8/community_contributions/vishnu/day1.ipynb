# %% [markdown]
# # Welcome to a very busy Week 8 folder
#
# ## We have lots to do this week!
#
# We'll move at a faster pace than usual, particularly as you're becoming proficient LLM engineers.
#
# # The Price is Right
#
# ## Week 8 Order of Play
#
# Day 1: Modal.com and SpecialistAgent
# Day 2: RAG, FrontierAgent, Ensemble Agent
# Day 3: ScannerAgent, MessengerAgent
# Day 4: AutonomousPlannerAgent and DealAgentFramework
# Day 5: The Price Is Right Finale

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#b22;">Especially important this week: pull the latest</h2>
#             <span style="color:#b22;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             Please see Guide 3 in the Guides folder if you're not sure how to do a <code>git pull</code>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import os
import locale
import modal
from agents.preprocessor import Preprocessor
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# Out[1]: True

# %%
# To check that your computer can output special characters, make sure this outputs UTF-8 

print(locale.getpreferredencoding())  # Should print 'UTF-8'
# Out:
# cp1252

# %%
os.environ["PYTHONIOENCODING"] = "utf-8"

# %% [markdown]
# # Setting up the modal tokens
#
# ## IMPORTANT - please do read and follow these instructions!
#
# First please visit: https://modal.com
#
# And sign up for an account. Then click the Avatar menu on the top right and select "Settings"
#
# Then click "API Tokens" in the left sidebar, then click "New Token".
#
# You will be given something like this to run:
#
# `modal token set --token-id ak-somethinghere --token-secret as-somethinghere`
#
# But because we're using uv, the real thing to run is this:
#
# `uv run modal token set --token-id ak-somethinghere --token-secret as-somethinghere`
#
# ### Troubleshooting
#
# If you have problems, 3 things to try:
#
# 1. Try running `uv run modal token new` before the `uv run modal token set..`
#
# 2. Suggestion from student David S. on Windows:
#
# > In case anyone else using Windows hits this problem: Along with having to run `modal token new` from a command prompt, you have to move the generated token file. It will deploy the token file (.modal.toml) to your Windows profile folder. The virtual environment couldn't see that location (strangely, it couldn't even after I set environment variables for it and rebooted). I moved that token file to the folder I'm operating out of for the lab and it stopped throwing auth errors.
#
# 3. Doing in the manual way:
#
# It might be totally fine to simply add the 2 keys directly to your .env file:
#
# ```
# MODAL_TOKEN_ID=ak-...
# MODAL_TOKEN_SECRET=as-...
# ```
#
# Then rerun `load_dotenv(override=True)` to load these environment variables.

# %%
from hello import app, hello, hello_europe

# %%
with app.run():
    reply=hello.local()
reply
# Out:
# [MOCK] app.run() entered
# [MOCK] app.run() exited
# Out[1]: 'Hello from Bengaluru, Karnataka, IN!!'

# %%
with app.run():
    reply=hello.remote()
reply
# Out:
# [MOCK] app.run() entered
# [MOCK] app.run() exited
# Out[1]: 'Hello from Bengaluru, Karnataka, IN!!'

# %% [markdown]
# ## Added thanks to student Tue H.
#
# If you look in hello.py, I've added a simple function hello_europe
#
# That uses the decorator:
# `@app.function(image=image, region="eu")`
#
# See the result below! More region specific settings are [here](https://modal.com/docs/guide/region-selection)
#
# Note that it does consume marginally more credits to specify a region.

# %%
with app.run():
    reply=hello_europe.remote()
reply
# Out:
# [MOCK] app.run() entered
# [MOCK] app.run() exited
# Out[1]: 'Hello from Bengaluru, Karnataka, IN!!'

# %% [markdown]
# # Before we move on -
#
# ## We need to set your HuggingFace Token as a secret in Modal
#
# ## Super important - please read - this confuses a lot of people!
#
# Secrets in Modal are given a **name** that describes the secret.
# Then the secret itself has a KEY and a VALUE.
# We will be setting up a secret with:
#
# Name: huggingface-secret
# Key: HF_TOKEN
# Value: hf_...
#
# ## The bulletproof recipe:
#
# 1. Go to modal.com, sign in and go to your dashboard
# 2. Click on Secrets in the nav bar
# 3. Create new secret, click on Hugging Face, this new secret needs to be called **huggingface-secret** because that's how we refer to it in the code
# 4. Fill in your key as HF_TOKEN and the value as your actual token hf_...
# 5. Click done
#
# ### And now back to business: time to work with Llama

# %%
# This import may give a deprecation warning about adding local Python modules to the Image
# That warning can be safely ignored. You may get the same warning in other places, too..

from llama import app, generate

# %%
with modal.enable_output():
    with app.run():
        result=generate.remote("Never gonna give you up, never gonna")
result

# Or it you object to being rickrolled, try this: "Hey Jude, don't make it"
# Out:
# [MOCK] app.run() entered
# [MOCK] app.run() exited
# Out[1]: 'Never gonna give you up, never gonna let you down, never gonna run around and desert you'

# %%
from pricer_ephemeral import app, price

# %%
with modal.enable_output():
    with app.run():
        result=price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
result
# Out:
# [MOCK] app.run() entered
# [MOCK] app.run() exited
# Out[1]: 299.0

# %%
preprocessor = Preprocessor()
text = preprocessor.preprocess("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(text)
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:190, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     189 try:
# --> 190     response = sync_httpx_client.post(
#     191         url=api_base,
#     192         headers=headers,
#     193         data=(
#     194             signed_json_body
#     195             if signed_json_body is not None
#     196             else json.dumps(data)
#     197         ),
#     198         timeout=timeout,
#     199         stream=stream,
#     200         logging_obj=logging_obj,
#     201     )
#     202 except httpx.HTTPStatusError as e:
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:898, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     897     setattr(e, "status_code", e.response.status_code)
# --> 898     raise e
#     899 except Exception as e:
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:880, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     879 response = self.client.send(req, stream=stream)
# --> 880 response.raise_for_status()
#     881 return response
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Server error '500 Internal Server Error' for url 'http://localhost:11434/api/generate'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/500
#
# During handling of the above exception, another exception occurred:
#
# OllamaError                               Traceback (most recent call last)
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\main.py:3369, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3363     api_base = (
#    3364         litellm.api_base
#    3365         or api_base
#    3366         or get_secret("OLLAMA_API_BASE")
#    3367         or "http://localhost:11434"
#    3368     )
# -> 3369     response = base_llm_http_handler.completion(
#    3370         model=model,
#    3371         stream=stream,
#    3372         messages=messages,
#    3373         acompletion=acompletion,
#    3374         api_base=api_base,
#    3375         model_response=model_response,
#    3376         optional_params=optional_params,
#    3377         litellm_params=litellm_params,
#    3378         shared_session=shared_session,
#    3379         custom_llm_provider="ollama",
#    3380         timeout=timeout,
#    3381         headers=headers,
#    3382         encoding=encoding,
#    3383         api_key=api_key,
#    3384         logging_obj=logging,  # model call logging done inside the class as we make need to modify I/O to fit aleph alpha's requirements
#    3385         client=client,
#    3386     )
#    3388 elif custom_llm_provider == "ollama_chat":
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:493, in BaseLLMHTTPHandler.completion(self, model, messages, api_base, custom_llm_provider, model_response, encoding, logging_obj, optional_params, timeout, litellm_params, acompletion, stream, fake_stream, api_key, headers, client, provider_config, shared_session)
#     491     sync_httpx_client = client
# --> 493 response = self._make_common_sync_call(
#     494     sync_httpx_client=sync_httpx_client,
#     495     provider_config=provider_config,
#     496     api_base=api_base,
#     497     headers=headers,
#     498     data=data,
#     499     signed_json_body=signed_json_body,
#     500     timeout=timeout,
#     501     litellm_params=litellm_params,
#     502     logging_obj=logging_obj,
#     503 )
#     504 return provider_config.transform_response(
#     505     model=model,
#     506     raw_response=response,
#    (...)    515     json_mode=json_mode,
#     516 )
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:215, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     214     else:
# --> 215         raise self._handle_error(e=e, provider_config=provider_config)
#     216 except Exception as e:
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:3517, in BaseLLMHTTPHandler._handle_error(self, e, provider_config)
#    3511     raise BaseLLMException(
#    3512         status_code=status_code,
#    3513         message=error_text,
#    3514         headers=error_headers,
#    3515     )
# -> 3517 raise provider_config.get_error_class(
#    3518     error_message=error_text,
#    3519     status_code=status_code,
#    3520     headers=error_headers,
#    3521 )
#
# OllamaError: {"error":"llama-server process no longer running: exit status 1 ggml_backend_cpu_buffer_type_alloc_buffer: failed to allocate buffer of size 1362493440\nalloc_tensor_range: failed to allocate CPU_REPACK buffer of size 1362493440\nerror loading model: unable to allocate CPU_REPACK buffer"}
#
# During handling of the above exception, another exception occurred:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[1], line 2
#       1 preprocessor = Preprocessor()
# ----> 2 text = preprocessor.preprocess("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
#       3 print(text)
#
# File c:\Users\shobhasreenivas\projects\llm_engineering\week8\agents\preprocessor.py:39, in Preprocessor.preprocess(self, text)
#      37 def preprocess(self, text: str) -> str:
#      38     messages = self.messages_for(text)
# ---> 39     response = completion(
#      40         messages=messages,
#      41         model=self.model_name,
#      42         reasoning_effort=self.reasoning_effort,
#      43         api_base=self.base_url,
#      44     )
#      45     self.total_input_tokens += response.usage.prompt_tokens
#      46     self.total_output_tokens += response.usage.completion_tokens
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\utils.py:1376, in client.<locals>.wrapper(*args, **kwargs)
#    1372 if logging_obj:
#    1373     logging_obj.failure_handler(
#    1374         e, traceback_exception, start_time, end_time
#    1375     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1376 raise e
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\utils.py:1245, in client.<locals>.wrapper(*args, **kwargs)
#    1243         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1244 # MODEL CALL
# -> 1245 result = original_function(*args, **kwargs)
#    1246 end_time = datetime.datetime.now()
#    1247 if _is_streaming_request(
#    1248     kwargs=kwargs,
#    1249     call_type=call_type,
#    1250 ):
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\main.py:3767, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3764     return response
#    3765 except Exception as e:
#    3766     ## Map to OpenAI Exception
# -> 3767     raise exception_type(
#    3768         model=model,
#    3769         custom_llm_provider=custom_llm_provider,
#    3770         original_exception=e,
#    3771         completion_kwargs=args,
#    3772         extra_kwargs=kwargs,
#    3773     )
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2274, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2272 if exception_mapping_worked:
#    2273     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2274     raise e
#    2275 else:
#    2276     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2243, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2241 exception_mapping_worked = True
#    2242 if hasattr(original_exception, "request"):
# -> 2243     raise APIConnectionError(
#    2244         message="{} - {}".format(exception_provider, error_str),
#    2245         llm_provider=custom_llm_provider,
#    2246         model=model,
#    2247         request=getattr(original_exception, "request", None),
#    2248     )
#    2249 else:
#    2250     raise APIConnectionError(
#    2251         message="{}\n{}".format(
#    2252             str(original_exception), traceback.format_exc()
#    (...)   2258         ),  # stub the request
#    2259     )
#
# APIConnectionError: litellm.APIConnectionError: OllamaException - {"error":"llama-server process no longer running: exit status 1 ggml_backend_cpu_buffer_type_alloc_buffer: failed to allocate buffer of size 1362493440\nalloc_tensor_range: failed to allocate CPU_REPACK buffer of size 1362493440\nerror loading model: unable to allocate CPU_REPACK buffer"}

# %%
preprocessor = Preprocessor(model_name="groq/openai/gpt-oss-20b")
text = preprocessor.preprocess("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(text)
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:190, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     189 try:
# --> 190     response = sync_httpx_client.post(
#     191         url=api_base,
#     192         headers=headers,
#     193         data=(
#     194             signed_json_body
#     195             if signed_json_body is not None
#     196             else json.dumps(data)
#     197         ),
#     198         timeout=timeout,
#     199         stream=stream,
#     200         logging_obj=logging_obj,
#     201     )
#     202 except httpx.HTTPStatusError as e:
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:898, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     897     setattr(e, "status_code", e.response.status_code)
# --> 898     raise e
#     899 except Exception as e:
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:880, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     879 response = self.client.send(req, stream=stream)
# --> 880 response.raise_for_status()
#     881 return response
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '401 Unauthorized' for url 'https://api.groq.com/openai/v1/chat/completions'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/401
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\main.py:1940, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    1938             optional_params[k] = v
# -> 1940     response = base_llm_http_handler.completion(
#    1941         model=model,
#    1942         stream=stream,
#    1943         messages=messages,
#    1944         acompletion=acompletion,
#    1945         api_base=api_base,
#    1946         model_response=model_response,
#    1947         optional_params=optional_params,
#    1948         litellm_params=litellm_params,
#    1949         shared_session=shared_session,
#    1950         custom_llm_provider=custom_llm_provider,
#    1951         timeout=timeout,
#    1952         headers=headers,
#    1953         encoding=encoding,
#    1954         api_key=api_key,
#    1955         logging_obj=logging,  # model call logging done inside the class as we make need to modify I/O to fit aleph alpha's requirements
#    1956         client=client,
#    1957     )
#    1958 elif custom_llm_provider == "aiohttp_openai":
#    1959     # NEW aiohttp provider for 10-100x higher RPS
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:493, in BaseLLMHTTPHandler.completion(self, model, messages, api_base, custom_llm_provider, model_response, encoding, logging_obj, optional_params, timeout, litellm_params, acompletion, stream, fake_stream, api_key, headers, client, provider_config, shared_session)
#     491     sync_httpx_client = client
# --> 493 response = self._make_common_sync_call(
#     494     sync_httpx_client=sync_httpx_client,
#     495     provider_config=provider_config,
#     496     api_base=api_base,
#     497     headers=headers,
#     498     data=data,
#     499     signed_json_body=signed_json_body,
#     500     timeout=timeout,
#     501     litellm_params=litellm_params,
#     502     logging_obj=logging_obj,
#     503 )
#     504 return provider_config.transform_response(
#     505     model=model,
#     506     raw_response=response,
#    (...)    515     json_mode=json_mode,
#     516 )
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:215, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     214     else:
# --> 215         raise self._handle_error(e=e, provider_config=provider_config)
#     216 except Exception as e:
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:3517, in BaseLLMHTTPHandler._handle_error(self, e, provider_config)
#    3511     raise BaseLLMException(
#    3512         status_code=status_code,
#    3513         message=error_text,
#    3514         headers=error_headers,
#    3515     )
# -> 3517 raise provider_config.get_error_class(
#    3518     error_message=error_text,
#    3519     status_code=status_code,
#    3520     headers=error_headers,
#    3521 )
#
# OpenAIError: {"error":{"message":"Invalid API Key","type":"invalid_request_error","code":"invalid_api_key"}}
#
#
# During handling of the above exception, another exception occurred:
#
# BadRequestError                           Traceback (most recent call last)
# Cell In[1], line 2
#       1 preprocessor = Preprocessor(model_name="groq/openai/gpt-oss-20b")
# ----> 2 text = preprocessor.preprocess("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
#       3 print(text)
#
# File c:\Users\shobhasreenivas\projects\llm_engineering\week8\agents\preprocessor.py:39, in Preprocessor.preprocess(self, text)
#      37 def preprocess(self, text: str) -> str:
#      38     messages = self.messages_for(text)
# ---> 39     response = completion(
#      40         messages=messages,
#      41         model=self.model_name,
#      42         reasoning_effort=self.reasoning_effort,
#      43         api_base=self.base_url,
#      44     )
#      45     self.total_input_tokens += response.usage.prompt_tokens
#      46     self.total_output_tokens += response.usage.completion_tokens
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\utils.py:1376, in client.<locals>.wrapper(*args, **kwargs)
#    1372 if logging_obj:
#    1373     logging_obj.failure_handler(
#    1374         e, traceback_exception, start_time, end_time
#    1375     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1376 raise e
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\utils.py:1245, in client.<locals>.wrapper(*args, **kwargs)
#    1243         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1244 # MODEL CALL
# -> 1245 result = original_function(*args, **kwargs)
#    1246 end_time = datetime.datetime.now()
#    1247 if _is_streaming_request(
#    1248     kwargs=kwargs,
#    1249     call_type=call_type,
#    1250 ):
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\main.py:3767, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3764     return response
#    3765 except Exception as e:
#    3766     ## Map to OpenAI Exception
# -> 3767     raise exception_type(
#    3768         model=model,
#    3769         custom_llm_provider=custom_llm_provider,
#    3770         original_exception=e,
#    3771         completion_kwargs=args,
#    3772         extra_kwargs=kwargs,
#    3773     )
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2274, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2272 if exception_mapping_worked:
#    2273     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2274     raise e
#    2275 else:
#    2276     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File ~\projects\llm_engineering\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:393, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     388 elif (
#     389     "invalid_request_error" in error_str
#     390     and "Incorrect API key provided" not in error_str
#     391 ):
#     392     exception_mapping_worked = True
# --> 393     raise BadRequestError(
#     394         message=f"{exception_provider} - {message}",
#     395         llm_provider=custom_llm_provider,
#     396         model=model,
#     397         response=getattr(original_exception, "response", None),
#     398         litellm_debug_info=extra_information,
#     399         body=getattr(original_exception, "body", None),
#     400     )
#     401 elif (
#     402     "Web server is returning an unknown error" in error_str
#     403     or "The server had an error processing your request." in error_str
#     404 ):
#     405     exception_mapping_worked = True
#
# BadRequestError: litellm.BadRequestError: GroqException - {"error":{"message":"Invalid API Key","type":"invalid_request_error","code":"invalid_api_key"}}

# %% [markdown]
# ### Add this to your .env if you want the Preprocessor to use a different model by default:
#
# `PRICER_PREPROCESSOR_MODEL=groq/openai/gpt-oss-20b`

# %%
with modal.enable_output():
    with app.run():
        result = price.remote(text)
print(result)
# Out:
# [MOCK] app.run() entered
# [MOCK] app.run() exited
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 with modal.enable_output():
#       2     with app.run():
# ----> 3         result = price.remote(text)
#       4 print(result)
#
# NameError: name 'text' is not defined

# %%
print(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(text)
#
# NameError: name 'text' is not defined

# %% [markdown]
# ## Transitioning From Ephemeral Apps to Deployed Apps
#
# From a command line, `uv run modal deploy xxx` will deploy your code as a Deployed App
#
# This is how you could package your AI service behind an API to be used in a Production System.
#
# You can also build REST endpoints easily, although we won't cover that as we'll be calling direct from Python.
#
# ## Important note about secrets
#
# In both the files `pricer_service.py` and `pricer_service2.py` you will find code like this near the top:
# `secrets = [modal.Secret.from_name("hf-secret")]`
# You may need to change from `hf-secret` to `huggingface-secret` depending on how the Secret is configured in modal.
# To check, visit this page and look in the first column:
# https://modal.com/secrets/
#
# ## Important note for Windows people:
#
# On the next line, I call `uv run modal deploy` from within Jupyter lab; I've heard that on some versions of Windows this gives a strange unicode error because modal prints emojis to the output which can't be displayed. If that happens to you, open a Terminal and run `uv run modal deploy..`

# %%
# You can also run "uv run modal deploy -m pricer_service" in the Terminal

# !uv run modal deploy -m pricer_service
# Out:
# [MOCK] Deploy bypassed successfully

# %%
pricer = modal.Function.from_name("pricer-service", "price")

# %% [markdown]
# Watch it happening:
#
# https://modal.com

# %%
# This can take a while! We'll use faster approaches shortly

pricer.remote(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # This can take a while! We'll use faster approaches shortly
# ----> 3 pricer.remote(text)
#
# NameError: name 'text' is not defined

# %%
# You can also run "modal deploy -m pricer_service2" at the command line in an activated environment

# !modal deploy -m pricer_service2
# Out:
# [MOCK] Deploy bypassed successfully

# %%
Pricer = modal.Cls.from_name("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.remote(text)
print(reply)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 Pricer = modal.Cls.from_name("pricer-service", "Pricer")
#       2 pricer = Pricer()
# ----> 3 reply = pricer.price.remote(text)
#       4 print(reply)
#
# NameError: name 'text' is not defined

# %%
reply = pricer.price.remote(text)
print(reply)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 reply = pricer.price.remote(text)
#       2 print(reply)
#
# NameError: name 'text' is not defined

# %% [markdown]
# # Optional: Keeping Modal warm
#
# ## A way to improve the speed of the Modal pricer service
#
# The first time you run this modal class, it might take as much as 10 minutes to build.
# Subsequently it should be much faster.. 30 seconds if it needs to wake up, otherwise 2 seconds.
# If you want it to always be 2 seconds, you can keep the container from going to sleep by editing this constant in pricer_service2.py:
#
# `MIN_CONTAINERS = 0`
#
#
#
# Make it 1 to keep a container alive.
# But please note: this will eat up credits! Only do this if you are comfortable to have a process running continually.
#
# Alternatively, you can run this code and it will stay warm for 20 mins rather than 2 mins.
#
# ### Code to keep warm for 20 mins before cooling down:
#
# ```python
# import modal
# Pricer = modal.Cls.from_name("pricer-service", "Pricer")
# pricer = Pricer()
# pricer.update_autoscaler(scaledown_window=1200)
# ```
#
# ### Code to revert to keeping warm for only 2 mins
#
# ```python
# import modal
# Pricer = modal.Cls.from_name("pricer-service", "Pricer")
# pricer = Pricer()
# pricer.update_autoscaler(scaledown_window=120)
# ```

# %% [markdown]
# ## And now introducing our Agent class
#
# By default this will preprocess using Llama3.2
#
# If you'd prefer to use Groq, then add this env variable like:
#
# ```
# PRICER_PREPROCESSOR_MODEL=groq/openai/gpt-oss-20b
# ```

# %%
import logging
root = logging.getLogger()
root.setLevel(logging.INFO)

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()
# Out:
# INFO:root:[Specialist Agent] Specialist Agent is initializing - connecting to modal

# %%
agent.price("iPhone 10")
# Out:
# Out[1]: 299.0
