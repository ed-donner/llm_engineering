# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
# !uv run modal deploy -m pricer_service
# Out:
# ⠸ Creating objects.....
# └── ⠋ Creating mount
#     /Users/temmyogunbo/andela/fork/llm_engineering/week8/community_contributions
# ⠦ Creating objects...files
# └── ⠸ Creating mount
#     /Users/temmyogunbo/andela/fork/llm_engineering/week8/community_contributions
# ⠏ Creating objects...files
# └── ⠦ Creating mount
#     /Users/temmyogunbo/andela/fork/llm_engineering/week8/community_contributions
# Building image im-zShmb4cM1F9ac8Haw0e1CN
# ⠹ Creating objects...
# ⠹ Creating objects...ers/temmyogunbo/andela/fork/llm_engineering/week8/commun
# └── 🔨 Created mount
#     /Users/temmyogunbo/andela/fork/llm_engineering/week8/community_contributions
# service.py
# => Step 0: FROM base
# ⠼ Creating objects...
# 🔨 Created mount /Users/temmyogunbo/andela/fork/llm_engineering/week8/commun
# => Step 1: RUN python -m pip install accelerate bitsandbytes huggingface peft torch transformers
# ⠼ Creating objects...
# ⠴ Creating objects...ers/temmyogunbo/andela/fork/llm_engineering/week8/commun
# ...

# %%
from price_gradio_app import create_app

demo = create_app()
demo.launch(inbrowser=True)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# INFO:root:[Ensemble Agent] Initializing Ensemble Agent
# INFO:root:[Specialist Agent] Specialist Agent is setting up - connecting to modal
# INFO:root:[Frontier Agent] Setting up Frontier Agent
# INFO:root:[Frontier Agent] Frontier Agent is setting up with OpenAI
# Logging in to Hugging Face...
# Setting up Chroma vectorstore...
# Initializing Ensemble Agent...
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: mps
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# INFO:root:[Frontier Agent] Frontier Agent is ready
# INFO:root:[Ensemble Agent] Ensemble Agent is ready
# ...
