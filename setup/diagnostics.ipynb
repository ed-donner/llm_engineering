# %% [markdown]
# # Gathering Essential Diagnostic information
#
# ## Please run this next cell to gather some important data
#
# Please run the next cell; it should take a minute or so to run (mostly the network test).
# Then email me the output of the last cell to ed@edwarddonner.com.
# Alternatively: this will create a file called report.txt - just attach the file to your email.

# %%
# Run my diagnostics report to collect key information for debugging
# Please email me the results. Either copy & paste the output, or attach the file report.txt

# !pip install -q requests speedtest-cli psutil setuptools
from diagnostics import Diagnostics
Diagnostics().run()
# Out:
# zsh:1: command not found: pip
# Starting diagnostics at 2025-12-20 17:51:17
#
# ===== System Information =====
# Operating System: Darwin
# MacOS Version: 26.0
# Architecture: ('64bit', '')
# Machine: arm64
# Processor: arm
# Total RAM: 36.00 GB
# Available RAM: 13.24 GB
# Free Disk Space: 1708.98 GB
#
# ===== File System Information =====
# Current Directory: /Users/gunaseka/projects/llm_engineering/setup
# Write permission: OK
#
# Files in Current Directory:
#  - SETUP-PC.md
#  - SETUP-linux.md
#  - SETUP-mac.md
#  - SETUP-new.md
#  - __pycache__
#  - diagnostics.ipynb
#  - diagnostics.py
#  - report.txt
#  - troubleshooting.ipynb
#
# ===== Git Repository Information =====
# Git Repository Root: /Users/gunaseka/projects/llm_engineering
# Current Commit: ed0118baf164c34cd7c1a9d7ca7295b57dc19861
# Remote Origin: https://github.com/ed-donner/llm_engineering.git
#
# ===== Environment File Check =====
# .env file exists at: /Users/gunaseka/projects/llm_engineering/.env
# OPENAI_API_KEY found in .env file
#
# ===== Anaconda Environment Check =====
# No active Anaconda environment detected
#
# ===== Virtualenv Check =====
# Virtualenv is active:
# Environment Path: /Users/gunaseka/projects/llm_engineering/.venv
# Environment Name: .venv
#
# Python Environment:
# Python Version: 3.12.12 (main, Dec  9 2025, 19:05:33) [Clang 21.1.4 ]
# Python Executable: /Users/gunaseka/projects/llm_engineering/.venv/bin/python
# /Users/gunaseka/projects/llm_engineering/setup/diagnostics.py:255: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Required Package Versions:
# openai: 2.7.1
# python-dotenv: 1.2.1
# requests: 2.32.5
# gradio: 5.49.1
# transformers: 4.57.1
#
# ===== Network Connectivity Check =====
# SSL Version: OpenSSL 3.5.4 30 Sep 2025
# ✓ Connected to https://www.google.com
#   Response time: 0.19s
#
# Performing bandwidth test using speedtest-cli...
# Download speed: 313.23 Mbps
# Upload speed: 103.70 Mbps
#
# ===== Environment Variables Check =====
#
# PYTHONPATH is not set.
#
# Python sys.path:
#  - /Users/gunaseka/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python312.zip
#  - /Users/gunaseka/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12
#  - /Users/gunaseka/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/lib-dynload
#  -
#  - /Users/gunaseka/projects/llm_engineering/.venv/lib/python3.12/site-packages
#  - /Users/gunaseka/projects/llm_engineering/.venv/lib/python3.12/site-packages/setuptools/_vendor
# OPENAI_API_KEY is set after calling load_dotenv()
#
# ===== Additional Diagnostics =====
# Temp directory is writable: /var/folders/wg/rj6s_ttd799b8s260qqpc14m0000gn/T
#
# ✅ All diagnostics passed successfully!
#
#
# Completed diagnostics at 2025-12-20 17:52:10
#
#
# Please send these diagnostics to me at ed@edwarddonner.com
# Either copy & paste the above output into an email, or attach the file report.txt that has been created in this directory.
