# %% [markdown]
# # Gathering Essential Diagnostic information
#
# ## Please run this next cell to gather some important data
#
# Please run the next cell; it should take a minute or so to run (mostly the network test).
# Then email me the output of the last cell to ed@edwarddonner.com.
# Alternatively: this will create a file called report.txt - just attach the file to your email.

# %%
# Run my diagnostics report to collect key information for debugging
# Please email me the results. Either copy & paste the output, or attach the file report.txt

# !pip install -q requests speedtest-cli psutil setuptools
from diagnostics import Diagnostics
Diagnostics().run()
# Out:
# Starting diagnostics at 2025-11-17 13:42:18
#
# ===== System Information =====
# Operating System: Darwin
# MacOS Version: 26.0.1
# Architecture: ('64bit', 'Mach-O')
# Machine: arm64
# Processor: arm
# Total RAM: 24.00 GB
# Available RAM: 4.45 GB
# Free Disk Space: 87.62 GB
#
# ===== File System Information =====
# Current Directory: /Users/trungnguyen/Documents/arctis-ai/self-learning/llm_engineering/setup
# Write permission: OK
#
# Files in Current Directory:
#  - SETUP-PC.md
#  - SETUP-linux.md
#  - SETUP-mac.md
#  - SETUP-new.md
#  - __pycache__
#  - diagnostics.ipynb
#  - diagnostics.py
#  - report.txt
#  - troubleshooting.ipynb
#
# ===== Git Repository Information =====
# Git Repository Root: /Users/trungnguyen/Documents/arctis-ai/self-learning/llm_engineering
# Current Commit: 22b72031ed89f522875fc4b6b9e7fb69b5398a9b
# Remote Origin: https://github.com/ed-donner/llm_engineering.git
#
# ===== Environment File Check =====
# .env file exists at: /Users/trungnguyen/Documents/arctis-ai/self-learning/llm_engineering/.env
# OPENAI_API_KEY found in .env file
#
# ===== Anaconda Environment Check =====
# Anaconda environment is active:
# Environment Path: /opt/anaconda3
# Environment Name: anaconda3
# Conda Version: conda 25.5.1
#
# Python Environment:
# Python Version: 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 11:23:37) [Clang 14.0.6 ]
# Python Executable: /opt/anaconda3/bin/python
#
# Required Package Versions:
# ERROR: Required package 'openai' is not installed
# python-dotenv: 1.1.0
# requests: 2.32.3
# ERROR: Required package 'gradio' is not installed
# ERROR: Required package 'transformers' is not installed
#
# ===== Virtualenv Check =====
# No active virtualenv detected
#
# ===== Network Connectivity Check =====
# SSL Version: OpenSSL 3.0.16 11 Feb 2025
# ✓ Connected to https://www.google.com
#   Response time: 0.29s
#
# Performing bandwidth test using speedtest-cli...
# Download speed: 84.82 Mbps
# Upload speed: 41.51 Mbps
#
# ===== Environment Variables Check =====
#
# PYTHONPATH is not set.
#
# Python sys.path:
#  - /opt/anaconda3/lib/python313.zip
#  - /opt/anaconda3/lib/python3.13
#  - /opt/anaconda3/lib/python3.13/lib-dynload
#  -
#  - /opt/anaconda3/lib/python3.13/site-packages
#  - /Users/trungnguyen/Documents/arctis-ai/development/arctis-user-management
#  - /opt/anaconda3/lib/python3.13/site-packages/aeosa
#  - /opt/anaconda3/lib/python3.13/site-packages/setuptools/_vendor
# OPENAI_API_KEY is set after calling load_dotenv()
#
# ===== Additional Diagnostics =====
# Temp directory is writable: /var/folders/qv/blw6g3lx4vggd6vt9wtr1rc00000gn/T
#
# ===== Errors Found =====
# The following critical issues were detected. Please address them before proceeding:
# - Required package 'openai' is not installed
# - Required package 'gradio' is not installed
# - Required package 'transformers' is not installed
#
#
# Completed diagnostics at 2025-11-17 13:43:10
#
#
# Please send these diagnostics to me at ed@edwarddonner.com
# Either copy & paste the above output into an email, or attach the file report.txt that has been created in this directory.
