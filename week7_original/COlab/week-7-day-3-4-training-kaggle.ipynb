# %% [markdown]
# # Predict Product Prices
#
# ## Day 3: Training!
#
# # IMPORTANT please read me!!
#
# When you run the pip installs below, you may get an error from pip complaining about an incompatible version of fsspec.
#
# You should ignore that error! The version of fsspec is the right version, needed by HuggingFace.
#
# If you ask ChatGPT, it will encourage you to pip install a more recent version of fsspec. But that would be problematic; HuggingFace will fail to load the dataset later with an obscure error about file systems.
#
# So please run the pip installs as they appear below, and look the other way if you get an error!

# %%
# pip installs

# !pip install -q --upgrade torch==2.5.1+cu124 torchvision==0.20.1+cu124 torchaudio==2.5.1+cu124 --index-url https://download.pytorch.org/whl/cu124
# !pip install -q --upgrade requests==2.32.3 bitsandbytes==0.46.0 transformers==4.48.3 accelerate==1.3.0 datasets==3.2.0 peft==0.14.0 trl==0.14.0 matplotlib wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.2/908.2 MB 1.9 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 6.5 MB/s eta 0:00:000:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 69.8 MB/s eta 0:00:00:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.1 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.3 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.7 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 35.5 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 14.6 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 9.0 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 10.2 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 149.1 kB/s eta 0:00:00a 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.7 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 9.0 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 4.8 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# fastai 2.8.4 requires fastcore<1.9,>=1.8.0, but you have fastcore 1.11.3 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 28.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 105.0 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 33.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 kB 29.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 kB 25.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 117.1 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 79.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 15.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 12.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 94.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.22.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# ydata-profiling 4.18.1 requires matplotlib<=3.10,>=3.5, but you have matplotlib 3.10.8 which is incompatible.
# google-adk 1.22.1 requires requests<3.0.0,>=2.32.4, but you have requests 2.32.3 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.47.0 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.3 which is incompatible.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# gradio 5.49.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.5 which is incompatible.
# bigframes 2.26.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# fastai 2.8.4 requires fastcore<1.9,>=1.8.0, but you have fastcore 1.11.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
# imports
# With much thanks to Islam S. for identifying that there was a missing import!

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments, set_seed, BitsAndBytesConfig
from datasets import load_dataset, Dataset, DatasetDict
import wandb
from peft import LoraConfig
from trl import SFTTrainer, SFTConfig
from datetime import datetime
import matplotlib.pyplot as plt
# Out:
# 2026-02-16 06:04:47.079700: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771221887.272590      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771221887.326593      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771221887.774662      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771221887.774712      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771221887.774714      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771221887.774721      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# Constants

BASE_MODEL = "google/codegemma-2b"
PROJECT_NAME = "pricer"
HF_USER = "marufmullah50" # your HF name here!

# Data

DATASET_NAME = f"{HF_USER}/lite-data"
# Or just use the one I've uploaded
# DATASET_NAME = "ed-donner/pricer-data"
MAX_SEQUENCE_LENGTH = 182


# Run name for saving the model in the hub

RUN_NAME =  f"{datetime.now():%Y-%m-%d_%H.%M.%S}"
PROJECT_RUN_NAME = f"{PROJECT_NAME}-{RUN_NAME}"
HUB_MODEL_NAME = f"{HF_USER}/{PROJECT_RUN_NAME}"

# Hyperparameters for QLoRA

LORA_R = 32
LORA_ALPHA = 64 #Because alpha = 2 x rank
TARGET_MODULES = ["q_proj", "v_proj", "k_proj", "o_proj"]
LORA_DROPOUT = 0.1
QUANT_4_BIT = True

# Hyperparameters for Training

EPOCHS = 1 # you can do more epochs if you wish, but only 1 is needed - more is probably overkill
BATCH_SIZE = 4 # on an A100 box this can go up to 16
GRADIENT_ACCUMULATION_STEPS = 1
LEARNING_RATE = 1e-4
LR_SCHEDULER_TYPE = 'cosine'
WARMUP_RATIO = 0.03
OPTIMIZER = "paged_adamw_32bit"

# Admin config - note that SAVE_STEPS is how often it will upload to the hub
# I've changed this from 5000 to 2000 so that you get more frequent saves

STEPS = 50
SAVE_STEPS = 2000
LOG_TO_WANDB = True

# %matplotlib inline

# %%
HUB_MODEL_NAME
# Out:
# 'marufmullah50/pricer-2026-02-16_06.04.59'

# %% [markdown]
# # More on Optimizers
#
# https://huggingface.co/docs/transformers/main/en/perf_train_gpu_one#optimizer-choice
#
# The most common is Adam or AdamW (Adam with Weight Decay).
# Adam achieves good convergence by storing the rolling average of the previous gradients; however, it adds an additional memory footprint of the order of the number of model parameters.

# %% [markdown]
# ### Log in to HuggingFace and Weights & Biases
#
# If you don't already have a HuggingFace account, visit https://huggingface.co to sign up and create a token.
#
# Then select the Secrets for this Notebook by clicking on the key icon in the left, and add a new secret called `HF_TOKEN` with the value as your token.
#
# Repeat this for weightsandbiases at https://wandb.ai and add a secret called `WANDB_API_KEY`

# %%
# ==============================
# Weights & Biases and hugging face Login (Kaggle)
# ==============================

import os
import wandb
from kaggle_secrets import UserSecretsClient
# Project name
LOG_TO_WANDB = True   # or False



# Get secret from Kaggle Secrets
user_secrets = UserSecretsClient()
from huggingface_hub import login

hf_token = user_secrets.get_secret('HF_TOKEN')
login(token=hf_token, add_to_git_credential=True)



wandb_api_key = user_secrets.get_secret("WANDB_API_KEY")

# Strip whitespace just in case
wandb_api_key = wandb_api_key.strip()

# Login to W&B
wandb.login(key=wandb_api_key)

# Configure project settings
os.environ["WANDB_PROJECT"] = PROJECT_NAME
os.environ["WANDB_LOG_MODEL"] = "checkpoint" if LOG_TO_WANDB else "end"
os.environ["WANDB_WATCH"] = "gradients"
# Out:
# Token has not been saved to git credential helper.
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: md-marufmullah50 (md-marufmullah50-military-institute-of-science-and-techn) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# README.md:   0%|          | 0.00/412 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/9.73M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/771k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
# if you wish to reduce the training dataset to 20,000 points instead, then uncomment this line:
#to train shorter
train = train.select(range(20000))

# %%
if LOG_TO_WANDB:
  wandb.init(project=PROJECT_NAME, name=RUN_NAME)
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260216_060518-wahehgzw</code>
# Syncing run <strong><a href='https://wandb.ai/md-marufmullah50-military-institute-of-science-and-techn/pricer/runs/wahehgzw' target="_blank">2026-02-16_06.04.59</a></strong> to <a href='https://wandb.ai/md-marufmullah50-military-institute-of-science-and-techn/pricer' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/md-marufmullah50-military-institute-of-science-and-techn/pricer' target="_blank">https://wandb.ai/md-marufmullah50-military-institute-of-science-and-techn/pricer</a>
#  View run at <a href='https://wandb.ai/md-marufmullah50-military-institute-of-science-and-techn/pricer/runs/wahehgzw' target="_blank">https://wandb.ai/md-marufmullah50-military-institute-of-science-and-techn/pricer/runs/wahehgzw</a>

# %% [markdown]
# ## Now load the Tokenizer and Model
#
# The model is "quantized" - we are reducing the precision to 4 bits.

# %%
# pick the right quantization

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

print(f"Memory footprint: {base_model.get_memory_footprint() / 1e6:.1f} MB")
# Out:
# tokenizer_config.json:   0%|          | 0.00/46.3k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/555 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/668 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# Memory footprint: 2039.6 MB

# %%
base_model
# Out:
# GemmaForCausalLM(
#   (model): GemmaModel(
#     (embed_tokens): Embedding(256000, 2048, padding_idx=0)
#     (layers): ModuleList(
#       (0-17): 18 x GemmaDecoderLayer(
#         (self_attn): GemmaAttention(
#           (q_proj): Linear4bit(in_features=2048, out_features=2048, bias=False)
#           (k_proj): Linear4bit(in_features=2048, out_features=256, bias=False)
#           (v_proj): Linear4bit(in_features=2048, out_features=256, bias=False)
#           (o_proj): Linear4bit(in_features=2048, out_features=2048, bias=False)
#         )
#         (mlp): GemmaMLP(
#           (gate_proj): Linear4bit(in_features=2048, out_features=16384, bias=False)
#           (up_proj): Linear4bit(in_features=2048, out_features=16384, bias=False)
#           (down_proj): Linear4bit(in_features=16384, out_features=2048, bias=False)
#           (act_fn): GELUActivation()
#         )
#         (input_layernorm): GemmaRMSNorm((2048,), eps=1e-06)
#         (post_attention_layernorm): GemmaRMSNorm((2048,), eps=1e-06)
#       )
#     )
#     (norm): GemmaRMSNorm((2048,), eps=1e-06)
#     (rotary_emb): GemmaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=2048, out_features=256000, bias=False)
# )

# %% [markdown]
# # Data Collator
#
# It's important that we ensure during Training that we are not trying to train the model to predict the description of products; only their price.
#
# We need to tell the trainer that everything up to "Price is $" is there to give context to the model to predict the next token, but does not need to be learned.
#
# The trainer needs to teach the model to predict the token(s) after "Price is $".
#
# There is a complicated way to do this by setting Masks, but luckily HuggingFace provides a super simple helper class to take care of this for us.

# %%
from trl import DataCollatorForCompletionOnlyLM
response_template = "Price is $"
collator = DataCollatorForCompletionOnlyLM(response_template, tokenizer=tokenizer)

# %% [markdown]
# # AND NOW
#
# ## We set up the configuration for Training
#
# We need to create 2 objects:
#
# A LoraConfig object with our hyperparameters for LoRA
#
# An SFTConfig with our overall Training parameters

# %%
# First, specify the configuration parameters for LoRA

lora_parameters = LoraConfig(
    lora_alpha=LORA_ALPHA,
    lora_dropout=LORA_DROPOUT,
    r=LORA_R,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=TARGET_MODULES,
)

# Next, specify the general configuration parameters for training

train_parameters = SFTConfig(
    output_dir=PROJECT_RUN_NAME,
    num_train_epochs=EPOCHS,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=1,
    eval_strategy="no",
    gradient_accumulation_steps=GRADIENT_ACCUMULATION_STEPS,
    optim=OPTIMIZER,
    save_steps=SAVE_STEPS,
    save_total_limit=10,
    logging_steps=STEPS,
    learning_rate=LEARNING_RATE,
    weight_decay=0.001,
    fp16=False,
    bf16=True,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=WARMUP_RATIO,
    group_by_length=True,
    lr_scheduler_type=LR_SCHEDULER_TYPE,
    report_to="wandb" if LOG_TO_WANDB else None,
    run_name=RUN_NAME,
    max_seq_length=MAX_SEQUENCE_LENGTH,
    dataset_text_field="text",
    save_strategy="steps",
    hub_strategy="every_save",
    push_to_hub=True,
    hub_model_id=HUB_MODEL_NAME,
    hub_private_repo=True
)

# And now, the Supervised Fine Tuning Trainer will carry out the fine-tuning
# Given these 2 sets of configuration parameters
# The latest version of trl is showing a warning about labels - please ignore this warning
# But let me know if you don't see good training results (loss coming down).

fine_tuning = SFTTrainer(
    model=base_model,
    train_dataset=train,
    peft_config=lora_parameters,
    args=train_parameters,
    data_collator=collator
  )
# Out:
# Map:   0%|          | 0/20000 [00:00<?, ? examples/s]
# /usr/local/lib/python3.12/dist-packages/trl/trainer/sft_trainer.py:300: UserWarning: You passed a processing_class with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `processing_class.padding_side = 'right'` to your code.
#   warnings.warn(

# %% [markdown]
# ## In the next cell, we kick off fine-tuning!
#
# This will run for some time, uploading to the hub every SAVE_STEPS steps.
#
# After some time, Google might stop your colab. For people on free plans, it can happen whenever Google is low on resources. For anyone on paid plans, they can give you up to 24 hours, but there's no guarantee.
#
# If your server is stopped, you can follow my colab here to resume from your last save:
#
# https://colab.research.google.com/drive/1qGTDVIas_Vwoby4UVi2vwsU0tHXy8OMO#scrollTo=R_O04fKxMMT-
#
# I've saved this colab with my final run in the output so you can see the example. The trick is that I needed to set `is_trainable=True` when loading the fine_tuned model.
#
# ### Anyway, with that in mind, let's kick this off!

# %%
# Fine-tune!
fine_tuning.train()

# Push our fine-tuned model to Hugging Face
fine_tuning.model.push_to_hub(PROJECT_RUN_NAME, private=True)
print(f"Saved to the hub: {PROJECT_RUN_NAME}")
# Out:
# wandb: WARNING The get_url method is deprecated and will be removed in a future release. Please use `run.url` instead.
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Supplying Demand 279457 Clothes Dryer Heating Element Connecting Wire Replacement Kit
# Alternate part numbers include 3140, and T2502. (2) 3 Inch wires with 5/16 Inch female spade connectors | (2) Wire nuts| Fits model specific dryers It is important to disconnect your appliance from the power supply before servicing. Supplying Demand replacement parts are compatible with Major Brands, but you should always verify fitment with your specific model. We have included a video in the product gallery to help you find your model number and information in the description below. SD products come in Supplying Demand packaging. Brand Name Supplying Demand, Model Info Weight 0.81 ounces, Dimensions 10.5 x 8 x 0.1 inches, model number Part
#
# Price. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# 6 Water Filters for Keurig K-Mini, K-Slim, K-Duo, K-Supreme, K-Classic, K-Elite, K-Select, K-Cafe, K-Compact, K-Express - Universal Fit Replacement Water Filter for Keurig Coffee Makers
# PACKAGE 6 High Quality Replacement Charcoal Water Filters for Keurig Coffee Makers COMPATIBLE with all Keurig 2.0 and 1.0 Brewers K10, K15, K40, K45, K50, K55, K60, K65, K70, K75, K79, K130, K140, K145, K150, K155, K200, K250, K300. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 2:17:13, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.284800</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.009600</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.075300</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.059000</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.057500</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.128900</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.068000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.063000</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.072700</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.937600</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.020400</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.063600</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>1.056800</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.952300</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.977900</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.992200</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>1.043400</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.989300</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>1.001500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.094300</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.953100</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>1.019500</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.977000</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.002500</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.950400</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.955900</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.981300</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>1.003100</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.938500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.020500</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.952800</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.988300</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.972400</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.925000</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.941900</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.989200</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.984500</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.958600</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.971500</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.929500</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.943800</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.987200</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>0.898200</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.974000</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>0.997300</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.901800</td>
#     </tr>
#     <tr>
#       <td>2350</td>
#       <td>0.934200</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.982500</td>
#     </tr>
#     <tr>
#       <td>2450</td>
#       <td>0.880500</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.916900</td>
#     </tr>
#     <tr>
#       <td>2550</td>
#       <td>0.997200</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.918400</td>
#     </tr>
#     <tr>
#       <td>2650</td>
#       <td>0.919300</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.938600</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>0.938500</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>1.013300</td>
#     </tr>
#     <tr>
#       <td>2850</td>
#       <td>0.913900</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.959500</td>
#     </tr>
#     <tr>
#       <td>2950</td>
#       <td>0.933700</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.957700</td>
#     </tr>
#     <tr>
#       <td>3050</td>
#       <td>0.923900</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>1.030300</td>
#     </tr>
#     <tr>
#       <td>3150</td>
#       <td>0.892900</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.936100</td>
#     </tr>
#     <tr>
#       <td>3250</td>
#       <td>0.980500</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.879200</td>
#     </tr>
#     <tr>
#       <td>3350</td>
#       <td>0.881500</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.890700</td>
#     </tr>
#     <tr>
#       <td>3450</td>
#       <td>0.945400</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.967000</td>
#     </tr>
#     <tr>
#       <td>3550</td>
#       <td>0.889200</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.874200</td>
#     </tr>
#     <tr>
#       <td>3650</td>
#       <td>0.925600</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.946000</td>
#     </tr>
#     <tr>
#       <td>3750</td>
#       <td>0.953800</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.946300</td>
#     </tr>
#     <tr>
#       <td>3850</td>
#       <td>0.950600</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.927100</td>
#     </tr>
#     <tr>
#       <td>3950</td>
#       <td>0.902700</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.931800</td>
#     </tr>
#     <tr>
#       <td>4050</td>
#       <td>0.905800</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.927100</td>
#     </tr>
#     <tr>
#       <td>4150</td>
#       <td>0.858200</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.928600</td>
#     </tr>
#     <tr>
#       <td>4250</td>
#       <td>0.991500</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.919900</td>
#     </tr>
#     <tr>
#       <td>4350</td>
#       <td>0.879700</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.919600</td>
#     </tr>
#     <tr>
#       <td>4450</td>
#       <td>0.886300</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.857500</td>
#     </tr>
#     <tr>
#       <td>4550</td>
#       <td>0.943800</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.902300</td>
#     </tr>
#     <tr>
#       <td>4650</td>
#       <td>0.948900</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.955000</td>
#     </tr>
#     <tr>
#       <td>4750</td>
#       <td>0.895700</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.949700</td>
#     </tr>
#     <tr>
#       <td>4850</td>
#       <td>0.905300</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.918900</td>
#     </tr>
#     <tr>
#       <td>4950</td>
#       <td>0.864100</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.893700</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# 2-Pack Replacement for Bosch Refrigerator Water Filter - Compatible with Bosch ULTRACLARITY, 644845 Fridge Water Filter Cartridge
# This is a Denali Pure Brand replacement part, NOT an OEM product. All mentions of brand names or model descriptions are made strictly to illustrate compatibility. All brand names and logos are registered trademarks of their respective owners. This product is not affiliated with any OEM brands and is not covered under any warranties offered by the original manufacturers. Any warranties for this product are offered solely by Denali Pure. Replacement for 644845 Filter Manufacturer Upstart Battery, model number Rank Tools & Home Improvement In-Refrigerator Water Filters 6021, Is Discontinued No, Available September 25, 2015, Duration 6 \tmonths, External Testing Certification. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# SOLOROCK 24 2.7 cb.ft. 26 lbs High Capacity Ventless Washer Dryer Combo White
# Extensively upgraded model, increased washing and drying capacity by 70% and 100% respectively with a bigger drum and new features! 12 Kg or 26 lbs 3.1 cb.ft. (Canadian Standard) or 2.7 cb. ft. (US Standard) 24 Ventless Washer & Dryer Combo - Front Load. Voltage/Frequency Rated Current 20A; Washing Capacity(DOE) 12 kg or 26 lbs; Drying Capacity 7 kg or 16 lbs; Energy verified for USA & Canada; Color White; Max spin speed 1200 rpm; Wash temps Hot+, Hot, Warm, Eco,. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Complete Tractor New DB Electrical Fuel Bowl Compatible with/Replacement for Massey Ferguson, New Holland, Ford, and Case/International Harvester | Glass Materiel | 3 5/8 Dimension
# **Verify the part fits before purchasing**Specs Description Fuel Bowloutside diameter 3 5/8 mounting hole 3/4 Note Rounded type bottom bowl for CAV type fuel filters #296 and OEM Numbers Atlantic (Prior) Harvester Holland Ferguson With/Replacement For Case/International Harvester 275 Compact Tractor, 375 Windrower, 454, 464, 484, 574, 584 Indust/Const, 674, 684, 784, 86, Holland 555E Indust/Const,. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Boundless Voyage Titanium Pour Over Coffee Filter Holder Outdoor Camping Reusable Coffee Dripper Holder Lightweight Portable (Holder(L)
# Item Name：Holder Model Model Material 99.8% Titanium Material 99.8% Titanium Size - - - - - - - - Weight - 10g - 10g - 14g - 14g - 16g - 16g - 18g - 18g pcs set) - 58g pcs set) - 58g Feature： Bring your own favorite filter, just match a simple stand, and you can taste the familiar taste when you travel. Bring your own favorite filter, just match a simple stand, and you can taste the familiar taste when you travel. A ring-shaped simple stand made of pure titanium. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Blue Ocean 36 RH668I Tempered Glass Stainless Steel LED Light Island Mount Kitchen Range Hood | 900 CFM | PRO PERFORMANCE | 3 Speed Exhaust Fan | Ducted/Ductless Convertible Duct
# SUPER HIGH AIRFLOW (900 CFM) and ULTRA QUIET Noise Level <65db High-tech 3 Speed Control Button Switch with Four 2W LED Lights Dimension 2.5 H x 35.5 W x 23.5”D (6.5 x 90 x 60cm) Material Brushed Stainless Steel Body, Aluminum Filters Includes 2 Charcoal Filters (For FREE) for Indoor Exhaust Recirculation Brand Name Blue Ocean, Model Info Weight 63.1 pounds, Dimensions 23.5\ D x 35.. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# GLACIER FRESH Replacement Water Filter, Compatible with Water Filter and LT120F Fresh Air Filter 4 Pack
# GLACIER FRESH Water Filter Statement Material and Construction and Performance Tested to NSF42 Standards. Tested & verified by independent laboratory testing, the Samsung* refrigerator water filter removes 97.9%* chlorine and improves water’s smell and taste. Water Filter Compatible Water Filter, Kenmore 9980, etc. Find NSF 42 Standard information Go to NSF's database, the manufacturer Ningbo Pureza Technology, LLC and model number. If you find that the product is not NSF42 certified, you can apply for a ten-fold claim for the purchase amount, this claim statement is listed for GLACIER FRESH and has nothing to do with NSF Water filter Service life Premium
#
# Price is. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Reusable Cups for Keurig K-Cup 2.0 and 1.0 Coffee Maker, Refillable Filter Pods, Stainless Steel
# Compatible with Keurig 1.0 and 2.0 brewer models - K200, K250, K300, K350, K400, K450, K460, K500, K550, K560 and Keurig 1.0 models – K40, K45, K60, K70, K75, K145, K150, K155, B30, B40, B44, B60, B70, B140, B145, B20. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Ansoon 312959 Clothes Dryer Drive Drum Belt Compatible for Maytag Dryers Replaces
# 312959 Dryer Drum Belt Compatible for brands Compatible for Whirlpool,Compatible for Maytag Compatible for Jenn-Airlong size 100 inch Replace Part Numbers LB234, 6 etc. 312959 Clothes Dryer Drive Drum Belt Replaces part numbers LB234, 6 Tip Before you replace the belt due to noise issues, check the drum support rollers and replace if you see signs of damage or wear. Non original aftermarket part. Fits OEM Standards! Manufacturer Ansoon, Part Weight 2.78 ounces, Dimensions 7.01 x 6.81 x 1.02 inches, model number Is Discontinued No, Rank Tools & Home. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# newlifeapp 338906 Gas Dryer Flame Sensor Compatible with LG, Samsung, Whirlpool, Kenmore, Maytag.
# 338906 Gas Dryer Flame Sensor. The flame sensor monitors whether the igniter is hot enough to ignite gas to light the burner. This part works with the following brands Whirlpool, Roper, Admiral, Maytag, Hardwick, Jenn-Air, Estate, Magic Chef, Crosley, Inglis, Norge, Modern Maid, Amana, Kenmore, KitchenAid, Caloric & Ikea. Replaces old numbers 10RS 303377 3-3377 338906 510213 56231 635013 78313 78. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# American Range A11200 Tip Assembly Short New Pilot
# Product Description American Range A11200 Tip Pilot Assembly, American Range provides high quality restaurant and hotel ranges and other professional kitchen products. From the Manufacturer American Range A11200 Tip Pilot Assembly, American Range provides high quality restaurant and hotel ranges and other professional kitchen products Genuine OEM Replacement part American Range provides high quality restaurant and hotel ranges and other professional kitchen products Use genuine OEM parts for safety reliability and performance Model number A11200 Brand Name American Range, Model Info Weight 0.8 ounces, Dimensions 9 x 5 x 5 inches, model number Is Discontinued No, Part Included Components Replacement Part, Rank Tools & Home Improvement Range Accessories 789, Available October 5, 2012
#
# Price is. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Vent-A-Hood 30 Emerald Series Under Cabinet Range Hood With 250 CFM Power Lung Blower Emerald Lip Styling Halogen Lighting SensaSource and Fire-Safe Design in Stainless
# Important This is a special order item. Orders for special order items from Vent-A-Hood are non-cancelable and non-returnable. 250 CFM 30 Under Cabinet Range Hood with a Single Blower and LED Lights from the Emerald Collection Popular contemporary design of this wall-mount hood with soft-cut corners gives an up-to-date look. All Vent-A-Hood products are suitable for use in damp locations (outdoor applications such as a covered patio) when installed in a GFCI protected branch circuit. The has a 250 CFM motor. Added to the range hood are LED Lights. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# 12 Gas Cooktops, 2 Burner Drop-in Propane/Natural Gas Cooker, 12 Inch Stainless Steel Gas Stove Top Dual Fuel Easy to Clean
# Stain-resistant Stainless Steel Surface + Perfect Dimension This gas cooktop has a stain-resistant stainless steel surface with 11.4'' x 19.7'' x x 500mm x 100mm) dimension. The built in size is 10.7'' x x 480mm) that can fit your kitchen perfectly. Melt-proof Knob Controls + High Power Burners This 12 inch drop-in gas cooker has 2 high efficiency sealed burners, one semi-rapid burner and a rapid burner. The melt-proof knobs are made of bakelite and the heavy cast iron pan support is more stable.. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Cuisinart Gold Tone Coffee Filter f/ Coffee Maker
# Cuisinart Gold Tone Coffee Filter f/ Coffee MakerThis replacement filter fits in the and the coffee makers.Model # GTF 6 packs per case 2 filters per pack Height 4 Width 5 Length 5 Shipping weight.11 lb 900479 Model # GTF 6 packs per case 2 filters per pack Height 4 Width 5 Weight 1.6 ounces, Dimensions 4.8 x 4.8 x 3.7 inches, model number GTF, Is Discontinued No, Assembled Height 3.7 inches, Assembled Width 4.8 inches, Weight 0.3 Pounds, Rank Health & Household Disposable Coffee Filters 1462, Paper & Plastic
#
# Price is. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Tier1 MWF Refrigerator Water Filter 6-pk | Replacement for GE SmartWater MWFP, MWFA, GWF, GWFA, HWF, Kenmore 9991, WSG-1, Fridge Filter
# Replacement Filter Models This water cartridge is a replacement for MWFP, MWF, MWFA, HWF, FXRT, MXRC, HXRT, FXRC, WF287, WSG-1, WF287, GWF, GWFA, GWF01, GWF06, MWFAP, MWFINT, HWFA, WMF, 9991, 46 9991, 9996, 46 9996, GF-MWF, CF8, PF8, CW-. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Broan Motor Assembly for 40000 Series Range Hoods
# Product Description Genuine Broan fan Motor assembly This Broan replacement fan motor assembly is designed to be used in the 40000 Series Range Hoods. From the Manufacturer Genuine Broan fan Motor assembly This Broan replacement fan motor assembly is designed to be used in the 40000 Series Range Hoods. Genuine Broan fan motor assembly This Broan replacement fan motor assembly is designed to be used in the 40000 Series Range Hoods Durable OEM replacement part Manufacturer Q2U LLC, formerly Davelle, Part Weight 1 Pounds, Dimensions 6 x 7 x 5 inches, model number Is Discontinued No, Color White, Material ABS, Voltage 12 Volts, Quantity 1, Rank Tools
#
# . This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# BUNN 12-Cup Commercial Coffee Filters, 1000 count,
# Manufactured from high quality, heavy weight paper, so the water flows properly through coffee/tea. Uniquely designed for strength so the sides are taller and you don't end up with overflow and grounds in your coffee. Produced using an elemental chlorine-free (ECF) bleaching method. 2 bags of 500 filters each High-quality paper prevents grounds from filtering through Tall sides minimize overflow. Base measures 4-1/4 inches Fits most 12-cup drip and airpot brewers. 50 filters per cluster Dimensions 15.75 x 7.75 x 7.75 inches, Weight 4 pounds, Department Mens, Manufacturer Bunn-O-Matic Corporation, Country of Origin. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Refrigerator Water Filter - Replacement Cartridge for 644845 - Compatible Bosch 644845 & Thermador 740570 - 1pk
# Refrigerator replacement filter for 644845 - Compatible Bosch 644845 & Thermador 740570 - 1pk Replacement for Bosh / Cuno Ultra Clarity 644845 Replacement for Thermador 740570 1 filter Made in USA FACTORY SEALED Dimensions 2.3 x 2.2 x 10.5 inches, Weight 9.6 ounces, Manufacturer Great Value, model number SGF BO90, Rank Tools & Home Improvement In-Refrigerator Water Filters 6883, Is. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# 119367 Reusable Coffee Filter Compatible with My K-Cup Keurig 2.0 K475 with Cover Lid K200 K250 K300 K350 K400 K450 K460 K460 K500 K550 K560 K575 Coffee Brewers Small Black Updated Model
# ✅UNIVERSAL FIT K475 Reusable Coffee Filter 119367 Compatible with My K-Cup Keurig 2.0 ✅WORK FOR BRAND Compatible with Keurig 2.0 k200, k250, k300, k350, k400, k450, k500, k550, k560,. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# 9083 Refrigerator Water Replacement Compatible with Kenmore Water 469083 9030 9020, 3-Pack
# Refrigerator water fiter 9083 fits Kenmore refrigerator models 4152, 4402, 4403, 4432, 4442, 4443, 4602, 4603, 5022, 5027, 5028, 5029, 5034, 5044, 5045, 5110, 5111, 5112, 5159, 5408,. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Compatible Dryer Belt for Maytag Part Number Kenmore / Sears Crosley Dryers
# Compatible Dryer Belt for Maytag Part Number Kenmore / Sears Crosley Dryers Replaces 5 rib wider belt. Matching idler pulley and rear support rollers Part Number 341241 replaces 2008, 8206, 8210, 920H4, 920H5, AP32, LB276, LB279, Belt fixes the following symptoms Dryer Drum Belt For 341241 Dryer Belt. Length Width 1/4. 4 rib. Dimensions 7 x 6.6 x 1.2 inches, Weight 2.39 ounces, model number Rank Tools & Home Improvement Dryer Replacement Parts 4. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Cuisinart Filter Basket
# This is an O.E.M. authorized part. Fits various Cuisinart models. OEM Part Number Fits the following models 3066 3067 3093 3094 3111 3112 KF140 KF437. Item is manufactured in United States. This is an O.E.M. authorized part Fits various Cuisinart models OEM Part Number Fits the following models 3066 3067 3093 3094 3111 3112 KF140 KF437 Item is manufactured in United States Dimensions 1 x 1 x 1 inches, Weight 2.39 ounces, Manufacturer C. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Edgewater Parts Refrigerator Ice Maker Compatible with Sub Zero Refrigerator
# Ice Maker Refrigerator Ice Maker For Sub Zero Refrigerator Includes Instructions And Help Guide; 8 Cube Fits These Sub Zero Models 201FD, 3211, 2511, 241, 251, 361, 501F, 511, 532, 542, 550, 561, 590, 801 Replaces 1 Year Warranty Brand Edgewater Parts, Model Name Refrigerator ice maker, Dimensions 14 x 4 x 5 inches; 2.7 Pounds, Capacity 1 Quarts, Wattage 15 watts, Is Discontinued No, model number Available December 17, . This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Hario V60 Size 03 Coffee Paper Filters Boxed (Total of 40 Sheets) (Natural)
# Hario 03 40 Count Boxed Coffee Paper Filters Size Size 03 Style Name 40 count Box Capacity 1-6 cups About Us Since 1921 The company has been dedicated to the design, production, and sale We began our history as a manufacturer of laboratory glassware. In 1964, we expanded our production to household items, starting with the coffee syphon. of heatproof glass since it was founded in 1921 and is the only heatproof glass manufacturer in Japan to have a factory. We also began producing lenses for automotive headlights in 1980. Today, We continue to make a variety of items, from microwave-. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# General Electric Range/Stove/Oven End Cap
# Product Description This is a Genuine Replacement Part, The Model Number and Name for The Following Item General Electric Range/stove/oven End Cap. From the Manufacturer This is a Genuine Replacement Part,The Model Number and Name for The Following Item General Electric Range/stove/oven End Cap General Electric This Is A Genuine Replacement Part Cooktop-Accessories From The Brand Name Ge Manufacturer General Electric, Part Weight 2.4 ounces, Dimensions 14 x 9.5 x 1.2 inches, model number Quantity 1, Rank Tools & Home Improvement Parts & Accessories 97207, Domestic Shipping can be shipped within U.S., International Shipping This item can be shipped to select countries outside of the U.S. Learn More, Available February
#
# Price. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# 2-Pack Drum Support Roller Kit & 306508 Bearing Kit Replacement for Maytag Dryer - Compatible with 303373 Drum Roller Wheel & 306508 Tumbler Bearing Kit Front Glide Rivets and Pad
# 2-Pack UpStart Components Replacement Drum Support Roller Kit & 306508 Bearing Kit for Maytag DryerPlease note This is an UpStart Components Brand replacement part, NOT an OEM product. All mentions of brand names or model descriptions are made strictly to illustrate compatibility. All brand names and logos are registered trademarks of their respective owners. This product is not affiliated with any brands and is not covered under any warranties offered by the original manufacturers. Any warranties for this product are offered solely by UpStart Components. UpStart Components Replacement Drum Support Roller Kit & 30. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# EdgeStar 15 Inch Wide 25 Bottle Built-In Wine Cooler
# PLEASE NOTE 25 bottle capacity is ONLY achieved when ALL stored bottles are standard sized 750ml 2.75 Bordeaux bottles, to accommodate larger bottles a shelf will need to be removed. Temperature Range 40-65� F; Digital temperature control w/ blue LED display; Single zone cooling; High/low temp alarm; Door ajar alarm Internal fan to evenly circulate air; Auto defrost; Built-in carbon filter; Dimensions 32 H x 15 W x 23 3/4 D Black dotted door tinting; Blue interior LED lighting; Reversible double-paned tempered glass door Undercounter or freestanding application; Rubber bushing absorbs vibration and noise from compressor Manufacturer EdgeStar, Part Weight
#
# Price is. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Whirlpool 56000 Blower Wheel, White
# Product Description The high quality Whirlpool Blower Wheel (56000 ) attaches to the drive motor shaft. The Blower Wheel blows air through the drum and out through the exhaust vent and replaces Please be aware that it is recommended to use saftey equipment and to disconnect the appliance from all utilities prior to any service or repair. Please refer to your owners manual to confirm part numbers and for instructions as some repairs require a trained service professional to complete. From the Manufacturer This is a genuine replacement part. The model number and name for the following item is Whirlpool 56000 Blower Wheel Manufacturer model # 56000 Genuine Replacement Part Whirlpool item Manufacturer model # 56000 Genuine Replacement Part Anderson Cooper & Brass item Manufacturer
#
# Price is. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Replacement Aluminum Filters Compatible with Broan Broan Sears/Kenmore x x 3/8 (2 PT LS)
# Filter Everything's A61070 replacement aluminum range filters are compatible with many models, including Broan Broan Sears/Kenmore Dimensions measure 11-7/8 x x 3/8 (2 PT LS) inches. Sold as a Replacement Aluminum Filters Compatible with Broan Broan Sears/Kenmore Dimensions measure 11-7/8 x x 3/8 (2 PT LS) inches 2-Pack Manufacturer Filter Everything, Part 2 Pack, Weight 8.8 ounces, Dimensions 20.5 x 12 x 1 inches, Size 11-7/8 x x 3/8 (2 PT LS) Material Aluminum,. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# #4 Cone Shape Permanent Coffee Filter (1) (1 Pack)
# Fits coffeemakers requiring #4 (10-12 cup) cone shape coffee filter. A great alternative to paper filters. Bulk packaging. No Retail Box. 10-12 Cup Permanent Cone Shape Coffee Filter. Fits all coffeemakers using #4 cone filters. Made from Surgical-Grade Stainless Steel. Dishwasher Safe For use with models Series, Series Series, and CHW-12 Fits models 176, 180, 197, 198, 199, 229, FMC2, 536 and 538. Does NOT fit Ninja coffee makers Generic Reusable GoldTone Filter eliminates paper coffee filters and fits any coffeemaker using Size 4 coffee filter Dimensions 5. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Range Hood Insert 30, AROAN Built-in Range Hood with Ducted/Ductless Convertible, Stainless Steel Vent Hood for Kitchen with 900 CFM, 4 Speed Soft Touch Switch, Aluminum Filters, Carbon
# √ 10 years warranty on motor, 5 years warranty on switch control and LED lamps √ 900CFM powerful airflow capacity √ Brushed stainless steel √ Four-speed soft touch electronic switch control (5 years warranty) √ NO button noise √ 3 minutes timer (Delayed Auto Shut-off Function) √ 2pcs dishwasher-safe aluminum filters √ 2pcs 2W brightness adjustable LED lamps on the front corner (adjustable brightness) √ Ultra-quiet powerful motor √ Motor Wattage 230W √ Noise levels Low speed 40 db., High speed . This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# LifeSupplyUSA Humidifier Filter Compatible with Protec WF2 Extended Life Vicks WF2; Fits Vicks V3100, V3900 Series, V3700, Sunbeam 1118 Series & Honeywell Series;
# Compatible with Protec WF2 Extended Life Vicks WF2; Fits Vicks V3100, V3900 Series, V3700, Sunbeam 1118 Series & Honeywell Series; For best results, change air filter at least once per season or more often depending on air quality and use. Traps Water Impurities & Dissolved Solids Before They Become Airborne Brand New Individually Sealed By LifeSupplyUSA Dimensions 12\ L x 8.5\ W x 5\ Th, Weight 1.6 ounces,
#
# . This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# VBGK Electric cooktop 30 inch,Electric Stove burner,Built-in and Countertop Electric Stove Top, LED Touch Heating Level, Timer & Kid Safety Lock, Touch 7200W Cooktop
# 220V- 240v Electric Radiant Cooktop 4 burner electric cooktop and 2000W and The 4 burners LED Touch Screen. It can heat up quickly and help to prepare different delicious foods at the same time. Save time and energy. Whether it’s a weekend gathering or friends' visit, you can easily finish a big meal to entertain them. TIPS The cooktop is without plug. Built-in Cooktop need to be conected to hard 9 Level Setting Drop-in Electric Cooktop The electric cooktop 30 inch, equipped with
#
# Price. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# SP22YA Electric Range Burner Surface Element by Beaquicy - Replacement for G-E Hot-point Ken-more Ranges/Stoves - Includes 1 8-Inch and 3 6-Inch Burners
# PRODUCT DESCRIPTION SP22YA Electric Range Burner Surface Element set SP22YA Electric Range Burner Surface Element set is made of non-metallic materials with high resistivity, small temperature coefficient of resistance, small deformation at high temperature and not easy to embrittle.Package includes 1 x Surface Element, 3 x Surface Burner. The 8-inch burner element with 4 turns is used with 240V 2100W, 6-inch surface element with 3 turns is used with 240V 1250W. PACKAGE INCLUDE 1 Surface Element. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Henny Penny 37230 Drop Shelf Bracket
# Product Description 37230, Drop Shelf Bracket, Hennie Penny is committed to developing new concepts, value-added services and customized solutions for foodservice operators. From the Manufacturer 37230, Drop Shelf Bracket, Henny Penny is committed to developing new concepts, value-added services and customized solutions for foodservice operators Genuine Oem Replacement Part Hennie Penny Is Committed To Developing New Concepts, Value-Added Services And Customized Solutions For Foodservice Operators Use Genuine Oem Parts For Safety Reliability And Performance From The Brand Name Henny Penny Manufacturer Henny Penny, Part 37230, Weight 11.2 ounces, Dimensions 7 x 5 x 4 inches, model number 37230, Thickness 6. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Star Motor/Fan Assembly 120 Volt
# Product Description MOTOR/FAN ASSEMBLY 120 VOLT. Star Genuine OEM replacement part. Since 1921, the Star Manufacturing Company has been making reliable, innovative commercial machines for cooking, serving and preparing food. Use genuine OEM parts for safety reliability and performance. From the Manufacturer MOTOR/FAN ASSEMBLY 120 VOLT. Star Genuine OEM replacement part. Since 1921, the Star Manufacturing Company has been making reliable, innovative commercial machines for cooking, serving and preparing food. Use genuine OEM parts for safety reliability and performance. Genuine OEM replacement part Since 1921, the Star Manufacturing Company has been making reliable, innovative commercial machines for cooking, serving and preparing food Use genuine OEM parts for safety reliability and performance Package dimensions 5.
#
# Price. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# LG Genuine OEM Door Shelf Bin (White) for LGRefrigerators
# This high quality Genuine OEM LG Door Shelf Bin attaches to the inside of the refrigerator door and typically holds jars and bottles. The White Door Shelf Bin has a clear front panel to promote visibility of shelf contents. Life's Good when choosing Genuine LG OEM Factory parts for your LG appliances. Please be aware that it is recommended to disconnect the appliance from all utilities prior to installation of the Door Shelf Bin.LG Refrigerator Models Compatible with the LG Door Shelf Bin 73132, 71032, 71036, 72302, 71039, 71033, 72309, 72303, 73139, 73. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# 280187 Washer Drain Pump Motor Only Replacement for Maytag Washing Machine - Compatible with Water Pump - UpStart Components Brand
# UpStart Components Replacement 280187 Washer Drain Pump Motor Only for Maytag Washing MachinePlease note This is an UpStart Components Brand replacement part, NOT an OEM product. All mentions of brand names or model descriptions are made strictly to illustrate compatibility. All brand names and logos are registered trademarks of their respective owners. This product is not affiliated with any brands and is not covered under any warranties offered by the original manufacturers. Any warranties for this product are offered solely by UpStart Components. UpStart Components Replacement 280187 Washer Drain Pump Motor Only for Maytag Washing Machine Ultra durable, high quality material resists wear and tear over time. Easy at-home installation. An affordable. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# 2-Pack Air Filter Factory Replacement For Dacor 62978 Range Hood Aluminum Foil Mesh Grease Filters 11-7/8 x x 3/8 Inches
# Authentic Air Filter Factory Brand Product UPC This non-OEM replacement mesh filter set is made in the USA and designed, as well as distributed solely by Air Filter Factory. This is not a OEM product and is not covered under any manufacturer's warranty. The brand name and logo are the registered trademarks of their respective owners. Any use of the brand name or model designation for this product is made solely for purposes of demonstrating compatibility. Part Number – 62978 Range Hood Grease Filter Replacement For Range Hood. Package Contains For Easy And Convenient Replacement. Quality – Proudly Made In The USA Our Compatible 62978 Aluminum Mesh
#
# Price is. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# ZERO 279838 & & Dryer Heating Element Kit Compatible with Whirlpool Dryer
# Package includes 1 PC 279838 dryer heating element, 1 PC dryer thermostat, 1 PC dryer thermal fuse 279838 heating element is rated at 5400 Watts 240 Volts and has 2- 5/16 male terminals. PREMIUM QUALITY - The replacement part is made from durable high quality material and well-tested by the manufacturer. Non original aftermarket part. Fits OEM Standards!Guaranteed to Exceed OEM Requirements. MONEY BACK GUARANTEE - For any reason you're not completely satisfied, you can ask for a replacement or full refund, no questions asked. Manufacturer Long Term, Part 279838 & & Weight 1.83 pounds,. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Ansoon MP22YA Electric Range Burner Coil Element Unit Set (2 pcs MP15YA 6 and 2 pcs MP21YA 8 ) with 4 Pack 330031 Surface Element Receptacle Kit Replacement Compatible for Whirlpool Ranges/Stoves
# Product Specification MP15YA * 2 pcs --- 6in (1500 Watt 230 Volts 4 Turns) MP21YA * 2 pcs --- 8in (2100 Watt 230 Volts 5 Turns) 330031 Range Receptacle Burner Kit * 4 packs --- One set includes Receptacle Block *1, High Temp Wire Leads *2, Two Different Metal Brackets to match the old one, Heat Shrink *2, and instructions. Compatible for Brands Compatible. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Smalibal Glass Egg Holder for Refrigerator, Egg Storage Box High Capacity Anti-Collision 15 Grid Refrigerator Egg Box Kitchen Accessories Blue
# ...
#
# Price. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Repairwares Clothes Dryer Belt 341241 695055 349533 694088
# A clothes dryer belt transfers power from the motor to the tumbler drum. When this part fails or begins to fail, the dryer may become noisy, fail to tumble, or fail to start. Product is universal and may differ from original. Always take appropriate safety precautions when performing troubleshooting or repairs.Universal replacement for many part numbers, including 2008 341241 345473 345473 349533 349533 529597 660996 660997 661561 6. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# PRYSM Range Igniter Replaces IGN5, 814269
# This Range Igniter Directly Replaces the following Part #'s IGN5, 10064, 10222, 12872, GR411, IGN-4, IGN-5, IGN-8, IGN5, Quality you can Trust - All Snap Products are made with premium materials and are tested so they last Buy with Confidence - Snap Supply Parts always come with a 1 Year Warranty Installation Instructions available on our website Compatible with all major brands Manufacturer PRYSM, Part Weight 5.6 ounces, Dimensions 10.5 x 3.25 x 2.25 inches, Country of Origin USA, Is Discontinued No, Rank Tools & Home Improvement . This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Portable Compact Dryer Blower Fan Belt for Panda Sonya
# high quality replacement blower fan belts are compatible for dryer models Panda (2.65 cu.ft Dryer) Panda (3.65 cu.ft Dryer) Panda (2.65 cu.ft Dryer) Panda (3.75 cu.ft Dryer) Sonya Sonya Condition New A brand-new, unused, unopened, undamaged item in its original packaging Model Color Green Type BELT Compatible Model Brand Name showingo, Model Info Weight 1.44 ounces, Dimensions 8.15 x 4.92 x 0.63 inches, model number Part Color green, Compatible Device Washing Machine, Rank Tools & Home Improvement Washer Parts & Accessories 1757, Available September 22, 2020, Brand
#
# Price is. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# New OEM Production for LG Refrigerator Water Inlet Valve Replacement Part by What'sUp? Replaces
# What's Up? AUTHORIZED OEM REPLACEMENT Part No Fits Models etc. Replaces part numbers Fix Common Symptoms You need to replace this part if your refrigerator won’t dispense water or leaks water onto the floor. It will restore proper water flow to your refrigerator’s water dispenser. Easy to install You can easily find the installation method by searching the online video site for the part number. See product description for list of compatible models Manufacturer by OEM factory, Part Weight 5.9 ounces, Dimensions 3.66 x 3.58 x 3.5 inches, model number Rank Appliances 3217, Refrigerators 804, Available February 18, 2021
#
# Price is. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Camco 00583 6 Universal Black Porcelain Drip Pan
# From the Manufacturer A clean drip pan provides more even cooking. This universal, 6-Inch black porcelain drip pan for electric ranges offers a quick and easy way to improve cooking results while enhancing the overall appearance of your stovetop. Resists scratches, stains and odors Dishwasher and self-cleaning oven safe Laboratory tested to 1000 deg F Manufacturer Camco, Brand Camco, Model 00583, Weight 2.4 ounces, Dimensions 8.8 x 7 x 9 inches, model number 00583, Is Discontinued No, Manufacturer Part 583, Rank Tools & Home Improvement Range Replacement Drip Pans 914, Available January 16, 2007
#
# Price. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Aprilaire 4332 Damper Assembly
# The Aprilaire 4332 damper assembly is designed for Aprilaire models 400, 500, 550, 550a, 558 and 600 humidifiers. Aprilaire 4332 damper assembly - includes damper blade, spring and knob. fits models 600, 500, 400 The Aprilaire 4332 humidifier damper assembly is a damper assembly kit that includes a damper blade, spring and knob The Aprilaire 4332 damper assembly is designed for Aprilaire models 400, 500, 550, 550a, 558 and 600 humidifiers. The Apri. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Danby Designer Energy Star Feet Upright Freezer in White,
# The Danby Designer Energy Star 8. feet upright freezer easily integrates into any setting and is ideal for for smaller families and couples. There's plenty of frozen food space with three quick-freeze shelves and four handy door bins. With a reversible door hinge, an integrated door handle and a smooth-back design, this little freezer will fit almost anywhere. 8. feet capacity upright freezer with manual defrost Energy Star compliance saves you money (247 kWh) Tight fitting door seal keeps all the cooling power locked inside Easy-to-use mechanical thermostat 3 quick freeze shelves and 4 door bins keep you organized Brand Name Danby, Model Info Weight 123.7 pounds, Dimensions 25.7\ D x 23.9
#
# Price. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Temperature and Humidity Controller (US Model)
# Controller measures and controls both humidity and temperature. Two independent outputs. On/off control. Control mode humidifying or dehumidifying, heating or cooling. Reliable sensor can be used in high humidity (>85% RH) and condensing environments. Plug-n-play controller. No wiring is needed. Has high and low limit alarms. Build-in audio buzzer. Dimensions 3.58 x 1.81 x 5.51 inches, Weight 1.2 Pounds, Manufacturer Auber Instruments, model number Rank Tools & Home Improvement Humidifier Accessories 183, Is Discontinued No, Available August 16, 2016, Color Black, Brand AUBER, Dimensions LxWxH 3.58 x 1
#
# Price is. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# GE Conversion Kit
# Product Description This is a Genuine Replacement Part, The Model Number and Name for The Following Item General Electric Range/stove/oven Conversion Kit. From the Manufacturer This is a Genuine Replacement Part,The Model Number and Name for The Following Item General Electric Range/stove/oven Conversion Kit General Electric This is a genuine replacement part Cooktop-accessories Manufacturer General Electric, Part Weight 0.32 ounces, Dimensions 8 x 7.5 x 0.3 inches, Country of Origin China, model number Is Discontinued No, Quantity 1, Included Components Single GE Conversion Kit, Rank Tools & Home Improvement Parts & Accessories 30254, Domestic Shipping can be shipped within U.S., International Shipping This item can be shipped to select countries outside of the U.S. Learn
#
# Price. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# EFP Humidifier Filter Replacement Wick for Kenmore 14912, Essick Emerson MoistAir 1211, 2412, HDC-2R Quiet Comfort - 6 Filters
# SIX PACK Includes 6 High Quality Aftermarket Replacement EFP Humidifier Wick Filters for Kenmore, Emerson, Essick, Quiet Comfort and Moistair - Dimensions 11 5/16 by 6 1/2 by 2 1/4 - Fits models 14912, 1211, 2412, 14909, E2R, HDC-2R HEALTHY AIR Replacing your humidifier filter regularly ensures that harmful particles are removed from the water before it is released into the air. QUALITY YOU CAN TRUST EFP High. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Lambro Industries 306 Aluminum Duct, 6 in x 8 ft,Silver
# Flexible Semi-Rigid duct expands to 8' long for clothes dryer, bathroom, kitchen or attic venting case dimensions 28.5 H x 13.5 W x 13.5 D. Item Weight 1.05 lb Country of Origin United States Brand name Lambro Item Dimensions 23.4 L x 7.2 W x 23.7 H Brand Name Lambro, Model Info 306, Weight 1.1 Pounds, Dimensions 96\ L x 6\ W, Country of Origin USA, model number 306, Is Discontinued No, Part 306, Color Silver, Material Type Aluminum, Included Components Product, guide, Rank. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Luma Comfort Clear Ice Cube Maker Machine | First Cubes In 15 Minutes, 28 lbs. of Ice in 24 Hours | Countertop Portable Design in Stainless Steel -
# Product Description This small ice maker has an attractive and compact design that's perfect for the countertop. This simple, hassle-free ice dispenser requires no installation, is easy to set up and control. Get your ice fast, with a quick 15 minute freezing time per cycle. The clear, restaurant-quality ice that you'll get with this ice maker not only looks great in any drink, but it also melts five times slower than cloudy ice. This portable ice maker can make up to 28lbs of ice per day.Luma Comfort is a manufacturer of home appliances and home comfort products, based in Southern California. The
#
# Price. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Reusable K Cups For Keurig with 100 Counts Paper K Cup Filters, Compatible with Keurig Reusable Coffee Pods Filter 2 Pack, Refillable Single K CUP for Keurig Coffee Maker 2.0 & 1.0
# ★ NEWEST CUP LID DESIGN,Vast Compatibility for Keurig 2.0 and 1.0 K200, K250, K300, K350, K360, K400, K450, K460, K500, K550, K560, K15, K31, K40, K44, K45, K50, K60, K66, K70, K77, K80, K. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Supplying Demand 814362 330169 Electric Range Control Knob 9 Piece Replacement Set Model Specific Not Universal
# Please see Model Number fitment information at the bottom of this page before placing your order for this part. Alternate part numbers include 2674, and Set includes (9) black knobs (4) Surface, (3) Selector, and (2) Oven thermostat | NOT universal | Adapters NOT included | Fits model specific ranges It is important to disconnect your appliance from the power and gas supply before servicing. Supplying Demand replacement parts are compatible with Major Brands, but you should always verify fitment with your specific model. We have included a video in the product gallery to help you find your model number and information in the description below. SD products come in Supplying Demand packaging
#
# . This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# NewAir Beverage Refrigerator Built In Cooler with 96 Can Capacity Soda Beer Fridge, Black Stainless Steel
# The New Air 15 Built-In 96 Can Beverage Fridge slides easily between standard base cabinets in your kitchen. It can also stand alone anywhere you like. This single-zone fridge features precision temperature controls that let you chill 96 standard cans all the way down to 37 degrees for icy refreshment. BUILT-IN OR FREESTANDING - The quiet, front-venting compressor system allows this wine fridge to fit snugly under standard kitchen counters. Just slide it into place for a sleek, integrated look that blends perfectly with your cabinetry — or let it stand alone. COMPACT DESIGN - Even though it's only 15 inches wide, this beverage fridge still holds up to 96
#
# Price is. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/trl/trainer/utils.py:139: UserWarning: Could not find response key `Price is $` in the following instance: <bos>How much does this cost to the nearest dollar?
#
# Quality (NEW) Motor for Nutone brоan Vent Bath Fan Model 9415 9415, K5895, K5894, 9415F, 9415H, 9415N, 9425, 9425F, 9425H
# Replacement fan motor assembly Replaces Broan Nutone part numbers Fits Broan Nutone model 9415, K5895, K5894, 9415F, 9415H, 9415N, 9425, 9425F, 9425H Includes single speed motor, 3-3/4 x 2 blower. This instance will be ignored in loss calculation. Note, if this happens often, consider increasing the `max_seq_length`.
#   warnings.warn(
# wandb: Adding directory to artifact (pricer-2026-02-16_06.04.59/checkpoint-5000)... Done. 0.3s
# README.md:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# No files have been modified since last commit. Skipping to prevent empty commit.
# Saved to the hub: pricer-2026-02-16_06.04.59

# %%
if LOG_TO_WANDB:
  wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁▁▁▁▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇██</td></tr><tr><td>train/global_step</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇█</td></tr><tr><td>train/grad_norm</td><td>▁▂▁▁▂▂▂▁▃▁▁▁▂▁▂▂▂▁▃▂▁▂▂▂▂▂▂▂▂▂▂▂▂▁▁▂▂▂▂█</td></tr><tr><td>train/learning_rate</td><td>███████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▄▅▄▄▄▂▃▃▂▃▃▂▂▃▃▂▃▂▃▃▂▂▃▂▄▂▃▂▃▂▁▂▂▃▁▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>total_flos</td><td>4.211551936339968e+16</td></tr><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/global_step</td><td>5000</td></tr><tr><td>train/grad_norm</td><td>12.24025</td></tr><tr><td>train/learning_rate</td><td>0</td></tr><tr><td>train/loss</td><td>0.8937</td></tr><tr><td>train_loss</td><td>0.96097</td></tr><tr><td>train_runtime</td><td>8230.8312</td></tr><tr><td>train_samples_per_second</td><td>2.43</td></tr><tr><td>train_steps_per_second</td><td>0.607</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">2026-02-16_06.04.59</strong> at: <a href='https://wandb.ai/md-marufmullah50-military-institute-of-science-and-techn/pricer/runs/wahehgzw' target="_blank">https://wandb.ai/md-marufmullah50-military-institute-of-science-and-techn/pricer/runs/wahehgzw</a><br> View project at: <a href='https://wandb.ai/md-marufmullah50-military-institute-of-science-and-techn/pricer' target="_blank">https://wandb.ai/md-marufmullah50-military-institute-of-science-and-techn/pricer</a><br>Synced 5 W&B file(s), 0 media file(s), 29 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260216_060518-wahehgzw/logs</code>
