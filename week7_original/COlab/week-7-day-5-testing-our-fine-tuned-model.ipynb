# %% [markdown]
# ## Predict Product Prices
#
# ### And now, to evaluate our fine-tuned open source model

# %%
# pip installs

# !pip install -q --upgrade torch==2.5.1+cu124 torchvision==0.20.1+cu124 torchaudio==2.5.1+cu124 --index-url https://download.pytorch.org/whl/cu124
# !pip install -q --upgrade requests==2.32.3 bitsandbytes==0.46.0 transformers==4.48.3 accelerate==1.3.0 datasets==3.2.0 peft==0.14.0 trl==0.14.0 matplotlib wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.2/908.2 MB 2.0 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 5.5 MB/s eta 0:00:000:00:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 106.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 75.3 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.1 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.9 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 34.8 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 14.9 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.4 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.4 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 3.8 MB/s eta 0:00:00:00:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 2.6 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 48.7 MB/s eta 0:00:0000:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# fastai 2.8.4 requires fastcore<1.9,>=1.8.0, but you have fastcore 1.11.3 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 27.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 100.9 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 23.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 24.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 kB 30.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 kB 29.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 111.1 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 81.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 99.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.22.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# ydata-profiling 4.18.1 requires matplotlib<=3.10,>=3.5, but you have matplotlib 3.10.8 which is incompatible.
# google-adk 1.22.1 requires requests<3.0.0,>=2.32.4, but you have requests 2.32.3 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.47.0 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.3 which is incompatible.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# gradio 5.49.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.5 which is incompatible.
# bigframes 2.26.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# fastai 2.8.4 requires fastcore<1.9,>=1.8.0, but you have fastcore 1.11.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
# imports

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import torch.nn.functional as F
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, set_seed
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
from peft import PeftModel
import matplotlib.pyplot as plt
# Out:
# 2026-02-16 08:45:17.134344: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771231517.328551      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771231517.379600      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771231517.840178      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771231517.840216      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771231517.840219      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771231517.840221      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# Constants

BASE_MODEL = "google/codegemma-2b"
PROJECT_NAME = "pricer"
HF_USER = "marufmullah50" # your HF name here!



# The run itself

RUN_NAME = "2026-02-16_06.04.59"
PROJECT_RUN_NAME = f"{PROJECT_NAME}-{RUN_NAME}"
REVISION = "6e95e86dc45991331ebde52c805d5a65aff5ab7a" # or REVISION = None
FINETUNED_MODEL = f"{HF_USER}/{PROJECT_RUN_NAME}"

# Uncomment this line if you wish to use my model
# FINETUNED_MODEL = f"ed-donner/{PROJECT_RUN_NAME}"



# Data

DATASET_NAME = f"{HF_USER}/lite-data"

# Or just use the one I've uploaded
# DATASET_NAME = "ed-donner/pricer-data"

# Hyperparameters for QLoRA

QUANT_4_BIT = True

# %matplotlib inline

# Used for writing to output in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %% [markdown]
# ### Log in to HuggingFace
#
# If you don't already have a HuggingFace account, visit https://huggingface.co to sign up and create a token.
#
# Then select the Secrets for this Notebook by clicking on the key icon in the left, and add a new secret called `HF_TOKEN` with the value as your token.

# %%
# Log in to HuggingFace

import os

from kaggle_secrets import UserSecretsClient




# Get secret from Kaggle Secrets
user_secrets = UserSecretsClient()
from huggingface_hub import login

hf_token = user_secrets.get_secret('HF_TOKEN')
login(token=hf_token, add_to_git_credential=True)
# Out:
# Token has not been saved to git credential helper.
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# README.md:   0%|          | 0.00/412 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/9.73M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/771k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
test[0]
# Out:
# {'text': "How much does this cost to the nearest dollar?\n\nSetpower Insulated Protective Cover for AJ30 Portable Refrigerator Freezer, suitable for AJ30 Only\nInsulation & Waterproof well-made insulation could save battery power and improve cooling efficiency by preventing cold air from flowing away. Durable and Foldable with its oxford cloth outer layer, it's durable and protects your portable refrigerator from scratches and dust. Expanded Bag for Accessories two expanded bags on its side, expand space to store the other accessories. Great Ventilation a hollowed design for positions of vents doesn't affect the ventilation. Attention this insulated cover is ONLY suitable for SetPower AJ30 portable refrigerator. FIT TO AJ30 ONLY. Brand Name Setpower, Model Info AJ30 COVER, model number AJ30 COVER, Installation Type Freestanding, Part AJ30 cover, Special Features Portable, Color\n\nPrice is $",
#  'price': 65.99}

# %% [markdown]
# ## Now load the Tokenizer and Model

# %%
# pick the right quantization (thank you Robert M. for spotting the bug with the 8 bit version!)

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

# Load the fine-tuned model with PEFT
if REVISION:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL, revision=REVISION)
else:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL)


print(f"Memory footprint: {fine_tuned_model.get_memory_footprint() / 1e6:.1f} MB")
# Out:
# tokenizer_config.json:   0%|          | 0.00/46.3k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/555 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/668 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/29.5M [00:00<?, ?B/s]
# Memory footprint: 2069.1 MB

# %%
fine_tuned_model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): GemmaForCausalLM(
#       (model): GemmaModel(
#         (embed_tokens): Embedding(256000, 2048, padding_idx=0)
#         (layers): ModuleList(
#           (0-17): 18 x GemmaDecoderLayer(
#             (self_attn): GemmaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=256, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=256, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): GemmaMLP(
#               (gate_proj): Linear4bit(in_features=2048, out_features=16384, bias=False)
#               (up_proj): Linear4bit(in_features=2048, out_features=16384, bias=False)
#               (down_proj): Linear4bit(in_features=16384, out_features=2048, bias=False)
#               (act_fn): GELUActivation()
#             )
#             (input_layernorm): GemmaRMSNorm((2048,), eps=1e-06)
#             (post_attention_layernorm): GemmaRMSNorm((2048,), eps=1e-06)
#           )
#         )
#         (norm): GemmaRMSNorm((2048,), eps=1e-06)
#         (rotary_emb): GemmaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=2048, out_features=256000, bias=False)
#     )
#   )
# )

# %% [markdown]
# # THE MOMENT OF TRUTH!
#
# ## Use the model in inference mode
#
# Remember, GPT-4o had an average error of \$76.
# Llama 3.1 base model had an average error of \$396.
# This human had an error of \$127.
#
# ## Caveat
#
# Keep in mind that prices of goods vary considerably; the model can't predict things like sale prices that it doesn't have any information about.

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
extract_price("Price is $a fabulous 899.99 or so")
# Out:
# 899.99

# %%
# Original prediction function takes the most likely next token

def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = fine_tuned_model.generate(inputs, attention_mask=attention_mask, max_new_tokens=3, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    return extract_price(response)

# %%
# An improved prediction function takes a weighted average of the top 3 choices
# This code would be more complex if we couldn't take advantage of the fact
# That Llama generates 1 token for any 3 digit number

top_K = 3

def improved_model_predict(prompt, device="cuda"):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    attention_mask = torch.ones(inputs.shape, device=device)

    with torch.no_grad():
        outputs = fine_tuned_model(inputs, attention_mask=attention_mask)
        next_token_logits = outputs.logits[:, -1, :].to('cpu')

    next_token_probs = F.softmax(next_token_logits, dim=-1)
    top_prob, top_token_id = next_token_probs.topk(top_K)
    prices, weights = [], []
    for i in range(top_K):
      predicted_token = tokenizer.decode(top_token_id[0][i])
      probability = top_prob[0][i]
      try:
        result = float(predicted_token)
      except ValueError as e:
        result = 0.0
      if result > 0:
        prices.append(result)
        weights.append(probability)
    if not prices:
      return 0.0, 0.0
    total = sum(weights)
    weighted_prices = [price * weight / total for price, weight in zip(prices, weights)]
    return sum(weighted_prices).item()

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(improved_model_predict, test)
# Out:
# 1: Guess: $1.83 Truth: $65.99 Error: $64.16 SLE: 10.00 Item: Setpower Insulated P...
# 2: Guess: $3.12 Truth: $9.68 Error: $6.56 SLE: 0.91 Item: TUAIC Refrigerator D...
# 3: Guess: $1.84 Truth: $155.98 Error: $154.14 SLE: 16.11 Item: Kegco Secondary Regu...
# 4: Guess: $3.41 Truth: $5.59 Error: $2.18 SLE: 0.16 Item: Refrigerator Door Sp...
# 5: Guess: $1.61 Truth: $98.40 Error: $96.79 SLE: 13.24 Item: Ice-O-Matic Float Va...
# 6: Guess: $1.96 Truth: $54.99 Error: $53.03 SLE: 8.64 Item: Wireless Temperature...
# 7: Guess: $3.52 Truth: $5.71 Error: $2.19 SLE: 0.16 Item: 3Inch Thermometer Hy...
# 8: Guess: $2.05 Truth: $9.53 Error: $7.48 SLE: 1.53 Item: GE GE Timer Knob Ass...
# 9: Guess: $1.46 Truth: $11.24 Error: $9.78 SLE: 2.58 Item: newlifeapp Dryer Lin...
# 10: Guess: $2.79 Truth: $12.88 Error: $10.09 SLE: 1.69 Item: Away NV350 NV351 NV3...
# 11: Guess: $1.57 Truth: $99.99 Error: $98.42 SLE: 13.47 Item: Refrigerator Ice Mak...
# 12: Guess: $1.63 Truth: $16.99 Error: $15.36 SLE: 3.70 Item: 2 PACKS Water Filter...
# 13: Guess: $1.68 Truth: $12.74 Error: $11.06 SLE: 2.67 Item: STANCO METAL PROD 41...
# 14: Guess: $1.37 Truth: $10.95 Error: $9.58 SLE: 2.62 Item: GE 6-Inch Drip Pan
# P...
# 15: Guess: $3.92 Truth: $66.50 Error: $62.58 SLE: 6.86 Item: Edgewater Parts Drai...
# 16: Guess: $2.06 Truth: $11.99 Error: $9.93 SLE: 2.09 Item: Elyum Size 04 Cone C...
# 17: Guess: $2.09 Truth: $49.95 Error: $47.86 SLE: 7.86 Item: Everydrop by Whirlpo...
# 18: Guess: $1.77 Truth: $26.92 Error: $25.15 SLE: 5.34 Item: Beverage Air Door Ga...
# 19: Guess: $1.37 Truth: $89.98 Error: $88.61 SLE: 13.31 Item: Frigidaire Counter T...
# 20: Guess: $2.83 Truth: $25.99 Error: $23.16 SLE: 3.82 Item: Supplying Demand Ele...
# 21: Guess: $1.45 Truth: $17.99 Error: $16.54 SLE: 4.19 Item: 2-Pack Dryer Lint Fi...
# 22: Guess: $1.33 Truth: $6.99 Error: $5.66 SLE: 1.51 Item: Qlear-CLWT Premium R...
# 23: Guess: $2.05 Truth: $39.99 Error: $37.94 SLE: 6.74 Item: HUBBELL AC Plug NEMA...
# 24: Guess: $1.40 Truth: $13.99 Error: $12.59 SLE: 3.36 Item: Refrigerator Egg Hol...
# 25: Guess: $3.83 Truth: $339.95 Error: $336.12 SLE: 18.11 Item: ZLINE 20.5 Ducted Wa...
# 26: Guess: $4.00 Truth: $67.99 Error: $63.99 SLE: 6.89 Item: Supplying Demand Top...
# 27: Guess: $3.04 Truth: $139.00 Error: $135.96 SLE: 12.57 Item: Compatible Ice Maker...
# 28: Guess: $2.69 Truth: $8.97 Error: $6.28 SLE: 0.99 Item: Blutoget 6 Louvered ...
# 29: Guess: $2.10 Truth: $39.65 Error: $37.55 SLE: 6.62 Item: Edgewater Parts Evap...
# 30: Guess: $2.90 Truth: $229.98 Error: $227.08 SLE: 16.66 Item: Winflo 30 In. Conver...
# 31: Guess: $2.79 Truth: $25.80 Error: $23.01 SLE: 3.83 Item: Washer Shock Absorbe...
# 32: Guess: $1.94 Truth: $11.99 Error: $10.05 SLE: 2.21 Item: 2 PACK AF Compatible...
# 33: Guess: $1.73 Truth: $9.99 Error: $8.26 SLE: 1.94 Item: Poweka Refillable Co...
# 34: Guess: $2.01 Truth: $21.99 Error: $19.98 SLE: 4.13 Item: 2-Pack Replacement f...
# 35: Guess: $2.58 Truth: $17.90 Error: $15.32 SLE: 2.77 Item: Supco Dryer Heating ...
# 36: Guess: $1.92 Truth: $84.00 Error: $82.08 SLE: 11.37 Item: Frymaster Common Ele...
# 37: Guess: $1.62 Truth: $16.24 Error: $14.62 SLE: 3.56 Item: Plumb Craft 5-Foot W...
# 38: Guess: $2.75 Truth: $23.99 Error: $21.24 SLE: 3.60 Item: Overbest Replacement...
# 39: Guess: $1.45 Truth: $6.99 Error: $5.54 SLE: 1.39 Item: Fill 'n Brew Individ...
# 40: Guess: $2.97 Truth: $24.99 Error: $22.02 SLE: 3.53 Item: Maytag EDR7D1 Compar...
# 41: Guess: $1.40 Truth: $11.61 Error: $10.21 SLE: 2.75 Item: Coffee Filters - Nat...
# 42: Guess: $3.04 Truth: $949.00 Error: $945.96 SLE: 29.82 Item: EdgeStar 20 Inch Wid...
# 43: Guess: $3.96 Truth: $74.00 Error: $70.04 SLE: 7.38 Item: Bosch Door Lower Bin...
# 44: Guess: $1.58 Truth: $22.05 Error: $20.47 SLE: 4.80 Item: Samsung Switch Door-...
# 45: Guess: $1.46 Truth: $284.00 Error: $282.54 SLE: 22.57 Item: Jenn air Stove Cartr...
# 46: Guess: $2.89 Truth: $91.78 Error: $88.89 SLE: 10.06 Item: Whole Parts Burner G...
# 47: Guess: $2.88 Truth: $45.20 Error: $42.32 SLE: 6.13 Item: DEFLECTO SK8WF Supur...
# 48: Guess: $3.21 Truth: $8.69 Error: $5.48 SLE: 0.69 Item: Supco RR109 Receptac...
# 49: Guess: $1.43 Truth: $16.18 Error: $14.75 SLE: 3.82 Item: Dryer Lint Screen Fi...
# 50: Guess: $4.54 Truth: $6.50 Error: $1.96 SLE: 0.09 Item: Replacement Light Bu...
# 51: Guess: $1.94 Truth: $32.21 Error: $30.27 SLE: 5.88 Item: ForeverPRO Drum Ligh...
# 52: Guess: $1.61 Truth: $15.39 Error: $13.78 SLE: 3.37 Item: Highcraft Dishwasher...
# 53: Guess: $1.86 Truth: $17.99 Error: $16.13 SLE: 3.58 Item: and Stove Burner Dri...
# 54: Guess: $2.06 Truth: $26.99 Error: $24.93 SLE: 4.89 Item: ReplacementBrand Com...
# 55: Guess: $3.15 Truth: $11.99 Error: $8.84 SLE: 1.30 Item: 2-Pack 341241 Dryer ...
# 56: Guess: $1.79 Truth: $44.46 Error: $42.67 SLE: 7.80 Item: Power Nut Kit - Comp...
# 57: Guess: $1.88 Truth: $15.99 Error: $14.11 SLE: 3.15 Item: Stovetop Extender Ov...
# 58: Guess: $1.96 Truth: $129.99 Error: $128.03 SLE: 14.37 Item: COSVALVE Portable Wa...
# 59: Guess: $2.34 Truth: $24.99 Error: $22.65 SLE: 4.21 Item: AlaSou Washer Dustpr...
# 60: Guess: $1.52 Truth: $27.38 Error: $25.86 SLE: 5.87 Item: Honeywell Pad for He...
# 61: Guess: $2.47 Truth: $16.95 Error: $14.48 SLE: 2.70 Item: HQRP 2-Pack Wick Fil...
# 62: Guess: $1.71 Truth: $10.82 Error: $9.11 SLE: 2.17 Item: Whirlpool Pad Washer...
# 63: Guess: $1.36 Truth: $19.00 Error: $17.64 SLE: 4.58 Item: Durable Disposable E...
# 64: Guess: $1.71 Truth: $12.98 Error: $11.27 SLE: 2.69 Item: Anti Vibration Pads ...
# 65: Guess: $1.70 Truth: $16.99 Error: $15.29 SLE: 3.60 Item: Reusable K Cups for ...
# 66: Guess: $1.96 Truth: $24.97 Error: $23.01 SLE: 4.72 Item: Apace Living Pour Ov...
# 67: Guess: $3.83 Truth: $10.91 Error: $7.08 SLE: 0.81 Item: Kitchen Basics 101 2...
# 68: Guess: $1.28 Truth: $14.98 Error: $13.70 SLE: 3.79 Item: Mist Water Filter Re...
# 69: Guess: $1.35 Truth: $7.90 Error: $6.55 SLE: 1.78 Item: NEW Dryer Drum Felt ...
# 70: Guess: $2.03 Truth: $25.75 Error: $23.72 SLE: 4.74 Item: Cobectal Dryer Drum ...
# 71: Guess: $2.15 Truth: $41.77 Error: $39.62 SLE: 6.81 Item: Washer Shock Absorbe...
# 72: Guess: $1.56 Truth: $20.68 Error: $19.12 SLE: 4.57 Item: Fafeicy WT2000 Digit...
# 73: Guess: $1.50 Truth: $69.99 Error: $68.49 SLE: 11.18 Item: TJ. Clothes Dryer, 1...
# 74: Guess: $2.03 Truth: $23.99 Error: $21.96 SLE: 4.45 Item: Suspension Support R...
# 75: Guess: $2.92 Truth: $28.69 Error: $25.77 SLE: 4.10 Item: Supplying Demand Ele...
# 76: Guess: $1.73 Truth: $42.00 Error: $40.27 SLE: 7.59 Item: General Electric Kno...
# 77: Guess: $3.74 Truth: $123.57 Error: $119.83 SLE: 10.68 Item: Frigidaire Oven Door...
# 78: Guess: $2.38 Truth: $8.99 Error: $6.61 SLE: 1.17 Item: Waytiffer Gas Burner...
# 79: Guess: $2.89 Truth: $36.95 Error: $34.06 SLE: 5.19 Item: USA Made MSWF Compat...
# 80: Guess: $2.96 Truth: $11.99 Error: $9.03 SLE: 1.41 Item: 2-Pack 341241 Dryer ...
# 81: Guess: $2.13 Truth: $41.30 Error: $39.17 SLE: 6.78 Item: Washing Machine Hose...
# 82: Guess: $1.85 Truth: $35.61 Error: $33.76 SLE: 6.52 Item: Bosch Dishwasher Doo...
# 83: Guess: $3.00 Truth: $169.99 Error: $166.99 SLE: 14.10 Item: Broan QS3 Series Ran...
# 84: Guess: $2.92 Truth: $19.91 Error: $16.99 SLE: 2.80 Item: Bosch Range Surface ...
# 85: Guess: $3.62 Truth: $9.57 Error: $5.95 SLE: 0.69 Item: LONYE Oven Thermal F...
# 86: Guess: $1.96 Truth: $29.69 Error: $27.73 SLE: 5.46 Item: Upgrade Stainless St...
# 87: Guess: $2.96 Truth: $21.93 Error: $18.97 SLE: 3.08 Item: Supco Icemaker Contr...
# 88: Guess: $2.64 Truth: $32.56 Error: $29.92 SLE: 4.94 Item: Evaporator Fan Motor...
# 89: Guess: $1.32 Truth: $22.78 Error: $21.46 SLE: 5.42 Item: UPGRADE Refrigerator...
# 90: Guess: $1.86 Truth: $24.79 Error: $22.93 SLE: 4.83 Item: Supreme Covers Porta...
# 91: Guess: $2.88 Truth: $33.69 Error: $30.81 SLE: 4.80 Item: Frigidaire Surface B...
# 92: Guess: $1.67 Truth: $12.99 Error: $11.32 SLE: 2.75 Item: TooCust Milk Frothin...
# 93: Guess: $1.35 Truth: $12.99 Error: $11.64 SLE: 3.19 Item: Premium Vials 38 x 2...
# 94: Guess: $1.72 Truth: $10.98 Error: $9.26 SLE: 2.19 Item: Washer Door Lid Swit...
# 95: Guess: $1.88 Truth: $26.44 Error: $24.56 SLE: 5.08 Item: Aqua Fresh Replaceme...
# 96: Guess: $1.43 Truth: $16.99 Error: $15.56 SLE: 4.01 Item: InterDesign Covered ...
# 97: Guess: $2.11 Truth: $25.25 Error: $23.14 SLE: 4.55 Item: Upgrade Gas Range Ov...
# 98: Guess: $1.59 Truth: $11.88 Error: $10.29 SLE: 2.57 Item: Washing Machine Inne...
# 99: Guess: $1.50 Truth: $28.99 Error: $27.49 SLE: 6.18 Item: Maxmartt 100mm Vent ...
# 100: Guess: $1.88 Truth: $23.12 Error: $21.25 SLE: 4.52 Item: Upgraded Lifetime Ap...
# 101: Guess: $2.08 Truth: $52.97 Error: $50.89 SLE: 8.21 Item: Whirlpool Sensor for...
# 102: Guess: $1.88 Truth: $25.99 Error: $24.11 SLE: 5.00 Item: Wintact Digital Temp...
# 103: Guess: $1.54 Truth: $17.99 Error: $16.45 SLE: 4.05 Item: BOTNA Range Hood Gre...
# 104: Guess: $1.79 Truth: $7.99 Error: $6.20 SLE: 1.37 Item: Milk Frothing Pitche...
# 105: Guess: $1.66 Truth: $28.99 Error: $27.33 SLE: 5.87 Item: 1040 Replacement Wic...
# 106: Guess: $1.68 Truth: $12.07 Error: $10.39 SLE: 2.51 Item: Stanco Gas Range Dri...
# 107: Guess: $1.50 Truth: $18.99 Error: $17.49 SLE: 4.32 Item: Dampp Chaser Piano H...
# 108: Guess: $2.05 Truth: $9.99 Error: $7.94 SLE: 1.64 Item: Gardens Light Switch...
# 109: Guess: $2.63 Truth: $29.99 Error: $27.36 SLE: 4.60 Item: Waterspecialist Repl...
# 110: Guess: $2.82 Truth: $9.99 Error: $7.17 SLE: 1.12 Item: Upgraded Stove Knob,...
# 111: Guess: $2.92 Truth: $31.69 Error: $28.77 SLE: 4.50 Item: 5-PACK Top Burner Co...
# 112: Guess: $1.35 Truth: $24.99 Error: $23.64 SLE: 5.78 Item: Large Capacity Egg H...
# 113: Guess: $1.84 Truth: $25.99 Error: $24.15 SLE: 5.06 Item: FireFly Home Stove T...
# 114: Guess: $2.28 Truth: $18.99 Error: $16.71 SLE: 3.27 Item: Annbully Cartoon USB...
# 115: Guess: $1.96 Truth: $9.99 Error: $8.03 SLE: 1.72 Item: Goldenvalueable 6 x ...
# 116: Guess: $2.88 Truth: $22.99 Error: $20.11 SLE: 3.32 Item: Blueangle Pink Hibis...
# 117: Guess: $1.74 Truth: $169.99 Error: $168.25 SLE: 17.08 Item: ROVSUN 13LBS Portabl...
# 118: Guess: $3.00 Truth: $36.99 Error: $33.99 SLE: 5.07 Item: 1-Year Warranty Drye...
# 119: Guess: $2.02 Truth: $33.99 Error: $31.97 SLE: 6.00 Item: ICEPURE Replacement ...
# 120: Guess: $3.91 Truth: $104.89 Error: $100.98 SLE: 9.43 Item: Whirlpool Water Inle...
# 121: Guess: $2.08 Truth: $19.98 Error: $17.90 SLE: 3.68 Item: Washing Machine Wate...
# 122: Guess: $1.60 Truth: $9.99 Error: $8.39 SLE: 2.07 Item: Sunflowers Refrigera...
# 123: Guess: $1.78 Truth: $28.10 Error: $26.32 SLE: 5.52 Item: General Electric Fro...
# 124: Guess: $2.24 Truth: $27.50 Error: $25.26 SLE: 4.72 Item: Supco Refrigerator W...
# 125: Guess: $1.97 Truth: $36.99 Error: $35.02 SLE: 6.50 Item: HASMX Dishwasher Cut...
# 126: Guess: $1.81 Truth: $19.84 Error: $18.03 SLE: 4.02 Item: Whirlpool Range Surf...
# 127: Guess: $1.57 Truth: $24.99 Error: $23.42 SLE: 5.35 Item: 950S - Compatible wi...
# 128: Guess: $1.39 Truth: $169.99 Error: $168.60 SLE: 18.24 Item: WAFIET 12 Inch Gas C...
# 129: Guess: $1.83 Truth: $19.99 Error: $18.16 SLE: 4.01 Item: Reusable Vertuo Caps...
# 130: Guess: $1.38 Truth: $25.95 Error: $24.57 SLE: 5.88 Item: Coffee Filter Holder...
# 131: Guess: $1.53 Truth: $39.96 Error: $38.43 SLE: 7.76 Item: Star Deflector-Burne...
# 132: Guess: $1.38 Truth: $15.99 Error: $14.61 SLE: 3.87 Item: General Electric Ran...
# 133: Guess: $2.23 Truth: $39.99 Error: $37.76 SLE: 6.46 Item: WiFi Temperature Sen...
# 134: Guess: $1.69 Truth: $21.53 Error: $19.84 SLE: 4.51 Item: KITCHEN BASICS 101 1...
# 135: Guess: $2.83 Truth: $26.99 Error: $24.16 SLE: 3.96 Item: Dryer Heating Elemen...
# 136: Guess: $1.97 Truth: $43.99 Error: $42.02 SLE: 7.39 Item: Samsung HAF-CIN EXP ...
# 137: Guess: $1.79 Truth: $9.41 Error: $7.62 SLE: 1.73 Item: HQRP 3-Pack Wick Fil...
# 138: Guess: $1.67 Truth: $8.99 Error: $7.32 SLE: 1.74 Item: Reusable K Cups For ...
# 139: Guess: $3.15 Truth: $61.51 Error: $58.36 SLE: 7.36 Item: for GE Icemaker Refr...
# 140: Guess: $3.17 Truth: $122.30 Error: $119.13 SLE: 11.47 Item: Whirlpool Inlet Valv...
# 141: Guess: $1.78 Truth: $14.89 Error: $13.11 SLE: 3.04 Item: 100 UNIVERSAL Round ...
# 142: Guess: $1.69 Truth: $39.99 Error: $38.30 SLE: 7.42 Item: TRUE 811502 Nozzle a...
# 143: Guess: $1.57 Truth: $17.90 Error: $16.33 SLE: 3.98 Item: Dianoo Espresso Stea...
# 144: Guess: $1.43 Truth: $16.77 Error: $15.34 SLE: 3.96 Item: Air Filter Factory R...
# 145: Guess: $2.74 Truth: $23.99 Error: $21.25 SLE: 3.61 Item: EvertechPRO Washer D...
# 146: Guess: $1.43 Truth: $35.00 Error: $33.57 SLE: 7.27 Item: Cheftek CT1010 Porta...
# 147: Guess: $3.55 Truth: $4.95 Error: $1.40 SLE: 0.07 Item: HQRP 4 Pin Universal...
# 148: Guess: $2.06 Truth: $18.89 Error: $16.83 SLE: 3.51 Item: 2-Pack TSD2 Start De...
# 149: Guess: $1.41 Truth: $8.77 Error: $7.36 SLE: 1.96 Item: Air Filter Factory R...
# 150: Guess: $1.68 Truth: $17.22 Error: $15.54 SLE: 3.67 Item: Plumb Pak Braided Wa...
# 151: Guess: $2.00 Truth: $20.98 Error: $18.98 SLE: 3.97 Item: Bosch Button, Silver...
# 152: Guess: $3.96 Truth: $37.37 Error: $33.41 SLE: 4.19 Item: Siwdoy 279816 Dryer ...
# 153: Guess: $1.70 Truth: $11.99 Error: $10.29 SLE: 2.47 Item: OUGAR8 Refrigerator ...
# 154: Guess: $2.96 Truth: $119.95 Error: $116.99 SLE: 11.69 Item: Bosch Range Hood Fan...
# 155: Guess: $1.47 Truth: $31.00 Error: $29.53 SLE: 6.57 Item: Replacement Filter C...
# 156: Guess: $2.04 Truth: $31.00 Error: $28.96 SLE: 5.54 Item: Aprilaire Humidifier...
# 157: Guess: $1.75 Truth: $7.97 Error: $6.22 SLE: 1.40 Item: Technivorm Moccamast...
# 158: Guess: $1.91 Truth: $51.50 Error: $49.59 SLE: 8.37 Item: LG Electronics Washi...
# 159: Guess: $2.85 Truth: $27.99 Error: $25.14 SLE: 4.07 Item: ALAZA Flower on Marb...
# 160: Guess: $2.00 Truth: $466.24 Error: $464.24 SLE: 25.48 Item: Frigidaire 30 Inch E...
# 161: Guess: $1.82 Truth: $50.36 Error: $48.54 SLE: 8.43 Item: General Electric Ref...
# 162: Guess: $2.60 Truth: $19.97 Error: $17.37 SLE: 3.11 Item: Small Size Pour Over...
# 163: Guess: $1.69 Truth: $29.95 Error: $28.26 SLE: 5.96 Item: Sealegend Dryer Vent...
# 164: Guess: $2.58 Truth: $23.99 Error: $21.41 SLE: 3.78 Item: Waterspecialist XWF ...
# 165: Guess: $3.12 Truth: $12.74 Error: $9.62 SLE: 1.45 Item: GARP 279816 Compatib...
# 166: Guess: $4.40 Truth: $8.99 Error: $4.59 SLE: 0.38 Item: Premium Dishwasher B...
# 167: Guess: $2.05 Truth: $24.99 Error: $22.94 SLE: 4.60 Item: UpStart Components R...
# 168: Guess: $1.62 Truth: $17.99 Error: $16.37 SLE: 3.92 Item: Chef's Star Stainles...
# 169: Guess: $1.55 Truth: $19.99 Error: $18.44 SLE: 4.45 Item: Egg Container for Re...
# 170: Guess: $1.69 Truth: $18.77 Error: $17.08 SLE: 3.97 Item: AMI PARTS Dryer Lint...
# 171: Guess: $1.64 Truth: $47.86 Error: $46.22 SLE: 8.52 Item: GE Igniter for Gas B...
# 172: Guess: $2.00 Truth: $34.45 Error: $32.45 SLE: 6.10 Item: General Electric Dry...
# 173: Guess: $7.00 Truth: $7.99 Error: $0.99 SLE: 0.01 Item: 312959 Dryer Belt Re...
# 174: Guess: $2.21 Truth: $27.99 Error: $25.78 SLE: 4.84 Item: 5-Pack Replacement E...
# 175: Guess: $2.84 Truth: $117.99 Error: $115.15 SLE: 11.80 Item: OEM Samsung Refriger...
# 176: Guess: $2.89 Truth: $989.99 Error: $987.10 SLE: 30.68 Item: vevor 24 Undercounte...
# 177: Guess: $1.97 Truth: $18.99 Error: $17.02 SLE: 3.64 Item: Reusable Vertuo Caps...
# 178: Guess: $2.00 Truth: $164.98 Error: $162.98 SLE: 16.11 Item: 32 x 30 2.5 Heavy Du...
# 179: Guess: $1.86 Truth: $19.36 Error: $17.50 SLE: 3.86 Item: Fluidmaster 9WM60 No...
# 180: Guess: $1.86 Truth: $16.00 Error: $14.14 SLE: 3.18 Item: AYZE Electric Restri...
# 181: Guess: $2.00 Truth: $21.40 Error: $19.40 SLE: 4.04 Item: Whirlpool Door Handl...
# 182: Guess: $1.94 Truth: $46.99 Error: $45.05 SLE: 7.81 Item: Upgraded Dryer Repai...
# 183: Guess: $1.74 Truth: $13.69 Error: $11.95 SLE: 2.82 Item: Camco 00553 8 GE/Hot...
# 184: Guess: $1.83 Truth: $22.72 Error: $20.89 SLE: 4.53 Item: GE Part Number KNOB ...
# 185: Guess: $1.58 Truth: $105.13 Error: $103.55 SLE: 13.81 Item: Manitowoc Ice Curtai...
# 186: Guess: $2.67 Truth: $32.50 Error: $29.83 SLE: 4.89 Item: Heating Element ( Re...
# 187: Guess: $1.84 Truth: $114.60 Error: $112.76 SLE: 13.73 Item: Vulcan Hart Thermo
# P...
# 188: Guess: $1.86 Truth: $84.96 Error: $83.10 SLE: 11.57 Item: Turbo Air Thermostat...
# 189: Guess: $3.00 Truth: $83.40 Error: $80.40 SLE: 9.30 Item: Frigidaire Dispenser...
# 190: Guess: $3.31 Truth: $9.99 Error: $6.68 SLE: 0.88 Item: Splutch Cam Kit Repl...
# 191: Guess: $3.75 Truth: $9.49 Error: $5.74 SLE: 0.63 Item: newlifeapp Dryer The...
# 192: Guess: $1.72 Truth: $29.99 Error: $28.27 SLE: 5.92 Item: Upgraded Dryer Rear ...
# 193: Guess: $1.44 Truth: $13.57 Error: $12.13 SLE: 3.19 Item: 2 Pack Top Burner Sp...
# 194: Guess: $1.89 Truth: $19.96 Error: $18.07 SLE: 3.93 Item: Washer Drain Pump Mo...
# 195: Guess: $2.86 Truth: $56.99 Error: $54.13 SLE: 7.35 Item: New-Refrigerator Ice...
# 196: Guess: $1.64 Truth: $16.37 Error: $14.73 SLE: 3.55 Item: Whirlpool Adjuster
# P...
# 197: Guess: $1.69 Truth: $19.99 Error: $18.30 SLE: 4.22 Item: Nispira Replacement ...
# 198: Guess: $2.05 Truth: $37.98 Error: $35.93 SLE: 6.49 Item: Mist Water Filter Re...
# 199: Guess: $2.78 Truth: $34.79 Error: $32.01 SLE: 5.06 Item: UPGRADE Refrigerator...
# 200: Guess: $2.05 Truth: $8.39 Error: $6.34 SLE: 1.26 Item: DPD Washer Lid Switc...
# 201: Guess: $3.27 Truth: $117.86 Error: $114.59 SLE: 11.07 Item: GENUINE Frigidaire B...
# 202: Guess: $1.70 Truth: $15.99 Error: $14.29 SLE: 3.39 Item: Anti Vibration Pads ...
# 203: Guess: $1.49 Truth: $10.99 Error: $9.50 SLE: 2.47 Item: Dryer Drum Support R...
# 204: Guess: $1.96 Truth: $24.43 Error: $22.47 SLE: 4.63 Item: Whirlpool 279816 Dry...
# 205: Guess: $3.07 Truth: $426.98 Error: $423.91 SLE: 21.68 Item: Empava 36 500 CFM Is...
# 206: Guess: $2.93 Truth: $39.99 Error: $37.06 SLE: 5.50 Item: SpiroPure NSF Certif...
# 207: Guess: $2.05 Truth: $26.99 Error: $24.94 SLE: 4.91 Item: Replacement for Jenn...
# 208: Guess: $1.32 Truth: $138.69 Error: $137.37 SLE: 16.80 Item: GE Genuine OEM Dampe...
# 209: Guess: $2.47 Truth: $13.97 Error: $11.50 SLE: 2.14 Item: Dryer Thermal Fuse T...
# 210: Guess: $2.00 Truth: $21.99 Error: $19.99 SLE: 4.15 Item: 2-Pack Replacement f...
# 211: Guess: $3.02 Truth: $18.88 Error: $15.86 SLE: 2.56 Item: Terminal Block Assem...
# 212: Guess: $2.11 Truth: $18.41 Error: $16.30 SLE: 3.36 Item: Whirlpool 308180 Bak...
# 213: Guess: $1.45 Truth: $9.95 Error: $8.50 SLE: 2.25 Item: LG Sensor Kenmore Wa...
# 214: Guess: $1.63 Truth: $18.00 Error: $16.37 SLE: 3.91 Item: Compatible Drum Belt...
# 215: Guess: $2.14 Truth: $33.95 Error: $31.81 SLE: 5.80 Item: Whirlpool Dryer Liqu...
# 216: Guess: $1.89 Truth: $42.95 Error: $41.06 SLE: 7.41 Item: MCGILL Replacement B...
# 217: Guess: $1.82 Truth: $59.99 Error: $58.17 SLE: 9.46 Item: New Upgraded Refrige...
# 218: Guess: $1.82 Truth: $55.58 Error: $53.76 SLE: 8.99 Item: TRUE 810719 Black Ga...
# 219: Guess: $3.43 Truth: $15.10 Error: $11.67 SLE: 1.66 Item: LG Genuine OEM Drain...
# 220: Guess: $2.09 Truth: $45.99 Error: $43.90 SLE: 7.40 Item: Waterspecialist Refr...
# 221: Guess: $3.00 Truth: $60.14 Error: $57.14 SLE: 7.44 Item: GlobPro Washer Water...
# 222: Guess: $1.98 Truth: $45.99 Error: $44.01 SLE: 7.61 Item: AQUA CREST 847200 Re...
# 223: Guess: $2.85 Truth: $16.24 Error: $13.39 SLE: 2.25 Item: Frigidaire Frigidare...
# 224: Guess: $1.31 Truth: $31.99 Error: $30.68 SLE: 7.08 Item: Supplying Demand Clo...
# 225: Guess: $1.96 Truth: $34.00 Error: $32.04 SLE: 6.10 Item: Whole Parts Dryer Pu...
# 226: Guess: $1.86 Truth: $26.99 Error: $25.13 SLE: 5.21 Item: i Cafillas Refillabl...
# 227: Guess: $1.75 Truth: $15.39 Error: $13.64 SLE: 3.19 Item: Thermostat
# Brand new...
# 228: Guess: $2.21 Truth: $27.77 Error: $25.56 SLE: 4.82 Item: Beaquicy Oven Bake E...
# 229: Guess: $1.63 Truth: $26.08 Error: $24.45 SLE: 5.43 Item: Whirlpool 661570 Bel...
# 230: Guess: $1.68 Truth: $18.99 Error: $17.31 SLE: 4.04 Item: iFillMug 33 Pack for...
# 231: Guess: $1.78 Truth: $159.18 Error: $157.40 SLE: 16.43 Item: Frigidaire Freezer D...
# 232: Guess: $1.43 Truth: $34.95 Error: $33.52 SLE: 7.27 Item: New York Air Airplan...
# 233: Guess: $1.82 Truth: $25.19 Error: $23.37 SLE: 4.97 Item: Amazon Basics Replac...
# 234: Guess: $3.80 Truth: $19.51 Error: $15.71 SLE: 2.11 Item: Upgraded Dishrack St...
# 235: Guess: $3.02 Truth: $37.45 Error: $34.43 SLE: 5.10 Item: Sportman Pastoral St...
# 236: Guess: $2.92 Truth: $29.99 Error: $27.07 SLE: 4.27 Item: Motor OEM Mania New ...
# 237: Guess: $1.61 Truth: $163.56 Error: $161.95 SLE: 17.19 Item: Refrigerator Ice Mak...
# 238: Guess: $1.68 Truth: $27.00 Error: $25.32 SLE: 5.51 Item: Appliance Slide for ...
# 239: Guess: $6.22 Truth: $5.99 Error: $0.23 SLE: 0.00 Item: Lower Dishwasher Whe...
# 240: Guess: $1.38 Truth: $6.64 Error: $5.26 SLE: 1.36 Item: Gas Female Cap ORIFI...
# 241: Guess: $3.15 Truth: $26.04 Error: $22.89 SLE: 3.51 Item: 9pcs Silicon Rubber ...
# 242: Guess: $1.88 Truth: $13.79 Error: $11.91 SLE: 2.68 Item: Supplying Demand Clo...
# 243: Guess: $1.80 Truth: $78.98 Error: $77.18 SLE: 11.24 Item: General Electric Ref...
# 244: Guess: $1.45 Truth: $27.99 Error: $26.54 SLE: 6.10 Item: i Cafilas New Lid St...
# 245: Guess: $1.39 Truth: $14.99 Error: $13.60 SLE: 3.62 Item: GHM Humidifier Repla...
# 246: Guess: $1.43 Truth: $50.25 Error: $48.82 SLE: 9.31 Item: Manitowoc Ice Water ...
# 247: Guess: $1.94 Truth: $101.36 Error: $99.42 SLE: 12.59 Item: General Electric Doo...
# 248: Guess: $1.63 Truth: $4.98 Error: $3.35 SLE: 0.67 Item: Kitchen Stove Gap Co...
# 249: Guess: $2.76 Truth: $9.89 Error: $7.13 SLE: 1.13 Item: Washer & Dryer Lid S...
# 250: Guess: $1.59 Truth: $27.99 Error: $26.40 SLE: 5.83 Item: Nispira Humidifier W...
