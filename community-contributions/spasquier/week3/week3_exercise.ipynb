# %% [markdown]
# # Synthetic data generator with model selection and Gradio UI
#
# This exercise generates sample data for an inventory management bot that users can contact to update inventory with chats.
#
# [https://colab.research.google.com/drive/1Tt8fOXVq1yIih1quZIH-MHcjSfN6_01w](https://colab.research.google.com/drive/1Tt8fOXVq1yIih1quZIH-MHcjSfN6_01w)
