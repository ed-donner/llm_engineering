# %% [markdown]
# # Week 1 - Day 1 Excersice
# **For week 1, day 1 exersice, I've created a tool that generates an email message given a subject line string.**
#
# 1. It sets a custom system prompt and user prompt prefix.
#
# 2. It sets up the messages array in the correct format expected by the OpenAI API.
#
# 3. It generates an email message according to the `email_subject` string.
#
# 4. Finally it displays the OpenAI markdown formatted response.

# %%
# Step 1: Importing libs and creating my prompts.
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
from openai import OpenAI

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

system_prompt = "You are an expert at generating email contents from subject lines"
user_prompt_prefix = """
    Generate a formatted email message with bullet lists
    and other details given the subject line provided:

"""

# Step 2: Make the OpenAI API messages list with the `email_subject` string.
def messages_for(email_subject):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + email_subject}
    ]
email_subject = "Random Shapes Inc. LLM Engineer position application - Salvador Pasquier"
messages = messages_for(email_subject)

# Step 3: Call OpenAI Chat endpoint using the "gpt-5-nano" model.
openai = OpenAI()
response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
email_message = response.choices[0].message.content

# Step 4: Display the result in markdown format.
display(Markdown(email_message))
# Out:
# Subject: Random Shapes Inc. Data Scientist position application - Salvador Pasquier
#
# Dear Hiring Team at Random Shapes Inc.,
#
# I am writing to express my interest in the Data Scientist position. I am enthusiastic about your work at Random Shapes Inc. and believe my background in data analysis, modeling, and collaboration with cross-functional teams would be a strong fit for your team.
#
# Overview of my background
# - [Degree] in [Field] from [Institution]
# - [X] years of experience applying statistical methods and machine learning to real-world data
# - Strong track record of turning complex data into actionable insights for product and business teams
#
# Key qualifications
# - Proficient in Python and R for data analysis, modeling, and machine learning
# - Experienced with SQL and data warehouses; comfortable pulling and shaping data from large datasets
# - Familiar with visualization tools (e.g., Tableau, Power BI) to communicate findings clearly
# - Knowledge of supervised and unsupervised learning, feature engineering, and model evaluation
# - Exposure to ML Ops concepts: model deployment, monitoring, and version control
# - Effective communicator with experience collaborating across product, engineering, and business teams
#
# Selected projects and experience
# - Led end-to-end data science initiatives, from problem definition and data gathering to model deployment and monitoring
# - Built predictive models to inform product decisions and optimize business metrics
# - Conducted exploratory data analysis to identify opportunities for process improvement and efficiency gains
# - Implemented data quality checks and robust validation to ensure reliable insights
#
# Why I’m excited about Random Shapes Inc.
# - Alignment with your mission to leverage data-driven insights to guide product and strategy
# - Opportunity to contribute to a diverse, cross-functional team solving complex problems
# - Commitment to innovation and continuous learning, which matches my professional values
#
# Education and credentials
# - [Degree], [Field], [Institution], [Year]
# - Relevant certifications or coursework (e.g., ML, data visualization, SQL, etc.) [if applicable]
#
# Portfolio and references
# - GitHub: [GitHub URL]
# - Portfolio / website: [Portfolio URL]
# - LinkedIn: [LinkedIn URL]
# - References available upon request
#
# Attachments
# - Resume
# - Cover Letter
#
# Availability
# - I am available for an interview at your earliest convenience
# - Start date: [notice period or immediate availability]
#
# Thank you for considering my application. I would welcome the opportunity to discuss how my background, skills, and interests align with the needs of Random Shapes Inc. Please feel free to contact me at [Phone] or [Email] to schedule a conversation.
#
# Sincerely,
# Salvador Pasquier
# Phone: [Phone]
# Email: [Email]
# LinkedIn: [LinkedIn URL]
# Portfolio: [Portfolio URL]
