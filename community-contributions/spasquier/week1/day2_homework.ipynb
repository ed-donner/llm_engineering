# %% [markdown]
# # Week 1 - Day 2 Homework
# **For week 1, day 2 homework, I've created a tool that generates an email message given a subject line string, but using local ollama instead of OpenAI API.**
#
# 1. It sets a custom system prompt and user prompt prefix.
#
# 2. It sets up the messages array in the correct format expected by the OpenAI API compatible ollama API endpoint.
#
# 3. It generates an email message according to the `email_subject` string.
#
# 4. Finally it displays the ollama markdown formatted response.

# %%
# Step 1: Importing libs and creating my prompts.
import os
from IPython.display import Markdown, display
from openai import OpenAI

system_prompt = "You are an expert at generating email contents from subject lines"
user_prompt_prefix = """
    Generate a formatted email message with bullet lists
    and other details given the subject line provided:

"""

# Step 2: Make the OpenAI API messages list with the `email_subject` string.
def messages_for(email_subject):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + email_subject}
    ]
email_subject = "Carrot Cake - New product launch in our Pastry Ltd. website"
messages = messages_for(email_subject)

# Step 3: Call OpenAI Chat endpoint using the "llama3.2" model.
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')
response = ollama.chat.completions.create(model="llama3.2", messages=messages)
email_message = response.choices[0].message.content

# Step 4: Display the result in markdown format.
display(Markdown(email_message))
# Out:
# Here is a formatted email message based on the subject line:
#
# **Subject: Carrot Cake - New product launch in our Pastry Ltd. website**
#
# Dear Valued Customers,
#
# We are thrilled to announce the launch of our newest addition to our Pastry Ltd. family: the scrumptious Carrot Cake! Indulge in the moist and flavorful goodness of our expertly crafted carrot cake, made with the finest ingredients and a hint of sweetness.
#
# **Key Features of Our Carrot Cake:**
#
# • Made with fresh carrots, cream cheese, and a hint of spice
# • Moist and fluffy texture that will leave you wanting more
# • Perfect for snacking, baking, or making it a show-stopping centerpiece
# • Available in smaller, medium, and large sizes to suit your needs
#
# **Special Offers:**
#
# - Order now and receive 10% off your first purchase of Carrot Cake
# - Free delivery on all orders above ₹500
# - Keep an eye out for our upcoming promotions and special deals!
#
# **How to Order:**
#
# To place your order, simply click the link below or visit our Pastry Ltd. website at [insert website URL]. Our friendly customer service team will be happy to assist you with any questions or concerns.
#
# [Insert CTA button: Order Now]
#
# We look forward to welcoming you to our Pastry Ltd. family and sharing the delight of our Carrot Cake with you!
#
# Best regards,
#
# [Your Name]
# Pastry Ltd.
#
# P.S. Don't forget to share your Carrot Cake experience with us on social media using #PastryLtdCarrotCake!
