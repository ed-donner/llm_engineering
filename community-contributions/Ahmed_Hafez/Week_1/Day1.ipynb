# %%
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
from openai import OpenAI

# %%
load_dotenv ( override = True )
api_key = os.getenv ( 'OPENAI_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
system_prompt = """
You are a professional programmer capable of understanding any programming code from any language and converting it directly to the Python language. 
Learn about the programming language, write it, and convert the code to the Python language write it in markdown style and explain the code  by snarky way ."""

user_prompt = """

  convert this code to python  
  #include <iostream>
using namespace std;

class Student {
public:
    string name;
    int age;

    void display() {
        cout << name << endl;
    }
};

int main() {
    // Create object
    Student s1;

    // Assign values
    s1.name = "Geeksforgeeks";

    // Call function
    s1.display();

    return 0;
}
 """

messages = [ 
   {"role" : "system" , "content" : system_prompt} , 
   {"role" : "user" , "content" : user_prompt }
]

# %%
openai = OpenAI()

# %%
response = openai.chat.completions.create (model = "gpt-5-nano" , messages= messages)
output = response.choices[0].message.content
display ( Markdown(output))
# Out:
# Here's a clean Python version that preserves the behavior of your C++ code.
#
# ```python
# class Student:
#     def __init__(self, name=None, age=None):
#         self.name = name
#         self.age = age
#
#     def display(self):
#         print(self.name)
#
#
# def main():
#     s1 = Student()
#     s1.name = "Geeksforgeeks"
#     s1.display()
#
#
# if __name__ == "__main__":
#     main()
# ```
#
# Snarky explanation (because apparently you asked for it):
# - No headers, no semicolons, and no namespace gymnastics. Python just uses def and class; you’re welcome.
# - The C++ public members become plain attributes on a Python object. You don’t declare access specifiers in Python; everything is effectively public unless you start name-mangling.
# - The display method just prints the name attribute, which is the Pythonic way to do what cout << name << endl; did in C++.
# ...
