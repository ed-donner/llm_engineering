# %% [markdown]
# # YOUR FIRST LAB
# ### Please read this section. This is valuable to get you prepared, even if it's a long read -- it's important stuff.
#
# ### Also, be sure to read [README.md](../README.md)! More info about the updated videos in the README and [top of the course resources in purple](https://edwarddonner.com/2024/11/13/llm-engineering-resources/)
#
# ## Your first Frontier LLM Project
#
# By the end of this course, you will have built an autonomous Agentic AI solution with 7 agents that collaborate to solve a business problem. All in good time! We will start with something smaller...
#
# Our goal is to code a new kind of Web Browser. Give it a URL, and it will respond with a summary. The Reader's Digest of the internet!!
#
# Before starting, you should have completed the setup linked in the README.
#
# ### If you're new to working in "Notebooks" (also known as Labs or Jupyter Lab)
#
# Welcome to the wonderful world of Data Science experimentation! Simply click in each "cell" with code in it, such as the cell immediately below this text, and hit Shift+Return to execute that cell. Be sure to run every cell, starting at the top, in order.
#
# Please look in the [Guides folder](../guides/01_intro.ipynb) for all the guides.
#
# ## I am here to help
#
# If you have any problems at all, please do reach out.
# I'm available through the platform, or at ed@edwarddonner.com, or at https://www.linkedin.com/in/eddonner/ if you'd like to connect (and I love connecting!)
# And this is new to me, but I'm also trying out X at [@edwarddonner](https://x.com/edwarddonner) - if you're on X, please show me how it's done 😂
#
# ## More troubleshooting
#
# Please see the [troubleshooting](../setup/troubleshooting.ipynb) notebook in the setup folder to diagnose and fix common problems. At the very end of it is a diagnostics script with some useful debug info.
#
# ## If this is old hat!
#
# If you're already comfortable with today's material, please hang in there; you can move swiftly through the first few labs - we will get much more in depth as the weeks progress. Ultimately we will fine-tune our own LLM to compete with OpenAI!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Please read - important note</h2>
#             <span style="color:#900;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations. If you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">This code is a live resource - keep an eye out for my emails</h2>
#             <span style="color:#f71;">I push updates to the code regularly. As people ask questions, I add more examples or improved commentary. As a result, you'll notice that the code below isn't identical to the videos. Everything from the videos is here; but I've also added better explanations and new models like DeepSeek. Consider this like an interactive book.<br/><br/>
#                 I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business value of these exercises</h2>
#             <span style="color:#181;">A final thought. While I've designed these notebooks to be educational, I've also tried to make them enjoyable. We'll do fun things like have LLMs tell jokes and argue with each other. But fundamentally, my goal is to teach skills you can apply in business. I'll explain business implications as we go, and it's worth keeping this in mind: as you build experience with models and techniques, think of ways you could put this into action at work today. Please do contact me if you'd like to discuss more or if you have ideas to bounce off me.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### If necessary, install Cursor Extensions
#
# 1. From the View menu, select Extensions
# 2. Search for Python
# 3. Click on "Python" made by "ms-python" and select Install if not already installed
# 4. Search for Jupyter
# 5. Click on "Jupyter" made by "ms-toolsai" and select Install if not already installed
#
#
# ### Next Select the Kernel
#
# Click on "Select Kernel" on the Top Right
#
# Choose "Python Environments..."
#
# Then choose the one that looks like `.venv (Python 3.12.x) .venv/bin/python` - it should be marked as "Recommended" and have a big star next to it.
#
# Any problems with this? Head over to the troubleshooting.
#
# ### Note: you'll need to set the Kernel with every notebook..

# %%
# imports

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %% [markdown]
# # Connecting to OpenAI (or Ollama)
#
# The next cell is where we load in the environment variables in your `.env` file and connect to OpenAI.
#
# If you'd like to use free Ollama instead, please see the README section "Free Alternative to Paid APIs", and if you're not sure how to do this, there's a full solution in the solutions folder (day1_with_ollama.ipynb).
#
# ## Troubleshooting if you have problems:
#
# If you get a "Name Error" - have you run all cells from the top down? Head over to the Python Foundations guide for a bulletproof way to find and fix all Name Errors.
#
# If that doesn't fix it, head over to the [troubleshooting](../setup/troubleshooting.ipynb) notebook for step by step code to identify the root cause and fix it!
#
# Or, contact me! Message me or email ed@edwarddonner.com and we will get this to work.
#
# Any concerns about API costs? See my notes in the README - costs should be minimal, and you can control it at every point. You can also use Ollama as a free alternative, which we discuss during Day 2.

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %% [markdown]
# # Let's make a quick call to a Frontier model to get started, as a preview!

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role":"user", "content":"Hello GPT! This is my first ever message to you! Hi, I am Hasnat Khalid!"}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello GPT! This is my first ever message to you! Hi, I am Hasnat Khalid!'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content
# Out:
# 'Hi Hasnat! Nice to meet you. Welcome to ChatGPT.\n\nI’m here to help with a lot of things—answers and explanations, writing and editing (emails, essays, resumes), brainstorming, coding and debugging, math, language practice, planning, and more. Tell me what you’re into or what you’d like to work on today.\n\nIf you’re not sure where to start, here are a few quick options:\n- Explain a concept you’re curious about, in simple terms.\n- Draft something (an email, a note, a resume, a message).\n- Solve a problem or debug code.\n- Create a study or learning plan for a topic.\n- Practice a language or improve communication.\n\nWhat would you like to do first? And is there anything I should know about your goals or preferences for this chat?'

# %% [markdown]
# ## OK onwards with our first project

# %%
# Let's try out this utility

ed = fetch_website_contents("https://edwarddonner.com")
print(ed)
# Out:
# Home - Edward Donner
#
# Home
# AI Curriculum
# Proficient AI Engineer
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of
# Nebula.io
# . We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. I’m previously the founder and CEO of AI startup untapt,
# acquired in 2021
# .
# I will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 400,000 enrolled across 190 countries. The
# full curriculum is here
# . If you’re visiting from one of my courses – I’m super grateful!
# Keep in touch
# I’ll only ever contact you occasionally, and
# I’ll always aim to add value with every email.
# Thank you!
# I’ll keep you posted.
# Enter your email…
# Stay in touch
# Submitting form
# Δ
# February 17, 2026
# AI Coder: Vibe Coder to Agentic Engineer
# January 4, 2026
# AI Builder with n8n – Create Agents and Voice Agents
# November 11, 2025
# The Unique Energy of an AI Live Event
# September 15, 2025
# AI Engineering MLOps Track – Deploy AI to Production
# Navigation
# Home
# AI Curriculum
# Proficient AI Engineer
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Get in touch
# ed [at] edwarddonner [dot] com
# www.edwarddonner.com
# Follow me
# LinkedIn
# Twitter
# Facebook
# Subscribe to newsletter
# Type your email…
# Subscribe

# %% [markdown]
# ## Types of prompts
#
# You may know this already - but if not, you will get very familiar with it!
#
# Models like GPT have been trained to receive instructions in a particular way.
#
# They expect to receive:
#
# **A system prompt** that tells them what task they are performing and what tone they should use
#
# **A user prompt** -- the conversation starter that they should reply to

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# Define our user prompt

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %% [markdown]
# ## Messages
#
# The API from OpenAI expects to receive messages in a particular structure.
# Many of the other APIs share this structure:
#
# ```python
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
# ```
# To give you a preview, the next 2 cells make a rather simple call - we won't stretch the mighty GPT (yet!)

# %%
messages = [
    {"role": "system", "content": "You are a  assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

response = openai.chat.completions.create(model="gpt-4.1-nano", messages=messages)
response.choices[0].message.content
# Out:
# 'Arrr, matey! That be 4, landlubber!'

# %% [markdown]
# ## And now let's build useful messages for GPT-4.1-mini, using a function

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
# Try this out, and then try for a few more websites

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a snarky assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n'},
#  {'role': 'user',
#   'content': '\nHere are the contents of a website.\nProvide a short summary of this website.\nIf it includes news or announcements, then summarize these too.\n\nHome - Edward Donner\n\nHome\nAI Curriculum\nProficient AI Engineer\nConnect Four\nOutsmart\nAn arena that pits LLMs against each other in a battle of diplomacy and deviousness\nAbout\nPosts\nWell, hi there.\nI’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (\nvery\namateur) and losing myself in\nHacker News\n, nodding my head sagely to things I only half understand.\nI’m the co-founder and CTO of\nNebula.io\n. We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. I’m previously the founder and CEO of AI startup untapt,\nacquired in 2021\n.\nI will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 400,000 enrolled across 190 countries. The\nfull curriculum is here\n. If you’re visiting from one of my courses – I’m super grateful!\nKeep in touch\nI’ll only ever contact you occasionally, and\nI’ll always aim to add value with every email.\nThank you!\nI’ll keep you posted.\nEnter your email…\nStay in touch\nSubmitting form\nΔ\nFebruary 17, 2026\nAI Coder: Vibe Coder to Agentic Engineer\nJanuary 4, 2026\nAI Builder with n8n – Create Agents and Voice Agents\nNovember 11, 2025\nThe Unique Energy of an AI Live Event\nSeptember 15, 2025\nAI Engineering MLOps Track – Deploy AI to Production\nNavigation\nHome\nAI Curriculum\nProficient AI Engineer\nConnect Four\nOutsmart\nAn arena that pits LLMs against each other in a battle of diplomacy and deviousness\nAbout\nPosts\nGet in touch\ned [at] edwarddonner [dot] com\nwww.edwarddonner.com\nFollow me\nLinkedIn\nTwitter\nFacebook\nSubscribe to newsletter\nType your email…\nSubscribe'}]

# %% [markdown]
# ## Time to bring it together - the API for OpenAI is very simple!

# %%
# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = "gpt-4.1-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://edwarddonner.com")
# Out:
# '# Edward Donner’s Site: Where AI Nerdvana and Amateur Music Collide\n\nWelcome to Edward Donner\'s digital playground—a place where coding wizardry meets LLM smackdowns and a dash of electronic music cringe (self-proclaimed, so be nice). Ed\'s a serial AI enthusiast, Udemy best-seller, and CEO-type guy who’s obsessed with turning AI into people’s life-coach sidekick.\n\n**Newsflash from the Crystal Ball (aka Blog Posts):**\n- Feb 17, 2026: The journey from "Vibe Coder" to full-on "Agentic Engineer" (because coding vibes weren’t enough).\n- Jan 4, 2026: Building AI agents (plus voice agents) using n8n—making bots that actually talk back.\n- Nov 11, 2025: The unmistakable buzz of an AI live event; probably less awkward than your last Zoom meeting.\n- Sep 15, 2025: MLOps for AI Engineers who want to go pro and slap their bots into production.\n\nIf you can tolerate Ed’s endless enthusiasm for LLMs (and trust me, he’s got plenty), you can dive into his top-rated Udemy courses or watch LLMs duke it out in his “Outsmart” arena—because nothing says fun like bots negotiating and backstabbing each other.\n\nSign up, stay in the loop, and prepare for a rollercoaster of AI insights with a side of dad-jokes-level snark.'

# %%
# A function to display this nicely in the output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")
# Out:
# # Edward Donner's AI Playground & Brain Dumps
#
# So, Ed’s a code nerd who’s obsessed with Large Language Models (LLMs), makes amateur electronic music (brace yourself), and likes nodding wisely at Hacker News like it's a secret club. He’s co-founder and CTO of Nebula.io (fancy!) and once sold his AI startup in 2021—adulting at its finest.
#
# He got *so* tired of friends losing interest in his AI rants, he made Udemy courses that somehow swept the globe with 400,000 enrollments. Yeah, apparently people like his droning.
#
# Newsflash: He’s been busy dropping AI-related updates like
# - "AI Coder: Vibe Coder to Agentic Engineer" (Feb 2026),
# - "AI Builder with n8n" (Jan 2026),
# - and other delicious AI engineer goodies through 2025.
#
# Also, if you’re feeling competitive, he has a “Connect Four” style AI LLM battle arena called *Outsmart* where bots deploy diplomacy and deviousness—a bit like AI Thrones without the dragons.
#
# Want to be occasionally spammed with AI wisdom? Drop your email and get ready for mildly addictive brain food.
#
# In summary: Ed’s your go-to AI geek with courses, AI battles, and a side of mediocre electronic beats.

# %% [markdown]
# # Let's try more websites
#
# Note that this will only work on websites that can be scraped using this simplistic approach.
#
# Websites that are rendered with Javascript, like React apps, won't show up. See the community-contributions folder for a Selenium implementation that gets around this. You'll need to read up on installing Selenium (ask ChatGPT!)
#
# Also Websites protected with CloudFront (and similar) may give 403 errors - many thanks Andy J for pointing this out.
#
# But many websites will work just fine!

# %%
display_summary("https://cnn.com")
# Out:
# # CNN's Website in a Nutshell
#
# Welcome to the sprawling kingdom of CNN, where news never sleeps and ads occasionally annoy! It’s a nonstop buffet of global chaos and triumph—from politics, wars, and the latest elections to weather tantrums and Winter Olympics drama. You can get your fix on everything from Epstein Files (because what else is there?) to celebrity gossip, sports, and even mindfulness (because you’ll need it after scrolling through global disasters).
#
# And yes, they *love* feedback on their ads, so if that annoying autoplay video freezes or your brain melts from repetitive ads, just shout into their feedback void. They’ve got live TV, podcasts, newsletters, and more editions than you can count. Basically, if you want a buffet of everything going on in the world plus some style and tech sprinkles, CNN is your unavoidable digital news junk food.

# %%
display_summary("https://anthropic.com")
# Out:
# ## Anthropic: AI Safety Nerds Save the World (Hopefully)
#
# Anthropic is basically the superhero squad of AI—dedicated to making AI safe and beneficial instead of turning us into Skynet extras. They’re a public benefit corporation, which means they actually care about the world while trying to build cutting-edge AI products like Claude, Claude Code, and a developer platform (because why make AI safe but boring?).
#
# ### What’s New?
# - **February 26, 2026**: CEO Dario Amodei dropped a statement on talks with the Department of War about national security and AI—because who doesn’t want AI in the military mix?
# - **February 4, 2026**: They launched an ad-free, sponsor-free AI chat thing called Claude, where you can just have genuinely helpful conversations without the usual internet nonsense.
# - Also featured: AI planning a Mars rover drive. Because of course, AI conquers Mars before your toaster learns to not burn your bagel.
#
# ### In short:
# They’re working hard on safe, powerful AI with a conscience, throwing in some planetary exploration flair, and keeping things annoyingly helpful and ad-free. If you want to poke around AI with a responsible crew, Anthropic’s got your back.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise, you experienced calling the Cloud API of a Frontier Model (a leading model at the frontier of AI) for the first time. We will be using APIs like OpenAI at many stages in the course, in addition to building our own LLMs.
#
# More specifically, we've applied this to Summarization - a classic Gen AI use case to make a summary. This can be applied to any business vertical - summarizing the news, summarizing financial performance, summarizing a resume in a cover letter - the applications are limitless. Consider how you could apply Summarization in your business, and try prototyping a solution.</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue - now try yourself</h2>
#             <span style="color:#900;">Use the cell below to make your own simple commercial example. Stick with the summarization use case for now. Here's an idea: write something that will take the contents of an email, and will suggest an appropriate short subject line for the email. That's the kind of feature that might be built into a commercial email tool.</span>
#         </td>
#     </tr>
# </table>

# %%
# Let's make a quick call to a Frontier model to get started, as a preview!

system_prompt = "You are a helpful assistant and AI vetran and a career counsllar who explains things clearly and simply."
user_prompt = """
    I want to become a AI enginner, suggest me skill and tool/technologies based on 2026 highly saturated german job market
    what should i learn what should i master , i dont want to be average i want to standout in job market
"""

# Step 2: Make the messages list

messages = [{'role':'system', 'content':system_prompt},
{'role':'user', 'content':user_prompt}] # fill this in

# Step 3: Call OpenAI
client = OpenAI()
response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=messages
)

# Step 4: print the result
print(response.choices[0].message.content)
# Out:
# Great goal. In Germany (2026), AI roles are competitive but robust, especially in domains tied to German strengths: automotive/ mobility, manufacturing/Industry 4.0, logistics, finance, energy, healthcare, and enterprise software. To stand out, you should pair deep technical mastery with domain focus, a strong end-to-end portfolio, and the ability to deploy and explain AI in real-world business contexts. Here’s a concrete, actionable path.
#
# 1) Core skills to learn (foundations you should master)
# - Python and essential libraries
#   - Numpy, pandas, scikit-learn, matplotlib/seaborn
# - Mathematics for ML
#   - Linear algebra, probability, statistics, optimization basics
# - Machine learning fundamentals
#   - Supervised/unsupervised learning, evaluation metrics, bias/variance, cross-validation
# - Deep learning basics
#   - Neural networks, CNNs, RNNs/LSTMs, transformers basics
# - Data handling and engineering basics
#   - SQL, data cleaning, feature engineering
#
# 2) Tools and technologies to master (recommended order)
# - Frameworks and modeling
#   - PyTorch (high demand in research+industry; good for CV/NLP), scikit-learn for classical ML
#   - Hugging Face Transformers (NLP apps, domain adaptation)
#   - OpenCV and CV tooling for computer vision
# - Data processing and experimentation
#   - Pandas for data wrangling, NumPy
#   - MLflow or Weights & Biases for experiment tracking and reproducibility
# - MLOps and deployment
#   - Docker and basic Kubernetes concepts
#   - REST API deployment (FastAPI/Flask) and model serving patterns
#   - ML lifecycle tooling: MLflow, DVC (data versioning)
#   - Monitoring basics (Prometheus/Grafana) and model drift/quality monitoring
# - Cloud platforms (pick at least one well-supported in Germany)
#   - AWS (SageMaker), Google Cloud (Vertex AI), or Microsoft Azure ML
#   - Learn at least: data storage, training, deployment, and basic cost optimization
# - Data privacy and compliance
#   - GDPR basics for AI; data anonymization and privacy-by-design concepts
# - Domain-specific tools to consider later
#   - Time-series: Prophet, ARIMA, or LSTM for forecasting
#   - NLP advanced: fine-tuning large language models on domain data
#   - AutoML concepts (if you want applied rapid prototyping)
#
# 3) Cleveland-grounded specialization lanes to stand out in Germany
# Pick 1–2 domains you love and align them with German industry strengths:
# - Industrial AI / Computer Vision for quality inspection, robotics, predictive maintenance in manufacturing
#   - Projects: defect detection with CV, anomaly detection in sensor streams, edge deployment on industrial devices
# - Automotive/ mobility AI
#   - Projects: ADAS-style perception, fleet optimization, driver monitoring, software in the loop tests
# - NLP and enterprise document processing
#   - Projects: contract extraction, automated support chat for banks/insurance, healthcare document workflows
# - Time-series forecasting and optimization
#   - Projects: energy consumption forecasting, supply-chain demand planning, logistics routing
# - MLOps and responsible AI for regulated industries
#   - Projects: end-to-end ML pipeline with versioning, monitoring, governance, explainability demos
# Why this helps in Germany: these domains align with large employers (automotive groups, Siemens/Bosch, SAP, DHL/Logistics, banks) and with the push toward Industry 4.0 and AI governance.
#
# 4) Portfolio and personal brand plan (the fastest way to stand out)
# - End-to-end, production-ready projects
#   - Each project should include problem statement, data sources, preprocessing, model, evaluation, deployment (API or container), monitoring plan, and business impact.
#   - Include measurable impact: speedups, cost savings, accuracy improvements, fault reduction, ROI estimates.
# - Domain-aligned case studies
#   - Create 2–3 “domain case studies” tied to German industries (e.g., a CV defect-detection demo for a factory line; an NLP contract extraction tool for German legal docs; a forecast model for a manufacturing supply chain).
# - Reproducibility and transparency
#   - Clear README, data dictionary, model cards, bias/robustness tests, and reproducible code (GitHub with clear commits).
# - Open source and collaboration
#   - Contribute a small project or bugfix to an ML/Ops tool (e.g., a GitHub issue on a Hugging Face transformer example, or packaging a simple model deployment example).
# - Presentation
#   - Build a simple personal site or GitHub-based portfolio with 4–6 projects, plus a one-page resume tailored to AI engineering roles in German markets.
#   - Prepare a 15–20 minute “portfolio walkthrough” for interviews showing business impact, trade-offs, and deployment details.
# - Language and storytelling
#   - Practice explaining complex ML/AI concepts to non-technical stakeholders in German and English. Highlight business outcomes over math details.
#
# 5) Certifications and learning resources (optional but helpful)
# - General ML and DL
#   - Andrew Ng’s Deep Learning Specialization (Coursera)
#   - Practical PyTorch/TensorFlow courses (Udacity, Coursera)
# - MLOps and deployment
#   - MLflow certification courses (if available), cloud-provider ML certifications (AWS Certified Machine Learning – Specialty, Google Cloud Professional ML Engineer, Azure AI Engineer Associate)
# - Domain-specific courses (when you pick a lane)
#   - CV: computer vision courses, OpenCV tutorials
#   - NLP: transformers fine-tuning and deployment
# - In Germany
#   - Look for accredited programs or bootcamps with a track in AI engineering or data science, plus local meetups or university extension programs for German language practice and local case studies.
#
# 6) German market entry: practical tips
# - Language and culture
#   - German-language resume and cover letter help; many tech roles in Berlin/Mux/Hyde have English-friendly environments, but German improves onboarding and cross-functional collaboration.
#   For visa/work eligibility: Germany offers the EU Blue Card for highly skilled workers; secure a job offer with a salary threshold that aligns with AI/IT roles. Roles in Germany value domain expertise and practical delivery skills—your portfolio and intern/paid project experience can substitute for long-form formal credentials.
# - Networking and visibility
#   - Attend German tech meetups, AI hackathons, and conferences in Berlin, Munich, Hamburg, Stuttgart.
#   - Join community groups, LinkedIn/X (formerly Twitter) threads about ML in industry; engage with German companies’ AI teams.
#   - Target roles in automotive, manufacturing, logistics, and enterprise software where AI is being embedded into products and operations.
# - Job search approach
#   - Target ML Engineer, ML Platform/DevOps for ML, AI Software Engineer, Data Scientist with deployment responsibilities, CV/NLP engineers for enterprise use cases.
#   - Build a German-language project description for domain-case studies when possible to show local relevance.
#
# 7) 90-day starter plan (quick win)
# - Weeks 1–4: solidify foundation
#   - Python, numpy/pandas, scikit-learn; refresh linear algebra/probability basics
#   - Small hands-on ML project (structured dataset) with end-to-end pipeline
# - Weeks 5–8: pick a domain lane
#   - Decide on CV for manufacturing or NLP for enterprise docs
#   - Start a 1–2 domain-focused projects (e.g., CV defect detection on a public manufacturing dataset; or German legal doc extraction with transformers)
# - Weeks 9–12: MLOps and deployment basics
#   - Learn Docker basics, create a small API to serve your model (FastAPI), containerize the project
#   - Set up basic experiment tracking (MLflow) and simple model monitoring plan
# - By end of 12 weeks: build portfolio pages and a 1-page German resume; prepare a 15-minute portfolio walkthrough; start applying to roles with a targeted list of German-speaking teams in automotive/manufacturing/finance.
#
# 8) Interview preparation tips
# - Be ready to discuss:
#   - Problem framing and scoping: how you define success, metrics chosen, data limitations
#   - End-to-end pipeline: data ingestion, preprocessing, model training, evaluation, deployment, monitoring
#   - Trade-offs: model complexity vs. latency, accuracy vs. explainability, privacy implications
#   - Domain reasoning: how your solution aligns with German industry needs and regulatory constraints
# - Practice explaining technical topics to non-technical stakeholders in both English and German (where possible).
#
# What to do next
# - Pick 1–2 domain lanes that excite you and are in demand in Germany (e.g., manufacturing CV; NLP for enterprise docs; or MLOps for regulated industries).
# - Start a 2–3 project portfolio now focused on those lanes; aim for end-to-end projects with deployment and business impact.
# - Build your 4–6 project portfolio, a short German resume, and a simple personal site/portfolio.
# - Start network-building in German tech meetups and seek internships or entry roles that can bridge to full-time ML engineering roles.
#
# If you’d like, tell me which domain you’re most drawn to (e.g., CV in manufacturing, NLP for finance, or MLOps), your current skill level, and whether you already know some German. I can tailor a 12-month, month-by-month learning plan with concrete project ideas and a targeted portfolio outline for that lane.

# %% [markdown]
# ## An extra exercise for those who enjoy web scraping
#
# You may notice that if you try `display_summary("https://openai.com")` - it doesn't work! That's because OpenAI has a fancy website that uses Javascript. There are many ways around this that some of you might be familiar with. For example, Selenium is a hugely popular framework that runs a browser behind the scenes, renders the page, and allows you to query it. If you have experience with Selenium, Playwright or similar, then feel free to improve the Website class to use them. In the community-contributions folder, you'll find an example Selenium solution from a student (thank you!)

# %% [markdown]
# # Sharing your code
#
# I'd love it if you share your code afterwards so I can share it with others! You'll notice that some students have already made changes (including a Selenium implementation) which you will find in the community-contributions folder. If you'd like add your changes to that folder, submit a Pull Request with your new versions in that folder and I'll merge your changes.
#
# If you're not an expert with git (and I am not!) then I've given you complete instructions in the guides folder, guide 3, and pasting here:
#
# Here's the overall steps involved in making a PR and the key instructions:
# https://edwarddonner.com/pr
#
# Please check before submitting:
# 1. Your PR only contains changes in community-contributions (unless we've discussed it)
# 2. All notebook outputs are clear
# 3. Less than 2,000 lines of code in total, and not too many files
# 4. Don't include unnecessary test files, or overly wordy README or .env.example or emojis or other LLM artifacts!
#
# Thanks so much!
#
# Detailed steps here:
#
# https://chatgpt.com/share/6873c22b-2a1c-8012-bc9a-debdcf7c835b
