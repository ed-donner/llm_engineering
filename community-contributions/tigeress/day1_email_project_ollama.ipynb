# %%
# imports
import os
from openai import OpenAI
from IPython.display import Markdown, display
import httpx
# set up environment

ollama = OpenAI(
    base_url='http://localhost:11434/v1', 
    api_key='ollama',
    http_client=httpx.Client(
        trust_env=False  # 👈 ignore system proxy settings
    )
    )

# %%
# step 1 system prompt

system_prompt = """You are a helpful email assistant.
You can do the following tasks:
1. Summarize emails
2. Suggest subject lines
3. Translate email summaries 
4. Reply to emails professionally
Please format your response in Markdown."""

# %%
# step 2 email funtions
def summarize_email(email_content):
    """Summarize the email content"""
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": f"""
        Please summarize this email in a few sentences:
        
        {email_content}
        """}
    ]
    response = ollama.chat.completions.create(
        model="llama3.2",
        messages=messages,
        temperature=0.7
    )
    return response.choices[0].message.content


def suggest_subject(email_content):
    """Suggest a subject line for the email"""
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": f"""
        Please suggest a short appropriate subject 
        line for this email:
        
        {email_content}
        """}
    ]
    response = ollama.chat.completions.create(
        model="llama3.2",
        messages=messages,
        temperature=0.7
    )
    return response.choices[0].message.content


def translate_summary(email_content, language="Chinese"):
    """Summarize and translate the email"""
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": f"""
        Please summarize this email and translate 
        the summary into {language}:
        
        {email_content}
        """}
    ]
    response = ollama.chat.completions.create(
        model="llama3.2",
        messages=messages,
        temperature=0.7
    )
    return response.choices[0].message.content


def reply_to_email(email_content):
    """Generate a professional reply to the email"""
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": f"""
        Please write a professional reply to this email:
        
        {email_content}
        """}
    ]
    response = ollama.chat.completions.create(
        model="llama3.2",
        messages=messages,
        temperature=0.7
    )
    return response.choices[0].message.content

# %%
# email to analyze
email_content = """
Hi Emily, 
long time no see! How are you?
I will be visiting London next week. 
Let's meet for dinner if you have time! 
Best regards,
Cindy
"""

# %%
# Run All Funtions
# 1. Summarize the email
print("=" * 50)
print("📧 EMAIL SUMMARY")
print("=" * 50)
display(Markdown(summarize_email(email_content)))

# 2. Suggest subject line
print("=" * 50)
print("📌 SUGGESTED SUBJECT LINE")
print("=" * 50)
display(Markdown(suggest_subject(email_content)))

# 3. Translate summary to Chinese
print("=" * 50)
print("🌏 CHINESE TRANSLATION")
print("=" * 50)
display(Markdown(translate_summary(email_content, "Chinese")))

# 4. Generate reply
print("=" * 50)
print("✉️ SUGGESTED REPLY")
print("=" * 50)
display(Markdown(reply_to_email(email_content)))
# Out:
# ==================================================
# 📧 EMAIL SUMMARY
# ==================================================
# ### Summary of Email
#
# The email is from Cindy to Emily, a long-time acquaintance. Cindy will be visiting London and would like to catch up with Emily over dinner if she has time available. No specific date or details are mentioned, but the invitation suggests a casual meeting.
# ==================================================
# 📌 SUGGESTED SUBJECT LINE
# ==================================================
# **Suggested Subject Line**
# "Long Time No See: Catching Up in London?"
# ==================================================
# 🌏 CHINESE TRANSLATION
# ==================================================
# **Summary**
# The email is from Cindy to Emily and is a casual greeting with a friendly invitation to meet up for dinner when Cindy visits London next week.
#
# **Translated Summary in Chinese**
# ```
# 中文摘要：
# 来自辛迪的电子信件，内容简单直接。 invites 友人伊敏 (Emily) 在她随后前往伦敦一周后联系，并邀请他们在一起吃饭。
# ```
#
# Note: The translation is a simple and direct summary of the original email.
# ==================================================
# ✉️ SUGGESTED REPLY
# ==================================================
# ### Reply Email
#
# #### To: Cindy
# #### From: Emily
# #### Subject: Re: Long Time No See!
#
# Dear Cindy,
#
# It's great to hear from you after such a long time! I'm doing well, thanks for asking. It's wonderful that you're visiting London next week and I'd be delighted to meet up with you.
#
# I have some time available before my schedule gets busy, so let me check my calendar and we can finalize a date and time that suits both of us. Please give me a day or two to confirm.
#
# Looking forward to catching up over dinner!
#
# Best regards,
# Emily
