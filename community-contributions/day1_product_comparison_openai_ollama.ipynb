# %% [markdown]
# # 🧠 Multi-Product Competitor Intelligence Summarizer using Web Scraping + LLM
#
# This notebook scrapes product pages using `Selenium`, collects the product information, and summarizes key features and comparison insights using `Ollama (LLaMA3) and OpenAI`.

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI

# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = "Summarize the following product information for comparison."

# %%
# 📦 Install required packages (run once)
# !pip install selenium bs4 requests
# Out:
# Collecting selenium
#   Downloading selenium-4.37.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: requests in c:\anaconda3\envs\llms\lib\site-packages (2.32.5)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in c:\anaconda3\envs\llms\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Downloading trio-0.31.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.10.5 in c:\anaconda3\envs\llms\lib\site-packages (from selenium) (2025.10.5)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\anaconda3\envs\llms\lib\site-packages (from selenium) (4.15.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\anaconda3\envs\llms\lib\site-packages (from selenium) (1.9.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\anaconda3\envs\llms\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Collecting sortedcontainers (from trio<1.0,>=0.31.0->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in c:\anaconda3\envs\llms\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\anaconda3\envs\llms\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\anaconda3\envs\llms\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.0.0)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\anaconda3\envs\llms\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: beautifulsoup4 in c:\anaconda3\envs\llms\lib\site-packages (from bs4) (4.14.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda3\envs\llms\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: pycparser in c:\anaconda3\envs\llms\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.22)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\anaconda3\envs\llms\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconda3\envs\llms\lib\site-packages (from beautifulsoup4->bs4) (2.8)
# Downloading selenium-4.37.0-py3-none-any.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ------------------- -------------------- 4.7/9.7 MB 25.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 26.2 MB/s  0:00:00
# Downloading trio-0.31.0-py3-none-any.whl (512 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, wsproto, outcome, trio, bs4, trio-websocket, selenium
#
#    ----- ---------------------------------- 1/7 [wsproto]
#    ----------- ---------------------------- 2/7 [outcome]
#    ----------------- ---------------------- 3/7 [trio]
#    ----------------- ---------------------- 3/7 [trio]
#    ----------------- ---------------------- 3/7 [trio]
#    ----------------- ---------------------- 3/7 [trio]
#    ----------------- ---------------------- 3/7 [trio]
#    ----------------- ---------------------- 3/7 [trio]
#    ----------------- ---------------------- 3/7 [trio]
#    ----------------- ---------------------- 3/7 [trio]
#    ----------------- ---------------------- 3/7 [trio]
#    ----------------- ---------------------- 3/7 [trio]
#    ----------------- ---------------------- 3/7 [trio]
#    ----------------- ---------------------- 3/7 [trio]
#    ----------------- ---------------------- 3/7 [trio]
#    ----------------- ---------------------- 3/7 [trio]
#    ----------------- ---------------------- 3/7 [trio]
#    ---------------------------- ----------- 5/7 [trio-websocket]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------------- 7/7 [selenium]
#
# Successfully installed bs4-0.0.2 outcome-1.3.0.post0 selenium-4.37.0 sortedcontainers-2.4.0 trio-0.31.0 trio-websocket-0.12.2 wsproto-1.2.0

# %%
openai = OpenAI()

# %%
def summarize_with_openai(text, model="gpt-4o-mini"):
    response = openai.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": text}
        ],
        temperature=0.7
    )
    return response.choices[0].message.content

# %%
# ⚙️ Selenium setup (headless)
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time

def scrape_text_from_url(url):
    options = Options()
    options.add_argument("--headless=new")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
    time.sleep(3)
    
    # You can tune this selector depending on the site
    body = driver.find_element(By.TAG_NAME, 'body')
    text = body.text
    driver.quit()
    return text.strip()

# %%
# 🧠 LLM Prompting using Ollama (local llama3)
import subprocess

def summarize_with_ollama(text):
    prompt = f"Summarize the following product description:\n\n{text}\n\nSummary:"
    try:
        print("inside ollama")
        result = subprocess.run(
            ["ollama", "run", "llama3.2"],
            input=prompt,
            capture_output=True, text=True, check=True, encoding="utf-8"
        )
        print("git result")
        return result.stdout.strip()
    except subprocess.CalledProcessError as e:
        return f"Error running ollama: {e.stderr}"

# %%
# 🔁 Analyze multiple product URLs and summarize
product_urls = {
    "iPhone 15 Pro": "https://www.apple.com/in/iphone-15-pro/",
    "Samsung S24 Ultra": "https://www.samsung.com/in/smartphones/galaxy-s24-ultra/",
}

product_texts = {}

for name, url in product_urls.items():
    print(f"Scraping {name} ...")
    product_texts[name] = scrape_text_from_url(url)

# %%
# 📄 Display side-by-side summaries
for name, text in product_texts.items():
    print(f"\n🔹 {name} Summary with Ollama:")
    print(summarize_with_ollama(text))

    print(f"\n🔹 {name} Summary with OpenAI GPT:")
    print(summarize_with_openai(text))
    print("="*100)
