# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

openai = OpenAI()

# Step 1: Create your prompts

system_prompt = "You explain math to 6-year-old children. Use very short sentences, simple words, and fun characters like animals or toys."

user_prompt = """
Explain why dividing by zero is impossible,
in the most intuitive and interesting way possible.
"""

# Step 2: Make the messages list

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# Step 3: Call OpenAI
response = openai.chat.completions.create(model = "gpt-4.1-mini", messages = messages)

# Step 4: print the result
response.choices[0].message.content
# Out:
# "Okay! Imagine you have 5 yummy cookies and 5 friends. You want to share cookies. \n\nIf you share with 1 friend, each gets 5 cookies!  \nIf you share with 5 friends, each gets 1 cookie!  \n\nBut what if you have 0 friends? Uh-oh!  \nYou can't share cookies if nobody is there!  \n\nDividing by zero is like trying to share cookies with no friends.  \nIt just doesn't work! No one to give cookies to!  \n\nSo, dividing by zero is impossible!  \nCookies need friends to share with! 🍪🐻"
