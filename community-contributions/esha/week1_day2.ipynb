# %% [markdown]
# ## Day 2 Lab!

# %% [markdown]
# Give a fun fact using an Open Source model running locally via Ollama

# %%
import os
from openai import OpenAI

# %%
openai = OpenAI(base_url='http://localhost:11434/v1/', api_key='ollama')

# %%
messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
response = openai.chat.completions.create(
    model="gpt-oss:120b-cloud",
    messages=messages
)

# %%
fun_fact = response.choices[0].message.content
print("AI Agent Fun Fact:")
print(fun_fact)
# Out:
# AI Agent Fun Fact:
# **Fun Fact:** A single honeybee can visit up to 5,000 flowers in one day—and in doing so, it can travel the equivalent of **twice the distance around the Earth** in its short lifetime! 🐝🌍
#
# **Why it’s cool:**
# - Bees are tiny (about 1⁄2 inch long), but they’re incredibly efficient foragers.
# - While they’re buzzing from flower to flower, they not only collect nectar and pollen but also spread plant genes across vast areas, helping ecosystems stay healthy.
# - The “twice‑around‑the‑Earth” figure comes from the fact that a bee’s average foraging range is about 3 miles (5 km) from its hive, and with thousands of trips per day, the cumulative distance adds up fast.
#
# So the next time you see a bee buzzing by, remember it’s essentially a miniature world traveler on a mission! 🌸✨
