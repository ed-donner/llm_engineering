# %% [markdown]
# # Kolekne kroki do wykonania
#
# 1. Instalacja:
#     1. Cursor AI
#     2. Środowiska UV (`uv`) -> [link do komend uv]()
#     3. Środowiska GIT (`git`) -> [link do komend do git + przepływ pracy]()
#     4. Ollama
# 2. Pobranie kodu do kursu z GitHuba:
#     1. Wykonanie `forka` i działanie w GitHubie
#     2.
# 3. Tworzenie środowiska Pythona lokalnie `.venv`
# 4. Tworzenie pliku `.env` z danymi wrażliwymi takie jak API key
# 5.
