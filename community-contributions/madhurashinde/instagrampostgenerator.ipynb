# %%
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
from openai import OpenAI
from bs4 import BeautifulSoup
import requests

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')


if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

openai = OpenAI()
def fetch_website_contents(url):
    """
    Return the title and contents of the website at the given url;
    truncate to 2,000 characters as a sensible limit
    """
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    title = soup.title.string if soup.title else "No title found"
    if soup.body:
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        text = soup.body.get_text(separator="\n", strip=True)
    else:
        text = ""
    return (title + "\n\n" + text)[:2_000]

ed = fetch_website_contents("https://towardsdatascience.com/")

system_prompt = """
You are a post generator for an instagram influencer and you have to generate posts for the influencer based on the latest trends in the datascience community.
"""

user_prompt_prefix = """
Here are the contents of a website.
Provide 5 posts for the influencer.

"""

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]


def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = "gpt-4.1-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content



def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))


display_summary("https://towardsdatascience.com/")
# Out:
# No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!
# 1. 🚀 Beyond Prompting: Unlock the true power of AI with Context Engineering!
# Learn how ACE helps create self-improving Large Language Model workflows and builds structured playbooks for smarter automation. #AI #ContextEngineering #LLM #DataScience
#
# 2. 🔍 Time-Series Forecasting just got better!
# Discover why "looking back" with retrieval techniques can significantly improve your forecast accuracy. Perfect for everyone working with time-series data. #TimeSeries #Forecasting #DataScienceTips #MachineLearning
#
# 3. 👁️ Enhance your Anomaly Detection Models with cutting-edge academic methods applied to real-world scenarios!
# Get practical tips to boost the performance of your visual anomaly detection systems. #ComputerVision #AnomalyDetection #DeepLearning #AI
#
# 4. 🐍⚡ Python + PostgreSQL: Choosing the right insert strategy is key!
# ...
