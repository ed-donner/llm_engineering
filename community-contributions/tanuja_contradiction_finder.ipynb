# %% [markdown]
# # Webpage Contradiction Finder
#
# This notebook downloads a webpage, extracts its readable text, and uses
# a local Ollama Gemma 3 model to identify potentially contradictory claims.
#
# The tool does not verify whether a claim is factually true. It only looks
# for statements within the webpage that appear inconsistent with each other.

# %%
import re

import requests
from bs4 import BeautifulSoup
from openai import OpenAI

MODEL = "gemma3"
MAX_CHARS = 12000

client = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama",
)
