# %%
import os
import requests 
from dotenv import load_dotenv
# from scraper import fetch_website_contents #not needed as extracting using jina ai
from IPython.display import Markdown, display
from openai import OpenAI

# %%
paper_url = 'https://rsisinternational.org/journals/ijrsi/articles/ai-powered-automated-and-portable-device-for-retinal-health-assessment/#:~:text=and%20portable%20solution%20using%20a,It%20is%20a'

# %%
#!ollama rm llama3.2:3b
# Out:
# Error: model 'llama3.2:3b' not found

# %%
# !ollama pull llama3.2:3b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
MODEL = "llama3.2:3b"
OLLAMA_BASE_URL = "http://localhost:11434/v1"
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
system_prompt = """
You are a precise and expert research paper analyst.
Given the scraped content of a research paper webpage, extract and present ONLY the following sections in structured markdown.
Do NOT invent or assume anything not present in the content.

## Paper Title
The full title of the paper.

## Authors
A list of all authors.

## Methodology
How the research was conducted — the approach, experimental setup, and evaluation methods used.

## Components / Technologies Used
All hardware components, software frameworks, machine learning models, libraries, datasets, sensors, or tools mentioned.

## PDF Link
The direct link to the PDF version of the paper if present in the content. Otherwise write: *Not found in content.*

## References
A numbered list of the key references cited in the paper.

## Research Gap
The specific gap, limitation, or unsolved problem in existing research that this paper identifies and addresses.

Respond in clean markdown. Do not wrap the markdown in a code block.
"""

# %%
user_prompt_prefix = """
Below is the scraped content of a research paper webpage.
Extract and structure all the requested information exactly as instructed in the system prompt.

---

"""

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
def fetch_website_contents(url):
    jina_url = f"https://r.jina.ai/{url}"
    headers = {
        "Authorization": "Bearer jina_2459dfb4dfc74a2485b91258a7113dcdWuNEPpbXB6QZL6AN1QVQy6z-2f9G",
        "X-Engine": "browser"
    }
    response = requests.get(jina_url, headers=headers)
    response.raise_for_status()
    return response.text

# %%
def summarize(url):
    content = fetch_website_contents(url)
    response = ollama.chat.completions.create(
        model=MODEL,
        messages=messages_for(content)
    )
    return response.choices[0].message.content

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary(paper_url)
# Out:
# The provided text is a draft of a journal article submission for the "Journal of Rural Science and Technology" (J-RST). Here's a reorganized version with proper formatting and headings:
#
# **Title**
#
# AI-Powered, Automated, and Portable Device for Retinal Health Assessment: A Review and Future Directions
#
# **Abstract**
#
# The advent of AI-powered technologies has revolutionized various fields of science and medicine. In this review article, we explore the development, applications, and future directions of an AI-powered, automated, and portable device designed to assess retinal health. Our comprehensive analysis highlights the benefits, limitations, and potential impact of such devices on global healthcare outcomes.
#
# **Introduction**
#
# Retinal diseases are a significant cause of blindness worldwide, with millions of people suffering from conditions like diabetic retinopathy, glaucoma, and age-related macular degeneration (AMD). Traditional diagnostic methods often involve subjective assessments by clinicians or optical coherence tomography (OCT) technology. Recent advancements in AI-powered technologies have led to the development of innovative devices capable of automated and portable retinal health assessments.
#
# **Methods**
#
# We conducted a systematic review of existing literature on AI-powered, automated, and portable devices for retinal health assessment. Our search included peer-reviewed articles, conference proceedings, and patents related to the topic. We analyzed the results, highlighting key characteristics, applications, benefits, limitations, and future directions of these devices.
#
# **Discussion**
#
# The analysis revealed several AI-powered devices capable of detecting various retinal diseases with high accuracy. These devices leverage computer vision algorithms, deep learning techniques, and machine learning models to analyze images obtained through mobile retinoscopes or digital cameras. Key advantages of these devices include portability, affordability, ease of use, and speed.
#
# **Conclusion**
#
# The development of AI-powered, automated, and portable devices for retinal health assessment holds significant promise for improving global healthcare outcomes. Future research directions should focus on standardizing evaluation protocols, enhancing device calibration, and exploring clinical trial methodologies to validate these technologies in real-world settings.
#
# **Future Directions**
#
# We foresee a future where AI-powered, automated, and portable devices become an integral part of primary care services worldwide. Continuous innovation in this field will lead to more effective diagnostic and therapeutic interventions for retinal diseases. Additionally, partnerships between industries, academia, and research institutions are necessary to drive progress in this area.
#
# **References**
#
# [List of reference sources cited in the article]
#
# **Disclaimer**
#
# The views expressed in this study do not necessarily reflect those of the authors or peer review board members.
#
# **Table 1: Key Characteristics of AI-Powered Devices for Retinal Health Assessment**
#
# | Criteria | Device A | Device B | Device C |
# | --- | --- | --- | --- |
# | Detection accuracy | 95% (sensitivity) | 90% (specificity) | 98.5% (precision) |
# | Portability | Yes | No | Yes |
# | Affordability | Low-cost (~ $500) | High-end (~ $20,000) | Moderate (~ $2,000) |
#
# **Table 2: Results of Clinical Trials Conducted on AI-Powered Devices**
#
# | Trial ID | Study Design | N (Patients) | Outcome Measure | p-values (significance level = 0.05) |
# | --- | --- | --- | --- | --- |
# | ITG001 | Case-control | 100 | Sensitivity: 95.2% (95% CI: 92-97.4%) | < 0.01 |
# | ABT012 | Cross-sectional | 200 | Precision: 93.7% (90-96.9%) | < 0.01 |
#
# Note: Tables and figures are not included in this text. However, they would typically accompany the article to provide additional supporting information.
#
# **Timeline**
#
# This review article outlines a comprehensive analysis of AI-powered, automated, and portable devices designed for retinal health assessment. Future studies should build upon these findings, focusing on clinical trial methodologies and real-world applications.
#
# By combining innovative technologies like AI with healthcare services in resource-limited settings, we aim to bridge the gap between diagnosis and treatment for millions suffering from vision loss worldwide.
