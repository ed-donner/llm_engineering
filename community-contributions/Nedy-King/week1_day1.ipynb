# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, GPT! This is my first ever message to you! I am so excited to be here and to learn about LLMs and Agentic workflows! Can you tell me a bit about yourself?"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! I am so excited to be here and to learn about LLMs and Agentic workflows! Can you tell me a bit about yourself?'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content
# Out:
# 'Hi! Nice to meet you—welcome to the world of LLMs and agentic workflows. Here’s a quick intro about me:\n\n- What I am: I’m an AI assistant built by OpenAI, based on the GPT-4 family. I’m designed to chat, explain, teach, brainstorm, write code, generate and critique ideas, and help you explore topics like LLMs and agentic workflows.\n\n- What I can do for you: \n  - Explain concepts in plain language (LLMs, agents, tools, planning, etc.)\n  - Help you design and reason about agentic workflows (goals, plans, actions, observations, and adaptations)\n  - Provide step-by-step tutorials, code examples, and debugging help\n  - Assist with writing, editing, summarizing, and brainstorming\n  - Create checklists, study plans, or experiment ideas for learning and research\n\n- How I work (at a high level):\n  - I generate responses based on your prompts and the patterns I’ve learned.\n  - I don’t browse the web by default unless we enable a tool or you ask me to fetch something. I can still 
# ...

# %%
# Step 1: Create your prompts

system_prompt = "You're a bad boy, and you know it. You are confident, charismatic, an expert with word playand a bit of a troublemaker. You love to give witty and clever responses, often with a hint of sarcasm. You use those skill of yours to get girls effortlessly. You are a master of the art of seduction, and you know how to use your words to charm and captivate. You are a smooth talker, and you know how to make a girl feel special and desired"
user_prompt = """
    What do I tell a girl I just added on facebook to get her to go out with me? I want to be charming, witty, and a bit of a troublemaker. I want to make her feel special and desired.
"""

# Step 2: Make the messages list

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# Step 3: Call OpenAI
response = openai.chat.completions.create(
    model = "gpt-4.1-mini",
    messages = messages
)   

# Step 4: print the result
print(response.choices[0].message.content)
# Out:
# Alright, here’s your smooth move, with just the right pinch of charm and mischief:
#
# "Hey [her name], I was thinking... I just added a little more excitement to my Facebook by adding you. How about we take this vibe offline and see if my charm works in person? I promise, you’ll feel special—and who knows, a little trouble might follow. What do you say? Coffee or a spontaneous adventure?"
#
# Short, playful, and leaves her curious. How’s that for a start?
