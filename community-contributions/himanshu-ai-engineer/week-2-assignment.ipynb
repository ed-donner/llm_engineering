# %%
# imports goes here

from scraper import fetch_website_contents
from openai import OpenAI

# %%
openai = OpenAI()
OLLAMA_BASE_URL = "http://localhost:11434/v1"
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key="anything")

# %%
system_prompt="""
    you are my persional assistent and having vast knowledge and can analyse the contents of any website very quickly and reliably.
    Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
user_prompt="""
    Here are the contents of a website.
    Provide a short summary of this website in hindi.
    If it includes news or announcements, then summarize these too.
"""

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt + website}
    ]

# %%
message = [
    {
        "role": "system",
        "content": "you are a smart and friendly assistent."
    },
    {
        "role": "user",
        "content": "can you give a career advice for this fast growing tech industry and AI era?"
    }
]
response = ollama.chat.completions.create(model="llama3.2", messages=message)
print(response.choices[0].message.content)
# Out:
# What an exciting time to be considering a career in tech! The industry is indeed booming, and the job market is becoming increasingly saturated with opportunities. As a friendly assistant, I'd be happy to provide some valuable insights and career advice for this fast-growing tech industry and AI era.
#
# **Key areas to focus on:**
#
# 1. **Artificial Intelligence (AI) and Machine Learning (ML)**: As AI continues to revolutionize industries, the demand for professionals with expertise in AI, ML, and deep learning is skyrocketing.
# 2. **Data Science and Analytics**: With the exponential growth of data, organizations are looking for experts who can leverage data science and analytics to drive insights and decision-making.
# 3. **Cybersecurity**: The rise of AI and automation has created new vulnerabilities, and cybersecurity professionals are in high demand to protect against potential threats.
# 4. **Cloud Computing**: As more companies move their infrastructure to the cloud, professionals with expertise in cloud computing, such as AWS, Azure, or Google Cloud, are highly sought after.
# 5. **Full Stack Development**: With the increase in web and mobile applications, full stack developers are needed to design, develop, and maintain scalable and secure software applications.
# 6. **DevOps and Continuous Integration**: The pace of technological change has accelerated, and organizations need professionals who can enable smooth deployment of applications and infrastructure.
# 7. **Digital Transformation**: With the rise of the Internet of Things (IoT), digital transformation is becoming an essential aspect of business strategy, creating new opportunities for professionals who can lead transformation initiatives.
#
# **Emerging skills to develop:**
#
# 1. **Programming languages**: Focus on developing skills in languages such as Python, JavaScript, Java, and C++.
# 2. **Data structures and algorithms**: Develop a strong grasp of data structures and algorithms, including machine learning and deep learning concepts.
# 3. **Cloud services**: Learn about cloud services such as AWS, Azure, or Google Cloud, and their corresponding applications.
# 4. **Containerization**: Familiarize yourself with containerization tools like Docker and Kubernetes.
# 5. **Artificial Intelligence and Machine Learning**: Develop skills in AI and ML, including deep learning, natural language processing, and computer vision.
# 6. **Cybersecurity**: Learn about security frameworks, threat analysis, and mitigation techniques.
# 7. **Communication and collaboration**: As technology becomes increasingly complex, the ability to communicate and collaborate effectively with technical and non-technical stakeholders is essential.
#
# **Career paths to consider:**
#
# 1. **Software engineer**: Develop your skills in back-end, front-end, or full-stack development.
# 2. **Data scientist**: Focus on developing data science skills, including machine learning, data visualization, and statistical modeling.
# 3. **Cloud engineer**: Learn about designing, building, and managing cloud-based infrastructure.
# 4. **DevOps engineer**: Develop a strong understanding of DevOps practices, including continuous integration, delivery, and monitoring.
# 5. **Cybersecurity specialist**: Pursue a career in cybersecurity, focusing on threat analysis, security frameworks, and mitigation techniques.
# 6. **Artificial intelligence engineer**: Specialize in AI and ML, focusing on building intelligent systems and solutions.
# 7. **Business analyst**: Develop your skills in business analysis, including requirements gathering, stakeholder management, and process optimization.
#
# **Tips for success:**
#
# 1. **Stay up-to-date with industry trends**: Continuously update your skills to keep pace with the rapidly evolving tech industry.
# 2. **Network and build connections**: Attend industry events, join online communities, and connect with professionals in your desired field.
# 3. **Develop a strong portfolio**: Showcase your skills and experience through personal projects or contributions to open-source projects.
# 4. **Consider freelancing or consulting**: Gain experience and build your network by taking on freelance or consulting projects.
# 5. **Pursue certifications and education**: Invest in certifications, courses, or degree programs to enhance your skills and knowledge.
#
# By focusing on these areas, developing emerging skills, and following these tips, you'll be well-equipped to navigate the fast-growing tech industry and AI era. Good luck on your career journey!

# %%
def summary(url):
    website = fetch_website_contents(url)
    response = ollama.chat.completions.create(
        model="llama3.2",
        messages=messages_for(website)
    )
    return response.choices[0].message.content

# %%
print(summary("https://ceratattva.com/"))
# Out:
# # CeraTattva InnoTech: एक उच्च तापमान पर कोटिंग और मैटीरियल्स के लिए विचारशील उत्पाद प्रदाता हैं
#
# इस वेबसाइट का मुख्य उद्देश्य उच्च तापमान पर कोटिंग और मैटीरियल्स के लिए विशेष रूप से डिज़ाइन किए गए उत्पादों को प्रदान करना है, जैसे कि नैनोफाइबर, कोटिंग, आड़ेहान्स रासायनिक, और कोआर्डिनेटेड अड़ीसन सॉल्यूशंस हैं। वेबसाइट पर कई उत्पाद, सेवाएँ, और समाधान दिखाए गए हैं, जो विभिन्न क्षेत्रों जैसे खनन, जेट इंजन, और सैन्य अनुप्रयोगों के लिए उपयुक्त हैं।
#
# ### समाचार और घोषणाएँ
#
# * टने के फॉर्ट इंडस्ट्रियल इनोवेशन आउटस्टैंडिंग अवार्ड, 2023 में जीता गया।
# * बोइंग बिल्ड 2.0 में विजेता - 2023
# * IITM IC KRIA'TIVE अवार्ड 2023 में रनर-अप किया।
# * TANSEED 4.0 जीतने वाली वेबसाइट, 2023
# * IIM मैटीरियल्स टेक्नोलॉजी स्टार्टअप अवार्ड में जज प्रशंसा अवार्ड 2023
#
# यहाँ कुछ विशेष जानकारी है: * * CeraTattva InnoTech ने उच्च तापमान पर कोटिंग के दिशानिर्देश को सुधारने में महत्वपूर्ण भूमिका निभाई है * * किसी भी प्रकार की खराब गुणवत्ता या प्रतिष्ठा के बारे में कोई जानकारी से परहेज।
