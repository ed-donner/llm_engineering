# %% [markdown]
# # Day 4
#
# ## Tokenizing with code

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4.1-mini")

tokens = encoding.encode("Hi my name is soni and poetry is my thing")

# %%
tokens
# Out:
# [12194, 922, 1308, 382, 2391, 72, 326, 38153, 382, 922, 4435]

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} = {token_text}")
# Out:
# 12194 = Hi
# 922 =  my
# 1308 =  name
# 382 =  is
# 2391 =  son
# 72 = i
# 326 =  and
# 38153 =  poetry
# 382 =  is
# 922 =  my
# 4435 =  thing

# %%
encoding.decode([12243])
# Out:
# 'izable'

# %%
from openai import OpenAI

openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

# %% [markdown]
# ### A message to OpenAI is a list of dicts

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi! I'm Soni!"}
    ]

# %%
response = openai.chat.completions.create(model="llama3.2", messages=messages)
response.choices[0].message.content
# Out:
# "Hi Soni! It's nice to meet you. What's on your mind today? Do you need assistance with anything or just want to chat?"

# %% [markdown]
# ### OK let's now ask a follow-up question

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What's my name?"}
    ]

# %%
response = openai.chat.completions.create(model="llama3.2", messages=messages)
response.choices[0].message.content
# Out:
# "I don't have that information. I'm a large language model, I don't have the ability to store or recall personal data about individual users, including their names. Each time you interact with me, it's a new conversation and I don't retain any information from previous conversations. Would you like to tell me your name?"

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi! I'm Soni!"},
    {"role": "assistant", "content": "Hi Soni! How can I assist you today?"},
    {"role": "user", "content": "What's my name?"}
    ]

# %%
response = openai.chat.completions.create(model="llama3.2", messages=messages)
response.choices[0].message.content
# Out:
# 'Your name is Soni.'
