# %% [markdown]
# # Sentiment Analyzer from PDF file.
# File is a poetry book of few poems which is analysed sentiment each one, results are depicted in bar and line diagram.
#
# free poetry book
# https://www.obooko.com/free-poetry-collections/the-dead-tell-no-tales
#
# https://colab.research.google.com/drive/1UVuyuNAHHRxLgniCExWXhavCpGHq3xO7?usp=sharing
