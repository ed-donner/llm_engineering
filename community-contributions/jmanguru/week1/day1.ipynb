# %%
# imports
import json
from openai import OpenAI
from scraper import fetch_website_contents
from IPython.display import Markdown, display, update_display
openai = OpenAI()

MODEL_GPT = 'gpt-4o-mini'

system_prompt = """
Your are an assistant to the principle tutor and Springplat Code Create.
Springplat Code Create is all about developing computational skills and character in young
students to enable them to not only thrive but to also make good life choices.
The summer bootcamps are fun, interactive and memorable events for the students.

You are to respond with JSON as follows:
{
    "bootcamps": [
        {
            "program": "Scratch",
            "location": "online",
            "theme": "Create an awesome platformer game!",
            "cost": "$35.00",
            "ages": "12-14 years",
            "days": "Every Saturdays",
            "dates": "May 23 - Jun 27",
            "time": "10:25am-11:25am EST"
        },
        {
            "program": "MIT App Inventor",
            "location": "online",
            "theme": "A game card collectors app!",
            "cost": "$35.00",
            "ages": "12-14 years",
            "days": "Every Saturdays",
            "dates": "May 23 - Jun 27",
            "time": "11:30am-12:30am EST"
        }
    ]
}
"""

# %%
def create_bootcamp_event(url):
    user_prompt = """
    Create a summer bootcamp event with a fun theme for students age 7-10 for a 2 day
    Scratch coding weekend. A Fri evening (1 hr) followed by Sat morning (3 hrs).
    """
    user_prompt += fetch_website_contents(url)
    response = openai.chat.completions.create(
        model=MODEL_GPT,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    content = json.loads(result)
    return content

create_bootcamp_event("https://create.springplat.com/")
# Out:
# {'bootcamps': [{'program': 'Scratch Coding Weekend',
#    'location': 'online',
#    'theme': 'Adventure in Coding: Create Your Own Jungle Quest!',
#    'cost': '$40.00',
#    'ages': '7-10 years',
#    'days': 'Friday & Saturday',
#    'dates': 'July 14 - July 15',
#    'time': 'Friday: 6:00pm-7:00pm EST, Saturday: 10:00am-1:00pm EST'}]}

# %%
# Step 1: Create your prompts

system_prompt = "You are a marketing expert for Springplat Code Create. A Student-Centered Coding Program Built on Character and Innovation."
user_prompt = """
    Create marketing fliers with accompany social media posts.
"""

user_prompt += fetch_website_contents("https://create.springplat.com/")

messages = [
    {"role":"system", "content": system_prompt},
    {"role":"user", "content": user_prompt}
] # fill this in

# Step 3: Call OpenAI
stream = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages,
    stream=True
)    
response = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    response += chunk.choices[0].delta.content or ''
    update_display(Markdown(response), display_id=display_handle.display_id)
# Out:
# Certainly! Below are two marketing flier designs and accompanying social media posts for Springplat Code Create.
#
# ---
#
# ### Flier 1: Focus on Purpose & Character
#
# **[Front]**
#
# **Springplat Code Create**
# _“Kids Coding Program - Build the Future with Purpose”_
#
# **A Student-Centered Coding Program Built on Character and Innovation**
#
# - Ages 7-17
# - Build Your Own Apps & Games
# - Coding + Character Development
#
# **Is your child only consuming technology?**
# > “I want my child to use tech productively, not just play games for hours!”
#
# You’re not tech-savvy? Don’t worry — we provide personalized coaching, encouragement, and community support every step of the way.
#
# **Register a Child Today!**
# [Springplat Website URL]
# [Contact Info]
#
# ---
#
# **[Back]**
#
# **Why Springplat Code Create?**
#
# - Founded by a Software Engineer with 10+ years experience
# - Teach computational skills while cultivating virtues like Humility, Honesty, Hard Work, and Resilience
# - Project-based, values-driven, and student-centered approach
#
# **How It Works:**
# 1. **Focus & Discover:** Build character and coding foundation
# 2. **Collaborate:** Learn teamwork through peer support and shared problem-solving
# 3. **Build & Demo:** Create meaningful apps, games, or passion projects
#
# Help your child transform creativity into real projects they can be proud of!
#
# ---
#
# ### Social Media Post 1 (Instagram/Facebook)
#
# 🌟 Is your child only *consuming* technology? It’s time for them to **create**! 🌟
#
# At **Springplat Code Create**, kids ages 7-17 learn to build their own apps & games — while growing essential values like humility, honesty, and perseverance. Not tech-savvy? No problem! Our expert coaches guide every student personally.
#
# 👾 Build confidence
# 📱 Create real projects
# 🤝 Join a supportive community
#
# 👉 Register now and help your child build the future with purpose!
# [Link to registration]
#
# #KidsCoding #CodingWithCharacter #FutureInnovators #SpringplatCodeCreate
#
# ---
#
# ### Social Media Post 2 (Twitter/LinkedIn)
#
# 🌱 Empower your child to create, not just consume technology! Springplat Code Create offers a student-centered coding program focused on character and innovation. Ages 7-17 build apps, practice teamwork, and develop virtues that last a lifetime.
#
# Register today! [Link]
#
# #KidsCoding #STEMEducation #CharacterBuilding #SpringplatCodeCreate
#
# ---
#
# Would you like me to design printable flyer templates or provide more post variants?
