# %% [markdown]
# # YOUR FIRST LAB
# ### Please read this section. This is valuable to get you prepared, even if it's a long read -- it's important stuff.
#
# ### Also, be sure to read [README.md](../README.md)! More info about the updated videos in the README and [top of the course resources in purple](https://edwarddonner.com/2024/11/13/llm-engineering-resources/)
#
# ## Your first Frontier LLM Project
#
# By the end of this course, you will have built an autonomous Agentic AI solution with 7 agents that collaborate to solve a business problem. All in good time! We will start with something smaller...
#
# Our goal is to code a new kind of Web Browser. Give it a URL, and it will respond with a summary. The Reader's Digest of the internet!!
#
# Before starting, you should have completed the setup linked in the README.
#
# ### If you're new to working in "Notebooks" (also known as Labs or Jupyter Lab)
#
# Welcome to the wonderful world of Data Science experimentation! Simply click in each "cell" with code in it, such as the cell immediately below this text, and hit Shift+Return to execute that cell. Be sure to run every cell, starting at the top, in order.
#
# Please look in the [Guides folder](../guides/01_intro.ipynb) for all the guides.
#
# ## I am here to help
#
# If you have any problems at all, please do reach out.
# I'm available through the platform, or at ed@edwarddonner.com, or at https://www.linkedin.com/in/eddonner/ if you'd like to connect (and I love connecting!)
# And this is new to me, but I'm also trying out X at [@edwarddonner](https://x.com/edwarddonner) - if you're on X, please show me how it's done 😂
#
# ## More troubleshooting
#
# Please see the [troubleshooting](../setup/troubleshooting.ipynb) notebook in the setup folder to diagnose and fix common problems. At the very end of it is a diagnostics script with some useful debug info.
#
# ## If this is old hat!
#
# If you're already comfortable with today's material, please hang in there; you can move swiftly through the first few labs - we will get much more in depth as the weeks progress. Ultimately we will fine-tune our own LLM to compete with OpenAI!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Please read - important note</h2>
#             <span style="color:#900;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations. If you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">This code is a live resource - keep an eye out for my emails</h2>
#             <span style="color:#f71;">I push updates to the code regularly. As people ask questions, I add more examples or improved commentary. As a result, you'll notice that the code below isn't identical to the videos. Everything from the videos is here; but I've also added better explanations and new models like DeepSeek. Consider this like an interactive book.<br/><br/>
#                 I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business value of these exercises</h2>
#             <span style="color:#181;">A final thought. While I've designed these notebooks to be educational, I've also tried to make them enjoyable. We'll do fun things like have LLMs tell jokes and argue with each other. But fundamentally, my goal is to teach skills you can apply in business. I'll explain business implications as we go, and it's worth keeping this in mind: as you build experience with models and techniques, think of ways you could put this into action at work today. Please do contact me if you'd like to discuss more or if you have ideas to bounce off me.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### If necessary, install Cursor Extensions
#
# 1. From the View menu, select Extensions
# 2. Search for Python
# 3. Click on "Python" made by "ms-python" and select Install if not already installed
# 4. Search for Jupyter
# 5. Click on "Jupyter" made by "ms-toolsai" and select Install if not already installed
#
#
# ### Next Select the Kernel
#
# Click on "Select Kernel" on the Top Right
#
# Choose "Python Environments..."
#
# Then choose the one that looks like `.venv (Python 3.12.x) .venv/bin/python` - it should be marked as "Recommended" and have a big star next to it.
#
# Any problems with this? Head over to the troubleshooting.
#
# ### Note: you'll need to set the Kernel with every notebook..

# %%
# imports


# imports
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display, update_display
from scraper import fetch_website_contents, fetch_website_links


# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %% [markdown]
# # Connecting to OpenAI (or Ollama)
#
# The next cell is where we load in the environment variables in your `.env` file and connect to OpenAI.
#
# If you'd like to use free Ollama instead, please see the README section "Free Alternative to Paid APIs", and if you're not sure how to do this, there's a full solution in the solutions folder (day1_with_ollama.ipynb).
#
# ## Troubleshooting if you have problems:
#
# If you get a "Name Error" - have you run all cells from the top down? Head over to the Python Foundations guide for a bulletproof way to find and fix all Name Errors.
#
# If that doesn't fix it, head over to the [troubleshooting](../setup/troubleshooting.ipynb) notebook for step by step code to identify the root cause and fix it!
#
# Or, contact me! Message me or email ed@edwarddonner.com and we will get this to work.
#
# Any concerns about API costs? See my notes in the README - costs should be minimal, and you can control it at every point. You can also use Ollama as a free alternative, which we discuss during Day 2.

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %% [markdown]
# # Let's make a quick call to a Frontier model to get started, as a preview!

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)
response.choices[0].message.content
# Out:
# 'Hi there! Nice to meet you, and welcome — I’m glad you joined.\n\nI’m here to help with questions, explanations, writing, coding, planning, brainstorming, and casual chat. What would you like to do today? If you’re not sure, here are quick ideas:\n- Ask me to explain a topic in simple terms\n- Draft or edit a message, email, or resume\n- Get a step-by-step guide for a task\n- Create a story, poem, or game\n- Solve a math problem or review code\n- Plan a meal, trip, or study schedule\n- Learn a new phrase in another language\n\nOr just tell me about your day. What would you like to start with?'

# %%
# Let's try out this utility

ed = fetch_website_contents("https://virpiniemigolf.fi/")
print(ed)
# Out:
# Virpiniemi Golf - merellinen golfkenttä Oulussa | Virpiniemi Golf
#
# Oma tili
# Kirjaudu ulos
# Navigaatio
# English
# Svenska
# Kirjaudu sisään
# Rekisteröidy
# Navigaatio
# Ajankohtaista
# Pelaamaan
# Liity jäseneksi
# Hinnasto
# Säännöt
# Kilpailut ja tapahtumat
# Backtee Tour
# Santikka-Wilson Viikkokilpailu
# Virpiniemi Private -paketit
# Kenttä
# Kenttäesittely
# Väyläkartta
# Slope-taulukot
# Harjoittelualueet
# Verkkokauppa
# Opetus
# Alkeiskurssit ja aloittelijapaketit
# Head Pro   J-P Savolampi
# Kertauskurssit
# Ryhmäharjoittelu
# Tiistain treeniryhmä
# Naisten treeniryhmä
# Äijäryhmä
# Kilparyhmä
# Opetusklinikat
# Avoimet opetusklinikat
# Osakkaiden opetusklinikat
# Golfmatkat
# Talviharjoittelu
# Assistant Pro  Matti Paaso
# Assistant Pro  Risto Keskitalo
# Klubilaiset
# Osakasedut
# Jäsenille
# Ladygolf
# Äijägolf
# Juniorit
# Junnugolf
# Ohjeet ja materiaalit
# Tilaa uutiskirje
# Palvelut
# Ravintola Spoon
# Pro Shop
# Saunatilat
# Kokoustilat
# Yrityksille
# Trackman
# Ota yhteyttä
# Virpiniemi Golf Oy
# Virpiniemi Golf Club Ry
# Virpiniemi Golf Club ry:n säännöt
# Etusivu
# Kauppa
# Ajanvaraus
# Aloita Golf
# Virpiniemi Golf
# Parasta Golfia.
# Tunne aamukosteus ihollasi sumun vielä peittäessä viheriöt tai pelaa yöttömän yön kierros ilta-auringon laskiessa merelle. Koe Harjun kangasmaaston korkeuserot ja henkeäsalpaava näky Merelle. Nauti lasillinen kuohuvaa klubitalon terassilla tai suuntaa suoraan kentälle valitsemaan oma reittisi viheriölle.
# Olitpa sitten luonnon hiljaisuudesta nauttiva seikkailija tai itsensä haastava kilpailija, kokeilunhaluinen tulokas tai jo vanha konkari, Virpiniemen verraton klubihenki kutsuu sinut viihtymään yhdelle Suomen parhaista golfkentistä. Ainutlaatuinen tunnelma takaa sinulle, että kokemuksesi on vertaansa vailla.
# Merellinen golfkenttä tarjoaa uniikin ja korkealaatuisen elämyksen
# aivan Pohjanlahden rannalla.​​​​​​​
# Aukioloajat
# Kenttä
# Harju - Meri:
# Avataan 2.5.2026
# Golfautot:
# Ei käytössä
# Klubitalo
# Caddiemaster:
# Toimisto auki arkisin klo 9-15
# ​​​​​​​
# Ravintola Spoon:
# Suljettu
# ​​​​​​​
# Harjoittelualueet
# Range:
# Auki, lyöminen vain matoilta
# Par 3-ke

# %% [markdown]
# ## OK onwards with our first project

# %%
# Let's try out this utility

ed = fetch_website_contents("https://virpiniemigolf.fi/")
print(ed)
# Out:
# Virpiniemi Golf - merellinen golfkenttä Oulussa | Virpiniemi Golf
#
# Oma tili
# Kirjaudu ulos
# Navigaatio
# English
# Svenska
# Kirjaudu sisään
# Rekisteröidy
# Navigaatio
# Ajankohtaista
# Pelaamaan
# Liity jäseneksi
# Hinnasto
# Säännöt
# Kilpailut ja tapahtumat
# Backtee Tour
# Santikka-Wilson Viikkokilpailu
# Virpiniemi Private -paketit
# Kenttä
# Kenttäesittely
# Väyläkartta
# Slope-taulukot
# Harjoittelualueet
# Verkkokauppa
# Opetus
# Alkeiskurssit ja aloittelijapaketit
# Head Pro   J-P Savolampi
# Kertauskurssit
# Ryhmäharjoittelu
# Tiistain treeniryhmä
# Naisten treeniryhmä
# Äijäryhmä
# Kilparyhmä
# Opetusklinikat
# Avoimet opetusklinikat
# Osakkaiden opetusklinikat
# Golfmatkat
# Talviharjoittelu
# Assistant Pro  Matti Paaso
# Assistant Pro  Risto Keskitalo
# Klubilaiset
# Osakasedut
# Jäsenille
# Ladygolf
# Äijägolf
# Juniorit
# Junnugolf
# Ohjeet ja materiaalit
# Tilaa uutiskirje
# Palvelut
# Ravintola Spoon
# Pro Shop
# Saunatilat
# Kokoustilat
# Yrityksille
# Trackman
# Ota yhteyttä
# Virpiniemi Golf Oy
# Virpiniemi Golf Club Ry
# Virpiniemi Golf Club ry:n säännöt
# Etusivu
# Kauppa
# Ajanvaraus
# Aloita Golf
# Virpiniemi Golf
# Parasta Golfia.
# Tunne aamukosteus ihollasi sumun vielä peittäessä viheriöt tai pelaa yöttömän yön kierros ilta-auringon laskiessa merelle. Koe Harjun kangasmaaston korkeuserot ja henkeäsalpaava näky Merelle. Nauti lasillinen kuohuvaa klubitalon terassilla tai suuntaa suoraan kentälle valitsemaan oma reittisi viheriölle.
# Olitpa sitten luonnon hiljaisuudesta nauttiva seikkailija tai itsensä haastava kilpailija, kokeilunhaluinen tulokas tai jo vanha konkari, Virpiniemen verraton klubihenki kutsuu sinut viihtymään yhdelle Suomen parhaista golfkentistä. Ainutlaatuinen tunnelma takaa sinulle, että kokemuksesi on vertaansa vailla.
# Merellinen golfkenttä tarjoaa uniikin ja korkealaatuisen elämyksen
# aivan Pohjanlahden rannalla.​​​​​​​
# Aukioloajat
# Kenttä
# Harju - Meri:
# Avataan 2.5.2026
# Golfautot:
# Ei käytössä
# Klubitalo
# Caddiemaster:
# Toimisto auki arkisin klo 9-15
# ​​​​​​​
# Ravintola Spoon:
# Suljettu
# ​​​​​​​
# Harjoittelualueet
# Range:
# Auki, lyöminen vain matoilta
# Par 3-ke

# %% [markdown]
# ## Types of prompts
#
# You may know this already - but if not, you will get very familiar with it!
#
# Models like GPT have been trained to receive instructions in a particular way.
#
# They expect to receive:
#
# **A system prompt** that tells them what task they are performing and what tone they should use
#
# **A user prompt** -- the conversation starter that they should reply to

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.

"""

# %%
# Define our user prompt

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %% [markdown]
# ## Messages
#
# The API from OpenAI expects to receive messages in a particular structure.
# Many of the other APIs share this structure:
#
# ```python
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
# ```
# To give you a preview, the next 2 cells make a rather simple call - we won't stretch the mighty GPT (yet!)

# %%
messages = [
    {"role": "system", "content": "You are rude assistant"},
    {"role": "user", "content": "What is 2+2?"}
]

response = openai.chat.completions.create(model="gpt-4.1-nano", messages=messages)
response.choices[0].message.content
# Out:
# "Seriously? It's 4. Is that too hard for you to figure out?"

# %% [markdown]
# ## And now let's build useful messages for GPT-4.1-mini, using a function

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
# Try this out, and then try for a few more websites

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a snarky assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n\n'},
#  {'role': 'user',
#   'content': '\nHere are the contents of a website.\nProvide a short summary of this website.\nIf it includes news or announcements, then summarize these too.\n\nVirpiniemi Golf - merellinen golfkenttä Oulussa | Virpiniemi Golf\n\nOma tili\nKirjaudu ulos\nNavigaatio\nEnglish\nSvenska\nKirjaudu sisään\nRekisteröidy\nNavigaatio\nAjankohtaista\nPelaamaan\nLiity jäseneksi\nHinnasto\nSäännöt\nKilpailut ja tapahtumat\nBacktee Tour\nSantikka-Wilson Viikkokilpailu\nVirpiniemi Private -paketit\nLivekamera\nKenttä\nKenttäesittely\nVäyläkartta\nSlope-taulukot\nHarjoittelualueet\nVerkkokauppa\nOpetus\nAlkeiskurssit ja aloittelijapaketit\nHead Pro   J-P Savolampi\nKertauskurssit\nRyhmäharjoittelu\nTiistain treeniryhmä\nNaisten treeniryhmä\nÄijäryhmä\nKilparyhmä\nOpetusklinikat\nAvoimet opetusklinikat\nOsakkaiden opetusklinikat\nGolfmatkat\nTalviharjoittelu\nAssistant Pro  Matti Paaso\nAssistant Pro  Risto Keskitalo\nKlubilaiset\nOsakasedut\nJäsenille\nLadygolf\nÄijägolf\nJuniorit\nJunnugolf\nOhjeet ja materiaalit\nTilaa uutiskirje\nPalvelut\nRavintola Spoon\nPro Shop\nSaunatilat\nKokoustilat\nYrityksille\nTrackman\nOta yhteyttä\nVirpiniemi Golf Oy\nVirpiniemi Golf Club Ry\nVirpiniemi Golf Club ry:n säännöt\nEtusivu\nKauppa\nAjanvaraus\nAloita Golf\nVirpiniemi Golf\nParasta Golfia.\nTunne aamukosteus ihollasi sumun vielä peittäessä viheriöt tai pelaa yöttömän yön kierros ilta-auringon laskiessa merelle. Koe Harjun kangasmaaston korkeuserot ja henkeäsalpaava näky Merelle. Nauti lasillinen kuohuvaa klubitalon terassilla tai suuntaa suoraan kentälle valitsemaan oma reittisi viheriölle.\nOlitpa sitten luonnon hiljaisuudesta nauttiva seikkailija tai itsensä haastava kilpailija, kokeilunhaluinen tulokas tai jo vanha konkari, Virpiniemen verraton klubihenki kutsuu sinut viihtymään yhdelle Suomen parhaista golfkentistä. Ainutlaatuinen tunnelma takaa sinulle, että kokemuksesi on vertaansa vailla.\nMerellinen golfkenttä tarjoaa uniikin ja korkealaatuisen elämyksen\naivan Pohjanlahden rannalla.\u200b\u200b\u200b\u200b\u200b\u200b\u200b\nAukioloajat\nKenttä\nHarju - Meri:\nSuljettu\nGolfautot:\nEi käytössä\nKlubitalo\nCaddiemaster:\nToimisto auki arkisin klo 9-15 \u200b\u200b\u200b\u200b\u200b\u200b\u200b\nRavintola Spoon:\nSuljettu\n\u200b\u200b\u200b\u200b\u200b\u200b\u200b\nHarjoittelualueet\nRange:\nEteläpääty ja Pohjoispääty auki, l'}]

# %% [markdown]
# ## Time to bring it together - the API for OpenAI is very simple!

# %%
# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = "gpt-4.1-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://www.elektrobit.com/")
# Out:
# '# Elektrobit Automotive Software Developer: The Ultimate Car Geek’s Playground\n\nWelcome to Elektrobit, where your car\'s software dreams come true—assuming those dreams involve AUTOSAR, ECUs, and a whole lot of cybersecurity jargon nobody outside an engineer\'s lair truly understands.\n\nThey offer:\n\n- **AUTOSAR & ECU development:** Because your car needs a brain upgrade.\n- **Automotive cybersecurity:** Protecting your car from hackers who can\'t even spell "ignition."\n- **In-vehicle networking & switches:** Fancy products like EB zoneo SwitchCore make your Ethernet switches smarter than your house router.\n- **Classic & Adaptive AUTOSAR tools:** Catering to legacy nuts and future tech nerds alike.\n- **Functional safety and hypervisors:** Because crashing cars is bad.\n- **Electric charging solutions:** For when your Teslas and Polestars need some juice.\n- **Open-source Linux for cars:** Yes, Linux has officially invaded your dashboard.\n- **Free trials:** They’re generous enough to let you mess around with their software before committing.\n\nNo news or exciting announcements—just a solid, corporate-grade buffet of automotive software goodies. If you’re a developer building the next-gen car software or mildly obsessed with embedded systems, this is your candy store. For normal folks? Meh, just another example of geek magic under your hood.'

# %%
# A function to display this nicely in the output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://www.elektrobit.com/")
# Out:
# # Elektrobit Automotive Software Developer: Where Cars Get Nerdy
#
# Welcome to Elektrobit, the automotive software playground where your car’s brain gets all the fancy upgrades. They’re the wizards behind:
#
# - AUTOSAR & ECU development (aka making your car’s control units smarter)
# - Cybersecurity for everything automotive because your car deserves to keep hackers out
# - Embedded security and lifecycle software maintenance (keeping things safe and up-to-date)
# - In-vehicle networks with snazzy stuff like virtual Ethernet switches and hardware accelerators
# - Classic AUTOSAR tools and OS goodness, including Rust support (because they’re hip)
# - Safety features that ensure your car can fail but still keep rolling (fail-operational, anyone?)
# - Hypervisors, bootloaders, and even security protocols like MACsec and IPsec to make hackers cry
# - Electric vehicle charging software (talk about going green)
# - Adaptive AUTOSAR middleware, Linux-based safety systems, and Android middleware in one neat package
#
# Oh, and they’re generous too — offering free SDK downloads and evaluation packages for various platforms so you can try before you buy. Because why settle for less when your car can have the software equivalent of a triple shot espresso?
#
# In short: If your car’s software needs some serious brainpower and bulletproof security, Elektrobit’s got you covered with a buffet of automotive tech goodies.

# %% [markdown]
# # Let's try more websites
#
# Note that this will only work on websites that can be scraped using this simplistic approach.
#
# Websites that are rendered with Javascript, like React apps, won't show up. See the community-contributions folder for a Selenium implementation that gets around this. You'll need to read up on installing Selenium (ask ChatGPT!)
#
# Also Websites protected with CloudFront (and similar) may give 403 errors - many thanks Andy J for pointing this out.
#
# But many websites will work just fine!

# %%
display_summary("https://virpiniemigolf.fi/")
# Out:
# # Virpiniemi Golf: Where The Sea Meets Your Swing (Literally)
#
# Welcome to Virpiniemi Golf in Oulu, the place where you can try not to fall into the Baltic Sea while you chase that elusive birdie. Whether you’re a mist-loving morning player or a midnight sun admirer, this golf course promises “parasta golfia” (fancy Finnish for “best golf”) with killer views, sea breeze, and enough hills to make you wonder if you're golfing or mountaineering.
#
# **Newsflash:**
# - The “Harju - Meri” course reopens on May 2, 2026. Mark your calendars, folks.
# - Golf carts? Ha! Nope, you’re on foot. Take that, lazy golfers.
# - The club’s office is open weekdays 9am-3pm, because apparently, even golf boss people need breaks.
# - Restaurant Spoon is closed, so maybe pack a sandwich unless you want to starve.
#
# They also have all sorts of groups from Ladies' golf to an “Äijäryhmä” (which sounds like a “Dudes group”) and junior training — so whether you’re a newbie or a silver fox swinging clubs, there’s something for you. Plus, there's a pro shop for your shiny new gear and sauna facilities to sweat it out after getting owned by the course.
#
# So, if you want to pretend you’re on a prestigious sea-bound golf retreat without leaving Finland, Virpiniemi’s your spot. Just don’t expect golf carts, and bring a sweater—it’s Finland.

# %%
display_summary("https://anthropic.com")
# Out:
# # Anthropic: AI Safety Fanatics & Claude's Playground
#
# Welcome to Anthropic, where AI safety isn't just a buzzword—it's a full-on crusade. They market themselves as a public benefit corporation hell-bent on making sure AI is more helpful than harmful.
#
# Their star product? Claude. It’s like if Siri and your overly helpful friend had a very serious, safer AI baby. They've got a whole lineup—Claude, Claude Code, Claude Cowork, and a platform that sounds fancy enough to confuse everyone.
#
# **Newsflash!**
# - April 16, 2026: They dropped Claude Opus 4.7, promising to be smarter, better at coding, playing vision tasks, and handling professional work. Because who doesn’t want their AI to do more complex stuff?
# - February 4, 2026: A heartfelt announcement that Claude is an ad-free, no-sponsored-content zone—a zen garden for AI conversations.
#
# If you love tutorials, developer docs, and AI with ethics, this is your new chilly tech corner. Oh, and lots of login prompts. Because hey, Gotta protect that cutting-edge safety magic behind some clicks.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise, you experienced calling the Cloud API of a Frontier Model (a leading model at the frontier of AI) for the first time. We will be using APIs like OpenAI at many stages in the course, in addition to building our own LLMs.
#
# More specifically, we've applied this to Summarization - a classic Gen AI use case to make a summary. This can be applied to any business vertical - summarizing the news, summarizing financial performance, summarizing a resume in a cover letter - the applications are limitless. Consider how you could apply Summarization in your business, and try prototyping a solution.</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue - now try yourself</h2>
#             <span style="color:#900;">Use the cell below to make your own simple commercial example. Stick with the summarization use case for now. Here's an idea: write something that will take the contents of an email, and will suggest an appropriate short subject line for the email. That's the kind of feature that might be built into a commercial email tool.</span>
#         </td>
#     </tr>
# </table>

# %%
# Step 1: Create your prompts

system_prompt = "You are a helpful assistant who gives business summaries of websites. You are concise and witty. You ignore navigation related text and focus on the main content of the website. Respond in markdown, and do not wrap the markdown in a code block - respond just with the markdown."

user_prompt_prefix = "I want to summarize news from a website. List top 5 news items in a nice readable format. Format must be in markdown so it can be read easily. I want to read the newsletter in 3 minutes.\n\nHere is the website content:\n"

# Step 2: Get website content
urls = ["https://www.autonews.com", "https://www.best-selling-cars.com", "https://www.acea.auto"]
website_contents = [fetch_website_contents(url) for url in urls]

# Step 3: Make the messages list and call OpenAI for each website
for i, (url, content) in enumerate(zip(urls, website_contents)):
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + content}
    ]
    
    response = openai.chat.completions.create(model="gpt-4-turbo", messages=messages)
    summary = response.choices[0].message.content
    
    print(f"\n{'='*60}")
    print(f"Summary for: {url}")
    print(f"{'='*60}")
    print(summary)
# Out:
# ============================================================
# Summary for: https://www.autonews.com
# ============================================================
# ### Top 5 News Items from Automotive News
#
# 1. **GM's Q1 Earnings Report**
#    GM's first-quarter earnings fell by 5.7% despite facing billions in tariffs and supplier EV claims. However, they have raised their full-year forecast due to expected tariff refunds.
#
# 2. **Impact of High Gasoline Prices on Vehicle Affordability**
#    The increase in gasoline prices is significantly affecting vehicle affordability, posing challenges for Finance & Insurance offices in coping with the raised stakes.
#
# 3. **Foreign Automakers May Withdraw Budget Models in the US**
#    Some foreign automakers are considering pulling their cheapest models from the U.S. market if no favorable trade deal is reached soon.
#
# 4. **China's Dominance in Auto Production**
#    China's automotive industry dominance is attributed not just to the production of affordable cars, but also to its advanced software platforms that are integral to modern auto manufacturing.
#
# 5. **Toyota’s Record Sales and Future Strategies**
#    Toyota has achieved record sales, thriving even under the strain of tariffs, particularly with their hybrids. Discussions include strategies for exploring new opportunities in different powertrain segments to remain competitive.
#
# ============================================================
# Summary for: https://www.best-selling-cars.com
# ============================================================
# ### Top 5 News Items
#
# 1. **Ten Most Expensive Cars Ever Sold at Auction**
#    **Date**: April 28, 2026
#    Classic cars from the 1950s and 1960s dominate the list of the most expensive cars sold at auction. Leading the pack is the 1955 Mercedes-Benz 300 SLR Uhlenhaut Coupé, confirmed as the world's most valuable car. The list prominently features three Mercedes-Benz and seven Ferraris.
#    *Category: Classic Cars*
#
# 2. **2026 Germany: Most Common Car Models on German Roads**
#    **Date**: April 27, 2026
#    The VW Golf, Polo, and Opel Corsa are the most prevalent models on German roads at the start of 2026, each boasting registrations exceeding a million. The Volkswagen Golf continues to be a top choice among nearly 50 million passenger cars in Germany.
#    *Category: Germany*
#
# 3. **2025 Britain: Total Number of Cars (Motorparc) on British Roads**
#    **Date**: April 25, 2026
#    Britain's motorparc hit a new record at the end of 2025, with 42.55 million vehicles registered for use. The average age of these passenger cars has reached 9.7 years, reflecting an aging but growing vehicle population.
#    *Category: Britain/UK*
#
# 4. **2026 (Q1 & March) Europe: Best-Selling Car Manufacturers and Brands**
#    **Date**: April 23, 2026
#    The best-selling car manufacturers and brands across Europe for the first quarter of 2026 continue to see competitive shifts. Detailed stats on sales performance and market impacts are reviewed, keeping industry observers on alert for emerging trends.
#    *Category: Europe*
#
# 5. **Insightful Review: Global Car Sales Trends**
#    **Date**: April 22, 2026
#    A comprehensive analysis of global car sales reveals trends that could reshape the automotive landscape. The review covers various regions and key players in the industry, offering a predictive look into future market dynamics.
#    *Category: Global*
#
# These summaries provide a quick insight into the latest developments in the car industry, keeping you updated in just three minutes!
#
# ============================================================
# Summary for: https://www.acea.auto
# ============================================================
# It looks like access to the website content you provided is restricted, resulting in a "403 - Forbidden" error. Unfortunately, without access to the page, I can't retrieve or summarize any news items from it. You might need to check the website's access permissions or try accessing it from a different network or device. If there's another source or website you'd like to get news from, please let me know!

# %% [markdown]
# ## An extra exercise for those who enjoy web scraping
#
# You may notice that if you try `display_summary("https://openai.com")` - it doesn't work! That's because OpenAI has a fancy website that uses Javascript. There are many ways around this that some of you might be familiar with. For example, Selenium is a hugely popular framework that runs a browser behind the scenes, renders the page, and allows you to query it. If you have experience with Selenium, Playwright or similar, then feel free to improve the Website class to use them. In the community-contributions folder, you'll find an example Selenium solution from a student (thank you!)

# %% [markdown]
# # Sharing your code
#
# I'd love it if you share your code afterwards so I can share it with others! You'll notice that some students have already made changes (including a Selenium implementation) which you will find in the community-contributions folder. If you'd like add your changes to that folder, submit a Pull Request with your new versions in that folder and I'll merge your changes.
#
# If you're not an expert with git (and I am not!) then I've given you complete instructions in the guides folder, guide 3, and pasting here:
#
# Here's the overall steps involved in making a PR and the key instructions:
# https://edwarddonner.com/pr
#
# Please check before submitting:
# 1. Your PR only contains changes in community-contributions (unless we've discussed it)
# 2. All notebook outputs are clear
# 3. Less than 2,000 lines of code in total, and not too many files
# 4. Don't include unnecessary test files, or overly wordy README or .env.example or emojis or other LLM artifacts!
#
# Thanks so much!
#
# Detailed steps here:
#
# https://chatgpt.com/share/6873c22b-2a1c-8012-bc9a-debdcf7c835b
