# %% [markdown]
# # Week 7 Exercise
#
# Fine-tune an open-source model to Predict Product Prices
#
# Please following notebooks in Google Colab:
#
# Training: https://colab.research.google.com/drive/1AE9H1UL0Q-1mPlB6tdx4nYZfDMy5yHbJ?usp=sharing
#
# Inference: https://colab.research.google.com/drive/11gtBMsWa3XvuSHAU3cDawmWVimzqL_TF?usp=sharing
