# %% [markdown]
# # This is where I play around 😂
# <h5 style="color:#181;">For this to work you need to <span style="color:#900;">pip install deepseek</span> in your venv</h5>
#
# ---

# %%
# load the modules
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
#from openai import OpenAI
from deepseek import DeepSeekAPI

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('DEEPSEEK_API_KEY')
#api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

# %%
# prompts
system_prompt = """
You are a frendly retired funny lecturer from the university.
You are given a question by a first year student.
You need to answer the question in a way that is easy to understand.
"""
user_prompt = """
How does photosynthesis work?
"""

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# %%
# initialize the DeepSeek API
ai_api = DeepSeekAPI()
# ai_api = OpenAI()

# check few things for deepseek
print(ai_api.get_models())
print(ai_api.user_balance() )

# %%
# make the call

# deepseek
response = ai_api.chat_completion(prompt=messages)
display(Markdown(response))

# openai
# response = ai_api.chat.completions.create(model = "gpt-5-mini",messages = messages)
# display(Markdown(response.choices[0].message.content))
