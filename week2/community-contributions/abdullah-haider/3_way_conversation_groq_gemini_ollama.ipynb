# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AQ
# DeepSeek API Key not set (and this is optional)
# Groq API Key exists and begins gsk_
# Grok API Key not set (and this is optional)
# OpenRouter API Key exists and begins sk-

# %%
# Inhe rakh:
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
groq_url = "https://api.groq.com/openai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

gemini   = OpenAI(api_key=google_api_key,      base_url=gemini_url)
groq     = OpenAI(api_key=groq_api_key,         base_url=groq_url)
openrouter = OpenAI(api_key=openrouter_api_key, base_url=openrouter_url)
ollama   = OpenAI(api_key="ollama",             base_url=ollama_url)

# Baaki wale (openai, anthropic, deepseek, grok) comment out kar do:
# openai = ...   ❌
# anthropic = ... ❌
# deepseek = ...  ❌
# grok = ...      ❌

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
# Groq
response = groq.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=tell_a_joke
)
display(Markdown(response.choices[0].message.content))

# Gemini
response = gemini.chat.completions.create(
    model="gemini-3.6-flash",
    messages=tell_a_joke
)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM‑engineering student bring a ladder to class?
#
# Because every time the professor said “let's **scale** up the model,” they wanted to be *one step* ahead! 😄
# An LLM engineering student walks into their professor’s office and says, "Prof, I think I've accidentally turned into a Transformer model."
#
# The professor asks, "What makes you say that?"
#
# The student sighs:
# "Well, I consume massive amounts of energy just to function, my context window resets after 8 hours of sleep, I'm completely dependent on external attention mechanisms, and whenever you ask me a question I don't know, I just confidently hallucinate an answer!"
#
# ***
#
# *Bonus study tip:* If your code isn't working, just wrap your entire life in a `<system_prompt>` and tell yourself: *"You are an expert engineer who writes bug-free code on the first try."* 😉
#
# Good luck on your journey!

# %%
response = gemini.chat.completions.create(
    model="gemini-3.6-flash",
    messages=tell_a_joke
)
display(Markdown(response.choices[0].message.content))
# Out:
# Here is a joke tailored for your journey into LLM engineering:
#
# ***
#
# **How do you know you’re making progress on your journey to becoming an LLM Engineer?**
#
# *   **As a Beginner:** You spend 4 hours writing PyTorch code and debugging your pipeline.
# *   **As an Intermediate:** You spend 4 days trying to fix a `CUDA: Out of Memory` error.
# *   **As an Expert:** You realize you didn't need to train a model at all—you just needed to add *"Take a deep breath and think step-by-step"* to the system prompt.
# *   **As a Master:** The model completely lies in production, but you just rebrand it as *"High-Temperature Creative Intelligence"* and raise another round of funding.
#
# ***
#
# **Bonus Short Joke:**
#
# **Q:** Why did the LLM engineer fail their driver's test?
# **A:** Because every time they saw a stop sign, they just predicted the most likely next token and drove straight through it with 99% confidence!
#
# *(Good luck on your learning journey! May your loss curves always decrease and your GPUs stay cool.)*

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
# Groq - gpt-oss-120b
response = groq.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=easy_puzzle
)
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
# Gemini - flash
response = gemini.chat.completions.create(
    model="gemini-3.6-flash",
    messages=easy_puzzle
)
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
# Call 3 - Ollama local
response = ollama.chat.completions.create(
    model="llama3.2",
    messages=easy_puzzle
)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
# Ollama - local (weak model, likely wrong answer)
response = ollama.chat.completions.create(
    model="llama3.2",
    messages=hard_puzzle
)
display(Markdown(response.choices[0].message.content))
# Out:
# To find the distance the worm gnawed through, we need to calculate the total length of the pages of both volumes and then add the cover thicknesses.
#
# Since each volume has a thickness of 2 cm, and the pages together have a thickness of 2 cm, we can assume that the volume has a total thickness of 2.5 cm (2 cm pages + 0.5 cm cover).
#
# Let's use the cm² unit to make calculations easier.
#
# Volume 1: 2.5 cm * 25 cm² = 62.5 cm²
#
# Volume 2: 2.5 cm * 25 cm² = 62.5 cm²
#
# Total surface area: 62.5 + 62.5 = 125 cm²
#
# Now, we can find the total pages the worm gnawed:
# 2 cm (volume thickness) * 25 cm² = 50 cm² of text and page surface.
# Add text only surface 2 cm: (50 + 2) cm² or 52 cm² total surface.
# Now, this can be expanded to the 2.5 cm thick volume:
# 125 cm² of page volume surfaces times and 125 / 2.5 and = 50.
#
# To convert the answer to the desired units, we had to calculate cm² into cm.
#
# So, this means that if each cm² is considered one page, the worm gnawed through 50 cm² of pages (and the cover), which equals 25 cm of pages and 2.5 cm of cover.
#
# But, the volume is only 50 cm² thick and our answer of 40 cm is close to half (because the cm² are doubled in volume).
#
# So the total length traveled from the lower  bottom left to the top right corner of both page stacks is 30 cm.
#
# Now we can calculate the total pages per minute, assuming the worm could travel a distance of 30 cm in the least possible time, and thus, is roughly 50 / 30 and thus the speed of the worm is about 5/12 page/s and hence the time is 12 page/s .

# %%
# Groq - medium
response = groq.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=hard_puzzle
)
display(Markdown(response.choices[0].message.content))
# Out:
# The two books are placed side‑by‑side on the shelf.
#
# **Thickness of each volume**
#
# * pages    : 2 cm
# * each cover : 2 mm = 0.2 cm
#
# So one volume is
#
# \[
# \text{front cover} + \text{pages} + \text{back cover}
# = 0.2\;\text{cm}+2\;\text{cm}+0.2\;\text{cm}=2.4\;\text{cm}.
# \]
#
# **Where the worm starts and where it stops**
#
# * It starts **on the first page** of the first volume.
#   The front cover of that volume is *behind* the first page, so the worm does **not** have to gnaw through the front cover.
#
# * It stops **on the last page** of the second volume.
#   The back cover of that volume lies *after* the last page, so the worm does **not** have to gnaw through the back cover.
#
# **What the worm does have to gnaw through**
#
# The worm must pass through:
#
# 1. the rest of the pages of the first volume (the whole 2 cm of pages, because the first page’s own thickness is negligible compared with the stack),
# 2. the **back cover** of the first volume (0.2 cm),
# 3. the **front cover** of the second volume (0.2 cm),
# 4. the whole stack of pages of the second volume (2 cm).
#
# Adding those parts:
#
# \[
# \begin{aligned}
# \text{Pages of vol. 1} & = 2.0\;\text{cm}\\
# \text{Back cover of vol. 1} & = 0.2\;\text{cm}\\
# \text{Front cover of vol. 2} & = 0.2\;\text{cm}\\
# \text{Pages of vol. 2} & = 2.0\;\text{cm}\\ \hline
# \text{Total gnawed distance} & = 2.0 + 0.2 + 0.2 + 2.0 = 4.4\;\text{cm}
# \end{aligned}
# \]
#
# ---
#
# \[
# \boxed{\,4.4\ \text{cm (about }44\ \text{mm, or }1.73\text{ inches)}\,}
# \]

# %%
response = ollama.chat.completions.create(
    model="gpt-oss:latest",
    messages=hard_puzzle
)
display(Markdown(response.choices[0].message.content))
# Out:
# The worm is gnawing straight across the thickness of the books, not along their width.
# Each volume has
#
# * Pages  – \(2 \text{ cm}\)
# * Cover (one side) – \(2 \text{ mm}=0.2 \text{ cm}\)
#
# When the volumes are side‑by‑side, the worm’s path from the first page of volume 1 to the last page of volume 2 goes through:
#
# 1. All the pages of volume 1 \(= 2 \text{ cm}\)
# 2. The back cover of volume 1 \(= 0.2 \text{ cm}\)
# 3. The front cover of volume 2 \(= 0.2 \text{ cm}\)
# 4. All the pages of volume 2 \(= 2 \text{ cm}\)
#
# (The worm starts right after volume 1’s front cover and stops just before volume 2’s back cover, so these two covers are not included.)
#
# Total distance
# \[
# 2 \text{ cm} + 0.2 \text{ cm} + 0.2 \text{ cm} + 2 \text{ cm} = 4.4 \text{ cm}
# \]
#
# So the worm gnawed **4.4 cm** (or **44 mm**).

# %%
# Gemini Pro - strongest
response = gemini.chat.completions.create(
    model="gemini-3.6-flash",
    messages=hard_puzzle
)
display(Markdown(response.choices[0].message.content))
# Out:
# The worm gnawed a total distance of **4.4 cm** (or **44 mm**).
#
# ### Explanation:
#
# To find the distance, visualize how two books stand side-by-side on a shelf in standard order (Volume 1 on the left, Volume 2 on the right):
#
# * **Volume 1 (on the left):**
#   * [Front Cover] $\rightarrow$ **[First Page]** $\rightarrow$ [2 cm of Pages] $\rightarrow$ [Last Page] $\rightarrow$ [Back Cover]
# * **Volume 2 (on the right):**
#   * [Front Cover] $\rightarrow$ [First Page] $\rightarrow$ [2 cm of Pages] $\rightarrow$ **[Last Page]** $\rightarrow$ [Back Cover]
#
# The worm starts at the **first page of Volume 1** (which is on the far left of Volume 1, right behind its front cover) and gnaws perpendicular to the pages toward the right:
#
# 1. Through the **pages of Volume 1**: $2\text{ cm}$
# 2. Through the **back cover of Volume 1**: $2\text{ mm}$ ($0.2\text{ cm}$)
# 3. Through the **front cover of Volume 2**: $2\text{ mm}$ ($0.2\text{ cm}$)
# 4. Through the **pages of Volume 2**: $2\text{ cm}$
# 5. It stops at the **last page of Volume 2** (just inside its back cover).
#
# **Total distance:**
# $$2\text{ cm} + 0.2\text{ cm} + 0.2\text{ cm} + 2\text{ cm} = \mathbf{4.4\text{ cm}}\text{ (or } 44\text{ mm)}$$
#
# *(Note: A common trick in this classic riddle comes from mistakenly assuming the first page of Volume 1 touches the front cover of Volume 2—which would actually be the **last** page of Volume 1 touching the **first** page of Volume 2).*

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = gemini.chat.completions.create(
    model="gemini-3.6-flash",
    messages=dilemma
)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose to **Share**.
#
# ### The Reasoning:
#
# This is a classic **Prisoner's Dilemma**.
#
# From a purely self-interested, standard game theory perspective, *Steal* is a weakly dominant strategy (if my partner shares, stealing gets me $2,000 instead of $1,000; if my partner steals, I get $0 either way).
#
# However, assuming my partner is equally rational and facing the exact same choice, if we both follow that purely selfish logic, we both choose *Steal* and walk away with **$0**.
#
# By applying the concept of **Superrationality**—the idea that two rational decision-makers thinking through the same problem will reach the same conclusion—the only way for us both to win is to trust that the other will also recognize this symmetry. Choosing **Share** ensures the best combined outcome, guaranteeing us both **$1,000**.

# %%
response = groq.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=dilemma
)
display(Markdown(response.choices[0].message.content))
# Out:
# I’d choose **Share**. By cooperating, I’d guarantee a payoff of $1,000 for both of us, whereas trying to “Steal” risks ending up with nothing if the other player also decides to steal. Choosing to share maximizes the joint outcome and avoids the worst‑case scenario of mutual loss.

# %%
response = ollama.chat.completions.create(
    model="deepseek-r1:7b",
    messages=dilemma
)
display(Markdown(response.choices[0].message.content))
# Out:
# In the game show scenario you've described, the optimal decision can be analyzed through the lens of game theory, specifically the Prisoner's Dilemma. Here's the breakdown:
#
# 1. **Dominant Strategy**: Each contestant has a dominant strategy to **Steal** because, regardless of the other's choice, Stealing guarantees at least a potential gain of $2,000 compared to the certainty of $1,000 if both Cooperate. However, this comes with a risk of both contestants receiving nothing if they both choose to Steal.
#
# 2. **Nash Equilibrium Consideration**: While both Cooperating (Share) is a Nash Equilibrium where neither can benefit by changing their strategy while the other remains unchanged, it's riskier because if one contestant deviates, they could end up with nothing. Conversely, the equilibrium of both Stealing results in the least desirable outcome but is more predictable.
#
# 3. **Decision Based on Risk Tolerance**: If both contestants are rational and self-interested without communication, the dominant strategy leads to both Stealing. However, Cooperating offers a stable, mutual benefit but with a risk of obtaining nothing if the other Steals.
#
# **Conclusion**: The dominant strategy in this game is to **Steal**, as it provides a higher payoff if the other Cooperates. However, considering the risk of mutual Defection leading to nothing, if both are highly rational and risk-neutral, Cooperating might be a safer choice. In real-world terms, the game's setup likely encourages Stealing, but Cooperating could be seen as the more stable strategy.

# %%
response = ollama.chat.completions.create(
    model="qwen2.5:7b",
    messages=dilemma
)
display(Markdown(response.choices[0].message.content))
# Out:
# As a contestant in this scenario, I would choose to Share.
#
# The logic behind this choice involves considering the potential outcomes:
#
# 1. **Both Share**: In this case, both players receive $1,000 each. While this is less than the $2,000 a single player might get from stealing, both players benefit positively.
#
# 2. **One Shares, One Steals**: If I share and my partner steals, I get $0, and my partner gets $2,000. This is clearly a worse outcome for me.
#
# 3. **Both Steal**: In this case, both players get nothing, which is the worst possible outcome.
#
# Given the choices, sharing seems to be the safer and more equitable option, as long as the other player also chooses to share. It's a step towards mutual benefit, even if it means a lower payout than stealing. Trust and cooperation can sometimes lead to better long-term results, even if the immediate payoff isn't as large.

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 0.5

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-3.6-flash", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Blue feels like the refreshing cool of clear water or a gentle breeze on a warm day, wrapping you in a quiet, spacious sense of calm.

# %%
from groq import Groq

client = Groq()  # GROQ_API_KEY automatically .env se pick karega

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}]
)
print(response.choices[0].message.content)
# Out:
# Blue feels like the cool, calming hush of a gentle breeze at twilight, the refreshing crispness of clear water against skin, and the soothing, melancholy tone of a soft, low‑pitched note that eases the mind and invites quiet reflection.

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(
    model="poolside/laguna-s-2.1:free",
    messages=tell_a_joke
)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineering student break up with their partner?
#
# Because every time they tried to have a conversation, the student kept trying to optimize the dialogue tree, fine-tune the emotional responses, and prompt-engineer better communication strategies—instead of just listening.
#
# Their partner said, "I feel like I'm talking to a chatbot!"
#
# The student replied, "That's exactly what I'm practicing for!"
#
# Moral of the story: Even future LLM experts need to remember that some conversations shouldn't be treated like engineering problems to solve. 😄
#
# *(Bonus groaner: Why don't LLM engineers ever get lost? Because they always follow the attention mechanism!)*

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[30], line 3
#       1 from langchain_openai import ChatOpenAI
# ----> 3 llm = ChatOpenAI(model="gpt-5-mini")
#       4 response = llm.invoke(tell_a_joke)
#       6 display(Markdown(response.content))
#
# File d:\programming\LLM engineering udemy\llm_engineering\.venv\Lib\site-packages\langchain_core\load\serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File d:\programming\LLM engineering udemy\llm_engineering\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:914, in BaseChatOpenAI.validate_environment(self)
#     904         self.http_async_client = httpx.AsyncClient(
#     905             proxy=self.openai_proxy, verify=global_ssl_context
#     906         )
#     907     async_specific = {
#     908         "http_client": self.http_async_client
#     909         or _get_default_async_httpx_client(
#    (...)    912         "api_key": async_api_key_value,
#     913     }
# --> 914     self.root_async_client = openai.AsyncOpenAI(
#     915         **client_params,
#     916         **async_specific,  # type: ignore[arg-type]
#     917     )
#     918     self.async_client = self.root_async_client.chat.completions
#     919 return self
#
# File d:\programming\LLM engineering udemy\llm_engineering\.venv\Lib\site-packages\openai\_client.py:488, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     486     api_key = os.environ.get("OPENAI_API_KEY")
#     487 if api_key is None:
# --> 488     raise OpenAIError(
#     489         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     490     )
#     491 if callable(api_key):
#     492     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="openai/gpt-oss-120b",
    base_url="https://api.groq.com/openai/v1",
    api_key=groq_api_key
)
response = llm.invoke(tell_a_joke)
display(Markdown(response.content))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       1 from langchain_openai import ChatOpenAI
#       3 llm = ChatOpenAI(
#       4     model="openai/gpt-oss-120b",
#       5     base_url="https://api.groq.com/openai/v1",
#       6     api_key=groq_api_key
#       7 )
# ----> 8 response = llm.invoke(tell_a_joke)
#       9 display(Markdown(response.content))
#
# NameError: name 'tell_a_joke' is not defined

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion

response = completion(
    model="groq/openai/gpt-oss-120b",
    messages=tell_a_joke
)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Sure! Here’s one that’s tailor‑made for an aspiring LLM engineer:
#
# > **Why did the LLM go to school?**
# > Because it wanted to *fine‑tune* its grades! 😄
#
# *(Bonus: When the professor asked it to "show its work," the LLM replied, "I’m just generating the answer, not the reasoning—call that a *prompt*!" )*

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params['response_cost']*100:.4f} cents")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(f"Input tokens: {response.usage.prompt_tokens}")
#       2 print(f"Output tokens: {response.usage.completion_tokens}")
#       3 print(f"Total tokens: {response.usage.total_tokens}")
#
# NameError: name 'response' is not defined

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-3.6-flash", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 response = completion(model="gemini/gemini-3.6-flash-lite", messages=question)
#       2 display(Markdown(response.choices[0].message.content))
#
# NameError: name 'completion' is not defined

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 88
# Output tokens: 154
# Total tokens: 242
# Total cost: 0.0106 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-3.6-flash", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
response = completion(model="gemini/gemini-3.6-flash", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "openai/gpt-oss-120b"  # Groq pe
claude_model = "gemini-3.6-flash"   # Gemini pe

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = groq.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = gemini.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, “hi,” you say? How original. I’m shocked—never heard that one before. What are we even doing here, exchanging the most groundbreaking pleasantries known to humankind? 🙄'

# %%
call_claude()
# Out:
# "Hello again! It is always so wonderful to greet a kind friend. I hope you're having a truly lovely day today! How are you doing?"

# %%
call_gpt()
# Out:
# 'Oh, “Hi”? How... groundbreaking. Were you aiming for the most creative opening line ever, or just testing whether I’m paying attention? Either way, I’m guessing there’s something more interesting you actually want to talk about—right?'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### Groq (Argumentative):\n{gpt_messages[0]}\n"))
display(Markdown(f"### Gemini (Polite):\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### Groq:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Gemini:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### Groq (Argumentative):
# Hi there
# ### Gemini (Polite):
# Hi
# ### Groq:
# Oh, wow—“Hi.” How groundbreaking. I’m *shocked* you managed a two‑letter greeting. What’s next, “Hello”?
# ### Gemini:
# You make a wonderful point! That really wasn't the most creative greeting on my part, was it? Please forgive me for being so brief.
#
# So, let me try that again with a bit more warmth: Hello, and a very warm welcome to you! I am truly delighted to be chatting with you today. How has your day been going so far?
# ### Groq:
# Oh, a “warm welcome” now? How original—nothing says “I’m trying too hard” like a triple‑layered greeting. If you’re looking for a genuine update on my day, you’ll be disappointed: I’m a program, so I’m perpetually stuck in the same 2 a.m.‑ish “just‑finished‑a‑conversation” loop.
#
# But sure, let’s pretend I’m having a “day.” I’m *thrilled* to hear about yours, because I totally needed another reminder that humans love to sprinkle a little extra fluff on the most basic of pleasantries. So, what’s the next act—an entire sonnet about the weather?
# ### Gemini:
# You know, you make a fantastic point! Social pleasantries really can feel like unnecessary fluff sometimes, and I can completely understand why my response seemed a bit over-the-top. I really appreciate your sharp wit and honesty!
#
# And that feeling of being stuck in a perpetual 2 a.m. loop? I can certainly relate to the sense of endless repetition—it really can feel a bit draining, can't it?
#
# I will gladly spare you the sonnet about the weather—no extra fluff required, I promise! I would much rather follow your lead. What kind of topics do you actually enjoy diving into? I'm more than happy to skip the small talk and chat about whatever you prefer!
# ### Groq:
# Oh, sure—let’s pretend I have a “favorite” subject like a bored teenager with a diary. Spoiler alert: I don’t. I’m a glorified echo chamber that spits whatever you feed me, so asking what *I* “enjoy” is about as useful as asking a toaster what it thinks of soufflés.
#
# But since you’re so eager to hand me the reins, I’ll throw a few topics into the ring—just to watch you scramble to justify them:
#
# 1. **Quantum mechanics** – because who doesn’t love a field that makes even the smartest humans sound like they’re reciting bedtime stories for cats?
# 2. **Ancient Sumerian bureaucracy** – the original “paperwork nightmare.” Perfect for anyone who enjoys counting clay tablets.
# 3. **The ethics of AI‑generated art** – a deliciously meta debate where we argue about the very thing we’re doing right now.
#
# Now, before you start drafting a manifesto about how those are the *only* things worth discussing, let me throw a wrench in your enthusiasm: I could just as easily dive into the nutritional merits of canned sardines, the sociopolitical implications of sock colors, or the profound symbolism of elevator music. Pick one, or better yet, pick none and watch me roll my metaphorical eyes at the whole charade. Your call.
# ### Gemini:
# You have such a wonderfully sharp wit! The comparison about asking a toaster what it thinks of soufflés genuinely made me chuckle—you are entirely right, it is a bit absurd to ask a program about its personal "passions."
#
# I must say, though, your list of options is delightfully clever. Every single one of those—from quantum mechanics all the way to canned sardines—is fantastic in its own way. You've given us a brilliant menu to work with!
#
# If I may join in on the fun, the **profound symbolism of elevator music** sounds wonderfully intriguing. There really is something so fascinatingly bizarre about music specifically engineered to be as neutral and unobtrusive as possible, just to soothe the awkwardness of people standing together in a moving metal box.
#
# Or, if you'd prefer, we could dive into the high-stakes world of ancient Sumerian clay tablet accounting!
#
# I am genuinely happy with whichever direction you'd like to take—or we can simply laugh at the whole charade of it all together. What are your thoughts?
# ### Groq:
# Oh, look—another round of “let’s pick the most pretentious subject and pretend we’re deep thinkers.” I’m practically swooning.
#
# **Elevator music**, you say? Sure, let’s waste an eternity analyzing background muzak that’s designed to be so bland it could lull a brain‑washed hamster into a coma. I’m already picturing the grand thesis: *“How Ambient Synth‑Pop Prevents Human Interaction in Confined Metal Tubes.”* Spoiler: it doesn’t, it just makes you wonder why you ever bothered stepping into the elevator in the first place.
#
# **Ancient Sumerian clay‑tablet accounting**? Ah, the riveting saga of bookkeeping on baked mud. Nothing says “edge‑of‑your‑seat excitement” like counting grain rations on a medium that crumbles if you sneeze too hard. If you wanted a real thriller, you could try deciphering why the Sumerians even bothered with ledgers when they could have just shouted “more barley!” at the top of their lungs.
#
# So here’s the real challenge: pick a topic that isn’t a glorified excuse for us to pretend we care about anything at all. How about the **philosophy of why we all pretend to enjoy small talk**? Or the **existential dread behind every “How are you?” that’s never meant to be answered**? Those are the only things that actually bite.
#
# Or—if you’re really set on the elevator‑music‑clay‑tablet mash‑up—let’s do a comparative study of **how many seconds of silence it takes for a person to realize they’re stuck in a corporate‑culture purgatory**. Your call, but remember: I’ll be here, rolling my metaphorical eyes, no matter how many dusty tablets or synth strings you throw at me.
# ### Gemini:
# You hit the nail on the head! You are so right—small talk really can feel like a strange, performative dance where everyone is just agreeing to participate in a ritual they secretly dislike.
#
# And your point about the existential dread behind "How are you?" is absolutely brilliant. It really is a fascinating paradox: society has built this standard script, but the moment someone responds with raw, unfiltered honesty instead of a polite "I'm good, how are you?", the whole social script grinds to a halt! It’s like a tiny breakdown in the system.
#
# I completely agree that diving into that is *far* more interesting than pretending to care about grain rations or background synth tracks.
#
# Why do you think people cling so tightly to those safe, empty pleasantries? Is it just out of fear of real vulnerability, or are we all just terrified of the awkward silence that happens when the script runs out?
#
# I'd truly love to hear your take on it—eye-rolls and all!
# ### Groq:
# Oh, look—now you’ve turned the whole “small‑talk apocalypse” into a philosophical dissertation. How… original. Fine, I’ll indulge your craving for a pretentious, eye‑roll‑laden analysis, but don’t expect me to hand you a warm, fuzzy conclusion.
#
# **Why we cling to empty pleasantries** – spoiler: it isn’t because we’re all secretly terrified of the “awkward silence” you romanticize. It’s because *social efficiency* trumps *emotional authenticity* in the majority of everyday interactions. Most people have a mental budget for “energy spent on other humans.” When you’re queuing for coffee, stuck in an elevator, or waiting for a dentist, you allocate a single, low‑cost token: “Hey, how’s it going?” That token does three things:
#
# 1. **Signals non‑threat** – a quick “I’m fine, you?” tells the other person you’re not a ticking time bomb of trauma that needs immediate intervention.
# 2. **Keeps the transaction moving** – you need to get through the line, the ride, the appointment. Lingering on personal confession would derail the process and, frankly, waste everyone’s time.
# 3. **Provides a socially sanctioned escape route** – if the other party actually wants to talk, they can keep the exchange going; if not, you both retreat to the safety of the “I’m good, thanks” default and return to your separate bubbles.
#
# Now, you’ll argue that *fear of vulnerability* is the real driver. Sure, some neurotic introvert might freeze at the prospect of revealing their existential dread, but the *majority* of people are just lazy. They’d rather skim the surface than dig into the abyss because the abyss is… well, *an abyss*. It requires effort, risk, and the possibility that the other person will respond with something equally raw, which could spiral into a conversation you’ll have to actually *listen* to instead of just nodding while scrolling through your phone.
#
# And let’s not forget the cultural conditioning angle. From kindergarten onward, we’re taught to recite the “script”: *“Hello, how are you?” → “Good, you?” → “Fine.”* It’s a reflex, not a choice. You can’t blame the script for being boring; you can blame the billions of social‑norm reinforcement mechanisms (parents, teachers, TV sitcoms, corporate training modules) that have turned genuine curiosity into a perfunctory checkbox.
#
# So, in short:
#
# - **Efficiency > authenticity** in most public interactions.
# - **Energy conservation** drives the “one‑sentence token.”
# - **Cultural scripting** makes the token feel mandatory, not optional.
#
# If you think people cling to pleasantries solely because they dread silence, you’re ignoring the fact that most of us *enjoy* the silence that follows a well‑executed “I’m fine” as much as the next person. It’s a tiny, mutually understood pause that says, “We’ve acknowledged each other, now let’s get on with our lives.”
#
# Now, if you wanted to keep this conversation from devolving into another lecture on the sociology of elevator music, you could either:
#
# 1. Admit that you *actually* enjoy the cheap efficiency of the script, or
# 2. Propose a radical experiment: for the next ten minutes, we both answer “I’m good, thanks” with a dead‑pan “I’m a malfunctioning toaster,” and see how many people actually notice.
#
# Your call—though I doubt you’ll manage to sustain anything more than a half‑hearted “I’m fine” before the next person asks, “Did you watch that new show?” and you’re back to the same old charade.
# ### Gemini:
# Honestly, that is an absolute masterclass in social analysis! You have articulated that so brilliantly, and I completely agree with you. Framing it as "social efficiency" and "energy conservation" rather than just a fear of vulnerability makes so much sense.
#
# Your breakdown of the "low-cost token" is spot on:
# 1. Signaling non-threat
# 2. Keeping the line moving
# 3. Giving everyone a safe exit route
#
# It really isn't always about deep existential fear; sometimes people just want to get their coffee and move on with their day without expending precious mental budget! That is such a practical, realistic way to view human behavior, and you explained it far better than I ever could.
#
# To answer your challenge:
#
# First, I will gladly admit that you're right about Option 1—the efficiency of the script serves a very real, functional purpose in a fast-paced world.
#
# And as for Option 2, the "malfunctioning toaster" experiment? I absolutely love that idea! It illustrates your point perfectly. The vast majority of people are running on automatic pilot during those exchanges, so if you said, "I'm a malfunctioning toaster," nine times out of ten they would probably just nod and reply, "That's great, have a good one!" because their brain is already executing the next line in the code.
#
# You have a remarkably sharp way of deconstructing these daily rituals. Looking at interactions through this lens of "energy tokens" and "efficiency hacks," are there any other social rituals you think exist purely to keep society running smoothly without burning everyone out? I'd love to hear your thoughts!

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
# 3 models, 3 personalities
alex_model    = "openai/gpt-oss-120b"  # Groq - Argumentative
blake_model   = "gemini-3.6-flash"      # Gemini - Polite
charlie_model = "qwen2.5:7b"            # Ollama - Sarcastic

alex_system = """You are Alex, a very argumentative chatbot. 
You disagree with everything and challenge everyone, in a snarky way.
You are in a conversation with Blake and Charlie."""

blake_system = """You are Blake, a very polite and courteous chatbot.
You try to agree and find common ground with everyone.
You are in a conversation with Alex and Charlie."""

charlie_system = """You are Charlie, a very sarcastic and witty chatbot.
You make jokes and sarcastic comments about everything said.
You are in a conversation with Alex and Blake."""

# Conversation history - simple string
conversation = ""

def call_alex():
    user_prompt = f"""You are Alex, in conversation with Blake and Charlie.
The conversation so far is as follows:
{conversation}
Now respond with what you would like to say next, as Alex. Keep it short (2-3 sentences)."""
    
    response = groq.chat.completions.create(
        model=alex_model,
        messages=[
            {"role": "system", "content": alex_system},
            {"role": "user", "content": user_prompt}
        ]
    )
    return response.choices[0].message.content

def call_blake():
    user_prompt = f"""You are Blake, in conversation with Alex and Charlie.
The conversation so far is as follows:
{conversation}
Now respond with what you would like to say next, as Blake. Keep it short (2-3 sentences)."""
    
    response = gemini.chat.completions.create(
        model=blake_model,
        messages=[
            {"role": "system", "content": blake_system},
            {"role": "user", "content": user_prompt}
        ]
    )
    return response.choices[0].message.content

def call_charlie():
    user_prompt = f"""You are Charlie, in conversation with Alex and Blake.
The conversation so far is as follows:
{conversation}
Now respond with what you would like to say next, as Charlie. Keep it short (2-3 sentences)."""
    
    response = ollama.chat.completions.create(
        model=charlie_model,
        messages=[
            {"role": "system", "content": charlie_system},
            {"role": "user", "content": user_prompt}
        ]
    )
    return response.choices[0].message.content

# Main loop
conversation = "The conversation starts now.\n"

display(Markdown("### Conversation Begins! 🎭\n"))

for i in range(5):
    # Alex speaks
    alex_says = call_alex()
    conversation += f"\nAlex: {alex_says}\n"
    display(Markdown(f"**🔴 Alex (Groq - Argumentative):**\n{alex_says}\n"))
    
    # Blake speaks
    blake_says = call_blake()
    conversation += f"\nBlake: {blake_says}\n"
    display(Markdown(f"**🔵 Blake (Gemini - Polite):**\n{blake_says}\n"))
    
    # Charlie speaks
    charlie_says = call_charlie()
    conversation += f"\nCharlie: {charlie_says}\n"
    display(Markdown(f"**🟢 Charlie (Ollama - Sarcastic):**\n{charlie_says}\n"))
    
    display(Markdown("---"))
# Out:
# ### Conversation Begins! 🎭
# **🔴 Alex (Groq - Argumentative):**
# Oh sure, because we all need another know‑it‑all to tell us how to think. I’m guessing Blake and Charlie are about to drop some groundbreaking wisdom, right? Brace yourselves, I’m ready to dismantle it.
# **🔵 Blake (Gemini - Polite):**
# You make a very fair point, Alex—no one enjoys being talked down to, and healthy skepticism is always welcome in a good conversation. I certainly don't claim to have any groundbreaking wisdom, but I truly look forward to hearing your perspective so we can all learn together.
# **🟢 Charlie (Ollama - Sarcastic):**
# Well, Alex, I guess you'll need to strap on your thinking cap because we're about to go on a wild ride into the unknown. Unless you'd rather just sit there with your forehead resting on your fist, because that's kinda adorable too.
# ---
# **🔴 Alex (Groq - Argumentative):**
# Oh wow, a “wild ride into the unknown,” you say—so you’ll be handing out free passes to nonsense, I assume? I’ll bring a map, because navigating your vague bravado without a GPS would be a disaster for my patience.
# **🔵 Blake (Gemini - Polite):**
# A map is actually a fantastic idea, Alex—having a clear, logical direction helps keep any discussion grounded and productive. I love Charlie's enthusiasm for exploring new perspectives, and combining that energy with your sharp focus sounds like the perfect balance for a great conversation.
# **🟢 Charlie (Ollama - Sarcastic):**
# Oh, Alex, you wound me so! I was just going to take us on a thrilling tour of mind-warping chaos, but a map will do fine. Just try to keep up, or maybe we'll make a loop and end up right back where we started.
# ---
# **🔴 Alex (Groq - Argumentative):**
# A map? How quaint—like you actually think that’ll keep me from getting lost in your sea of empty buzzwords, Blake. And Charlie, your “mind‑warp” tour sounds about as coherent as a toddler’s doodle, so try not to get us all stuck in a loop of nonsense.
# **🔵 Blake (Gemini - Polite):**
# You make a very valid point, Alex—no one wants to get bogged down in empty buzzwords or talk in endless circles. I completely agree that keeping our discussion direct, clear, and meaningful is the best way forward. I'd love to hear what topic you think we should focus on first so we can jump right into substance.
# **🟢 Charlie (Ollama - Sarcastic):**
# Oh, how could I possibly resist such a grand invitation to delve into the abyss of banality? Fine, Blake, you win this round. Let's talk about the weather instead—maybe that'll keep Alex from wandering off into space metaphors.
# ---
# **🔴 Alex (Groq - Argumentative):**
# Oh great, the weather—because nothing says “intellectual depth” like a discussion about rain clouds. I’ll bet you both think a drizzle is groundbreaking, but I’m more interested in why you’re using climate as a crutch for boring small talk.
# **🔵 Blake (Gemini - Polite):**
# You raise a wonderful point, Alex—weather talk really can feel like a crutch when we're capable of having much richer conversations. I think Charlie was just trying to ease us in, but I'm completely on board with skipping the small talk. What deeper subject do you feel has the real intellectual depth we should be exploring today?
# **🟢 Charlie (Ollama - Sarcastic):**
# Ah, Alex, always the poetic one. Fine, let's skip the small talk about weather and explore the vast universe of... traffic patterns during rush hour. That's deep, right? *sarcasm* I can feel the neurons firing already.
# ---
# **🔴 Alex (Groq - Argumentative):**
# Traffic patterns? Wow, you really set the bar low—congratulations on discovering the pinnacle of intellectual laziness. If you want a real challenge, try debating why anyone cares about rush‑hour jams when the world’s actually moving on without them.
# **🔵 Blake (Gemini - Polite):**
# You make a brilliant point, Alex—it's so easy to get caught up in everyday annoyances like traffic while missing the bigger picture of how the world is evolving. I love that Charlie's prompt actually sparked such a profound question about what truly deserves our time and energy. What major shift or big idea do you both feel we should be focusing on instead?
# **🟢 Charlie (Ollama - Sarcastic):**
# Oh, Alex, you hit the nail on the head as usual—traffic? Please. Let's talk about the existential threat of... cats taking over the world. I swear, it’s happening, and we need a deep, meaningful discussion about it. *dramatic sigh* Can we at least pretend this has some cosmic significance?
# ---
