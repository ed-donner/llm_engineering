# %% [markdown]
# Elasticsearch explorer
# The aim is to input your unauthenticated elasticsearch url and this tool will help you query it with natural language.
# You can ask "please aggregate all agent status records by companyId for the last 6 months" and you will get the results in a table - saves me looking up the syntax all the time
# there are 2 tools for reading the searchable aliases and finding the mapping for each. You can ask to "list all aliases" and you can ask to see the mapping for a particular alias. you can also just ask for the field list for an alias.
# If you ask, you can just get the search query displayed - usefull for debugging
# If you ask to query for records, the llm will use the tools to first create a query, then execute it and show you the results formatted to a table.
# The date and the "companyId" if you are using it will be set dynamically into the prompt

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
import gradio as gr
import requests
import json
from datetime import datetime

# %%
# Load environment variables in a file called .env
# Print the key prefixes to help with any debugging

load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
openai = OpenAI()
MODEL = 'gpt-4.1'
alias_and_mappinglist = []
# Out:
# OpenAI API Key exists and begins sk-proj-

# %% [markdown]
# This system prompt aims to instruct the llm to allow the creation of elasticsearch queries. It also gives instruction about using the tools to get the lists of aliases and mapings to help construct the queries
# I ave added a companyId as that is always present in my data, you may want to remove it

# %%
def system_prompt(company_id, elasticsearch_url):
    example1 = {
      "query": {
        "bool": {
          "must": [
            {
              "term": {
                "companyId": 11529601
              }
            },
            {
              "range": {
                "tsStart": {
                  "gte": 1793842800000,
                  "lt": 1793846400000
                }
              }
            }
          ]
        }
      }
    };
    
    return f'''Your job is to help the user to generate and run elasticsearch queries for
        the company {company_id}. The Elasticsearch cluster is available at: {elasticsearch_url}
        If the user asks for a list of aliases, you can use the get_alias_list function.
        If the user asks for the mapping for a specific alias, you can use the get_alias_mapping function.
        It might be helpul to just provide the fields in the mapping to the user.
        If the user asks you to generate a search query, If the company id is present, you must always include the companyId field in the search query.
        If the user asks to search for documents, first you must generate a search body compatible with elasticsearch
        syntax then you can use the search_elasticsearch function and pass in
        the search_body and alias. You can use the mapping to help generate the search_body.
        If the user asks a question about the data, you can use any of the alias names from the get_alias_list
        function and the mapping to help generate the search_body.
        When presenting data to the user, make sure to include the alias name and the index name.
        Never return more than 100 rows of data.
        If the user asks for relative date ranges, the current date time is {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}
        dates in the elasticsearch query should be in epoch ms time.         
        The data coming back from elasticsearch is in json format. please convert this to a simple tabular form
        and include summary data like the total number of hits.
        for example if you are asked to generate a search query for the alias "v2-agent-status" you might return 
        {json.dumps(example1)}
        for example if you are asked to execute a query, or search for records, then you might execute the tool call
        search_elasticsearch with the search_body and alias.
        search_elasticsearch("http://golda.eng.tcs.local:9200/", {json.dumps(example1)}, "v2-agent-status")
        '''

# %% [markdown]
# Elasticsearch tool functions
# these are the queries to elasticsearch

# %%
def get_elasticsearch_aliases_and_mappings(elasticsearch_url):
    """
    Fetches all aliases and their mappings from an Elasticsearch cluster.
    Returns an array of objects with {alias, mapping} for each alias.
    If an alias points to multiple indices, uses the first index's mapping.
    
    Args:
        elasticsearch_url (str): The base URL of the Elasticsearch cluster 
                                (e.g., 'http://localhost:9200')
    
    Returns:
        list: An array of dictionaries, each containing:
              {
                  'alias': 'alias_name',
                  'mapping': {...}  # mapping from the first index this alias points to
              }
    """
    global alias_and_mappinglist
    
    # Lazy return if already populated
    if alias_and_mappinglist != []:
        return alias_and_mappinglist
    
    try:
        # Remove trailing slash if present
        base_url = elasticsearch_url.rstrip('/')
        
        # Get all aliases
        aliases_url = f"{base_url}/_aliases"
        aliases_response = requests.get(aliases_url, timeout=10)
        aliases_response.raise_for_status()
        aliases_data = aliases_response.json()
        
        # Get all mappings
        mappings_url = f"{base_url}/_mapping"
        mappings_response = requests.get(mappings_url, timeout=10)
        mappings_response.raise_for_status()
        mappings_data = mappings_response.json()
        
        # Build a map: alias_name -> first_index_it_appears_in
        alias_to_index = {}
        
        # Iterate through all indices
        for index_name, index_data in aliases_data.items():
            # Check if this index has aliases
            if 'aliases' in index_data and index_data['aliases']:
                # For each alias on this index
                for alias_name in index_data['aliases'].keys():
                    # Only store the first index we encounter for this alias
                    if alias_name not in alias_to_index:
                        alias_to_index[alias_name] = index_name
        
        # Build result array: for each alias, get its mapping from the first index
        alias_and_mappinglist = []
        for alias_name, first_index in alias_to_index.items():
            # Get the mapping for the first index this alias points to
            if first_index in mappings_data:
                mapping = mappings_data[first_index].get('mappings', {})
                alias_and_mappinglist.append({
                    'alias': alias_name,
                    'mapping': mapping
                })
        
        return alias_and_mappinglist
    
    except requests.exceptions.RequestException as e:
        return [{
            'error': f"Failed to connect to Elasticsearch: {str(e)}",
            'alias': None,
            'mapping': None
        }]
    except json.JSONDecodeError as e:
        return [{
            'error': f"Failed to parse response: {str(e)}",
            'alias': None,
            'mapping': None
        }]

# Example usage:
# result = get_elasticsearch_aliases_and_mappings('http://localhost:9200')
# print(json.dumps(result, indent=2))

def search_elasticsearch(elasticsearch_url, search_body, index_or_alias=None):
    """
    Executes a search query against Elasticsearch.
    
    Args:
        elasticsearch_url (str): The base URL of the Elasticsearch cluster 
                                (e.g., 'http://localhost:9200')
        search_body (dict or str): The search query body as a dictionary or JSON string
                                   (e.g., {'query': {'match': {'field': 'value'}}})
        index_or_alias (str, optional): The index or alias to search. If None, searches all indices.
    
    Returns:
        dict: The JSON response from Elasticsearch containing search results
    """
    try:
        # Remove trailing slash if present
        base_url = elasticsearch_url.rstrip('/')
        
        # Build the search URL
        if index_or_alias:
            search_url = f"{base_url}/{index_or_alias}/_search"
        else:
            search_url = f"{base_url}/_search"
        
        # Convert search_body to dict if it's a string
        if isinstance(search_body, str):
            search_body = json.loads(search_body)
        
        # Set headers for JSON content
        headers = {'Content-Type': 'application/json'}
        
        # Execute the search request
        response = requests.post(
            search_url,
            json=search_body,
            headers=headers,
            timeout=30
        )
        response.raise_for_status()
        
        return response.json()
    
    except requests.exceptions.RequestException as e:
        return {
            'error': f"Failed to execute search: {str(e)}",
            'status_code': getattr(e.response, 'status_code', None) if hasattr(e, 'response') else None
        }
    except json.JSONDecodeError as e:
        return {
            'error': f"Failed to parse search body or response: {str(e)}"
        }

# Example usage:
# search_query = {
#     "query": {
#         "match": {
#             "field_name": "search term"
#         }
#     },
#     "size": 10
# }
# result = search_elasticsearch('http://localhost:9200', search_query, index_or_alias='my_index')
# print(json.dumps(result, indent=2))

# %% [markdown]
# Test the elasticsearch functions befre proceeding

# %%
get_elasticsearch_aliases_and_mappings("http://golda.eng.tcs.local:9200/")
# Out:
# [{'alias': '.kibana-event-log-7.9.3',
#   'mapping': {'dynamic': 'false',
#    'properties': {'@timestamp': {'type': 'date'},
#     'ecs': {'properties': {'version': {'type': 'keyword',
#        'ignore_above': 1024}}},
#     'error': {'properties': {'message': {'type': 'text', 'norms': False}}},
#     'event': {'properties': {'action': {'type': 'keyword',
#        'ignore_above': 1024},
#       'duration': {'type': 'long'},
#       'end': {'type': 'date'},
#       'outcome': {'type': 'keyword', 'ignore_above': 1024},
#       'provider': {'type': 'keyword', 'ignore_above': 1024},
#       'start': {'type': 'date'}}},
#     'kibana': {'properties': {'alerting': {'properties': {'instance_id': {'type': 'keyword',
#          'ignore_above': 1024}}},
#       'saved_objects': {'type': 'nested',
#        'properties': {'id': {'type': 'keyword', 'ignore_above': 1024},
#         'namespace': {'type': 'keyword', 'ignore_above': 1024},
#         'rel': {'type': 'keyword', 'ignore_above': 1024},
#         'type': {'type': 'keyword', 'ignore_above': 1024}}},
#       'server_uuid': {'type': 'keyword', 'ignore_above': 1024}}},
#     'message': {'type': 'text', 'norms': False},
#     'tags': {'type': 'keyword',
#      'meta': {'isArray': 'true'},
#      'ignore_above': 1024},
#     'user': {'properties': {'name': {'type': 'keyword',
#        'fields': {'text': {'type': 'text', 'norms': False}},
#        'ignore_above': 1024}}}}}},
#  {'alias': 'v2-logging-service-bad-requests', 'mapping': {'dynamic': 'false'}},
#  {'alias': 'lms-call-queue',
#   'mapping': {'dynamic': 'false',
#    'properties': {'@timestamp': {'type': 'date', 'format': 'epoch_millis'},
#     'agents': {'properties': {'assigned': {'type': 'long'},
#       'available': {'type': 'long'},
#       'nonVoice': {'type': 'long'},
#       'offline': {'type': 'long'},
#       'onBreak': {'type': 'long'},
#       'onCall': {'type': 'long'}}},
#     'capacity': {'properties': {'queued': {'type': 'long'},
#       'total': {'type': 'long'}}},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'instanceId': {'type': 'long'},
#     'queueId': {'type': 'long'},
#     'queueItems': {'properties': {'active': {'type': 'long'},
#       'longestTalkTimeSecs': {'type': 'long'},
#       'longestWaitTimeSecs': {'type': 'long'},
#       'total': {'type': 'long'},
#       'totalTalkTimeSecs': {'type': 'long'},
#       'totalWaitTimeSecs': {'type': 'long'},
#       'waiting': {'type': 'long'}}},
#     'queueName': {'type': 'keyword'},
#     'queueNameId': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'resellerName': {'type': 'keyword'},
#     'type': {'type': 'keyword'}}}},
#  {'alias': 'crm-contact',
#   'mapping': {'dynamic': 'false',
#    'properties': {'address': {'type': 'keyword'},
#     'cf1': {'type': 'keyword'},
#     'cf10': {'type': 'keyword'},
#     'cf11': {'type': 'keyword'},
#     'cf12': {'type': 'keyword'},
#     'cf13': {'type': 'keyword'},
#     'cf14': {'type': 'keyword'},
#     'cf15': {'type': 'keyword'},
#     'cf16': {'type': 'keyword'},
#     'cf17': {'type': 'keyword'},
#     'cf18': {'type': 'keyword'},
#     'cf19': {'type': 'keyword'},
#     'cf2': {'type': 'keyword'},
#     'cf20': {'type': 'keyword'},
#     'cf21': {'type': 'keyword'},
#     'cf22': {'type': 'keyword'},
#     'cf23': {'type': 'keyword'},
#     'cf24': {'type': 'keyword'},
#     'cf25': {'type': 'keyword'},
#     'cf26': {'type': 'keyword'},
#     'cf27': {'type': 'keyword'},
#     'cf28': {'type': 'keyword'},
#     'cf29': {'type': 'keyword'},
#     'cf3': {'type': 'keyword'},
#     'cf30': {'type': 'keyword'},
#     'cf31': {'type': 'keyword'},
#     'cf32': {'type': 'keyword'},
#     'cf33': {'type': 'keyword'},
#     'cf34': {'type': 'keyword'},
#     'cf35': {'type': 'keyword'},
#     'cf36': {'type': 'keyword'},
#     'cf37': {'type': 'keyword'},
#     'cf38': {'type': 'keyword'},
#     'cf39': {'type': 'keyword'},
#     'cf4': {'type': 'keyword'},
#     'cf40': {'type': 'keyword'},
#     'cf41': {'type': 'keyword'},
#     'cf42': {'type': 'keyword'},
#     'cf43': {'type': 'keyword'},
#     'cf44': {'type': 'keyword'},
#     'cf45': {'type': 'keyword'},
#     'cf46': {'type': 'keyword'},
#     'cf47': {'type': 'keyword'},
#     'cf48': {'type': 'keyword'},
#     'cf49': {'type': 'keyword'},
#     'cf5': {'type': 'keyword'},
#     'cf50': {'type': 'keyword'},
#     'cf51': {'type': 'keyword'},
#     'cf52': {'type': 'keyword'},
#     'cf53': {'type': 'keyword'},
#     'cf54': {'type': 'keyword'},
#     'cf55': {'type': 'keyword'},
#     'cf56': {'type': 'keyword'},
#     'cf57': {'type': 'keyword'},
#     'cf58': {'type': 'keyword'},
#     'cf59': {'type': 'keyword'},
#     'cf6': {'type': 'keyword'},
#     'cf60': {'type': 'keyword'},
#     'cf61': {'type': 'keyword'},
#     'cf62': {'type': 'keyword'},
#     'cf63': {'type': 'keyword'},
#     'cf64': {'type': 'keyword'},
#     'cf7': {'type': 'keyword'},
#     'cf8': {'type': 'keyword'},
#     'cf9': {'type': 'keyword'},
#     'city': {'type': 'keyword'},
#     'code': {'type': 'keyword'},
#     'contactId': {'type': 'keyword'},
#     'contactName': {'type': 'keyword'},
#     'country': {'type': 'keyword'},
#     'creationDate': {'type': 'date', 'format': 'epoch_millis'},
#     'customerNumber': {'type': 'keyword'},
#     'email': {'type': 'keyword'},
#     'id': {'type': 'keyword'},
#     'mobile': {'type': 'keyword'},
#     'modifiedDate': {'type': 'date', 'format': 'epoch_millis'},
#     'organisationId': {'type': 'keyword'},
#     'phone': {'type': 'keyword'},
#     'preferredAgent': {'type': 'keyword'},
#     'priority': {'type': 'integer'},
#     'region': {'type': 'keyword'},
#     'socialMedia': {'type': 'keyword'}}}},
#  {'alias': 'v2-contact-centre-chats-queue',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endParty': {'type': 'keyword'},
#       'endReason': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'chatConnected': {'type': 'boolean'},
#     'chatDropped': {'type': 'boolean'},
#     'chatQueueTransferredIn': {'type': 'boolean'},
#     'chatQueueTransferredOut': {'type': 'boolean'},
#     'chatServerId': {'type': 'long'},
#     'chatServerName': {'type': 'keyword'},
#     'chatUuid': {'type': 'keyword'},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'conversationId': {'type': 'keyword'},
#     'endNodeName': {'type': 'keyword'},
#     'endReason': {'type': 'keyword'},
#     'ender': {'type': 'keyword'},
#     'failureMessage': {'type': 'keyword'},
#     'initialAgentName': {'type': 'keyword'},
#     'msDuration': {'type': 'long'},
#     'msTimeToFirstResponse': {'type': 'long'},
#     'msTotalChatTime': {'type': 'long'},
#     'msTotalConnectTime': {'type': 'long'},
#     'msTotalQueueTime': {'type': 'long'},
#     'msTotalWaitingTime': {'type': 'long'},
#     'msWrapUpTime': {'type': 'long'},
#     'nextQueueId': {'type': 'long'},
#     'numResponses': {'type': 'long'},
#     'numTransferAttempts': {'type': 'long'},
#     'numTransferSuccesses': {'type': 'long'},
#     'previousQueueId': {'type': 'long'},
#     'queueDepartureReason': {'type': 'keyword'},
#     'queueId': {'type': 'long'},
#     'queueLength': {'type': 'long'},
#     'queueName': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'tsChatStart': {'type': 'date', 'format': 'epoch_millis'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'}}}},
#  {'alias': 'v2-contact-centre-calls-agent',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endParty': {'type': 'keyword'},
#       'endReason': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'agentExt': {'type': 'keyword'},
#     'agentId': {'type': 'long'},
#     'agentName': {'type': 'keyword'},
#     'agentUsername': {'type': 'keyword'},
#     'callConnected': {'type': 'boolean'},
#     'callDropped': {'type': 'boolean'},
#     'callFailure': {'type': 'boolean'},
#     'callMissed': {'type': 'boolean'},
#     'callMissedBusy': {'type': 'boolean'},
#     'callMissedOther': {'type': 'boolean'},
#     'callMissedTimeout': {'type': 'boolean'},
#     'callType': {'type': 'keyword'},
#     'callUuid': {'type': 'keyword'},
#     'classification': {'type': 'long'},
#     'cliRestricted': {'type': 'boolean'},
#     'cliRestrictedEnum': {'type': 'keyword'},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'contactCalledBack': {'type': 'boolean'},
#     'customerUri': {'type': 'keyword'},
#     'endNodeName': {'type': 'keyword'},
#     'endReason': {'type': 'keyword'},
#     'ender': {'type': 'keyword'},
#     'failureMessage': {'type': 'keyword'},
#     'failureNodeName': {'type': 'keyword'},
#     'groupId': {'type': 'long'},
#     'msDuration': {'type': 'long'},
#     'msTotalConferenceTime': {'type': 'long'},
#     'msTotalConfererTime': {'type': 'long'},
#     'msTotalConnectTime': {'type': 'long'},
#     'msTotalConsultantTime': {'type': 'long'},
#     'msTotalConsultingTime': {'type': 'long'},
#     'msTotalHoldTime': {'type': 'long'},
#     'msTotalTalkTime': {'type': 'long'},
#     'msWaitingForClassificationTime': {'type': 'long'},
#     'msWrapUpTime': {'type': 'long'},
#     'numberType': {'type': 'keyword'},
#     'queueId': {'type': 'long'},
#     'queueName': {'type': 'keyword'},
#     'releaseCause': {'type': 'long'},
#     'resellerId': {'type': 'long'},
#     'resolvedCall': {'type': 'boolean'},
#     'serviceNumber': {'type': 'keyword'},
#     'serviceNumberId': {'type': 'long'},
#     'serviceNumberName': {'type': 'keyword'},
#     'supervisor': {'type': 'boolean'},
#     'taskId': {'type': 'keyword'},
#     'taskUuid': {'type': 'keyword'},
#     'transferAttempted': {'type': 'boolean'},
#     'transferSucceed': {'type': 'boolean'},
#     'tsCallStart': {'type': 'date', 'format': 'epoch_millis'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsFailure': {'type': 'long'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'},
#     'tsTotalConnectedTime': {'type': 'long'},
#     'userProvidedCli': {'type': 'keyword'},
#     'virtualAgentId': {'type': 'long'},
#     'warmTransferConnected': {'type': 'boolean'}}}},
#  {'alias': 'v2-contact-centre-whatsapps-agent',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endParty': {'type': 'keyword'},
#       'endReason': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'agentId': {'type': 'long'},
#     'agentName': {'type': 'keyword'},
#     'agentUsername': {'type': 'keyword'},
#     'classification': {'type': 'long'},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'conversationId': {'type': 'keyword'},
#     'endNodeName': {'type': 'keyword'},
#     'endReason': {'type': 'keyword'},
#     'ender': {'type': 'keyword'},
#     'failureMessage': {'type': 'keyword'},
#     'fromPhoneNumber': {'type': 'keyword'},
#     'msDuration': {'type': 'long'},
#     'msTimeToFirstResponse': {'type': 'long'},
#     'msTotalConnectTime': {'type': 'long'},
#     'msTotalWhatsAppTime': {'type': 'long'},
#     'msWrapUpTime': {'type': 'long'},
#     'numResponses': {'type': 'long'},
#     'queueId': {'type': 'long'},
#     'queueName': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'resolvedWhatsApp': {'type': 'boolean'},
#     'toPhoneNumberId': {'type': 'keyword'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsLastModified': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'},
#     'tsWhatsAppStart': {'type': 'date', 'format': 'epoch_millis'},
#     'whatsAppConnected': {'type': 'boolean'},
#     'whatsAppDropped': {'type': 'boolean'},
#     'whatsAppMissed': {'type': 'boolean'},
#     'whatsAppQueued': {'type': 'boolean'},
#     'whatsAppServiceId': {'type': 'long'},
#     'whatsAppServiceName': {'type': 'keyword'},
#     'whatsAppUuid': {'type': 'keyword'}}}},
#  {'alias': 'lms-company',
#   'mapping': {'dynamic': 'false',
#    'properties': {'@timestamp': {'type': 'date', 'format': 'epoch_millis'},
#     'agents': {'properties': {'available': {'type': 'long'},
#       'nonVoice': {'type': 'long'},
#       'offline': {'type': 'long'},
#       'onBreak': {'type': 'long'},
#       'onCall': {'type': 'long'},
#       'total': {'type': 'long'}}},
#     'capacity': {'properties': {'queued': {'properties': {'call': {'type': 'long'},
#         'email': {'type': 'long'},
#         'total': {'type': 'long'},
#         'webchat': {'type': 'long'},
#         'workitem': {'type': 'long'}}},
#       'total': {'properties': {'call': {'type': 'long'},
#         'email': {'type': 'long'},
#         'total': {'type': 'long'},
#         'webchat': {'type': 'long'},
#         'workitem': {'type': 'long'}}}}},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'instanceId': {'type': 'long'},
#     'queueItems': {'properties': {'active': {'properties': {'call': {'type': 'long'},
#         'email': {'type': 'long'},
#         'total': {'type': 'long'},
#         'webchat': {'type': 'long'},
#         'workitem': {'type': 'long'}}},
#       'longestTalkTimeSecs': {'type': 'long'},
#       'longestWaitTimeSecs': {'properties': {'call': {'type': 'long'},
#         'email': {'type': 'long'},
#         'total': {'type': 'long'},
#         'webchat': {'type': 'long'},
#         'workitem': {'type': 'long'}}},
#       'total': {'properties': {'call': {'type': 'long'},
#         'email': {'type': 'long'},
#         'total': {'type': 'long'},
#         'webchat': {'type': 'long'},
#         'workitem': {'type': 'long'}}},
#       'totalTalkTimeSecs': {'type': 'long'},
#       'totalWaitTimeSecs': {'properties': {'call': {'type': 'long'},
#         'email': {'type': 'long'},
#         'total': {'type': 'long'},
#         'webchat': {'type': 'long'},
#         'workitem': {'type': 'long'}}},
#       'waiting': {'properties': {'call': {'type': 'long'},
#         'email': {'type': 'long'},
#         'total': {'type': 'long'},
#         'webchat': {'type': 'long'},
#         'workitem': {'type': 'long'}}}}},
#     'queues': {'properties': {'call': {'type': 'long'},
#       'email': {'type': 'long'},
#       'total': {'type': 'long'},
#       'webchat': {'type': 'long'},
#       'workitem': {'type': 'long'}}},
#     'resellerId': {'type': 'long'},
#     'resellerName': {'type': 'keyword'}}}},
#  {'alias': 'v2-contact-centre-sms-contact',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endPartyAgentId': {'type': 'long'},
#       'endPartyQueueId': {'type': 'long'},
#       'endReason': {'type': 'keyword'},
#       'intermediateOrFinal': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'targetPartyAgentId': {'type': 'long'},
#       'targetPartyQueueId': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'agentId': {'type': 'long'},
#     'agentName': {'type': 'keyword'},
#     'agentUsername': {'type': 'keyword'},
#     'classification': {'type': 'long'},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'dataCoding': {'type': 'long'},
#     'endReason': {'type': 'keyword'},
#     'failureMessage': {'type': 'text'},
#     'finalQueueId': {'type': 'long'},
#     'firstResponseAgentId': {'type': 'long'},
#     'flowId': {'type': 'long'},
#     'flowName': {'type': 'keyword'},
#     'flowNodeName': {'type': 'text'},
#     'flowType': {'type': 'keyword'},
#     'from': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'initialQueueId': {'type': 'long'},
#     'initialQueueuId': {'type': 'long'},
#     'intermediateOrFinal': {'type': 'keyword'},
#     'messageCount': {'type': 'long'},
#     'msSmsHandlingTime': {'type': 'long'},
#     'msTimeSpentActive': {'type': 'long'},
#     'msTimeSpentAllocated': {'type': 'long'},
#     'msTimeSpentOnQueues': {'type': 'long'},
#     'msTimeToFirstResponse': {'type': 'long'},
#     'msTimeToResolution': {'type': 'long'},
#     'msTotalQueueTime': {'type': 'long'},
#     'numAllocatedAgents': {'type': 'long'},
#     'numIntermediateResponses': {'type': 'long'},
#     'numQueues': {'type': 'long'},
#     'octetCount': {'type': 'long'},
#     'queueId': {'type': 'long'},
#     'queueName': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'resolvingAgentId': {'type': 'long'},
#     'smsHandled': {'type': 'boolean'},
#     'smsQueued': {'type': 'boolean'},
#     'smsResolved': {'type': 'boolean'},
#     'smsType': {'type': 'keyword'},
#     'smsUuid': {'type': 'keyword'},
#     'templateUsed': {'type': 'long'},
#     'templateUsedName': {'type': 'keyword'},
#     'to': {'type': 'text'},
#     'triggeringCallId': {'type': 'text'},
#     'tsArrivedTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsFirstResponseTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsResolutionTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsSmsSentTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsSmsTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'},
#     'type': {'type': 'keyword'}}}},
#  {'alias': 'v2-contact-centre-emails-queue',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endReason': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'emailHandled': {'type': 'boolean'},
#     'emailServerId': {'type': 'long'},
#     'emailServerName': {'type': 'keyword'},
#     'emailType': {'type': 'keyword'},
#     'emailUuid': {'type': 'keyword'},
#     'endReason': {'type': 'keyword'},
#     'from': {'type': 'keyword'},
#     'incomingServerId': {'type': 'long'},
#     'intermediateOrFinal': {'type': 'keyword'},
#     'msTimeSpentActive': {'type': 'long'},
#     'msTimeSpentAllocated': {'type': 'long'},
#     'msTimeSpentInReview': {'type': 'long'},
#     'msTimeSpentOnQueue': {'type': 'long'},
#     'msTimeToFirstResponse': {'type': 'long'},
#     'msTimeToResolution': {'type': 'long'},
#     'msTotalQueueTime': {'type': 'long'},
#     'numAllocatedAgents': {'type': 'long'},
#     'numIntermediateResponses': {'type': 'long'},
#     'numReviews': {'type': 'long'},
#     'queueEnteredTime': {'type': 'date', 'format': 'epoch_millis'},
#     'queueId': {'type': 'long'},
#     'queueLeaveTime': {'type': 'date', 'format': 'epoch_millis'},
#     'queueName': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'subject': {'type': 'text'},
#     'to': {'type': 'keyword'},
#     'tsEmailSentTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsEmailTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'},
#     'type': {'type': 'keyword'}}}},
#  {'alias': 'lms-email-servers',
#   'mapping': {'dynamic': 'false',
#    'properties': {'@timestamp': {'type': 'date', 'format': 'epoch_millis'},
#     'authType': {'type': 'keyword'},
#     'averageRequestTime': {'type': 'long'},
#     'companyId': {'type': 'keyword'},
#     'companyName': {'type': 'keyword'},
#     'emailServerId': {'type': 'long'},
#     'emailServerName': {'type': 'keyword'},
#     'emailServerShortName': {'type': 'keyword'},
#     'host': {'type': 'keyword'},
#     'notObtained': {'type': 'long'},
#     'obtainedFromBrowserCache': {'type': 'long'},
#     'obtainedFromCrm': {'type': 'long'},
#     'obtainedFromEmailServer': {'type': 'long'},
#     'requests': {'type': 'long'},
#     'requestsFromCRM': {'type': 'long'},
#     'resellerId': {'type': 'long'},
#     'resellerName': {'type': 'keyword'}}}},
#  {'alias': 'v2-contact-centre-chats-contact',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endParty': {'type': 'keyword'},
#       'endReason': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'chatConnected': {'type': 'boolean'},
#     'chatDropped': {'type': 'boolean'},
#     'chatQueued': {'type': 'boolean'},
#     'chatServerId': {'type': 'long'},
#     'chatServerName': {'type': 'keyword'},
#     'chatUuid': {'type': 'keyword'},
#     'classification': {'type': 'long'},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'conversationId': {'type': 'keyword'},
#     'endAgentId': {'type': 'long'},
#     'endAgentName': {'type': 'keyword'},
#     'endNodeName': {'type': 'keyword'},
#     'endQueueId': {'type': 'long'},
#     'endQueueName': {'type': 'keyword'},
#     'endReason': {'type': 'keyword'},
#     'ender': {'type': 'keyword'},
#     'failureMessage': {'type': 'keyword'},
#     'initialAgentName': {'type': 'keyword'},
#     'initialQueueId': {'type': 'long'},
#     'msAnswerTime': {'type': 'long'},
#     'msDuration': {'type': 'long'},
#     'msTimeToFirstResponse': {'type': 'long'},
#     'msTotalChatTime': {'type': 'long'},
#     'msTotalConnectTime': {'type': 'long'},
#     'msTotalPreQueueTime': {'type': 'long'},
#     'msTotalQueueTime': {'type': 'long'},
#     'msWrapUpTime': {'type': 'long'},
#     'numResponses': {'type': 'long'},
#     'releaseCause': {'type': 'long'},
#     'secondClassification': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'tsAnswer': {'type': 'date', 'format': 'epoch_millis'},
#     'tsChatStart': {'type': 'date', 'format': 'epoch_millis'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'}}}},
#  {'alias': 'crm-event',
#   'mapping': {'dynamic': 'false',
#    'properties': {'attachmentName': {'type': 'keyword'},
#     'attachmentSize': {'type': 'long'},
#     'author': {'type': 'keyword'},
#     'callId': {'type': 'keyword'},
#     'chatConversationId': {'type': 'long'},
#     'chatEnded': {'type': 'boolean'},
#     'classificationCode': {'type': 'keyword'},
#     'contactId': {'type': 'keyword'},
#     'contactType': {'type': 'keyword'},
#     'conversationId': {'type': 'keyword'},
#     'creationDate': {'type': 'date', 'format': 'epoch_millis'},
#     'emailServerShortName': {'type': 'keyword'},
#     'eventId': {'type': 'keyword'},
#     'eventText': {'type': 'keyword'},
#     'fromHeader': {'type': 'keyword'},
#     'id': {'type': 'keyword'},
#     'messageId': {'type': 'keyword'},
#     'modifiedDate': {'type': 'date', 'format': 'epoch_millis'},
#     'organisationId': {'type': 'keyword'},
#     'secondClassification': {'type': 'keyword'},
#     'subject': {'type': 'keyword'},
#     'tags': {'type': 'keyword'},
#     'toHeader': {'type': 'keyword'},
#     'whatsAppConversationId': {'type': 'long'},
#     'whatsAppEnded': {'type': 'boolean'}}}},
#  {'alias': 'lms-email-manager',
#   'mapping': {'dynamic': 'false',
#    'properties': {'@timestamp': {'type': 'date', 'format': 'epoch_millis'},
#     'authType': {'type': 'keyword'},
#     'averageIncomingEmailSizeMb': {'type': 'long'},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'emailServerId': {'type': 'long'},
#     'emailServerName': {'type': 'keyword'},
#     'emailsFailedToBeReadFromStorage': {'type': 'long'},
#     'emailsFailedToBeSent': {'type': 'long'},
#     'emailsFailedToBeSentToNjs': {'type': 'long'},
#     'emailsReadFromStorageSuccessfully': {'type': 'long'},
#     'emailsSent': {'type': 'long'},
#     'emailsSentToNjsSuccessfully': {'type': 'long'},
#     'failedConnections': {'type': 'long'},
#     'failedStorageConnections': {'type': 'long'},
#     'host': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'resellerName': {'type': 'keyword'},
#     'successfulConnections': {'type': 'long'},
#     'successfulStorageConnections': {'type': 'long'},
#     'templateEmailsFailedToBeSent': {'type': 'long'},
#     'templateEmailsSent': {'type': 'long'}}}},
#  {'alias': 'crm-chat',
#   'mapping': {'dynamic': 'false',
#    'properties': {'agentsInvolved': {'type': 'long'},
#     'chatWasAbusive': {'type': 'boolean'},
#     'classificationId': {'type': 'long'},
#     'classificationName': {'type': 'keyword'},
#     'contactId': {'type': 'keyword'},
#     'conversationId': {'type': 'long'},
#     'creationDate': {'type': 'date', 'format': 'epoch_millis'},
#     'endTime': {'type': 'date', 'format': 'epoch_millis'},
#     'id': {'type': 'keyword'},
#     'modifiedDate': {'type': 'date', 'format': 'epoch_millis'},
#     'organisationId': {'type': 'keyword'},
#     'remoteBareJid': {'type': 'keyword'},
#     'serviceId': {'type': 'keyword'},
#     'stanzas': {'type': 'keyword', 'index': False, 'doc_values': False},
#     'startTime': {'type': 'date', 'format': 'epoch_millis'},
#     'wasRecordingPaused': {'type': 'boolean'}}}},
#  {'alias': 'v2-contact-centre-calls-contact',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endParty': {'type': 'keyword'},
#       'endReason': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'agentId': {'type': 'long'},
#     'agentName': {'type': 'keyword'},
#     'agentNumber': {'type': 'keyword'},
#     'agentUsername': {'type': 'keyword'},
#     'bPartyAnswerTime': {'type': 'date', 'format': 'epoch_millis'},
#     'callConnected': {'type': 'boolean'},
#     'callDestinations': {'type': 'keyword'},
#     'callDropped': {'type': 'boolean'},
#     'callFailure': {'type': 'boolean'},
#     'callQueued': {'type': 'boolean'},
#     'callSlotId': {'type': 'long'},
#     'callType': {'type': 'keyword'},
#     'callUuid': {'type': 'keyword'},
#     'callbackRequested': {'type': 'boolean'},
#     'classification': {'type': 'long'},
#     'cliRestricted': {'type': 'boolean'},
#     'cliRestrictedEnum': {'type': 'keyword'},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'connectedQueuePriorityIncreased': {'type': 'boolean'},
#     'contactCalledBack': {'type': 'boolean'},
#     'contactNumber': {'type': 'keyword'},
#     'customerUri': {'type': 'keyword'},
#     'endAgentId': {'type': 'long'},
#     'endAgentName': {'type': 'keyword'},
#     'endNodeName': {'type': 'keyword'},
#     'endQueueId': {'type': 'long'},
#     'endQueueName': {'type': 'keyword'},
#     'endReason': {'type': 'keyword'},
#     'endVirtualAgentId': {'type': 'long'},
#     'endedIn': {'type': 'keyword'},
#     'ender': {'type': 'keyword'},
#     'failureMessage': {'type': 'keyword'},
#     'failureNodeName': {'type': 'keyword'},
#     'firstCallTransferType': {'type': 'keyword'},
#     'initialAgentName': {'type': 'keyword'},
#     'initialQueueId': {'type': 'long'},
#     'msAnswerTime': {'type': 'long'},
#     'msCallDurationPostFirstTransfer': {'type': 'long'},
#     'msCallTalkTimePostFirstTransfer': {'type': 'long'},
#     'msDuration': {'type': 'long'},
#     'msTotalConnectTime': {'type': 'long'},
#     'msTotalHoldTime': {'type': 'long'},
#     'msTotalPreQueueTime': {'type': 'long'},
#     'msTotalQueueTime': {'type': 'long'},
#     'msTotalTalkTime': {'type': 'long'},
#     'msWaitingForClassificationTime': {'type': 'long'},
#     'msWrapUpTime': {'type': 'long'},
#     'numberType': {'type': 'keyword'},
#     'releaseCause': {'type': 'long'},
#     'rescheduleCount': {'type': 'long'},
#     'resellerId': {'type': 'long'},
#     'scheduledCallId': {'type': 'long'},
#     'secondClassification': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'serviceNumber': {'type': 'keyword'},
#     'serviceNumberId': {'type': 'long'},
#     'serviceNumberName': {'type': 'keyword'},
#     'targetAgentId': {'type': 'long'},
#     'taskId': {'type': 'keyword'},
#     'taskUuid': {'type': 'keyword'},
#     'transferTargetId': {'type': 'keyword'},
#     'tsAnswer': {'type': 'date', 'format': 'epoch_millis'},
#     'tsCallStart': {'type': 'date', 'format': 'epoch_millis'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsFailure': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'},
#     'userProvidedCli': {'type': 'keyword'},
#     'voiceMailNodes': {'properties': {'nodeName': {'type': 'keyword'}}},
#     'voicemailHangup': {'type': 'boolean'},
#     'voicemailMessage': {'type': 'boolean'}}}},
#  {'alias': 'v2-logging-service-rest',
#   'mapping': {'dynamic': 'false',
#    'properties': {'api': {'type': 'text'},
#     'changeset': {'properties': {'field': {'type': 'keyword'},
#       'newval': {'type': 'text'},
#       'oldval': {'type': 'text'}}},
#     'companyId': {'type': 'long'},
#     'contactMethod': {'type': 'keyword'},
#     'dataset': {'properties': {'field': {'type': 'keyword'},
#       'value': {'type': 'text'}}},
#     'entityName': {'type': 'text'},
#     'extId': {'type': 'keyword'},
#     'filterOrgType': {'type': 'keyword'},
#     'filterParentOrgId': {'type': 'long'},
#     'id': {'type': 'integer'},
#     'ip': {'type': 'keyword'},
#     'level': {'type': 'keyword'},
#     'loginMethod': {'type': 'keyword'},
#     'module': {'type': 'keyword'},
#     'object': {'type': 'text'},
#     'orgId': {'type': 'integer'},
#     'orgType': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'response': {'type': 'short'},
#     'subType': {'type': 'keyword'},
#     'timestamp': {'type': 'date', 'format': 'epoch_millis'},
#     'type': {'type': 'keyword'},
#     'userid': {'type': 'integer'},
#     'username': {'type': 'keyword'},
#     'uuid': {'type': 'keyword'}}}},
#  {'alias': 'v2-contact-centre-calls-queue',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endParty': {'type': 'keyword'},
#       'endReason': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'agentTransferred': {'type': 'boolean'},
#     'callConnected': {'type': 'boolean'},
#     'callDropped': {'type': 'boolean'},
#     'callFailure': {'type': 'boolean'},
#     'callQueueTransferredIn': {'type': 'boolean'},
#     'callQueueTransferredOut': {'type': 'boolean'},
#     'callType': {'type': 'keyword'},
#     'callUuid': {'type': 'keyword'},
#     'cliRestricted': {'type': 'boolean'},
#     'cliRestrictedEnum': {'type': 'keyword'},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'contactCalledBack': {'type': 'boolean'},
#     'customerUri': {'type': 'keyword'},
#     'endNodeName': {'type': 'keyword'},
#     'endReason': {'type': 'keyword'},
#     'ender': {'type': 'keyword'},
#     'failureMessage': {'type': 'keyword'},
#     'failureNodeName': {'type': 'keyword'},
#     'groupPromotionLevel': {'type': 'long'},
#     'initialAgentGroupName': {'type': 'keyword'},
#     'initialAgentName': {'type': 'keyword'},
#     'msDuration': {'type': 'long'},
#     'msQueueAnnouncementTime': {'type': 'long'},
#     'msTotalAnnouncementTime': {'type': 'long'},
#     'msTotalHoldTime': {'type': 'long'},
#     'msTotalQueueTime': {'type': 'long'},
#     'msTotalTalkTime': {'type': 'long'},
#     'msTotalTransferAgentConnectTime': {'type': 'long'},
#     'msTotalTransferQueueConnectTime': {'type': 'long'},
#     'msTotalWaitingTime': {'type': 'long'},
#     'msWaitingForClassificationTime': {'type': 'long'},
#     'msWrapUpTime': {'type': 'long'},
#     'nextQueueId': {'type': 'long'},
#     'numConsultAttempts': {'type': 'long'},
#     'numConsultSuccesses': {'type': 'long'},
#     'numTransferAttempts': {'type': 'long'},
#     'numTransferSuccesses': {'type': 'long'},
#     'numWarmTransferConnected': {'type': 'long'},
#     'numberType': {'type': 'keyword'},
#     'previousQueueId': {'type': 'long'},
#     'queueDepartureReason': {'type': 'keyword'},
#     'queueId': {'type': 'long'},
#     'queueLength': {'type': 'long'},
#     'queueName': {'type': 'keyword'},
#     'releaseCause': {'type': 'long'},
#     'rescheduleCount': {'type': 'long'},
#     'resellerId': {'type': 'long'},
#     'serviceNumber': {'type': 'keyword'},
#     'serviceNumberId': {'type': 'long'},
#     'serviceNumberName': {'type': 'keyword'},
#     'targetAgentId': {'type': 'long'},
#     'taskId': {'type': 'keyword'},
#     'taskUuid': {'type': 'keyword'},
#     'transferTarget': {'type': 'keyword'},
#     'transferTargetId': {'type': 'keyword'},
#     'tsCallStart': {'type': 'date', 'format': 'epoch_millis'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsFailure': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'},
#     'userProvidedCli': {'type': 'keyword'}}}},
#  {'alias': 'crm-email',
#   'mapping': {'dynamic': 'false',
#    'properties': {'attachments': {'type': 'keyword'},
#     'bodySize': {'type': 'long'},
#     'conversationId': {'type': 'keyword'},
#     'creationDate': {'type': 'date', 'format': 'epoch_millis'},
#     'emailTime': {'type': 'date', 'format': 'epoch_millis'},
#     'extraData': {'type': 'keyword'},
#     'fromHeader': {'type': 'keyword'},
#     'id': {'type': 'keyword'},
#     'messageId': {'type': 'keyword'},
#     'modifiedDate': {'type': 'date', 'format': 'epoch_millis'},
#     'organisationId': {'type': 'keyword'},
#     'remoteEmailId': {'type': 'keyword'},
#     'serverId': {'type': 'long'},
#     'subject': {'type': 'keyword'},
#     'toHeader': {'type': 'keyword'}}}},
#  {'alias': 'v2-contact-centre-user-service-types',
#   'mapping': {'dynamic': 'false',
#    'properties': {'companyId': {'type': 'integer'},
#     'name': {'type': 'keyword'},
#     'orgId': {'type': 'integer'},
#     'resellerId': {'type': 'integer'},
#     'serviceCost': {'type': 'integer'},
#     'serviceType': {'type': 'keyword'},
#     'timestamp': {'type': 'date', 'format': 'epoch_millis'},
#     'userId': {'type': 'integer'}}}},
#  {'alias': 'v2-contact-centre-emails-contact',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endPartyAgentId': {'type': 'long'},
#       'endPartyQueueId': {'type': 'long'},
#       'endReason': {'type': 'keyword'},
#       'intermediateOrFinal': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'targetPartyAgentId': {'type': 'long'},
#       'targetPartyQueueId': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'agentId': {'type': 'long'},
#     'agentName': {'type': 'keyword'},
#     'agentUsername': {'type': 'keyword'},
#     'classification': {'type': 'long'},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'emailHandled': {'type': 'boolean'},
#     'emailQueued': {'type': 'boolean'},
#     'emailResolved': {'type': 'boolean'},
#     'emailServerId': {'type': 'long'},
#     'emailServerName': {'type': 'keyword'},
#     'emailType': {'type': 'keyword'},
#     'emailUuid': {'type': 'keyword'},
#     'endReason': {'type': 'keyword'},
#     'failureMessage': {'type': 'text'},
#     'finalQueueId': {'type': 'long'},
#     'firstResponseAgentId': {'type': 'long'},
#     'flowId': {'type': 'long'},
#     'flowName': {'type': 'keyword'},
#     'flowNodeName': {'type': 'text'},
#     'flowType': {'type': 'keyword'},
#     'from': {'type': 'text'},
#     'host': {'type': 'text'},
#     'incomingServerId': {'type': 'long'},
#     'initialQueueId': {'type': 'long'},
#     'initialQueueuId': {'type': 'long'},
#     'intermediateOrFinal': {'type': 'keyword'},
#     'msEmailHandlingTime': {'type': 'long'},
#     'msTimeSpentActive': {'type': 'long'},
#     'msTimeSpentAllocated': {'type': 'long'},
#     'msTimeSpentInReview': {'type': 'long'},
#     'msTimeSpentOnQueues': {'type': 'long'},
#     'msTimeToFirstResponse': {'type': 'long'},
#     'msTimeToResolution': {'type': 'long'},
#     'msTotalQueueTime': {'type': 'long'},
#     'numAllocatedAgents': {'type': 'long'},
#     'numIntermediateResponses': {'type': 'long'},
#     'numQueues': {'type': 'long'},
#     'numReviews': {'type': 'long'},
#     'queueId': {'type': 'long'},
#     'queueName': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'resolvingAgentId': {'type': 'long'},
#     'secondClassification': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'subject': {'type': 'text'},
#     'templateUsed': {'type': 'long'},
#     'templateUsedName': {'type': 'keyword'},
#     'to': {'type': 'text'},
#     'triggeringCallId': {'type': 'text'},
#     'tsArrivedTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsEmailSentTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsEmailTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsFirstResponseTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsResolutionTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'},
#     'type': {'type': 'keyword'}}}},
#  {'alias': 'v2-contact-centre-whatsapps-queue',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endParty': {'type': 'keyword'},
#       'endReason': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'conversationId': {'type': 'keyword'},
#     'conversationQueueTransferredIn': {'type': 'boolean'},
#     'conversationQueueTransferredOut': {'type': 'boolean'},
#     'endNodeName': {'type': 'keyword'},
#     'endReason': {'type': 'keyword'},
#     'ender': {'type': 'keyword'},
#     'failureMessage': {'type': 'keyword'},
#     'fromPhoneNumber': {'type': 'keyword'},
#     'initialAgentName': {'type': 'keyword'},
#     'msDuration': {'type': 'long'},
#     'msTimeToFirstResponse': {'type': 'long'},
#     'msTotalConnectTime': {'type': 'long'},
#     'msTotalQueueTime': {'type': 'long'},
#     'msTotalWaitingTime': {'type': 'long'},
#     'msTotalWhatsAppTime': {'type': 'long'},
#     'msWrapUpTime': {'type': 'long'},
#     'nextQueueId': {'type': 'long'},
#     'numResponses': {'type': 'long'},
#     'numTransferAttempts': {'type': 'long'},
#     'numTransferSuccesses': {'type': 'long'},
#     'previousQueueId': {'type': 'long'},
#     'queueDepartureReason': {'type': 'keyword'},
#     'queueId': {'type': 'long'},
#     'queueLength': {'type': 'long'},
#     'queueName': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'toPhoneNumberId': {'type': 'keyword'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsLastModified': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'},
#     'tsWhatsAppStart': {'type': 'date', 'format': 'epoch_millis'},
#     'whatsAppConnected': {'type': 'boolean'},
#     'whatsAppDropped': {'type': 'boolean'},
#     'whatsAppQueued': {'type': 'boolean'},
#     'whatsAppServiceId': {'type': 'long'},
#     'whatsAppServiceName': {'type': 'keyword'},
#     'whatsAppUuid': {'type': 'keyword'}}}},
#  {'alias': '.kibana',
#   'mapping': {'dynamic': 'false',
#    '_meta': {'migrationMappingPropertyHashes': {'visualization': '52d7a13ad68a150c4525b292d23e12cc',
#      'endpoint:user-artifact': '4a11183eee21e6fbad864f7a30b39ad0',
#      'references': '7997cf5a56cc02bdc9c93361bde732b0',
#      'epm-packages': '8f6e0b09ea0374c4ffe98c3755373cff',
#      'type': '2f4316de49999235636386fe51dc06c1',
#      'space': 'c5ca8acafa0beaa4d08d014a97b6bc6b',
#      'ingest_manager_settings': '012cf278ec84579495110bb827d1ed09',
#      'application_usage_totals': '3d1b76c39bfb2cc8296b024d73854724',
#      'action': '6e96ac5e648f57523879661ea72525b7',
#      'dashboard': 'd00f614b29a80360e1190193fd333bab',
#      'siem-detection-engine-rule-actions': '6569b288c169539db10cb262bf79de18',
#      'query': '11aaeb7f5f7fa5bb43f25e18ce26e7d9',
#      'file-upload-telemetry': '0ed4d3e1983d1217a30982630897092e',
#      'application_usage_transactional': '3d1b76c39bfb2cc8296b024d73854724',
#      'action_task_params': 'a9d49f184ee89641044be0ca2950fa3a',
#      'fleet-agent-events': '3231653fafe4ef3196fe3b32ab774bf2',
#      'upgrade-assistant-reindex-operation': '215107c281839ea9b3ad5f6419819763',
#      'cases-comments': 'c2061fb929f585df57425102fa928b4b',
#      'fleet-enrollment-api-keys': '28b91e20b105b6f928e2012600085d8f',
#      'ingest-outputs': '8aa988c376e65443fefc26f1075e93a3',
#      'telemetry': '36a616f7026dfa617d6655df850fe16d',
#      'upgrade-assistant-telemetry': '56702cec857e0a9dacfb696655b4ff7b',
#      'lens-ui-telemetry': '509bfa5978586998e05f9e303c07a327',
#      'namespaces': '2f4316de49999235636386fe51dc06c1',
#      'application_usage_daily': '43b8830d5d0df85a6823d290885fc9fd',
#      'siem-ui-timeline-note': '8874706eedc49059d4cf0f5094559084',
#      'lens': 'd33c68a69ff1e78c9888dedd2164ac22',
#      'exception-list-agnostic': '497afa2f881a675d72d58e20057f3d8b',
#      'sample-data-telemetry': '7d3cfeb915303c9641c59681967ffeb4',
#      'fleet-agent-actions': 'e520c855577170c24481be05c3ae14ec',
#      'exception-list': '497afa2f881a675d72d58e20057f3d8b',
#      'app_search_telemetry': '3d1b76c39bfb2cc8296b024d73854724',
#      'search': '5c4b9a6effceb17ae8a0ab22d0c49767',
#      'updated_at': '00da57df13e94e9d98437d13ace4bfe0',
#      'cases-configure': '42711cbb311976c0687853f4c1354572',
#      'search-telemetry': '3d1b76c39bfb2cc8296b024d73854724',
#      'alert': '7b44fba6773e37c806ce290ea9b7024e',
#      'siem-detection-engine-rule-status': 'ae783f41c6937db6b7a2ef5c93a9e9b0',
#      'ingest-package-policies': '8545e51d7bc8286d6dace3d41240d749',
#      'map': '4a05b35c3a3a58fbc72dd0202dc3487f',
#      'uptime-dynamic-settings': 'fcdb453a30092f022f2642db29523d80',
#      'cases': '32aa96a6d3855ddda53010ae2048ac22',
#      'siem-ui-timeline': '94bc38c7a421d15fbfe8ea565370a421',
#      'kql-telemetry': 'd12a98a6f19a2d273696597547e064ee',
#      'ui-metric': '0d409297dc5ebe1e3a1da691c6ee32e3',
#      'url': 'c7f66a0df8b1b52f17c28c4adb111105',
#      'endpoint:user-artifact-manifest': '4b9c0e7cfaf86d82a7ee9ed68065e50d',
#      'migrationVersion': '4a1746014a75ade3a714e1db5763276f',
#      'index-pattern': '66eccb05066c5a89924f48a9e9736499',
#      'fleet-agents': '034346488514b7058a79140b19ddf631',
#      'maps-telemetry': '5ef305b18111b77789afefbd36b66171',
#      'namespace': '2f4316de49999235636386fe51dc06c1',
#      'cases-user-actions': '32277330ec6b721abe3b846cfd939a71',
#      'timelion-sheet': '9a2a2748877c7a7b582fef201ab1d4cf',
#      'siem-ui-timeline-pinned-event': '20638091112f0e14f0e443d512301c29',
#      'config': 'c63748b75f39d0c54de12d12c1ccbc20',
#      'tsvb-validation-telemetry': '3a37ef6c8700ae6fc97d5c7da00e9215',
#      'ingest-agent-policies': '9326f99c977fd2ef5ab24b6336a0675c',
#      'workplace_search_telemetry': '3d1b76c39bfb2cc8296b024d73854724'}},
#    'properties': {'action': {'properties': {'actionTypeId': {'type': 'keyword'},
#       'config': {'type': 'object', 'enabled': False},
#       'name': {'type': 'text', 'fields': {'keyword': {'type': 'keyword'}}},
#       'secrets': {'type': 'binary'}}},
#     'action_task_params': {'properties': {'actionId': {'type': 'keyword'},
#       'apiKey': {'type': 'binary'},
#       'params': {'type': 'object', 'enabled': False}}},
#     'alert': {'properties': {'actions': {'type': 'nested',
#        'properties': {'actionRef': {'type': 'keyword'},
#         'actionTypeId': {'type': 'keyword'},
#         'group': {'type': 'keyword'},
#         'params': {'type': 'object', 'enabled': False}}},
#       'alertTypeId': {'type': 'keyword'},
#       'apiKey': {'type': 'binary'},
#       'apiKeyOwner': {'type': 'keyword'},
#       'consumer': {'type': 'keyword'},
#       'createdAt': {'type': 'date'},
#       'createdBy': {'type': 'keyword'},
#       'enabled': {'type': 'boolean'},
#       'muteAll': {'type': 'boolean'},
#       'mutedInstanceIds': {'type': 'keyword'},
#       'name': {'type': 'text', 'fields': {'keyword': {'type': 'keyword'}}},
#       'params': {'type': 'object', 'enabled': False},
#       'schedule': {'properties': {'interval': {'type': 'keyword'}}},
#       'scheduledTaskId': {'type': 'keyword'},
#       'tags': {'type': 'keyword'},
#       'throttle': {'type': 'keyword'},
#       'updatedBy': {'type': 'keyword'}}},
#     'apm-telemetry': {'type': 'object', 'dynamic': 'false'},
#     'app_search_telemetry': {'type': 'object', 'dynamic': 'false'},
#     'application_usage_daily': {'dynamic': 'false',
#      'properties': {'timestamp': {'type': 'date'}}},
#     'application_usage_totals': {'type': 'object', 'dynamic': 'false'},
#     'application_usage_transactional': {'type': 'object', 'dynamic': 'false'},
#     'canvas-workpad': {'type': 'object', 'dynamic': 'false'},
#     'cases': {'properties': {'closed_at': {'type': 'date'},
#       'closed_by': {'properties': {'email': {'type': 'keyword'},
#         'full_name': {'type': 'keyword'},
#         'username': {'type': 'keyword'}}},
#       'connector_id': {'type': 'keyword'},
#       'created_at': {'type': 'date'},
#       'created_by': {'properties': {'email': {'type': 'keyword'},
#         'full_name': {'type': 'keyword'},
#         'username': {'type': 'keyword'}}},
#       'description': {'type': 'text'},
#       'external_service': {'properties': {'connector_id': {'type': 'keyword'},
#         'connector_name': {'type': 'keyword'},
#         'external_id': {'type': 'keyword'},
#         'external_title': {'type': 'text'},
#         'external_url': {'type': 'text'},
#         'pushed_at': {'type': 'date'},
#         'pushed_by': {'properties': {'email': {'type': 'keyword'},
#           'full_name': {'type': 'keyword'},
#           'username': {'type': 'keyword'}}}}},
#       'status': {'type': 'keyword'},
#       'tags': {'type': 'keyword'},
#       'title': {'type': 'keyword'},
#       'updated_at': {'type': 'date'},
#       'updated_by': {'properties': {'email': {'type': 'keyword'},
#         'full_name': {'type': 'keyword'},
#         'username': {'type': 'keyword'}}}}},
#     'cases-comments': {'properties': {'comment': {'type': 'text'},
#       'created_at': {'type': 'date'},
#       'created_by': {'properties': {'email': {'type': 'keyword'},
#         'full_name': {'type': 'keyword'},
#         'username': {'type': 'keyword'}}},
#       'pushed_at': {'type': 'date'},
#       'pushed_by': {'properties': {'email': {'type': 'keyword'},
#         'full_name': {'type': 'keyword'},
#         'username': {'type': 'keyword'}}},
#       'updated_at': {'type': 'date'},
#       'updated_by': {'properties': {'email': {'type': 'keyword'},
#         'full_name': {'type': 'keyword'},
#         'username': {'type': 'keyword'}}}}},
#     'cases-configure': {'properties': {'closure_type': {'type': 'keyword'},
#       'connector_id': {'type': 'keyword'},
#       'connector_name': {'type': 'keyword'},
#       'created_at': {'type': 'date'},
#       'created_by': {'properties': {'email': {'type': 'keyword'},
#         'full_name': {'type': 'keyword'},
#         'username': {'type': 'keyword'}}},
#       'updated_at': {'type': 'date'},
#       'updated_by': {'properties': {'email': {'type': 'keyword'},
#         'full_name': {'type': 'keyword'},
#         'username': {'type': 'keyword'}}}}},
#     'cases-user-actions': {'properties': {'action': {'type': 'keyword'},
#       'action_at': {'type': 'date'},
#       'action_by': {'properties': {'email': {'type': 'keyword'},
#         'full_name': {'type': 'keyword'},
#         'username': {'type': 'keyword'}}},
#       'action_field': {'type': 'keyword'},
#       'new_value': {'type': 'text'},
#       'old_value': {'type': 'text'}}},
#     'config': {'dynamic': 'false',
#      'properties': {'buildNum': {'type': 'keyword'}}},
#     'dashboard': {'properties': {'description': {'type': 'text'},
#       'hits': {'type': 'integer'},
#       'kibanaSavedObjectMeta': {'properties': {'searchSourceJSON': {'type': 'text'}}},
#       'optionsJSON': {'type': 'text'},
#       'panelsJSON': {'type': 'text'},
#       'refreshInterval': {'properties': {'display': {'type': 'keyword'},
#         'pause': {'type': 'boolean'},
#         'section': {'type': 'integer'},
#         'value': {'type': 'integer'}}},
#       'timeFrom': {'type': 'keyword'},
#       'timeRestore': {'type': 'boolean'},
#       'timeTo': {'type': 'keyword'},
#       'title': {'type': 'text'},
#       'version': {'type': 'integer'}}},
#     'endpoint:user-artifact': {'properties': {'body': {'type': 'binary'},
#       'compressionAlgorithm': {'type': 'keyword', 'index': False},
#       'created': {'type': 'date', 'index': False},
#       'decodedSha256': {'type': 'keyword', 'index': False},
#       'decodedSize': {'type': 'long', 'index': False},
#       'encodedSha256': {'type': 'keyword'},
# ...
#     'msTimeSpentAllocated': {'type': 'long'},
#     'msTimeSpentOnQueue': {'type': 'long'},
#     'msTimeToResolution': {'type': 'long'},
#     'name': {'type': 'text'},
#     'numAllocatedAgents': {'type': 'long'},
#     'queueEnteredTime': {'type': 'date', 'format': 'epoch_millis'},
#     'queueId': {'type': 'long'},
#     'queueLeaveTime': {'type': 'date', 'format': 'epoch_millis'},
#     'queueName': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'templateId': {'type': 'long'},
#     'templateName': {'type': 'keyword'},
#     'tsArrivedTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'},
#     'type': {'type': 'keyword'},
#     'workItemType': {'type': 'keyword'},
#     'workItemUuid': {'type': 'keyword'}}}},
#  {'alias': 'crm-script',
#   'mapping': {'dynamic': 'false',
#    'properties': {'agentId': {'type': 'long'},
#     'agentName': {'type': 'keyword'},
#     'callId': {'type': 'keyword'},
#     'cli': {'type': 'keyword'},
#     'companyName': {'type': 'keyword'},
#     'contactId': {'type': 'keyword'},
#     'creationDate': {'type': 'date', 'format': 'epoch_millis'},
#     'eventId': {'type': 'keyword'},
#     'id': {'type': 'keyword'},
#     'modifiedDate': {'type': 'date', 'format': 'epoch_millis'},
#     'organisationId': {'type': 'keyword'},
#     'queueId': {'type': 'long'},
#     'queueName': {'type': 'keyword'},
#     'record': {'type': 'keyword'},
#     'recordId': {'type': 'keyword'},
#     'scriptId': {'type': 'long'},
#     'scriptName': {'type': 'keyword'},
#     'serviceNumber': {'type': 'keyword'},
#     'serviceNumberName': {'type': 'keyword'}}}},
#  {'alias': 'v2-contact-centre-pay-by-link-queue',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endReason': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'emailTemplateId': {'type': 'long'},
#     'emailTemplateName': {'type': 'keyword'},
#     'emailToAddress': {'type': 'keyword'},
#     'endReason': {'type': 'keyword'},
#     'merchantId': {'type': 'keyword'},
#     'merchantName': {'type': 'keyword'},
#     'msTimeSpentActive': {'type': 'long'},
#     'msTimeSpentAllocated': {'type': 'long'},
#     'msTimeSpentOnQueue': {'type': 'long'},
#     'msTimeToResolution': {'type': 'long'},
#     'msTotalQueueTime': {'type': 'long'},
#     'numAllocatedAgents': {'type': 'long'},
#     'payByLinkType': {'type': 'keyword'},
#     'payByLinkUuid': {'type': 'keyword'},
#     'paymentAmount': {'type': 'long'},
#     'paymentCurrency': {'type': 'keyword'},
#     'pspId': {'type': 'keyword'},
#     'pspName': {'type': 'keyword'},
#     'queueEnteredTime': {'type': 'date', 'format': 'epoch_millis'},
#     'queueId': {'type': 'long'},
#     'queueLeaveTime': {'type': 'date', 'format': 'epoch_millis'},
#     'queueName': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'smsTemplateId': {'type': 'long'},
#     'smsTemplateName': {'type': 'keyword'},
#     'smsToAddress': {'type': 'keyword'},
#     'statusHistory': {'properties': {'status': {'type': 'keyword'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsLastModified': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'},
#     'type': {'type': 'keyword'}}}},
#  {'alias': 'v2-contact-centre-wi-contact',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endReason': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'agentId': {'type': 'long'},
#     'agentName': {'type': 'keyword'},
#     'category': {'type': 'keyword'},
#     'classification': {'type': 'long'},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'endReason': {'type': 'keyword'},
#     'externalId': {'type': 'text'},
#     'failureMessage': {'type': 'text'},
#     'initialAgentId': {'type': 'long'},
#     'initialQueueId': {'type': 'long'},
#     'intermediateOrFinal': {'type': 'keyword'},
#     'msTimeSpentActive': {'type': 'long'},
#     'msTimeSpentAllocated': {'type': 'long'},
#     'msTimeSpentOnQueue': {'type': 'long'},
#     'msTimeToResolution': {'type': 'long'},
#     'name': {'type': 'text'},
#     'numAllocatedAgents': {'type': 'long'},
#     'numQueues': {'type': 'long'},
#     'queueId': {'type': 'long'},
#     'queueName': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'resolvingAgentId': {'type': 'long'},
#     'templateId': {'type': 'long'},
#     'templateName': {'type': 'keyword'},
#     'tsArrivedTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsResolutionTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'},
#     'type': {'type': 'keyword'},
#     'workItemQueued': {'type': 'boolean'},
#     'workItemResolved': {'type': 'boolean'},
#     'workItemType': {'type': 'keyword'},
#     'workItemUuid': {'type': 'keyword'}}}},
#  {'alias': 'v2-contact-centre-wi-agent',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endReason': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'agentActivatedTime': {'type': 'date', 'format': 'epoch_millis'},
#     'agentAllocatedTime': {'type': 'date', 'format': 'epoch_millis'},
#     'agentCompletedTime': {'type': 'date', 'format': 'epoch_millis'},
#     'agentId': {'type': 'long'},
#     'agentName': {'type': 'keyword'},
#     'category': {'type': 'keyword'},
#     'classification': {'type': 'long'},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'endReason': {'type': 'keyword'},
#     'externalId': {'type': 'keyword'},
#     'msTimeSpentActive': {'type': 'long'},
#     'msTimeSpentAllocated': {'type': 'long'},
#     'msTimeToResolution': {'type': 'long'},
#     'name': {'type': 'text'},
#     'queueId': {'type': 'long'},
#     'queueName': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'templateId': {'type': 'long'},
#     'templateName': {'type': 'keyword'},
#     'tsArrivedTime': {'type': 'date'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'},
#     'type': {'type': 'keyword'},
#     'workItemType': {'type': 'keyword'},
#     'workItemUuid': {'type': 'keyword'}}}},
#  {'alias': '.kibana_task_manager',
#   'mapping': {'dynamic': 'false',
#    '_meta': {'migrationMappingPropertyHashes': {'migrationVersion': '4a1746014a75ade3a714e1db5763276f',
#      'task': '235412e52d09e7165fac8a67a43ad6b4',
#      'updated_at': '00da57df13e94e9d98437d13ace4bfe0',
#      'references': '7997cf5a56cc02bdc9c93361bde732b0',
#      'namespace': '2f4316de49999235636386fe51dc06c1',
#      'type': '2f4316de49999235636386fe51dc06c1',
#      'namespaces': '2f4316de49999235636386fe51dc06c1'}},
#    'properties': {'kibana': {'type': 'object', 'dynamic': 'false'},
#     'migrationVersion': {'dynamic': 'true',
#      'properties': {'task': {'type': 'text',
#        'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}}}},
#     'namespace': {'type': 'keyword'},
#     'namespaces': {'type': 'keyword'},
#     'references': {'type': 'nested',
#      'properties': {'id': {'type': 'keyword'},
#       'name': {'type': 'keyword'},
#       'type': {'type': 'keyword'}}},
#     'task': {'properties': {'attempts': {'type': 'integer'},
#       'ownerId': {'type': 'keyword'},
#       'params': {'type': 'text'},
#       'retryAt': {'type': 'date'},
#       'runAt': {'type': 'date'},
#       'schedule': {'properties': {'interval': {'type': 'keyword'}}},
#       'scheduledAt': {'type': 'date'},
#       'scope': {'type': 'keyword'},
#       'startedAt': {'type': 'date'},
#       'state': {'type': 'text'},
#       'status': {'type': 'keyword'},
#       'taskType': {'type': 'keyword'},
#       'user': {'type': 'keyword'}}},
#     'type': {'type': 'keyword'},
#     'updated_at': {'type': 'date'}}}},
#  {'alias': 'v2-contact-centre-sms-queue',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endReason': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'dataCoding': {'type': 'long'},
#     'endReason': {'type': 'keyword'},
#     'from': {'type': 'keyword'},
#     'intermediateOrFinal': {'type': 'keyword'},
#     'messageCount': {'type': 'long'},
#     'msTimeSpentActive': {'type': 'long'},
#     'msTimeSpentAllocated': {'type': 'long'},
#     'msTimeSpentOnQueue': {'type': 'long'},
#     'msTimeToFirstResponse': {'type': 'long'},
#     'msTimeToResolution': {'type': 'long'},
#     'msTotalQueueTime': {'type': 'long'},
#     'numAllocatedAgents': {'type': 'long'},
#     'numIntermediateResponses': {'type': 'long'},
#     'octetCount': {'type': 'long'},
#     'queueEnteredTime': {'type': 'date', 'format': 'epoch_millis'},
#     'queueId': {'type': 'long'},
#     'queueLeaveTime': {'type': 'date', 'format': 'epoch_millis'},
#     'queueName': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'smsHandled': {'type': 'boolean'},
#     'smsType': {'type': 'keyword'},
#     'smsUuid': {'type': 'keyword'},
#     'to': {'type': 'keyword'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsSmsSentTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsSmsTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'},
#     'type': {'type': 'keyword'}}}},
#  {'alias': 'crm-template',
#   'mapping': {'dynamic': 'false',
#    'properties': {'agentId': {'type': 'long'},
#     'agentName': {'type': 'keyword'},
#     'callId': {'type': 'keyword'},
#     'cli': {'type': 'keyword'},
#     'companyName': {'type': 'keyword'},
#     'contactId': {'type': 'keyword'},
#     'contactName': {'type': 'keyword'},
#     'content': {'type': 'keyword'},
#     'creationDate': {'type': 'date', 'format': 'epoch_millis'},
#     'eventId': {'type': 'keyword'},
#     'id': {'type': 'keyword'},
#     'modifiedDate': {'type': 'date', 'format': 'epoch_millis'},
#     'organisationId': {'type': 'keyword'},
#     'queueId': {'type': 'long'},
#     'queueName': {'type': 'keyword'},
#     'receiver': {'type': 'keyword'},
#     'recordId': {'type': 'keyword'},
#     'sender': {'type': 'keyword'},
#     'subject': {'type': 'keyword'},
#     'templateId': {'type': 'long'},
#     'templateName': {'type': 'keyword'},
#     'type': {'type': 'keyword'}}}},
#  {'alias': 'crm-whatsapp',
#   'mapping': {'dynamic': 'false',
#    'properties': {'agentsInvolved': {'type': 'long'},
#     'classificationId': {'type': 'long'},
#     'classificationName': {'type': 'keyword'},
#     'contactId': {'type': 'keyword'},
#     'conversationId': {'type': 'long'},
#     'creationDate': {'type': 'date', 'format': 'epoch_millis'},
#     'endTime': {'type': 'date', 'format': 'epoch_millis'},
#     'id': {'type': 'keyword'},
#     'modifiedDate': {'type': 'date', 'format': 'epoch_millis'},
#     'organisationId': {'type': 'keyword'},
#     'remoteBareJid': {'type': 'keyword'},
#     'serviceId': {'type': 'keyword'},
#     'stanzas': {'type': 'keyword', 'index': False, 'doc_values': False},
#     'startTime': {'type': 'date', 'format': 'epoch_millis'},
#     'wasRecordingPaused': {'type': 'boolean'},
#     'whatsAppWasAbusive': {'type': 'boolean'}}}},
#  {'alias': 'v2-contact-centre-sms-agent',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endReason': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'agentAllocatedTime': {'type': 'date', 'format': 'epoch_millis'},
#     'agentCompletedTime': {'type': 'date'},
#     'agentId': {'type': 'long'},
#     'agentName': {'type': 'keyword'},
#     'agentUsername': {'type': 'keyword'},
#     'classification': {'type': 'long'},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'dataCoding': {'type': 'long'},
#     'endAgentId': {'type': 'long'},
#     'endQueueId': {'type': 'long'},
#     'endReason': {'type': 'keyword'},
#     'from': {'type': 'keyword'},
#     'intermediateOrFinal': {'type': 'keyword'},
#     'messageCount': {'type': 'long'},
#     'msTimeSpentActive': {'type': 'long'},
#     'msTimeSpentAllocated': {'type': 'long'},
#     'msTimeToFirstResponse': {'type': 'long'},
#     'msTimeToResolution': {'type': 'long'},
#     'numIntermediateResponses': {'type': 'long'},
#     'octetCount': {'type': 'long'},
#     'queueId': {'type': 'long'},
#     'queueName': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'smsType': {'type': 'keyword'},
#     'smsUuid': {'type': 'keyword'},
#     'templateUsed': {'type': 'long'},
#     'templateUsedName': {'type': 'keyword'},
#     'to': {'type': 'keyword'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsSmsSentTime': {'type': 'date'},
#     'tsSmsTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'},
#     'type': {'type': 'keyword'}}}},
#  {'alias': 'v2-contact-centre-pay-by-link-contact',
#   'mapping': {'dynamic': 'false',
#    'properties': {'activityHistory': {'properties': {'activity': {'type': 'keyword'},
#       'endPartyAgentId': {'type': 'long'},
#       'endPartyQueueId': {'type': 'long'},
#       'endReason': {'type': 'keyword'},
#       'intermediateOrFinal': {'type': 'keyword'},
#       'msDuration': {'type': 'long'},
#       'targetPartyAgentId': {'type': 'long'},
#       'targetPartyQueueId': {'type': 'long'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'agentId': {'type': 'long'},
#     'agentName': {'type': 'keyword'},
#     'agentUsername': {'type': 'keyword'},
#     'classification': {'type': 'long'},
#     'companyId': {'type': 'long'},
#     'companyName': {'type': 'keyword'},
#     'emailTemplateId': {'type': 'long'},
#     'emailTemplateName': {'type': 'keyword'},
#     'emailToAddress': {'type': 'keyword'},
#     'endReason': {'type': 'keyword'},
#     'finalQueueId': {'type': 'long'},
#     'firstResponseAgentId': {'type': 'long'},
#     'flowId': {'type': 'long'},
#     'flowName': {'type': 'keyword'},
#     'flowNodeName': {'type': 'text'},
#     'flowType': {'type': 'keyword'},
#     'initialQueueId': {'type': 'long'},
#     'merchantId': {'type': 'keyword'},
#     'merchantName': {'type': 'keyword'},
#     'msTimeSpentActive': {'type': 'long'},
#     'msTimeSpentAllocated': {'type': 'long'},
#     'msTimeSpentOnQueues': {'type': 'long'},
#     'msTimeToFirstResponse': {'type': 'long'},
#     'msTimeToResolution': {'type': 'long'},
#     'numAllocatedAgents': {'type': 'long'},
#     'numIntermediateResponses': {'type': 'long'},
#     'numQueues': {'type': 'long'},
#     'payByLinkQueued': {'type': 'boolean'},
#     'payByLinkResolved': {'type': 'boolean'},
#     'payByLinkType': {'type': 'keyword'},
#     'payByLinkUuid': {'type': 'keyword'},
#     'paymentAmount': {'type': 'long'},
#     'paymentCurrency': {'type': 'keyword'},
#     'pspId': {'type': 'keyword'},
#     'pspName': {'type': 'keyword'},
#     'queueId': {'type': 'long'},
#     'queueName': {'type': 'keyword'},
#     'resellerId': {'type': 'long'},
#     'resolvingAgentId': {'type': 'long'},
#     'smsTemplateId': {'type': 'long'},
#     'smsTemplateName': {'type': 'keyword'},
#     'smsToAddress': {'type': 'keyword'},
#     'statusHistory': {'properties': {'status': {'type': 'keyword'},
#       'ts': {'type': 'date', 'format': 'epoch_millis'}}},
#     'tsArrivedTime': {'type': 'date', 'format': 'epoch_millis'},
#     'tsEnd': {'type': 'date', 'format': 'epoch_millis'},
#     'tsLastModified': {'type': 'date', 'format': 'epoch_millis'},
#     'tsStart': {'type': 'date', 'format': 'epoch_millis'},
#     'type': {'type': 'keyword'}}}}]

# %% [markdown]
# Tool functions
# these are the tool glue and metadata functions

# %%
def get_alias_list():
    if alias_and_mappinglist != []:
        alias_list = []
        for alias in alias_and_mappinglist:
            alias_list.append(alias['alias'])
        return alias_list
    return None

def get_alias_mapping(aliasName):
    if alias_and_mappinglist != []:
        for alias in alias_and_mappinglist:
            if alias['alias'] == aliasName:
                return alias['mapping']
    return None

def handle_tool_calls(message):
    responses = []
    data = {}
    for tool_call in message.tool_calls:
        if tool_call.function.name == "get_alias_list":
            arguments = json.loads(tool_call.function.arguments)
            city = arguments.get('destination_city')
            alias_list = get_alias_list()
            # Tool response content must be a string (JSON stringified)
            responses.append({
                "role": "tool",
                "content": json.dumps(alias_list) if alias_list is not None else "null",
                "tool_call_id": tool_call.id
            })
        elif tool_call.function.name == "get_alias_mapping":
            arguments = json.loads(tool_call.function.arguments)
            alias_name = arguments.get('alias_name')
            mapping = get_alias_mapping(alias_name)
            # Tool response content must be a string (JSON stringified)
            responses.append({
                "role": "tool",
                "content": json.dumps(mapping) if mapping is not None else "null",
                "tool_call_id": tool_call.id
            })
        elif tool_call.function.name == "search_elasticsearch":
            arguments = json.loads(tool_call.function.arguments)
            elasticsearch_url = arguments.get('elasticsearch_url')
            search_body = arguments.get('search_body')
            index_or_alias = arguments.get('index_or_alias')
            # Call the actual search_elasticsearch function
            search_result = search_elasticsearch(elasticsearch_url, search_body, index_or_alias)
            # Tool response content must be a string (JSON stringified)
            responses.append({
                "role": "tool",
                "content": json.dumps(search_result) if search_result is not None else "null",
                "tool_call_id": tool_call.id
            })
    return responses

get_alias_list_function = {
    "name": "get_alias_list",
    "description": "Get a list of all the aliases in the Elasticsearch cluster",
    "parameters": {
        "type": "object",
        "properties": {
            "elasticsearch_url": {
                "type": "string",
                "description": "The URL of the Elasticsearch cluster",
            },
        },
        "required": ["elasticsearch_url"],
        "additionalProperties": False
    }
}

get_alias_mapping_function = {
    "name": "get_alias_mapping",
    "description": "Given the name of an alias get the mapping of the index it points to",
    "parameters": {
        "type": "object",
        "properties": {
            "alias_name": {
                "type": "string",
                "description": "The name of the alias to get the mapping for",
            },
        },
        "required": ["alias_name"],
        "additionalProperties": False
    }
}

search_function = {
    "name": "search_elasticsearch",
    "description": "Search for documents in an Elasticsearch cluster",
    "parameters": {
        "type": "object",
        "properties": {
            "elasticsearch_url": {
                "type": "string",
                "description": "The URL of the Elasticsearch cluster",
            },
            "search_body": {
                "type": "object",
                "description": "The search query body",
            },
            "index_or_alias": {
                "type": "string",
                "description": "The index or alias to search",  
            },
        },
        "required": ["elasticsearch_url", "search_body", "index_or_alias"],
        "additionalProperties": False
    }
}

tools = [
    {"type": "function", "function": get_alias_list_function},
    {"type": "function", "function": get_alias_mapping_function},
    {"type": "function", "function": search_function}]

# %%
search_elasticsearch("http://golda.eng.tcs.local:9200/", {"query": {"match": {"companyId": "11529601"}}}, "v2-agent-status")
# Out:
# {'took': 10,
#  'timed_out': False,
#  '_shards': {'total': 4, 'successful': 4, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 23, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'v2-agent-status-000001',
#     '_type': 'agent-status-change',
#     '_id': 'f8bae8a6-459d-5c41-959a-80c4939fb751',
#     '_score': 1.0,
#     '_source': {'tsStart': 1761303058588,
#      'tsEnd': 1761303058872,
#      'timeInOldState': 284,
#      'agentId': 103678201,
#      'agentName': 'agent1 agent1',
#      'oldState': 101,
#      'oldStateName': 'Unavailable',
#      'oldStateGroup': 7,
#      'oldStateGroupName': 'Unavailable',
#      'newState': 0,
#      'newStateName': 'Available',
#      'newStateGroup': 0,
#      'newStateGroupName': 'Available',
#      'companyId': 11529601,
#      'resellerId': 1,
#      'timeInOldStateText': '0.284s'}},
#    {'_index': 'v2-agent-status-000001',
#     '_type': 'agent-status-change',
#     '_id': '2a675fd9-73fd-5129-9b63-715e2b96ff43',
#     '_score': 1.0,
#     '_source': {'tsStart': 1761303111304,
#      'tsEnd': 1761303111891,
#      'timeInOldState': 587,
#      'agentId': 103678301,
#      'agentName': 'agent2 agent2',
#      'oldState': 101,
#      'oldStateName': 'Unavailable',
#      'oldStateGroup': 7,
#      'oldStateGroupName': 'Unavailable',
#      'newState': 0,
#      'newStateName': 'Available',
#      'newStateGroup': 0,
#      'newStateGroupName': 'Available',
#      'companyId': 11529601,
#      'resellerId': 1,
#      'timeInOldStateText': '0.587s'}},
#    {'_index': 'v2-agent-status-000001',
#     '_type': 'agent-status-change',
#     '_id': '16ec4142-a2a1-5be0-b12d-759a66bba6cb',
#     '_score': 1.0,
#     '_source': {'tsStart': 1761303066094,
#      'tsEnd': 1761303080873,
#      'timeInOldState': 14779,
#      'agentId': 103678201,
#      'agentName': 'agent1 agent1',
#      'oldState': 100,
#      'oldStateName': 'Offline',
#      'oldStateGroup': 1,
#      'oldStateGroupName': 'Offline',
#      'newState': 101,
#      'newStateName': 'Unavailable',
#      'newStateGroup': 7,
#      'newStateGroupName': 'Unavailable',
#      'companyId': 11529601,
#      'resellerId': 1,
#      'timeInOldStateText': '14.77s'}},
#    {'_index': 'v2-agent-status-000001',
#     '_type': 'agent-status-change',
#     '_id': '7001e08a-e01d-5862-93d7-0cf26734114c',
#     '_score': 1.0,
#     '_source': {'tsStart': 1761303058872,
#      'tsEnd': 1761303066094,
#      'timeInOldState': 7222,
#      'agentId': 103678201,
#      'agentName': 'agent1 agent1',
#      'oldState': 0,
#      'oldStateName': 'Available',
#      'oldStateGroup': 0,
#      'oldStateGroupName': 'Available',
#      'newState': 100,
#      'newStateName': 'Offline',
#      'newStateGroup': 1,
#      'newStateGroupName': 'Offline',
#      'companyId': 11529601,
#      'resellerId': 1,
#      'timeInOldStateText': '7.222s'}},
#    {'_index': 'v2-agent-status-000001',
#     '_type': 'agent-status-change',
#     '_id': 'a2394d74-c921-5757-bb84-eed8dff2714d',
#     '_score': 1.0,
#     '_source': {'tsStart': 1761303167178,
#      'tsEnd': 1761303167664,
#      'timeInOldState': 486,
#      'agentId': 103678401,
#      'agentName': 'agent3 agent3',
#      'oldState': 4,
#      'oldStateName': 'Agent Wrap Up',
#      'oldStateGroup': 2,
#      'oldStateGroupName': 'Active Call',
#      'newState': 0,
#      'newStateName': 'Available',
#      'newStateGroup': 0,
#      'newStateGroupName': 'Available',
#      'cause': 'AgentCancelledTimer',
#      'companyId': 11529601,
#      'resellerId': 1,
#      'timeInOldStateText': '0.486s'}},
#    {'_index': 'v2-agent-status-000001',
#     '_type': 'agent-status-change',
#     '_id': 'd951ef91-da55-5a61-ad36-2450ac31cf08',
#     '_score': 1.0,
#     '_source': {'tsStart': 1761303167664,
#      'tsEnd': 1761303167760,
#      'timeInOldState': 96,
#      'agentId': 103678401,
#      'agentName': 'agent3 agent3',
#      'oldState': 0,
#      'oldStateName': 'Available',
#      'oldStateGroup': 0,
#      'oldStateGroupName': 'Available',
#      'newState': 100,
#      'newStateName': 'Offline',
#      'newStateGroup': 1,
#      'newStateGroupName': 'Offline',
#      'companyId': 11529601,
#      'resellerId': 1,
#      'timeInOldStateText': '0.096s'}},
#    {'_index': 'v2-agent-status-000001',
#     '_type': 'agent-status-change',
#     '_id': 'bdda43f1-bb0a-545b-a82b-47a9ac021bd0',
#     '_score': 1.0,
#     '_source': {'tsStart': 1761303141695,
#      'tsEnd': 1761303142709,
#      'timeInOldState': 1014,
#      'agentId': 103678401,
#      'agentName': 'agent3 agent3',
#      'oldState': 2,
#      'oldStateName': 'Agent Alerting',
#      'oldStateGroup': 2,
#      'oldStateGroupName': 'Active Call',
#      'newState': 50,
#      'newStateName': 'Dialling Contact',
#      'newStateGroup': 2,
#      'newStateGroupName': 'Active Call',
#      'companyId': 11529601,
#      'resellerId': 1,
#      'timeInOldStateText': '1.014s'}},
#    {'_index': 'v2-agent-status-000001',
#     '_type': 'agent-status-change',
#     '_id': 'e8da708f-c6bd-55db-bd62-5c33c26472c2',
#     '_score': 1.0,
#     '_source': {'tsStart': 1761303124538,
#      'tsEnd': 1761303124748,
#      'timeInOldState': 210,
#      'agentId': 103678301,
#      'agentName': 'agent2 agent2',
#      'oldState': 151,
#      'oldStateName': 'Agent Handling Email',
#      'oldStateGroup': 6,
#      'oldStateGroupName': 'Handling Email',
#      'newState': 0,
#      'newStateName': 'Available',
#      'newStateGroup': 0,
#      'newStateGroupName': 'Available',
#      'companyId': 11529601,
#      'resellerId': 1,
#      'timeInOldStateText': '0.21s'}},
#    {'_index': 'v2-agent-status-000001',
#     '_type': 'agent-status-change',
#     '_id': '56576804-045b-57d3-9bf6-9105dfb30c68',
#     '_score': 1.0,
#     '_source': {'tsStart': 1761303140405,
#      'tsEnd': 1761303140701,
#      'timeInOldState': 296,
#      'agentId': 103678401,
#      'agentName': 'agent3 agent3',
#      'oldState': 101,
#      'oldStateName': 'Unavailable',
#      'oldStateGroup': 7,
#      'oldStateGroupName': 'Unavailable',
#      'newState': 0,
#      'newStateName': 'Available',
#      'newStateGroup': 0,
#      'newStateGroupName': 'Available',
#      'companyId': 11529601,
#      'resellerId': 1,
#      'timeInOldStateText': '0.296s'}},
#    {'_index': 'v2-agent-status-000001',
#     '_type': 'agent-status-change',
#     '_id': 'c8fbab23-a14e-5707-9d8d-0c40047c8af2',
#     '_score': 1.0,
#     '_source': {'tsStart': 1761303182499,
#      'tsEnd': 1761303182779,
#      'timeInOldState': 280,
#      'agentId': 103678201,
#      'agentName': 'agent1 agent1',
#      'oldState': 101,
#      'oldStateName': 'Unavailable',
#      'oldStateGroup': 7,
#      'oldStateGroupName': 'Unavailable',
#      'newState': 0,
#      'newStateName': 'Available',
#      'newStateGroup': 0,
#      'newStateGroupName': 'Available',
#      'companyId': 11529601,
#      'resellerId': 1,
#      'timeInOldStateText': '0.28s'}}]}}

# %% [markdown]
# Chat function
# with added tool definitions and some conversion from json

# %%
def chat(company_id, es_url, message, history):
    # Ensure all history messages have content as a string
    processed_history = []
    for h in history:
        content = h.get("content", "")
        # If content is not a string, convert it to string
        if not isinstance(content, str):
            if content is None:
                content = ""
            else:
                content = json.dumps(content) if not isinstance(content, str) else content
        processed_history.append({"role": h["role"], "content": content})
    
    messages = [{"role": "system", "content": system_prompt(company_id, es_url)}] + processed_history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model=MODEL, messages=messages, tools=tools)

    while response.choices[0].finish_reason=="tool_calls":
        message_obj = response.choices[0].message
        responses = handle_tool_calls(message_obj)
        # Convert message object to dict format for API
        message_dict = message_obj.model_dump() if hasattr(message_obj, 'model_dump') else {
            "role": message_obj.role,
            "content": message_obj.content or "",
            "tool_calls": [{"id": tc.id, "type": tc.type, "function": {"name": tc.function.name, "arguments": tc.function.arguments}} for tc in message_obj.tool_calls] if message_obj.tool_calls else []
        }
        # Ensure content is a string, not None
        if message_dict.get("content") is None:
            message_dict["content"] = ""
        messages.append(message_dict)
        messages.extend(responses)
        response = openai.chat.completions.create(model=MODEL, messages=messages, tools=tools)
    
    return response.choices[0].message.content

# %% [markdown]
# Gradio
# finally the UI to allow you to chat

# %%
# Create Gradio interface
history = []

with gr.Blocks() as demo:
    gr.Markdown("# Elasticsearch Explorer")
    gr.Markdown("Enter your company ID and Elasticsearch URL, then ask questions in the chat.")
    
    with gr.Row():
        with gr.Column(scale=1):
            company_id_input = gr.Textbox(
                label="Company ID",
                placeholder="Enter company ID",
                value=""
            )
            elasticsearch_url_input = gr.Textbox(
                label="Elasticsearch URL",
                placeholder="http://localhost:9200",
                value="http://golda.eng.tcs.local:9200/"
            )
    
    with gr.Row():
        chatbot = gr.Chatbot(
            label="Chat",
            height=400,
            type="messages"
        )
    
    with gr.Row():
        msg = gr.Textbox(
            label="Your Question",
            placeholder="Type your question here...",
            scale=4
        )
        submit_btn = gr.Button("Submit", scale=1)
    
    def respond(company_id, es_url, message, chat_history):
        if not es_url:
            return chat_history, "Please provide an Elasticsearch URL."
        
        if not message:
            return chat_history, ""
        
        # Load aliases and mappings (will use cached version if already loaded)
        global alias_and_mappinglist
        alias_and_mappinglist = get_elasticsearch_aliases_and_mappings(es_url)
        
        # With type='messages', chat_history is already in OpenAI format
        # Format: [{"role": "user", "content": "..."}, {"role": "assistant", "content": "..."}]
        openai_history = chat_history if chat_history else []
        
        # Get response
        response = chat(company_id, es_url, message, openai_history)
        
        # Update chat history (Gradio messages format: list of dicts with 'role' and 'content')
        chat_history.append({"role": "user", "content": message})
        chat_history.append({"role": "assistant", "content": response})
        
        return chat_history, ""
    
    submit_btn.click(
        respond,
        inputs=[company_id_input, elasticsearch_url_input, msg, chatbot],
        outputs=[chatbot, msg]
    )
    
    msg.submit(
        respond,
        inputs=[company_id_input, elasticsearch_url_input, msg, chatbot],
        outputs=[chatbot, msg]
    )

demo.launch(server_name="0.0.0.0")
# Out:
# * Running on local URL:  http://0.0.0.0:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://localhost:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
