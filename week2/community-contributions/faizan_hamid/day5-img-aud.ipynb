# %% [markdown]
# # Image and Audio Generation

# %%
# some importes
import base64
from io import BytesIO
from PIL import Image
from openai import OpenAI

# %%
ollama_base_url = 'http://localhost:11434/v1'
# model = 'llama3.2:3b'
model = 'qwen2.5:3b'
openai = OpenAI()
ollama = OpenAI(base_url=ollama_base_url,api_key='ollama')

# %%
def image_generate(city):
    image_response = ollama.images.generate(
        model=model,
        prompt=f"An image representing a vacation in {city}, showing tourist spots and everything unique about {city}, in a vibrant pop-art style",
        size='1024x1024',
        n=1,
    )
    image_base64 = image_response.data[0].b64_json
    image_data = base64.b64decode(image_base64)
    return Image.open(BytesIO(image_data))

# %%
image = image_generate('kashmir')
display(image)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 image = image_generate('kashmir')
#       2 display(image)
#
# Cell In[5], line 2, in image_generate(city)
#       1 def image_generate(city):
# ----> 2     image_response = ollama.images.generate(
#       3         model=model,
#       4         prompt=f"An image representing a vacation in {city}, showing tourist spots and everything unique about {city}, in a vibrant pop-art style",
#       5         size='1024x1024',
#
# File c:\Users\LOG IN\Desktop\llm_engineering\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Users\LOG IN\Desktop\llm_engineering\.venv\Lib\site-packages\openai\resources\images.py:997, in Images.generate(self, prompt, background, model, moderation, n, output_compression, output_format, partial_images, quality, response_format, size, stream, style, user, extra_headers, extra_query, extra_body, timeout)
#     967 @required_args(["prompt"], ["prompt", "stream"])
#     968 def generate(
#     969     self,
#    (...)    995     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     996 ) -> ImagesResponse | Stream[ImageGenStreamEvent]:
# --> 997     return self._post(
#     998         "/images/generations",
#     999         body=maybe_transform(
#    1000             {
#    1001                 "prompt": prompt,
#    1002                 "background": background,
#    1003                 "model": model,
#    1004                 "moderation": moderation,
#    1005                 "n": n,
#    1006                 "output_compression": output_compression,
#    1007                 "output_format": output_format,
#    1008                 "partial_images": partial_images,
#    1009                 "quality": quality,
#    1010                 "response_format": response_format,
#    1011                 "size": size,
#    1012                 "stream": stream,
#    1013                 "style": style,
#    1014                 "user": user,
#    1015             },
#    1016             image_generate_params.ImageGenerateParamsStreaming
#    1017             if stream
#    1018             else image_generate_params.ImageGenerateParamsNonStreaming,
#    1019         ),
#    1020         options=make_request_options(
#    1021             extra_headers=extra_headers,
#    1022             extra_query=extra_query,
#    1023             extra_body=extra_body,
#    1024             timeout=timeout,
#    1025             security={"bearer_auth": True},
#    1026         ),
#    1027         cast_to=ImagesResponse,
#    1028         stream=stream or False,
#    1029         stream_cls=Stream[ImageGenStreamEvent],
#    1030     )
#
# File c:\Users\LOG IN\Desktop\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\LOG IN\Desktop\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1110, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
# -> 1110 return self._process_response(
#    1111     cast_to=cast_to,
#    1112     options=options,
#    1113     response=response,
#    1114     stream=stream,
#    1115     stream_cls=stream_cls,
#    1116     retries_taken=retries_taken,
#    1117 )
#
# File c:\Users\LOG IN\Desktop\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1199, in SyncAPIClient._process_response(self, cast_to, options, response, stream, stream_cls, retries_taken)
#    1196 if bool(response.request.headers.get(RAW_RESPONSE_HEADER)):
#    1197     return cast(ResponseT, api_response)
# -> 1199 return api_response.parse()
#
# File c:\Users\LOG IN\Desktop\llm_engineering\.venv\Lib\site-packages\openai\_response.py:326, in APIResponse.parse(self, to)
#     323 if not self._is_sse_stream:
#     324     self.read()
# --> 326 parsed = self._parse(to=to)
#     327 if is_given(self._options.post_parser):
#     328     parsed = self._options.post_parser(parsed)
#
# File c:\Users\LOG IN\Desktop\llm_engineering\.venv\Lib\site-packages\openai\_response.py:268, in BaseAPIResponse._parse(self, to)
#     263     # If the API responds with content that isn't JSON then we just return
#     264     # the (decoded) text without performing any parsing so that you can still
#     265     # handle the response however you need to.
#     266     return response.text  # type: ignore
# --> 268 data = response.json()
#     270 return self._client._process_response_data(
#     271     data=data,
#     272     cast_to=cast_to,  # type: ignore
#     273     response=response,
#     274 )
#
# File c:\Users\LOG IN\Desktop\llm_engineering\.venv\Lib\site-packages\httpx\_models.py:832, in Response.json(self, **kwargs)
#     831 def json(self, **kwargs: typing.Any) -> typing.Any:
# --> 832     return jsonlib.loads(self.content, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     347     s = s.decode(detect_encoding(s), 'surrogatepass')
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#     354     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     340 def decode(self, s, _w=WHITESPACE.match):
#     341     """Return the Python representation of ``s`` (a ``str`` instance
#     342     containing a JSON document).
#     343
#     344     """
# --> 345     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346     end = _w(s, end).end()
#     347     if end != len(s):
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     361     obj, end = self.scan_once(s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
