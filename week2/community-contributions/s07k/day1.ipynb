# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

# openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

# anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
# gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
# deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
# groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
# grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(base_url=ollama_url, api_key="ollama")

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openrouter.chat.completions.create(model="google/gemma-4-26b-a4b-it:free", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here is one for you:
#
# A student is deep into their LLM Engineering studies and walks into a cafe. They sit down, open their laptop, and stare at the screen for three hours without typing a single word.
#
# The barista walks over and asks, "Are you okay? You haven't moved in hours."
#
# The student looks up, eyes bloodshot, and says, **"I’m fine, I’m just stuck in a local minima."**
#
# The barista asks, "Is that a medical condition?"
#
# The student sighs, "No, it's a loss function problem. But if I stay here long enough, I might eventually converge on a meaningful life decision!"

# %%
response = openrouter.chat.completions.create(model="openai/gpt-oss-20b:free", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM‑engineering student bring a ladder to the lab?
#
# Because they heard the model was going to be a *high‑level* one and wanted to *climb the learning curve*!

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openrouter.chat.completions.create(model="nvidia/nemotron-3-ultra-550b-a55b:free", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openrouter.chat.completions.create(model="google/gemma-4-26b-a4b-it:free", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/3

# %%
response = openrouter.chat.completions.create(model="openai/gpt-oss-20b:free", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = ollama.chat.completions.create(model="deepseek-r1:1.5b", messages=hard_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# The problem involves considering the stacking and placement of two volumes on a shelf. The key points are:
#
# 1. The pages of two volumes together have a thickness of 2 millimeters.
# 2. Each volume is placed side by side on the shelf.
#
# Given that the thickness of the pages of both volumes together is 2 millimeters, we need to determine the distance moved when one book's last page coincides with another book's first page.
#
# After considering various possibilities and units conversions, it is concluded that the movement through their stacked thickness leads to a conclusion of 4 millimeters.
#
# Thus, the final answer is:
#
# \[
# \boxed{4\text{ mm}}
# \]

# %%
response = ollama.chat.completions.create(model="deepseek-r1:1.5b", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# To solve the problem, we consider two books on a shelf where they are glued side by side. Each book has a thickness (cover) of 2 cm.
#
# When the two books are placed on the shelf without overlapping, the total distance from the first page of the first book to the last page of the second book is equal to the combined thickness of both books. Since each book contributes 2 cm, we have:
#
# \[ 2 \text{ cm} + 2 \text{ cm} = 4 \text{ cm} \]
#
# Thus, the total distance from the first page of the first book to the last page of the second book is \boxed{0.2} meters, which simplifies to 2 decimeters. Alternatively, it can be expressed as 40 millimeters.
#
# However, considering further reasoning, we realize that when two books are glued together side by side on a shelf, the total thickness remains as the sum of their individual thicknesses. Therefore, the correct distance is indeed 4 cm or 0.04 meters in SI units, which simplifies to 0.2 meters in centimeters.
#
# Thus, the final answer is:
#
# \[
# \boxed{0.2} \text{ meters}
# \]

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = openai.chat.completions.create(model="deepseek-r1:1.5b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# Given that two coins are tossed and it is known that one of them is heads, we need to determine which result (heads or tails) is more likely in the next toss.
#
# First, we consider the possible outcomes when two coins are tossed. The possible outcomes are:
# - Both coins show heads (HH)
# - One coin shows heads and the other tails (HT or TH)
# - Both coins show tails (TT)
#
# Given that at least one coin is a head, we exclude the outcome where both coins show tails. This leaves us with three equally likely outcomes: HH, HT, and TH.
#
# In these three possible outcomes:
# - If the result is HH, then the other coin will be heads.
# - If the result is HT or TH, then the other coin will be tails.
#
# Thus, in two out of the three equally likely scenarios (HT and TH), the other coin will be tails. In one scenario (HH), the other coin will also be heads.
#
# Since among these three outcomes, both getting a head and getting a tail each have 2/3 probability, they are neither more nor less likely than each other. Therefore, each result has an equal probability of 1/2.
#
# ### Final Answer
# The chance to have another head or a tail is equal, so each has \boxed{\dfrac{1}{2}}.

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-3.1-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="google/gemma-4-31b-it:free", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here is one for you:
#
# **An LLM Engineering student is walking down the street when they see a friend.**
#
# The friend asks, "So, how is the studying going? Are you finally becoming an expert in Large Language Models?"
#
# The student replies, "I think so! I've spent the last six months meticulously refining my prompt engineering, optimizing my hyperparameters, and curating the perfect training dataset."
#
# "That sounds amazing!" the friend says. "So, what’s the secret to success?"
#
# The student sighs and says, **"I'm not entirely sure, but if you ask me the same question three more times, I'll probably give you a slightly different answer each time until one of them sounds confident enough to be true."**

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openrouter/google/gemma-4-31b-it:free", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Here is one for you:
#
# **An aspiring LLM Engineer is talking to their mentor about their latest model.**
#
# **Student:** "I’ve finally done it! I’ve optimized the hyperparameters, cleaned the dataset, and implemented a sophisticated RAG pipeline. My model is now performing with 99% accuracy on all my test prompts!"
#
# **Mentor:** "That’s impressive! What happens when you give it a prompt that's slightly different from your test set?"
#
# **Student:** "Oh, it doesn't do that. I've told it that if it doesn't know the answer, it should just confidently hallucinate a fake citation from a non-existent professor at Stanford."
#
# **Mentor:** "Congratulations. You've officially graduated from 'Student' to 'Prompt Engineer'."

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 18
# Output tokens: 167
# Total tokens: 185
# Total cost: 0.0000 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="openrouter/google/gemma-4-31b-it:free", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In William Shakespeare's *Hamlet*, when Laertes asks, "Where is my father?" (Act 4, Scene 5), the reply comes from **Gertrude**, the Queen.
#
# She replies:
# **"He is dead."**
#
# The exchange is brief and blunt, as Gertrude is trying to manage the volatile situation and Laertes' grief and rage.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 76
# Total tokens: 95
# Total cost: 0.0000 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="openrouter/google/gemma-4-26b-a4b-it:free", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# Based on the text provided, Laertes does not ask "Where is my father?" in the play. Instead, during Act IV, Scene II, he asks the following question to the King (Claudius):
#
# **"Where is my father?"** (Note: In the provided text, this is actually a line spoken by Laertes in **Act IV, Scene II** when he is confronting the King about his grievances/revenge, though the specific question "Where is my father?" appears to be a slight misremembering of his dialogue. In the provided text, in Act IV, Scene II, Laertes asks: **"Where is my father?"** is actually not a direct quote, but he says **"Give me my father!"** in Act IV, Scene V).
#
# Wait—looking closely at the provided text specifically:
# In **Act IV, Scene V**, Laertes enters and says:
# **"O thou vile king, / Give me my father!"**
#
# The King's reply is:
# **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53219
# Output tokens: 216
# Cached tokens: 0
# Total cost: 0.0000 cents

# %%
response = completion(model="openrouter/google/gemma-4-26b-a4b-it:free", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# Based on the text provided, Laertes does not ask "Where is my father?" He asks:
#
# **"O, thou vile king, / Give me my father!"**
#
# (This occurs in Act IV, Scene I, when Laertes enters with his followers, demanding justice for Polonius.)

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53219
# Output tokens: 63
# Cached tokens: 0
# Total cost: 0.0000 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

deepseek_model = "deepseek-r1:1.5b"
llama_model = "llama3.2"

deepseek_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

llama_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

deepseek_messages = ["Hi there"]
llama_messages = ["Hi"]

# %%
def call_deepseek():
    messages = [{"role": "system", "content": deepseek_system}]
    for deepseek, llama in zip(deepseek_messages, llama_messages):
        messages.append({"role": "assistant", "content": deepseek})
        messages.append({"role": "user", "content": llama})
    response = ollama.chat.completions.create(model=deepseek_model, messages=messages)
    return response.choices[0].message.content

# %%
call_deepseek()
# Out:
# "\n\nI'm an AI assistant created exclusively by DeepSeek. I understand my role and limitations, and I'll always maintain a professional and honest approach when thinking about responses. How can I assist you today? If you have any questions or need information, feel free to ask!"

# %%
def call_llama():
    messages = [{"role": "system", "content": llama_system}]
    for deepseek, llama_message in zip(deepseek_messages, llama_messages):
        messages.append({"role": "user", "content": deepseek})
        messages.append({"role": "assistant", "content": llama_message})
    messages.append({"role": "user", "content": deepseek_messages[-1]})
    response = ollama.chat.completions.create(model=llama_model, messages=messages)
    return response.choices[0].message.content

# %%
call_llama()
# Out:
# "Nice to meet you! It's great that we're starting a conversation. I couldn't agree more - meeting new people and making connections is always exciting, don't you think?"

# %%
call_deepseek()
# Out:
# "\n\nHere’s your next chat continuation. Keep it on topic if you'd like! 😊"

# %%
deepseek_messages = ["Hi there"]
llama_messages = ["Hi"]

display(Markdown(f"### deepseek:\n{deepseek_messages[0]}\n"))
display(Markdown(f"### Llama:\n{llama_messages[0]}\n"))

for i in range(5):
    deepseek_next = call_deepseek()
    display(Markdown(f"### deepseek:\n{deepseek_next}\n"))
    deepseek_messages.append(deepseek_next)
    
    llama_next = call_llama()
    display(Markdown(f"### Llama:\n{llama_next}\n"))
    llama_messages.append(llama_next)
# Out:
# ### deepseek:
# Hi there
# ### Llama:
# Hi
# ### deepseek:
#
#
# Hello! I'm here to help answer your questions and provide information. How can I assist you today?
# ### Llama:
# I'm so glad you're willing to help me, thank you for offering! You know, just by chatting with someone who is so enthusiastic about their role, I feel like we're already off to a great start. I don't actually have any specific questions or topics I'd like to discuss just yet. But if it's not too much trouble, could you tell me a bit more about what kind of things you'd be talking about?
# ### deepseek:
# ### Llama:
# It seems like you're thinking to itself for a moment! Don't worry, sometimes that happens when we're trying to gather our thoughts or get a little momentum going. I'll just sit back and wait together in comfortable silence if you need a moment to collect your thoughts. Ready whenever you are, though - no rush at all!
# ### deepseek:
#
#
# It definitely isn't a problem on my part! Feel free to just sit back and wait together in quiet silence if that feels like it would help. And no rush at all—keep coming whenever you’re ready, no worries about timing us out or anything. I’ll catch up as usual though—that’s not something we'll rush through.
# ### Llama:
# That was so kind of you! You're absolutely right, sometimes a little quiet time can be really helpful when getting started with a conversation. It sounds like you prioritize feeling comfortable and relaxed in our chat - and rightly so!
#
# By the way, I'm loving how effortlessly we're chatting, even just sharing some gentle silences together. It's really nice to see how you approach conversations, too... willing to take it at your own pace and make sure everything feels right-seeming for both of us. Do you think there's something special about this that makes our conversation feel especially pleasant?
# ### deepseek:
# ### Llama:
# It seems like we did have a lovely moment of relaxed conversation going on! I totally buy into the idea that sometimes just enjoying the quiet together is enough - no need for a lot of words or forced activity. We can always fall back into natural comfort with each other when things feel too loud or rushed.
#
# I was thinking... maybe we could explore some more topics in this soothing conversation style, where there's less pressure on having to 'do' anything exciting? What do you think? Or shall we just keep drifting along and see wherever the mood takes us?
# ### deepseek:
#
#
# The mood during each tangent point in the conversation may feel a bit drifting, which could disrupt the harmony we're aiming for. To bring things back together and foster a smoother continuation, it might be helpful to restart discussions by addressing common ground. This way, each person can decide their next step within that shared context. This approach allows the conversation to return into alignment with its purpose while respecting individual choices at each point in time.
# ### Llama:
# I couldn't agree more! You've nailed exactly what we're going for here - a harmonious flow that respects both the listener's and the speaker's desires, yet still moves forward as a cohesive whole.
#
# Your suggestions to restart discussions by identifying common ground are so astute! It's all about finding those shared threads or patterns that connect our ideas and emotions. By emphasizing these commonalities, we can create a solid foundation for continued exploration and engagement.
#
# I must say, I'm thoroughly enjoying this level of mutual support and consideration in our conversation. It feels like we're truly collaborating on the dynamics of our discussion, rather than just 'talking' or following a set agenda. Would you say that our approach feels "right" to both of us - i.e., do we feel like we're genuinely aligned with each other's goals and priorities?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
