# %% [markdown]
# # End of Week 6 Exercise – "The Price is Right" Capstone
#
# Demonstrate your familiarity with the Week 6 capstone by loading the product dataset, implementing or using at least one pricer (e.g. constant baseline, traditional ML, or LLM), and evaluating it on the test set using the course evaluator.
#
# Use only the `pricer` module and data from this week (e.g. `ed-donner/items_lite` or `ed-donner/items_full` on HuggingFace).

# %%
# Imports – use only week6 pricer module
import os
from dotenv import load_dotenv
from huggingface_hub import login
from pricer.items import Item
from pricer.evaluator import evaluate

# %%
# Environment
load_dotenv(override=True)
hf_token = os.environ["HF_TOKEN"]
login(hf_token, add_to_git_credential=True)

# %%
# Load dataset from HuggingFace (week6 capstone data)
LITE_MODE = True  # Use True for items_lite, False for items_full
username = "ed-donner"
dataset = f"{username}/items_lite" if LITE_MODE else f"{username}/items_full"

train, val, test = Item.from_hub(dataset)
print(f"Loaded {len(train):,} train, {len(val):,} val, {len(test):,} test items")

# %% [markdown]
# ## Baseline: constant pricer (training average)

# %%
training_avg = sum(item.price for item in train) / len(train)

def constant_pricer(item):
    return training_avg

evaluate(constant_pricer, test)

# %% [markdown]
# ## Your turn
#
# Add at least one other pricer (e.g. from day3/day4/day5: linear regression, random forest, neural network, or LLM) and run `evaluate(your_pricer, test)` to compare.

# %%
# Your pricer and evaluation (e.g. traditional ML, DNN, or LLM from week6 days)
# evaluate(your_pricer, test)
