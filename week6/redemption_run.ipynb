# %% [markdown]
# # Week 6 Optional Extra - Deep Neural Network
#
# Just to redeem ourselves from the disappointing result
#
# I trained the Deep Neural Network in pricer/deep_neural_network.py and I've uploaded weights here. Download this file to the week6 directory:
#
# The file `deep_neural_network.pth` here:
#
# https://drive.google.com/drive/folders/1uq5C9edPIZ1973dArZiEO-VE13F7m8MK?usp=drive_link

# %%
from dotenv import load_dotenv
import os
from huggingface_hub import login
from pricer.evaluator import evaluate
from pricer.deep_neural_network import DeepNeuralNetworkRunner
from pricer.items import Item

# %%
# environment

LITE_MODE = False

load_dotenv(override=True)
hf_token = os.environ['HF_TOKEN']
login(hf_token, add_to_git_credential=True)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
username = "ed-donner"
dataset = f"{username}/items_lite" if LITE_MODE else f"{username}/items_full"

train, val, test = Item.from_hub(dataset)

print(f"Loaded {len(train):,} training items, {len(val):,} validation items, {len(test):,} test items")
# Out:
# Loaded 800,000 training items, 10,000 validation items, 10,000 test items

# %%
runner = DeepNeuralNetworkRunner(train, val[:1000])
runner.setup()
# Out:
# Deep Neural Network created with 289,128,449 parameters
# Using cpu

# %% [markdown]
# ## If you want to train this yourself
#
# Then run this - it takes about 4 hours on my M1 Mac hammering the GPU:
#
# ```python
# runner.train(epochs=5)
# runner.save('deep_neural_network.pth')
# ```
#
# ## Or just download the file `deep_neural_network.pth` here:
#
# https://drive.google.com/drive/folders/1uq5C9edPIZ1973dArZiEO-VE13F7m8MK?usp=drive_link
#
# And put it in this week6 directory.

# %%
#runner.load('deep_neural_network.pth')                          # to load on a MAC
runner.load('deep_neural_network.pth', 'cpu')                   # use this one if want to load on a Win PC device --- if so comment out the line above
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 2
#       1 #runner.load('deep_neural_network.pth')                          # to load on a MAC
# ----> 2 runner.load('deep_neural_network.pth', "cpu")                   # use this one if want to load on a Win PC device --- if so comment out the line above
#
# File c:\Users\fberr\projects\llm_engineering\week6\pricer\deep_neural_network.py:164, in DeepNeuralNetworkRunner.load(self, path, device)
#     163 def load(self, path, device="mps"):
# --> 164     self.model.load_state_dict(torch.load(path), map_location=device)
#     165     self.model.to(self.device)
#
# File c:\Users\fberr\projects\llm_engineering\.venv\Lib\site-packages\torch\serialization.py:1521, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1519 if weights_only:
#    1520     try:
# -> 1521         return _load(
#    1522             opened_zipfile,
#    1523             map_location,
#    1524             _weights_only_unpickler,
#    1525             overall_storage=overall_storage,
#    1526             **pickle_load_args,
#    1527         )
#    1528     except pickle.UnpicklingError as e:
#    1529         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#
# File c:\Users\fberr\projects\llm_engineering\.venv\Lib\site-packages\torch\serialization.py:2122, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    2120 global _serialization_tls
#    2121 _serialization_tls.map_location = map_location
# -> 2122 result = unpickler.load()
#    2123 _serialization_tls.map_location = None
#    2125 torch._utils._validate_loaded_sparse_tensors()
#
# File c:\Users\fberr\projects\llm_engineering\.venv\Lib\site-packages\torch\_weights_only_unpickler.py:535, in Unpickler.load(self)
#     527     if (
#     528         type(pid) is tuple
#     529         and len(pid) > 0
#     530         and torch.serialization._maybe_decode_ascii(pid[0]) != "storage"
#     531     ):
#     532         raise UnpicklingError(
#     533             f"Only persistent_load of storage is allowed, but got {pid[0]}"
#     534         )
# --> 535     self.append(self.persistent_load(pid))
#     536 elif key[0] in [BINGET[0], LONG_BINGET[0]]:
#     537     idx = (read(1) if key[0] == BINGET[0] else unpack("<I", read(4)))[0]
#
# File c:\Users\fberr\projects\llm_engineering\.venv\Lib\site-packages\torch\serialization.py:2086, in _load.<locals>.persistent_load(saved_id)
#    2084 else:
#    2085     nbytes = numel * torch._utils._element_size(dtype)
# -> 2086     typed_storage = load_tensor(
#    2087         dtype, nbytes, key, _maybe_decode_ascii(location)
#    2088     )
#    2090 return typed_storage
#
# File c:\Users\fberr\projects\llm_engineering\.venv\Lib\site-packages\torch\serialization.py:2052, in _load.<locals>.load_tensor(dtype, numel, key, location)
#    2048 # TODO: Once we decide to break serialization FC, we can
#    2049 # stop wrapping with TypedStorage
#    2051 if torch._guards.detect_fake_mode(None) is None:
# -> 2052     wrap_storage = restore_location(storage, location)
#    2053 else:
#    2054     storage._fake_device = location
#
# File c:\Users\fberr\projects\llm_engineering\.venv\Lib\site-packages\torch\serialization.py:698, in default_restore_location(storage, location)
#     678 """
#     679 Restores `storage` using a deserializer function registered for the `location`.
#     680
#    (...)    695        all matching ones return `None`.
#     696 """
#     697 for _, _, fn in _package_registry:
# --> 698     result = fn(storage, location)
#     699     if result is not None:
#     700         return result
#
# File c:\Users\fberr\projects\llm_engineering\.venv\Lib\site-packages\torch\serialization.py:564, in _mps_deserialize(obj, location)
#     562 def _mps_deserialize(obj, location):
#     563     if location.startswith("mps"):
# --> 564         return obj.mps()
#
# File c:\Users\fberr\projects\llm_engineering\.venv\Lib\site-packages\torch\storage.py:272, in _StorageBase.mps(self)
#     270 """Return a MPS copy of this storage if it's not already on the MPS."""
#     271 if self.device.type != "mps":
# --> 272     return torch.UntypedStorage(self.size(), device="mps").copy_(self, False)
#     273 return self
#
# RuntimeError: torch.UntypedStorage(): Storage device not recognized: mps

# %%
def deep_neural_network(item):
    return runner.inference(item)

evaluate(deep_neural_network, test)
