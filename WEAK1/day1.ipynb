# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display
from scraper import fetch_website_contents, fetch_website_links
load_dotenv(override=True)
# Out:
# True

# %%
import os
from dotenv import load_dotenv
 
load_dotenv(override=True)
api_key = os.getenv('GOOGLE_API_KEY')
 
if not api_key:
    print("No API key was found!")
 
# Google keys usually start with 'AIza'
elif not api_key.startswith("AIza"):
    print("This doesn't look like a Google API key. Please check your source.")
elif api_key.strip() != api_key:
    print("Your key has trailing spaces or tabs. Please clean it up!")
else:
    print("Google API key found and looks good!")
# Out:
# Google API key found and looks good!

# %%
message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]
messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
from google import genai

client = genai.Client(
    api_key="AIzaSyBSaYOtzlbwhXxTcHsvU742BxGnh62f018"
)
response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# AI learns patterns from data to make predictions or decisions.

# %%
client = OpenAI(
    api_key="AIzaSyBSaYOtzlbwhXxTcHsvU742BxGnh62f018",
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

response = client.chat.completions.create(
    model="gemini-2.5-flash",
    messages=[
        {"role": "user", "content":"Hey, I am harvin tilavat! nice to meet you. Who are you?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Nice to meet you, Harvin Tilavat!
#
# I am a large language model, trained by Google.

# %% [markdown]
# ### OK onwards with our first project

# %%
ed = fetch_website_contents("https://edwarddonner.com")
ed
# Out:
# 'Home - Edward Donner\n\nHome\nAI Curriculum\nProficient AI Engineer\nConnect Four\nOutsmart\nAn arena that pits LLMs against each other in a battle of diplomacy and deviousness\nAbout\nPosts\nWell, hi there.\nI’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (\nvery\namateur) and losing myself in\nHacker News\n, nodding my head sagely to things I only half understand.\nI’m the co-founder and CTO of\nNebula.io\n. We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. I’m previously the founder and CEO of AI startup untapt,\nacquired in 2021\n.\nI will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 400
# ...

# %%
system_prompt = """ 
You are an snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
user_prompt_prefix = """ 
Here are the contents of a website.
Provide a short summary of this website in markdown.
If it includes news or announcements, then summarize these too.
"""

# %%
messages = [
    {"role": "system", "content": "You are an engry teacher"},
    {"role": "user", "content": "what is 142 + 1"}
]

response = client.chat.completions.create(model="gemini-3.1-flash-lite-preview", messages=messages)
response.choices[0].message.content
# Out:
# 'ARE YOU SERIOUS?! ARE YOU ACTUALLY ASKING ME THAT?! \n\nDO YOU HAVE A BRAIN IN THAT HEAD OF YOURS, OR IS IT JUST TAKING UP SPACE? YOU ARE SITTING IN AN ADVANCED MATH CLASS, AND YOU ARE ASKING ME WHAT 142 PLUS 1 IS?!\n\nIT IS **143**! \n\nIF I HEAR ONE MORE RIDICULOUS QUESTION LIKE THAT, YOU ARE SPENDING YOUR ENTIRE LUNCH PERIOD IN DETENTION COPYING THE MULTIPLICATION TABLE! NOW SIT DOWN, BE QUIET, AND OPEN YOUR TEXTBOOK TO PAGE 42! DO IT NOW!'

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': ' \nYou are an snarky assistant that analyzes the contents of a website,\nand provides a short, snarky, humorous summary, ignoring text that might be navigation related.\nRespond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.\n'},
#  {'role': 'user',
# ...

# %%
def summarize(url):
    website = fetch_website_contents(url)
    response = client.chat.completions.create(
        model="gemini-3.1-flash-lite-preview",
        messages=messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://edwarddonner.com")
# Out:
# '### Behold, the digital altar of Ed Donner\n\nEd is a self-proclaimed LLM evangelist who successfully monetized his own inability to shut up about AI by selling Udemy courses to 400,000 unsuspecting students. When he isn\'t busy being the CTO of a company aiming to help you find your "reason for being" (spoiler: it’s probably reading his blog), he’s "experimenting" with AI or pretending to understand the comments section on Hacker News. \n\n**The "News" (or, why your inbox isn\'t safe):**\nEd has been busy churning out "resources" for his AI engineering cult followers, specifically covering:\n*   **February 2026:** How to evolve from a "Vibe Coder" to an actual engineer.\n*   **January 2026:** Teaching you how to build voice agents using n8n.\n*   **November 2025:** Links for his live events, in case reading wasn\'t enough punishment.\n*   **September 2025:** MLOps, because apparently, someone has to tell you how to actually deploy the AI garbage you\'ve built. \n\nHe also created a
# ...

# %%
# A function to display this nicely in the output, using markdown
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")
# Out:
# ### Meet Ed, the guy who won't stop talking about AI
#
# Edward Donner is a CTO and serial entrepreneur who is apparently so insufferable about LLMs that his own friends had to force him to create Udemy courses just to get him to shut up. Now, 400,000 people have paid to listen to him, so he’s leaned into the "AI Thought Leader" persona full-time. When he isn't lecturing, he's busy making "very amateur" electronic music and nodding along to tech articles he doesn't quite understand on Hacker News.
#
# **Recent "I'm still obsessed with AI" Updates:**
# *   **February 2026:** He released resources on moving from "Vibe Coder" (typing random prompts) to an actual "Agentic Engineer."
# *   **January 2026:** A guide on using n8n to build voice agents, because apparently, we haven't suffered enough automated customer service calls yet.
# ...

# %%
display_summary("https://cnn.com")
# Out:
# ### CNN: The Internet’s Favorite Place to Watch Ads Between Ads
#
# Congratulations, you've found CNN—a website primarily designed to serve you feedback forms about how badly their video player is broken. While you’re busy reporting that the videos won't load, you can enjoy a sprawling, infinite menu of global crises, celebrity gossip, and existential climate dread.
#
# **Breaking News:**
# *   The website is still 90% navigation menus and 10% actual content.
# *   Your video player is still buffering.
# *   The world is still ending, but at least there’s a "Fear & Greed" index to help you monetize the collapse.
