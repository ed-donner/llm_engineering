# %% [markdown]
# <a href="https://colab.research.google.com/github/mbhoge/llm_engineering/blob/mb_llm_excercise/hf_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
